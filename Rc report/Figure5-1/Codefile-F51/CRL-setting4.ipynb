# %%
from rsl_rl.env import VecEnv
from rsl_rl.runners import OnPolicyRunner
import torch
import numpy as np
torch.set_printoptions(precision=5, linewidth=200, sci_mode=False)

N          = 100020
state_dim  = 8
action_dim = 5
T          = 60
budget     = 3600.
N_envs     = 1024 * 64
ΔT         = 1.0
device     = 'cuda'
usr_std = 0.01
test_num = 100
seed = 0

parameter_static = dict(N          = N,
                        B          = budget,
                        T          = T,
                        alpha      = 0.6,
                        v_max      = 0.2/14,
                        cost_ti    = 0.0977,
                        cost_ta    = 0.02,
                        cost_v     = 0.07,
                        cost_poc_0 = 0.000369,
                        cost_poc_1 = 0.001057,
                        pid        = 1.10/1000,
                        psr        = 0.7,
                        pid_plus   = 0.1221/1000,
                        pir        = 1/8,
                        prs        = 1/7)

Random_mean = {"beta2" : 0.78735,
               "beta1" : 0.15747,
               "pei"   : 0.10714,
               "per"   : 0.04545}

space = {"beta2" : [Random_mean['beta2'],Random_mean['beta2']*usr_std],
         "beta1" : [Random_mean['beta1'], Random_mean['beta1']*usr_std],
         "pei"   : [Random_mean['pei'], Random_mean['pei']*usr_std],
         "per"   : [Random_mean['per'], Random_mean['per']*usr_std]}

Init_state = torch.tensor([[100000 / N, 20 / N, 0, 0, 0, 0, 1, 0]], 
                         dtype=torch.float32).to(torch.device(device))

# %%
class myVecEnv(VecEnv):
    def __init__(self, interval, n_envs = N_envs):
        self.B = parameter_static['B']  # total budget
        self.N = parameter_static['N']
        self.device = device
        self.init_state = Init_state
        self.states = self.init_state.repeat(n_envs, 1)
        self.num_envs = n_envs
        self.num_obs = state_dim
        self.num_privileged_obs = None
        self.num_actions = action_dim
        self.max_episode_length = parameter_static['T']
        
        torch.manual_seed(seed)
        self.parameter_random = {
            key: torch.empty(self.num_envs).normal_(
                interval[key][0],
                interval[key][1]
            ).to(torch.device(device))
            for key, value in Random_mean.items()
        }

        for key, value in Random_mean.items():
            indice = self.parameter_random[key] < 0
            self.parameter_random[key][indice] = -self.parameter_random[key][indice] 

        # optimization flags for pytorch JIT
        torch._C._jit_set_profiling_mode(False)
        torch._C._jit_set_profiling_executor(False)
        
        # allocate buffers
        self.privileged_obs_buf = None
        self.obs_buf = torch.zeros(self.num_envs, self.num_obs, device=self.device, dtype=torch.float)
        self.rew_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.float)
        self.reset_buf = torch.ones(self.num_envs, device=self.device, dtype=torch.long)
        self.episode_length_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.long)
        
        self.actions = torch.zeros(self.num_envs, self.num_actions, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_sums = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_acts = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.extras = {}
    
    def para_update(self, para):
        self.parameter_random = para
        
    def step(self, actions):
        # actions clip
        soft_bound = [-0.5, 1.5]
        out_of_limits = -(actions - soft_bound[0]).clip(max=0.)
        out_of_limits += (actions - soft_bound[1]).clip(min=0.)
        scale_action = -0.1
        reward_action = scale_action * torch.sum(out_of_limits, dim=1).clip(max=1.).to(self.device)
        self.actions = torch.clip(actions, 0., 1.).to(self.device)

        # update actions & states
        b, p = self.states[:, -2] * self.B, self.states[:, -1]
        inv_c = self.cost_function(self.actions)
        b -= inv_c
        b = torch.clip(b, 0., self.B).to(self.device)
        mask = (b > 0).float().unsqueeze(-1)
        self.act = self.actions * mask
        inv_c = self.cost_function(self.act)
        next_state, reward_original = self.transition(self.act)
        self.extras['reward_original'] = reward_original
        self.extras['inv_cost'] = inv_c
        self.episode_length_buf += 1
        p = self.episode_length_buf / self.max_episode_length
        self.states = torch.cat([next_state / self.N, (b / self.B).unsqueeze(-1), p.unsqueeze(-1)], dim=-1)
        
        # check termination
        self.reset_buf = self.episode_length_buf >= self.max_episode_length
        
        # compute reward
        r_mean = -6584
        r_std  =  7347
        reward = (reward_original - inv_c - r_mean) / r_std
        #if reward > 0: 
        #reward = torch.exp(reward)/10
        #reward = torch.exp((1e5 + reward_original - inv_c) / 5e4)
        self.rew_buf       = reward + reward_action
        self.episode_sums += reward + reward_action
        self.episode_acts += reward_action
        
        # compute resets
        env_ids = self.reset_buf.nonzero(as_tuple=False).flatten()
        self.reset_idx(env_ids)
        
        # compute observations
        return self.get_observations(), self.states, self.rew_buf, self.reset_buf, self.extras

    def reset_idx(self, env_ids):
        """Reset selected robots"""
        if len(env_ids) == 0:
            return
        
        assert len(env_ids) == self.num_envs
        # reset robot states
        self.states[env_ids] = self.init_state
        # reset buffers
        self.episode_length_buf[env_ids] = 0
        self.reset_buf[env_ids] = 1
        # fill extras
        self.extras["episode"] = {}
        self.extras["episode"]['rew_sum'] = torch.mean(self.episode_sums[env_ids]) / (self.max_episode_length * ΔT)
        self.extras["episode"]['rew_act'] = torch.mean(self.episode_acts[env_ids]) / (self.max_episode_length * ΔT)
        self.episode_sums[env_ids] = 0.
        self.episode_acts[env_ids] = 0.
    
    def reset(self):
        """ Reset all robots"""
        self.reset_idx(torch.arange(self.num_envs, device=self.device))
        return {}, {}
    
    def get_observations(self):
        o_mean = torch.tensor([[0.58712867, 0.06804276, 0.00308146, 0.25684301, 0.00261079, 0.08229331, 0.26572794, 0.51      ]], dtype=torch.float32).to(torch.device(self.device))
        o_std  = torch.tensor([[0.41484398, 0.07883003, 0.00389494, 0.292568  , 0.00394907, 0.06906768, 0.33943075, 0.28861739]], dtype=torch.float32).to(torch.device(self.device))
        self.obs_buf = (self.states - o_mean) / o_std
        return self.obs_buf
    
    def get_privileged_observations(self):
        return self.privileged_obs_buf

    def cost_function(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]

        cost_it  = it * u_it * parameter_static['cost_ti']
        cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
        cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
        per_poc  = ((st + et + at + rt) / self.N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
        cost_poc = (st + et + rt + at) * w * per_poc
        return cost_poc + cost_it + cost_v + cost_q

    def transition(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
        ht = st + et + at + it + rt

        st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * self.parameter_random['beta1'] + (et + at * (1 - u_aq)) * self.parameter_random['beta2']) / ht
        st_out_e = st_out * parameter_static['alpha']
        st_out_i = st_out * (1 - parameter_static['alpha'])
        st_out_r = u_sv * parameter_static['v_max'] * st * parameter_static['psr']
        et_out_r = et * self.parameter_random['per']
        et_out_i = et * self.parameter_random['pei']
        et_out_a = et * w * (1 - self.parameter_random['per'] - self.parameter_random['pei'])
        at_out_i = at * self.parameter_random['pei']
        at_out_r = at * self.parameter_random['per']
        it_out_r = it * parameter_static['pir'] * u_it
        it_out_d = it * parameter_static['pid'] * (1 - u_it) + it * u_it * parameter_static['pid_plus']
        rt_out_s = rt * parameter_static['prs']
        
        stn = st - st_out_e - st_out_i - st_out_r + rt_out_s
        etn = et - et_out_r - et_out_i - et_out_a + st_out_e
        atn = at - at_out_r - at_out_i + et_out_a
        itn = it - it_out_r - it_out_d + st_out_i + et_out_i + at_out_i
        dtn = dt + it_out_d
        rtn = rt + et_out_r + at_out_r + it_out_r + st_out_r - rt_out_s

        reward = -2.6 * st_out - 100 * it_out_d

        next_state = torch.stack([stn, etn, atn, itn, dtn, rtn], dim=-1)
        return next_state, reward

# %%
import inspect

class BaseConfig:
    def __init__(self) -> None:
        """ Initializes all member classes recursively. Ignores all namse starting with '__' (buit-in methods)."""
        self.init_member_classes(self)
    
    @staticmethod
    def init_member_classes(obj):
        # iterate over all attributes names
        for key in dir(obj):
            # disregard builtin attributes
            # if key.startswith("__"):
            if key=="__class__":
                continue
            # get the corresponding attribute object
            var =  getattr(obj, key)
            # check if it the attribute is a class
            if inspect.isclass(var):
                # instantate the class
                i_var = var()
                # set the attribute to the instance instead of the type
                setattr(obj, key, i_var)
                # recursively init members of the attribute
                BaseConfig.init_member_classes(i_var)

class LeggedRobotCfgPPO(BaseConfig):
    seed = 0
    runner_class_name = 'OnPolicyRunner'
    class policy:
        init_noise_std = 2
        actor_hidden_dims  = [64, 32, 16] 
        critic_hidden_dims = [64, 32, 16]
        activation = 'elu' # can be elu, relu, selu, crelu, lrelu, tanh, sigmoid
        # only for 'ActorCriticRecurrent':
        # rnn_type = 'lstm'
        # rnn_hidden_size = 512
        # rnn_num_layers = 1
        
    class algorithm:
        # training params
        value_loss_coef = 0.5
        use_clipped_value_loss = True
        clip_param = 0.2
        entropy_coef = 0.01
        num_learning_epochs = 5
        num_mini_batches = 64 # mini batch size = num_envs*nsteps / nminibatches
        learning_rate = 1.e-4
        schedule = 'adaptive' # could be adaptive, fixed
        gamma = 0.99
        lam = 0.95
        desired_kl = 0.01
        max_grad_norm = 1.

    class runner:
        policy_class_name = 'ActorCritic'
        algorithm_class_name = 'PPO'
        num_steps_per_env =  150 # per iteration
        max_iterations    = 100 # number of policy updates

        # logging
        save_interval = 100 # check for potential saves every this many iterations
        experiment_name = 'test'
        run_name = ''
        # load and resume
        resume = True
        load_run = -1 # -1 = last run
        checkpoint = -1 # -1 = last saved model
        resume_path = None # updated from load_run and chkpt
        
def class_to_dict(obj) -> dict:
    if not  hasattr(obj,"__dict__"):
        return obj
    result = {}
    for key in dir(obj):
        if key.startswith("_"):
            continue
        element = []
        val = getattr(obj, key)
        if isinstance(val, list):
            for item in val:
                element.append(class_to_dict(item))
        else:
            element = class_to_dict(val)
        result[key] = element
    return result

# %%
def para_sampling(intvl, num_sample=N_envs):
    parameter_random = {
        key: torch.empty(num_sample).normal_(
        intvl[key][0],
        intvl[key][1]
        ).to(torch.device(device))
        for key, value in Random_mean.items()
    }
    for key, value in Random_mean.items():
        indice = parameter_random[key] < 0
        parameter_random[key][indice] = -parameter_random[key][indice] 
    return parameter_random

def update_space(final_indices, para_buf, space):
    para_est = {}
    for key, tensor_values in para_buf.items():
        selected_values = torch.mean(tensor_values[final_indices[0], final_indices[1]]) 
        para_values = torch.mean(tensor_values[final_indices[0], final_indices[1]], dim=0)
        update_values = space[key][0] + 0.5 * (selected_values - space[key][0])
        space[key] = [update_values , update_values  * 0.1]
        para_est[key] = para_values
    return space, para_est


def cal_err(para_value, env_para):
    gap = []
    for key, value in env_para.items():
        gap_temp = torch.mean(torch.abs(para_value[key] - env_para[key])/(env_para[key]))
        gap.append(gap_temp)
    return sum(gap)/len(gap) # 所有值都在范围内，返回 0
    
def state_estimator(env_sample, action_sim, state_sim, state_prior, space, iter): 
    env_sample.reset()
    env_sample.states = state_prior  
    para_buf, mse_buf, obs_buf, states_buf = {}, {}, {}, {}
    for i in range(iter):
        para = para_sampling(space, test_num)
        env_sample.para_update(para)
        obs_sample, states_sample, _, _, _ = env_sample.step(action_sim.detach())  
        mse = torch.mean((state_sim[:,2:4] - states_sample[:,2:4]) ** 2, dim=1) 
        if i == 0:
            mse_buf = mse.unsqueeze(0)
            obs_buf = obs_sample.unsqueeze(0)
            states_buf = states_sample.unsqueeze(0)
            for key, values in para.items():
                para_buf[key] = para[key].unsqueeze(0)
        else:
            mse_buf = torch.cat((mse_buf, mse.unsqueeze(0)), dim=0)
            obs_buf = torch.cat((obs_buf, obs_sample.unsqueeze(0)),dim=0)
            states_buf = torch.cat((states_buf, states_sample.unsqueeze(0)), dim=0)
            for key, values in para.items():
                para_buf[key] = torch.cat((para_buf[key], para[key].unsqueeze(0)), dim=0)
                
     
    k = int(iter * 0.05)
    _, row_indices = torch.topk(mse_buf, k=k, dim=0, largest=False)
    column_indices = torch.arange(mse_buf.shape[1]).repeat(k, 1)
    top_indices = [row_indices, column_indices]
    obs_est = torch.mean(obs_buf[row_indices,column_indices,:], dim=0)
    state_est = torch.mean(states_buf[row_indices,column_indices,:], dim=0)
    state_est[:,-1] = state_prior[:,-1] + torch.tensor(1/T)
    return obs_est, state_est, top_indices, para_buf

# %%
para_err = 2.5
torch.manual_seed(seed)
para_true = []
for t in range(T):
    para_temp = {
        key: torch.empty(test_num).uniform_(
            Random_mean[key] / para_err, 
            Random_mean[key] * para_err
        ).to(torch.device(device))
        for key, value in Random_mean.items()
        }
    para_true.append(para_temp)

# %%
env = myVecEnv(space, test_num)
env.para_update(para_true[0])
train_cfg = LeggedRobotCfgPPO()
train_cfg_dict = class_to_dict(train_cfg)


env_transfer = myVecEnv(space)
runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_test_rand', device=env.device)
runner.load(f'rsl_output_main/model_100.pt')

policy = runner.get_inference_policy(device=env.device)

reward_history = []
act_buf = []
state_his_buf = []
death_buf = []

env_sample = myVecEnv(space, test_num)
state_est = env.states
obs_est = env.get_observations()
for t in range(T-1):
    actions = policy(obs_est.detach())
    obs, states, _, _, infos = env.step(actions.detach())
    reward_history.append((-infos['reward_original'] + infos['inv_cost']).tolist())
    death_buf.append((-infos['reward_original']).tolist())
    act_buf.append(env.act)
    state_his_buf.append(env.states)
    obs_est, state_buf, top_indices, para_buf = state_estimator(env_sample, actions, states, state_est, space, 1024)
    space, para_v = update_space(top_indices, para_buf, space) 

    runner.learn(num_learning_iterations=25, init_at_random_ep_len=False)
    policy = runner.get_inference_policy(device=env.device)
    env_transfer = myVecEnv(space)
    runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_test_rand', device=env.device)
    runner.load(f'rsl_test_rand/model_{int(t)* 25}.pt')


    if t < T - 1: env.para_update(para_true[t + 1])
    print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
env.reset()

reward_history = np.array(reward_history)
print(f'score     : {np.sum(reward_history, axis=0)/T       }')
print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
# Out:
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2284543 steps/s (collection: 0.667s, learning 3.636s)
#                Value function loss: 142.5378
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.63
#                        Mean reward: 45.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4641
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.30s
#                         Total time: 4.30s
#                                ETA: 107.6s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2369414 steps/s (collection: 0.645s, learning 3.504s)
#                Value function loss: 144.6782
#                     Surrogate loss: 0.0007
#              Mean action noise std: 4.69
#                        Mean reward: 46.00
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7657
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.15s
#                         Total time: 8.45s
#                                ETA: 101.4s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2362677 steps/s (collection: 0.644s, learning 3.517s)
#                Value function loss: 131.0451
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.76
#                        Mean reward: 45.80
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7668
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.16s
#                         Total time: 12.61s
#                                ETA: 96.7s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2376254 steps/s (collection: 0.644s, learning 3.493s)
#                Value function loss: 131.8155
#                     Surrogate loss: 0.0007
#              Mean action noise std: 4.81
#                        Mean reward: 45.82
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7668
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.14s
#                         Total time: 16.75s
#                                ETA: 92.1s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2378789 steps/s (collection: 0.639s, learning 3.494s)
#                Value function loss: 120.9523
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.87
#                        Mean reward: 45.80
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7668
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.13s
#                         Total time: 20.88s
#                                ETA: 87.7s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2388577 steps/s (collection: 0.641s, learning 3.475s)
#                Value function loss: 121.5071
#                     Surrogate loss: 0.0031
#              Mean action noise std: 4.94
#                        Mean reward: 46.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7649
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.12s
#                         Total time: 25.00s
#                                ETA: 83.3s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2369483 steps/s (collection: 0.643s, learning 3.505s)
#                Value function loss: 114.3146
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.00
#                        Mean reward: 45.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7639
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.15s
#                         Total time: 29.15s
#                                ETA: 79.1s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2392486 steps/s (collection: 0.643s, learning 3.466s)
#                Value function loss: 115.2126
#                     Surrogate loss: 0.0009
#              Mean action noise std: 5.08
#                        Mean reward: 46.04
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7645
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.11s
#                         Total time: 33.26s
#                                ETA: 74.8s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2419191 steps/s (collection: 0.641s, learning 3.423s)
#                Value function loss: 110.0399
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.15
#                        Mean reward: 45.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7633
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.06s
#                         Total time: 37.32s
#                                ETA: 70.5s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2415352 steps/s (collection: 0.645s, learning 3.425s)
#                Value function loss: 110.2140
#                     Surrogate loss: 0.0026
#              Mean action noise std: 5.21
#                        Mean reward: 45.59
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7630
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.07s
#                         Total time: 41.39s
#                                ETA: 66.2s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2412295 steps/s (collection: 0.637s, learning 3.439s)
#                Value function loss: 104.9139
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.28
#                        Mean reward: 45.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7605
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.08s
#                         Total time: 45.46s
#                                ETA: 62.0s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2416528 steps/s (collection: 0.638s, learning 3.430s)
#                Value function loss: 104.5630
#                     Surrogate loss: 0.0011
#              Mean action noise std: 5.35
#                        Mean reward: 45.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7586
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.07s
#                         Total time: 49.53s
#                                ETA: 57.8s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2409745 steps/s (collection: 0.646s, learning 3.433s)
#                Value function loss: 101.6371
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.43
#                        Mean reward: 45.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7586
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.08s
#                         Total time: 53.61s
#                                ETA: 53.6s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2412127 steps/s (collection: 0.645s, learning 3.431s)
#                Value function loss: 102.0143
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.50
#                        Mean reward: 45.26
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7595
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.08s
#                         Total time: 57.69s
#                                ETA: 49.4s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2406847 steps/s (collection: 0.642s, learning 3.442s)
#                Value function loss: 94.8475
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.56
#                        Mean reward: 45.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7599
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.08s
#                         Total time: 61.77s
#                                ETA: 45.3s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2351089 steps/s (collection: 0.645s, learning 3.536s)
#                Value function loss: 111.2999
#                     Surrogate loss: 0.0010
#              Mean action noise std: 5.64
#                        Mean reward: 45.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7597
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.18s
#                         Total time: 65.95s
#                                ETA: 41.2s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2349124 steps/s (collection: 0.636s, learning 3.549s)
#                Value function loss: 107.3011
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.72
#                        Mean reward: 45.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7585
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.18s
#                         Total time: 70.14s
#                                ETA: 37.1s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2343606 steps/s (collection: 0.648s, learning 3.547s)
#                Value function loss: 115.9443
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.80
#                        Mean reward: 45.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7565
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.19s
#                         Total time: 74.33s
#                                ETA: 33.0s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2350249 steps/s (collection: 0.635s, learning 3.548s)
#                Value function loss: 118.1301
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.88
#                        Mean reward: 45.37
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7555
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.18s
#                         Total time: 78.51s
#                                ETA: 28.9s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2347933 steps/s (collection: 0.647s, learning 3.540s)
#                Value function loss: 137.7706
#                     Surrogate loss: 0.0020
#              Mean action noise std: 5.96
#                        Mean reward: 45.76
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7562
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.19s
#                         Total time: 82.70s
#                                ETA: 24.8s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2352941 steps/s (collection: 0.643s, learning 3.535s)
#                Value function loss: 146.2068
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.04
#                        Mean reward: 45.68
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7553
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.18s
#                         Total time: 86.88s
#                                ETA: 20.7s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2342910 steps/s (collection: 0.643s, learning 3.552s)
#                Value function loss: 164.4678
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.11
#                        Mean reward: 45.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7534
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.20s
#                         Total time: 91.07s
#                                ETA: 16.6s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2361451 steps/s (collection: 0.648s, learning 3.515s)
#                Value function loss: 175.4398
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.20
#                        Mean reward: 45.37
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7524
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.16s
#                         Total time: 95.24s
#                                ETA: 12.4s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2404640 steps/s (collection: 0.641s, learning 3.447s)
#                Value function loss: 202.2828
#                     Surrogate loss: 0.0008
#              Mean action noise std: 6.28
#                        Mean reward: 45.45
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7526
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.09s
#                         Total time: 99.33s
#                                ETA: 8.3s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2400280 steps/s (collection: 0.646s, learning 3.450s)
#                Value function loss: 204.6421
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.35
#                        Mean reward: 45.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7535
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.10s
#                         Total time: 103.42s
#                                ETA: 4.1s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 3.3497894439697267
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 1949792 steps/s (collection: 0.707s, learning 4.335s)
#                Value function loss: 131.6507
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.69
#                        Mean reward: 45.10
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4494
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 5.04s
#                         Total time: 5.04s
#                                ETA: 126.0s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 1974690 steps/s (collection: 0.662s, learning 4.316s)
#                Value function loss: 138.2198
#                     Surrogate loss: 0.0023
#              Mean action noise std: 4.75
#                        Mean reward: 45.61
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7414
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.98s
#                         Total time: 10.02s
#                                ETA: 120.2s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 1970494 steps/s (collection: 0.661s, learning 4.328s)
#                Value function loss: 133.5500
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.82
#                        Mean reward: 45.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7425
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.99s
#                         Total time: 15.01s
#                                ETA: 115.1s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 1976696 steps/s (collection: 0.658s, learning 4.315s)
#                Value function loss: 146.1550
#                     Surrogate loss: 0.0016
#              Mean action noise std: 4.87
#                        Mean reward: 44.51
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7438
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.97s
#                         Total time: 19.98s
#                                ETA: 109.9s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 1966233 steps/s (collection: 0.663s, learning 4.337s)
#                Value function loss: 142.0766
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.93
#                        Mean reward: 44.81
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7436
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 5.00s
#                         Total time: 24.98s
#                                ETA: 104.9s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 1993666 steps/s (collection: 0.665s, learning 4.266s)
#                Value function loss: 162.7418
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.00
#                        Mean reward: 45.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7421
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.93s
#                         Total time: 29.91s
#                                ETA: 99.7s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 1996593 steps/s (collection: 0.662s, learning 4.261s)
#                Value function loss: 154.9443
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.06
#                        Mean reward: 45.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7429
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.92s
#                         Total time: 34.84s
#                                ETA: 94.6s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2009939 steps/s (collection: 0.655s, learning 4.236s)
#                Value function loss: 176.5882
#                     Surrogate loss: 0.0008
#              Mean action noise std: 5.13
#                        Mean reward: 44.78
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7439
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.89s
#                         Total time: 39.73s
#                                ETA: 89.4s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2008286 steps/s (collection: 0.656s, learning 4.239s)
#                Value function loss: 161.7213
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.20
#                        Mean reward: 45.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7430
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.89s
#                         Total time: 44.62s
#                                ETA: 84.3s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2005305 steps/s (collection: 0.655s, learning 4.247s)
#                Value function loss: 181.1785
#                     Surrogate loss: 0.0005
#              Mean action noise std: 5.25
#                        Mean reward: 45.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7431
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.90s
#                         Total time: 49.52s
#                                ETA: 79.2s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2012502 steps/s (collection: 0.652s, learning 4.232s)
#                Value function loss: 167.0047
#                     Surrogate loss: 0.0023
#              Mean action noise std: 5.32
#                        Mean reward: 45.71
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7448
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.88s
#                         Total time: 54.41s
#                                ETA: 74.2s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2008712 steps/s (collection: 0.661s, learning 4.233s)
#                Value function loss: 183.0826
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.39
#                        Mean reward: 45.28
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7453
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.89s
#                         Total time: 59.30s
#                                ETA: 69.2s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2003891 steps/s (collection: 0.671s, learning 4.234s)
#                Value function loss: 165.3503
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.46
#                        Mean reward: 45.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7438
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.91s
#                         Total time: 64.21s
#                                ETA: 64.2s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 1999848 steps/s (collection: 0.682s, learning 4.233s)
#                Value function loss: 184.4620
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.52
#                        Mean reward: 44.87
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7442
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.92s
#                         Total time: 69.12s
#                                ETA: 59.2s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2011885 steps/s (collection: 0.649s, learning 4.237s)
#                Value function loss: 168.8037
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.59
#                        Mean reward: 44.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7478
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.89s
#                         Total time: 74.01s
#                                ETA: 54.3s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2008423 steps/s (collection: 0.661s, learning 4.234s)
#                Value function loss: 188.8483
#                     Surrogate loss: 0.0007
#              Mean action noise std: 5.65
#                        Mean reward: 45.50
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7503
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.89s
#                         Total time: 78.90s
#                                ETA: 49.3s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2004216 steps/s (collection: 0.654s, learning 4.251s)
#                Value function loss: 165.9701
#                     Surrogate loss: 0.0008
#              Mean action noise std: 5.72
#                        Mean reward: 44.81
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7499
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.90s
#                         Total time: 83.81s
#                                ETA: 44.4s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2005372 steps/s (collection: 0.668s, learning 4.234s)
#                Value function loss: 186.8683
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.79
#                        Mean reward: 45.57
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7501
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.90s
#                         Total time: 88.71s
#                                ETA: 39.4s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2010314 steps/s (collection: 0.651s, learning 4.239s)
#                Value function loss: 172.9435
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.88
#                        Mean reward: 45.34
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7510
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.89s
#                         Total time: 93.60s
#                                ETA: 34.5s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2008163 steps/s (collection: 0.653s, learning 4.242s)
#                Value function loss: 194.4709
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.93
#                        Mean reward: 45.44
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7496
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.90s
#                         Total time: 98.50s
#                                ETA: 29.5s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 1984461 steps/s (collection: 0.654s, learning 4.300s)
#                Value function loss: 176.4031
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.01
#                        Mean reward: 45.63
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7468
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.95s
#                         Total time: 103.45s
#                                ETA: 24.6s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2003284 steps/s (collection: 0.652s, learning 4.255s)
#                Value function loss: 200.3219
#                     Surrogate loss: 0.0009
#              Mean action noise std: 6.06
#                        Mean reward: 45.70
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7443
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.91s
#                         Total time: 108.36s
#                                ETA: 19.7s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 1992024 steps/s (collection: 0.656s, learning 4.279s)
#                Value function loss: 184.7112
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.14
#                        Mean reward: 45.58
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7475
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.93s
#                         Total time: 113.29s
#                                ETA: 14.8s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 1999723 steps/s (collection: 0.661s, learning 4.255s)
#                Value function loss: 210.0255
#                     Surrogate loss: 0.0006
#              Mean action noise std: 6.20
#                        Mean reward: 45.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7510
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.92s
#                         Total time: 118.21s
#                                ETA: 9.9s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2002567 steps/s (collection: 0.653s, learning 4.256s)
#                Value function loss: 188.4209
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.28
#                        Mean reward: 45.06
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7520
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.91s
#                         Total time: 123.12s
#                                ETA: 4.9s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 6.281377052307129
# ################################################################################
#                         Learning iteration 25/50
#
#                        Computation: 2414879 steps/s (collection: 0.677s, learning 3.394s)
#                Value function loss: 189.5369
#                     Surrogate loss: 0.0011
#              Mean action noise std: 6.37
#                        Mean reward: 45.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4574
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.07s
#                         Total time: 4.07s
#                                ETA: 0.0s
#
# ################################################################################
#                         Learning iteration 26/50
#
#                        Computation: 2439190 steps/s (collection: 0.640s, learning 3.390s)
#                Value function loss: 233.2039
#                     Surrogate loss: 0.0006
#              Mean action noise std: 6.44
#                        Mean reward: 46.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7540
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.03s
#                         Total time: 8.10s
#                                ETA: -0.3s
#
# ################################################################################
#                         Learning iteration 27/50
#
#                        Computation: 2443482 steps/s (collection: 0.636s, learning 3.387s)
#                Value function loss: 226.1179
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.52
#                        Mean reward: 46.01
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7561
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.02s
#                         Total time: 12.12s
#                                ETA: -0.9s
#
# ################################################################################
#                         Learning iteration 28/50
#
#                        Computation: 2446170 steps/s (collection: 0.633s, learning 3.385s)
#                Value function loss: 281.1018
#                     Surrogate loss: 0.0009
#              Mean action noise std: 6.58
#                        Mean reward: 45.54
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7575
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.02s
#                         Total time: 16.14s
#                                ETA: -1.7s
#
# ################################################################################
#                         Learning iteration 29/50
#
#                        Computation: 2430802 steps/s (collection: 0.643s, learning 3.401s)
#                Value function loss: 255.8240
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.68
#                        Mean reward: 45.76
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7595
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.04s
#                         Total time: 20.19s
#                                ETA: -2.7s
#
# ################################################################################
#                         Learning iteration 30/50
#
#                        Computation: 2453187 steps/s (collection: 0.639s, learning 3.368s)
#                Value function loss: 313.3625
#                     Surrogate loss: 0.0009
#              Mean action noise std: 6.74
#                        Mean reward: 46.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7600
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.01s
#                         Total time: 24.19s
#                                ETA: -3.9s
#
# ################################################################################
#                         Learning iteration 31/50
#
#                        Computation: 2441702 steps/s (collection: 0.645s, learning 3.381s)
#                Value function loss: 278.3804
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.83
#                        Mean reward: 46.07
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7610
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.03s
#                         Total time: 28.22s
#                                ETA: -5.3s
#
# ################################################################################
#                         Learning iteration 32/50
#
#                        Computation: 2449299 steps/s (collection: 0.641s, learning 3.373s)
#                Value function loss: 337.6141
#                     Surrogate loss: 0.0009
#              Mean action noise std: 6.91
#                        Mean reward: 45.78
# ...
#                    Total timesteps: 78643200
#                     Iteration time: 4.06s
#                         Total time: 32.08s
#                                ETA: -31.5s
#
# ################################################################################
#                       Learning iteration 1433/1450
#
#                        Computation: 2409301 steps/s (collection: 0.656s, learning 3.424s)
#                Value function loss: 375.4419
#                     Surrogate loss: 0.0000
#              Mean action noise std: 2809.87
#                        Mean reward: 47.02
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7824
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.08s
#                         Total time: 36.16s
#                                ETA: -35.5s
#
# ################################################################################
#                       Learning iteration 1434/1450
#
#                        Computation: 2429592 steps/s (collection: 0.627s, learning 3.419s)
#                Value function loss: 441.6138
#                     Surrogate loss: 0.0008
#              Mean action noise std: 2812.11
#                        Mean reward: 47.05
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7823
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.05s
#                         Total time: 40.21s
#                                ETA: -39.5s
#
# ################################################################################
#                       Learning iteration 1435/1450
#
#                        Computation: 2429355 steps/s (collection: 0.655s, learning 3.392s)
#                Value function loss: 378.1136
#                     Surrogate loss: 0.0010
#              Mean action noise std: 2814.67
#                        Mean reward: 47.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7823
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.05s
#                         Total time: 44.25s
#                                ETA: -43.5s
#
# ################################################################################
#                       Learning iteration 1436/1450
#
#                        Computation: 2482309 steps/s (collection: 0.625s, learning 3.335s)
#                Value function loss: 443.8199
#                     Surrogate loss: 0.0018
#              Mean action noise std: 2816.61
#                        Mean reward: 47.01
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7823
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 3.96s
#                         Total time: 48.21s
#                                ETA: -47.3s
#
# ################################################################################
#                       Learning iteration 1437/1450
#
#                        Computation: 2487905 steps/s (collection: 0.626s, learning 3.325s)
#                Value function loss: 377.4222
#                     Surrogate loss: 0.0005
#              Mean action noise std: 2819.22
#                        Mean reward: 47.02
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7822
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 3.95s
#                         Total time: 52.17s
#                                ETA: -51.2s
#
# ################################################################################
#                       Learning iteration 1438/1450
#
#                        Computation: 2467320 steps/s (collection: 0.659s, learning 3.325s)
#                Value function loss: 444.0041
#                     Surrogate loss: 0.0016
#              Mean action noise std: 2821.13
#                        Mean reward: 47.00
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7821
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 3.98s
#                         Total time: 56.15s
#                                ETA: -55.1s
#
# ################################################################################
#                       Learning iteration 1439/1450
#
#                        Computation: 2482124 steps/s (collection: 0.632s, learning 3.328s)
#                Value function loss: 378.1154
#                     Surrogate loss: 0.0005
#              Mean action noise std: 2823.94
#                        Mean reward: 46.99
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7819
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 3.96s
#                         Total time: 60.11s
#                                ETA: -59.0s
#
# ################################################################################
#                       Learning iteration 1440/1450
#
#                        Computation: 2471043 steps/s (collection: 0.640s, learning 3.338s)
#                Value function loss: 444.1877
#                     Surrogate loss: 0.0021
#              Mean action noise std: 2825.84
#                        Mean reward: 46.99
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7817
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 3.98s
#                         Total time: 64.09s
#                                ETA: -62.9s
#
# ################################################################################
#                       Learning iteration 1441/1450
#
#                        Computation: 2459045 steps/s (collection: 0.664s, learning 3.334s)
#                Value function loss: 378.0864
#                     Surrogate loss: 0.0006
#              Mean action noise std: 2828.51
#                        Mean reward: 46.99
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7815
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.00s
#                         Total time: 68.09s
#                                ETA: -66.9s
#
# ################################################################################
#                       Learning iteration 1442/1450
#
#                        Computation: 2484088 steps/s (collection: 0.624s, learning 3.333s)
#                Value function loss: 444.0972
#                     Surrogate loss: 0.0002
#              Mean action noise std: 2831.02
#                        Mean reward: 46.92
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7811
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 3.96s
#                         Total time: 72.04s
#                                ETA: -70.7s
#
# ################################################################################
#                       Learning iteration 1443/1450
#
#                        Computation: 2426671 steps/s (collection: 0.627s, learning 3.424s)
#                Value function loss: 378.1935
#                     Surrogate loss: 0.0000
#              Mean action noise std: 2833.91
#                        Mean reward: 46.96
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7809
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.05s
#                         Total time: 76.09s
#                                ETA: -74.7s
#
# ################################################################################
#                       Learning iteration 1444/1450
#
#                        Computation: 2423078 steps/s (collection: 0.655s, learning 3.402s)
#                Value function loss: 447.2898
#                     Surrogate loss: 0.0021
#              Mean action noise std: 2835.75
#                        Mean reward: 46.94
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7808
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.06s
#                         Total time: 80.15s
#                                ETA: -78.7s
#
# ################################################################################
#                       Learning iteration 1445/1450
#
#                        Computation: 2425560 steps/s (collection: 0.629s, learning 3.424s)
#                Value function loss: 379.9021
#                     Surrogate loss: 0.0005
#              Mean action noise std: 2838.49
#                        Mean reward: 46.92
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7805
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.05s
#                         Total time: 84.20s
#                                ETA: -82.7s
#
# ################################################################################
#                       Learning iteration 1446/1450
#
#                        Computation: 2441546 steps/s (collection: 0.634s, learning 3.392s)
#                Value function loss: 445.2557
#                     Surrogate loss: 0.0008
#              Mean action noise std: 2840.82
#                        Mean reward: 46.92
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7804
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.03s
#                         Total time: 88.23s
#                                ETA: -86.6s
#
# ################################################################################
#                       Learning iteration 1447/1450
#
#                        Computation: 2426846 steps/s (collection: 0.647s, learning 3.404s)
#                Value function loss: 380.8661
#                     Surrogate loss: 0.0005
#              Mean action noise std: 2843.50
#                        Mean reward: 46.95
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7805
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.05s
#                         Total time: 92.28s
#                                ETA: -90.6s
#
# ################################################################################
#                       Learning iteration 1448/1450
#
#                        Computation: 2446416 steps/s (collection: 0.628s, learning 3.390s)
#                Value function loss: 444.9602
#                     Surrogate loss: 0.0069
#              Mean action noise std: 2844.11
#                        Mean reward: 46.95
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7806
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.02s
#                         Total time: 96.30s
#                                ETA: -94.6s
#
# ################################################################################
#                       Learning iteration 1449/1450
#
#                        Computation: 2433172 steps/s (collection: 0.629s, learning 3.411s)
#                Value function loss: 379.8290
#                     Surrogate loss: 0.0003
#              Mean action noise std: 2847.00
#                        Mean reward: 46.94
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7808
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.04s
#                         Total time: 100.34s
#                                ETA: -98.5s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 1679.138667262137
# score     : [5820.40799081  395.32992967  283.75051713  138.01684263  574.326771
#  2062.68038867 3999.95491066  224.25708213   95.08254136 1409.59195577
#    79.25575705  599.86927229  141.60457448  451.37743633   78.22118465
#   189.50117289  194.6804629  8458.73882243   75.33162993 1217.93675954
#   539.32148852 1475.99522667  170.59147067 1652.11963379 2413.36105433
#    79.21285714 1271.0909997    74.03605763  897.78993917  211.92205891
#  4391.15602403 5604.11708743 3767.64146379  354.79950437  188.26169693
#   179.71582924  250.1232508   199.48375982 5228.97041731  989.17387551
#    77.59731705   66.8934949   270.49751662  161.1766967   281.20888955
#  3296.54070148  163.6119897  4693.02239889   72.7672976    84.13795526
#  6196.25635783 5447.44081726 1437.22250417  186.72913042 3528.99520429
#   122.50644536 2274.57063387  145.99118675 2001.93213038  637.03797801
#   149.70924651 4731.45466639 5237.51140347  563.09196453 4310.45084931
#  3038.20632779  110.79848885  172.60969414  126.55943661 8478.59225178
#  1176.02559222  699.36807193  120.29802321  671.27256331 3893.86677457
#   147.88171237 4310.30598658  253.9651238    79.73508428 5211.84155296
#    63.46414571  119.82005419   84.72031515  140.84158378 4507.40132273
#   273.20378602 4384.64612592  637.12409993  484.28797896  111.05269329
#   419.29796975 4968.36983522 5389.23652763 5362.85419788   68.02923495
#  3273.65122107   89.15135719 1023.74650568   66.29901265 5388.18759974]
# score.mean: 1679.138667262137

# %%
a = np.sum(reward_history, axis=0)/T

# %%
min(a)
# Out:
# 63.464145713547865

# %%
max(a)
# Out:
# 8478.592251777649

# %%
np.std(a)
# Out:
# 2139.9976122938856
