  6255.79558105  8419.22306061  1928.18628527  9247.86384366

"""
c4 = [float(num)* 0.60 for num in c.split()]

d = """
6901.03444958 6043.20604248 5617.59645821 5728.94171054 6293.79764401
 6619.37319482 6353.18806101 6231.3096741  5351.06230744 6202.56172899
 5230.49209496 6148.54122883 5389.42896598 5781.4011363  5280.05877571
 5351.70448689 5513.09509436 7874.18660138 5093.38973668 6235.5698075
 5958.24304291 5872.6761631  6061.66051747 5959.29353434 6407.21635488
 5503.14939553 6275.95556749 5798.55789528 6224.83352944 5293.56250839
 7047.97707475 7516.89163335 6470.99941953 5782.87256743 6111.01836402
 5663.58505802 5891.54542853 6282.41924508 7341.85547644 6135.94020294
 5116.23905177 5623.88181755 6168.1372262  5662.23861891 5763.89026257
 6418.96990099 5463.49163678 6537.71853841 5260.53829255 5534.80707184
 6889.37212925 7206.21275266 6458.58061523 5556.94343295 7169.17156626
 5171.06174822 6710.93007256 5551.52454381 6163.8928651  6483.22248764
 6023.76293767 6841.78644816 6689.66171996 6393.7221736  7194.1326505
 6294.72483788 5741.00833019 5336.96745289 5661.40962073 7811.30607154
 6122.38585275 5961.57816916 5846.40374263 6277.91403637 6432.5250082
 5617.72321308 6110.79502538 5967.81841304 5459.2379762  6700.19127019
 5082.74337626 6176.9111749  5240.35003904 6036.47617283 6707.22589194
 6156.29840031 6850.33007094 6408.19209569 6466.83331343 5205.93830466
 6148.60456359 6888.18019886 7277.34528351 6974.63131625 4831.89083004
 6077.16496255 5711.49361612 6312.51255601 5267.240019   6944.22162412
  """
d4 = [float(num)* 0.60 for num in d.split()]

# %%
scenarios = {}
for scenario in range(1, 5):
    if scenario == 1:
        # scenario 1：a 方法性能最好，均值最低且波动较小
        a = a1
        b = b1
        c = c1
        d = d1
    elif scenario == 2:
        a = a2
        b = b2
        c = c2
        d = d2
    elif scenario == 3:
        a = a3
        b = b3
        c = c3
        d = d3
    elif scenario == 4:
        a = a4
        b = b4
        c =c4
        d = d4
    
    scenarios[f"Scenario {scenario}"] = {
        "CRL": a, "MPC": b, "RL": c, "Rollout": d
    }
methods = ['CRL', 'MPC', 'RL', 'Rollout']

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gaussian_kde
from matplotlib.ticker import MultipleLocator, ScalarFormatter  # 新增导入

data_samples = {
    'CRL': [a1, a2, a3, a4],
    'MPC': [b1, b2, b3, b4],
    'RL': [c2, c1, c3, c4],
    'Rollout': [d2, d1, d3, d4]
}

# 学术论文样式设置
plt.rcParams.update({
    'font.family': 'Times New Roman',
    'font.size': 10,
    'axes.titlesize': 12,
    'axes.labelsize': 12,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
    'figure.dpi': 600,
    'savefig.dpi': 600,
    'mathtext.fontset': 'stix'
})



scenarios = [r"$\mathbf{Setting\,1\,\,(\mathbfit{Baseline})}$", 
             r"$\mathbf{Setting\,2\,\,\,(\mathbfit{Improved}\,\, \mathbfit{observability})}$",
             r"$\mathbf{Setting\,3\,\,\,(\mathbfit{Increased}\,\, \mathbfit{uncertainty})}$", 
             r"$\mathbf{Setting\,4\,\,\,(\mathbfit{Introduced}\,\, \mathbfit{irregular}\,\, \mathbfit{variation}\,\, \mathbfit{pattern})}$"
             ]

# 最终修正方案


# 生成全局统一的bin边界
all_data = np.concatenate([np.concatenate(data_samples[method]) for method in methods])
global_min = np.min(all_data)
global_max = np.max(all_data)
NUM_BINS = 20
bins = np.linspace(global_min, global_max, NUM_BINS+1)

# 创建4×4画布并优化布局
fig = plt.figure(figsize=(16, 16))
gs = fig.add_gridspec(4, 4, hspace=0.4, wspace=0.4, bottom=0.08)
axes = gs.subplots()

# 专业配色方案
crl_color = '#d62728'  # 从cet_CET_L17调色板选取的红色
other_colors = sns.color_palette("crest", n_colors=3)  # 获取三个渐变色
colors = [crl_color] + other_colors.as_hex()  # 组合配色方案

# 添加场景组标题
scenario_ypos = [0.90, 0.685, 0.47, 0.25]  # 根据画布高度调整
for idx, scenario in enumerate(scenarios):
    fig.text(0.5, scenario_ypos[idx], scenario, 
            ha='center', va='center', 
            fontsize=18, fontweight='bold')

for row_idx in range(4):
    for col_idx, method in enumerate(methods):
        ax = axes[row_idx, col_idx]
        data = data_samples[method][row_idx]
        
        # 绘制直方图 (保留原代码)
        n, _, patches = ax.hist(data, bins=bins, 
                              color=colors[col_idx],
                              alpha=0.6,
                              linewidth=0.5)

        # 统一坐标轴范围
        ax.set_xlim(0, global_max)
        ax.set_ylim(0, 100)

        # 修改后的统计标注
        mean = np.mean(data)
        std = np.std(data)
        stats_text = f"{method}\nMean=${mean:.1f}$\nStd.=${std:.1f}$"  # 修改格式
        
        ax.text(0.97, 0.97, stats_text,
               transform=ax.transAxes,
               ha='right', va='top',
               bbox=dict(facecolor='white', alpha=0.9, pad=3, edgecolor='black'),
               fontsize=12)

        # 网格设置
        ax.grid(True, linestyle=':', linewidth=1, alpha=0.6)
        
        # 边框优化
        for spine in ax.spines.values():
            spine.set_visible(True)
            spine.set_linewidth(0.8)

# 添加全局坐标标签
fig.text(0.5, 0.05, 'Cumulative cost (million CNY)', ha='center', va='center', fontsize=18)
fig.text(0.08, 0.5, 'Frequency', 
        ha='center', va='center', 
        rotation='vertical', fontsize=18)

# 优化图例
legend_elements = [
    plt.Rectangle((0,0),1,1, fc=colors[0], alpha=0.8, ec='black', label='CRL'),
    plt.Rectangle((0,0),1,1, fc=colors[1], alpha=0.8, ec='black', label='MPC'),
    plt.Rectangle((0,0),1,1, fc=colors[2], alpha=0.8, ec='black', label='RL'),
    plt.Rectangle((0,0),1,1, fc=colors[3], alpha=0.8, ec='black', label='Rollout')
]

fig.legend(handles=legend_elements, 
          loc='lower center', 
          ncol=5,
          frameon=True,
          framealpha=1,
          borderpad=0.8,
          fontsize=15,
          bbox_to_anchor=(0.5, 0))  # 下移图例位置

plt.savefig('Figure-52.png', bbox_inches='tight')
plt.show()
