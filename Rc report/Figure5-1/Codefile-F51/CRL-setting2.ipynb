# %%
from rsl_rl.env import VecEnv
from rsl_rl.runners import OnPolicyRunner
import torch
import numpy as np
torch.set_printoptions(precision=5, linewidth=200, sci_mode=False)

N          = 100020
state_dim  = 8
action_dim = 5
T          = 60
budget     = 3600.
N_envs     = 1024 * 64
ΔT         = 1.0
device     = 'cuda'
usr_std = 0.01
test_num = 100
seed = 0

parameter_static = dict(N          = N,
                        B          = budget,
                        T          = T,
                        alpha      = 0.6,
                        v_max      = 0.2/14,
                        cost_ti    = 0.0977,
                        cost_ta    = 0.02,
                        cost_v     = 0.07,
                        cost_poc_0 = 0.000369,
                        cost_poc_1 = 0.001057,
                        pid        = 1.10/1000,
                        psr        = 0.7,
                        pid_plus   = 0.1221/1000,
                        pir        = 1/8,
                        prs        = 1/7)

Random_mean = {"beta2" : 0.78735,
               "beta1" : 0.15747,
               "pei"   : 0.10714,
               "per"   : 0.04545}

space = {"beta2" : [Random_mean['beta2'],Random_mean['beta2']*usr_std],
         "beta1" : [Random_mean['beta1'], Random_mean['beta1']*usr_std],
         "pei"   : [Random_mean['pei'], Random_mean['pei']*usr_std],
         "per"   : [Random_mean['per'], Random_mean['per']*usr_std]}

Init_state = torch.tensor([[100000 / N, 20 / N, 0, 0, 0, 0, 1, 0]], 
                         dtype=torch.float32).to(torch.device(device))

# %%
class myVecEnv(VecEnv):
    def __init__(self, interval, n_envs = N_envs):
        self.B = parameter_static['B']  # total budget
        self.N = parameter_static['N']
        self.device = device
        self.init_state = Init_state
        self.states = self.init_state.repeat(n_envs, 1)
        self.num_envs = n_envs
        self.num_obs = state_dim
        self.num_privileged_obs = None
        self.num_actions = action_dim
        self.max_episode_length = parameter_static['T']
        
        torch.manual_seed(seed)
        self.parameter_random = {
            key: torch.empty(self.num_envs).normal_(
                interval[key][0],
                interval[key][1]
            ).to(torch.device(device))
            for key, value in Random_mean.items()
        }

        for key, value in Random_mean.items():
            indice = self.parameter_random[key] < 0
            self.parameter_random[key][indice] = -self.parameter_random[key][indice] 

        # optimization flags for pytorch JIT
        torch._C._jit_set_profiling_mode(False)
        torch._C._jit_set_profiling_executor(False)
        
        # allocate buffers
        self.privileged_obs_buf = None
        self.obs_buf = torch.zeros(self.num_envs, self.num_obs, device=self.device, dtype=torch.float)
        self.rew_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.float)
        self.reset_buf = torch.ones(self.num_envs, device=self.device, dtype=torch.long)
        self.episode_length_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.long)
        
        self.actions = torch.zeros(self.num_envs, self.num_actions, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_sums = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_acts = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.extras = {}
    
    def para_update(self, para):
        self.parameter_random = para
        
    def step(self, actions):
        # actions clip
        soft_bound = [-0.5, 1.5]
        out_of_limits = -(actions - soft_bound[0]).clip(max=0.)
        out_of_limits += (actions - soft_bound[1]).clip(min=0.)
        scale_action = -0.1
        reward_action = scale_action * torch.sum(out_of_limits, dim=1).clip(max=1.).to(self.device)
        self.actions = torch.clip(actions, 0., 1.).to(self.device)

        # update actions & states
        b, p = self.states[:, -2] * self.B, self.states[:, -1]
        inv_c = self.cost_function(self.actions)
        b -= inv_c
        b = torch.clip(b, 0., self.B).to(self.device)
        mask = (b > 0).float().unsqueeze(-1)
        self.act = self.actions * mask
        inv_c = self.cost_function(self.act)
        next_state, reward_original = self.transition(self.act)
        self.extras['reward_original'] = reward_original
        self.extras['inv_cost'] = inv_c
        self.episode_length_buf += 1
        p = self.episode_length_buf / self.max_episode_length
        self.states = torch.cat([next_state / self.N, (b / self.B).unsqueeze(-1), p.unsqueeze(-1)], dim=-1)
        
        # check termination
        self.reset_buf = self.episode_length_buf >= self.max_episode_length
        
        # compute reward
        r_mean = -6584
        r_std  =  7347
        reward = (reward_original - inv_c - r_mean) / r_std
        #if reward > 0: 
        #reward = torch.exp(reward)/10
        #reward = torch.exp((1e5 + reward_original - inv_c) / 5e4)
        self.rew_buf       = reward + reward_action
        self.episode_sums += reward + reward_action
        self.episode_acts += reward_action
        
        # compute resets
        env_ids = self.reset_buf.nonzero(as_tuple=False).flatten()
        self.reset_idx(env_ids)
        
        # compute observations
        return self.get_observations(), self.states, self.rew_buf, self.reset_buf, self.extras

    def reset_idx(self, env_ids):
        """Reset selected robots"""
        if len(env_ids) == 0:
            return
        
        assert len(env_ids) == self.num_envs
        # reset robot states
        self.states[env_ids] = self.init_state
        # reset buffers
        self.episode_length_buf[env_ids] = 0
        self.reset_buf[env_ids] = 1
        # fill extras
        self.extras["episode"] = {}
        self.extras["episode"]['rew_sum'] = torch.mean(self.episode_sums[env_ids]) / (self.max_episode_length * ΔT)
        self.extras["episode"]['rew_act'] = torch.mean(self.episode_acts[env_ids]) / (self.max_episode_length * ΔT)
        self.episode_sums[env_ids] = 0.
        self.episode_acts[env_ids] = 0.
    
    def reset(self):
        """ Reset all robots"""
        self.reset_idx(torch.arange(self.num_envs, device=self.device))
        return {}, {}
    
    def get_observations(self):
        o_mean = torch.tensor([[0.58712867, 0.06804276, 0.00308146, 0.25684301, 0.00261079, 0.08229331, 0.26572794, 0.51      ]], dtype=torch.float32).to(torch.device(self.device))
        o_std  = torch.tensor([[0.41484398, 0.07883003, 0.00389494, 0.292568  , 0.00394907, 0.06906768, 0.33943075, 0.28861739]], dtype=torch.float32).to(torch.device(self.device))
        self.obs_buf = (self.states - o_mean) / o_std
        return self.obs_buf
    
    def get_privileged_observations(self):
        return self.privileged_obs_buf

    def cost_function(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]

        cost_it  = it * u_it * parameter_static['cost_ti']
        cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
        cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
        per_poc  = ((st + et + at + rt) / self.N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
        cost_poc = (st + et + rt + at) * w * per_poc
        return cost_poc + cost_it + cost_v + cost_q

    def transition(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
        ht = st + et + at + it + rt

        st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * self.parameter_random['beta1'] + (et + at * (1 - u_aq)) * self.parameter_random['beta2']) / ht
        st_out_e = st_out * parameter_static['alpha']
        st_out_i = st_out * (1 - parameter_static['alpha'])
        st_out_r = u_sv * parameter_static['v_max'] * st * parameter_static['psr']
        et_out_r = et * self.parameter_random['per']
        et_out_i = et * self.parameter_random['pei']
        et_out_a = et * w * (1 - self.parameter_random['per'] - self.parameter_random['pei'])
        at_out_i = at * self.parameter_random['pei']
        at_out_r = at * self.parameter_random['per']
        it_out_r = it * parameter_static['pir'] * u_it
        it_out_d = it * parameter_static['pid'] * (1 - u_it) + it * u_it * parameter_static['pid_plus']
        rt_out_s = rt * parameter_static['prs']
        
        stn = st - st_out_e - st_out_i - st_out_r + rt_out_s
        etn = et - et_out_r - et_out_i - et_out_a + st_out_e
        atn = at - at_out_r - at_out_i + et_out_a
        itn = it - it_out_r - it_out_d + st_out_i + et_out_i + at_out_i
        dtn = dt + it_out_d
        rtn = rt + et_out_r + at_out_r + it_out_r + st_out_r - rt_out_s

        reward = -2.6 * st_out - 100 * it_out_d

        next_state = torch.stack([stn, etn, atn, itn, dtn, rtn], dim=-1)
        return next_state, reward

# %%
import inspect

class BaseConfig:
    def __init__(self) -> None:
        """ Initializes all member classes recursively. Ignores all namse starting with '__' (buit-in methods)."""
        self.init_member_classes(self)
    
    @staticmethod
    def init_member_classes(obj):
        # iterate over all attributes names
        for key in dir(obj):
            # disregard builtin attributes
            # if key.startswith("__"):
            if key=="__class__":
                continue
            # get the corresponding attribute object
            var =  getattr(obj, key)
            # check if it the attribute is a class
            if inspect.isclass(var):
                # instantate the class
                i_var = var()
                # set the attribute to the instance instead of the type
                setattr(obj, key, i_var)
                # recursively init members of the attribute
                BaseConfig.init_member_classes(i_var)

class LeggedRobotCfgPPO(BaseConfig):
    seed = 1
    runner_class_name = 'OnPolicyRunner'
    class policy:
        init_noise_std = 2
        actor_hidden_dims  = [64, 32, 16] 
        critic_hidden_dims = [64, 32, 16]
        activation = 'elu' # can be elu, relu, selu, crelu, lrelu, tanh, sigmoid
        # only for 'ActorCriticRecurrent':
        # rnn_type = 'lstm'
        # rnn_hidden_size = 512
        # rnn_num_layers = 1
        
    class algorithm:
        # training params
        value_loss_coef = 0.5
        use_clipped_value_loss = True
        clip_param = 0.2
        entropy_coef = 0.01
        num_learning_epochs = 5
        num_mini_batches = 64 # mini batch size = num_envs*nsteps / nminibatches
        learning_rate = 1.e-4
        schedule = 'adaptive' # could be adaptive, fixed
        gamma = 0.99
        lam = 0.95
        desired_kl = 0.01
        max_grad_norm = 1.

    class runner:
        policy_class_name = 'ActorCritic'
        algorithm_class_name = 'PPO'
        num_steps_per_env =  150 # per iteration
        max_iterations    = 100 # number of policy updates

        # logging
        save_interval = 100 # check for potential saves every this many iterations
        experiment_name = 'test'
        run_name = ''
        # load and resume
        resume = True
        load_run = -1 # -1 = last run
        checkpoint = -1 # -1 = last saved model
        resume_path = None # updated from load_run and chkpt
        
def class_to_dict(obj) -> dict:
    if not  hasattr(obj,"__dict__"):
        return obj
    result = {}
    for key in dir(obj):
        if key.startswith("_"):
            continue
        element = []
        val = getattr(obj, key)
        if isinstance(val, list):
            for item in val:
                element.append(class_to_dict(item))
        else:
            element = class_to_dict(val)
        result[key] = element
    return result

# %%
def para_sampling(intvl, num_sample=N_envs):
    parameter_random = {
        key: torch.empty(num_sample).normal_(
        intvl[key][0],
        intvl[key][1]
        ).to(torch.device(device))
        for key, value in Random_mean.items()
    }
    for key, value in Random_mean.items():
        indice = parameter_random[key] < 0
        parameter_random[key][indice] = -parameter_random[key][indice] 
    return parameter_random

def update_space(final_indices, para_buf, space):
    para_est = {}
    for key, tensor_values in para_buf.items():
        selected_values = torch.mean(tensor_values[final_indices[0], final_indices[1]]) 
        para_values = torch.mean(tensor_values[final_indices[0], final_indices[1]], dim=0)
        update_values = space[key][0] + 0.5 * (selected_values - space[key][0])
        space[key] = [update_values , update_values  * 0.1]
        para_est[key] = para_values
    return space, para_est


def cal_err(para_value, env_para):
    gap = []
    for key, value in env_para.items():
        gap_temp = torch.mean(torch.abs(para_value[key] - env_para[key])/(env_para[key]))
        gap.append(gap_temp)
    return sum(gap)/len(gap) # 所有值都在范围内，返回 0
    
def state_estimator(env_sample, action_sim, state_sim, state_prior, space, iter): 
    env_sample.reset()
    env_sample.states = state_prior  
    para_buf, mse_buf, obs_buf, states_buf = {}, {}, {}, {}
    for i in range(iter):
        para = para_sampling(space, test_num)
        env_sample.para_update(para)
        obs_sample, states_sample, _, _, _ = env_sample.step(action_sim.detach())  
        mse = torch.mean((state_sim[:,:6] - states_sample[:,:6]) ** 2, dim=1) 
        if i == 0:
            mse_buf = mse.unsqueeze(0)
            obs_buf = obs_sample.unsqueeze(0)
            states_buf = states_sample.unsqueeze(0)
            for key, values in para.items():
                para_buf[key] = para[key].unsqueeze(0)
        else:
            mse_buf = torch.cat((mse_buf, mse.unsqueeze(0)), dim=0)
            obs_buf = torch.cat((obs_buf, obs_sample.unsqueeze(0)),dim=0)
            states_buf = torch.cat((states_buf, states_sample.unsqueeze(0)), dim=0)
            for key, values in para.items():
                para_buf[key] = torch.cat((para_buf[key], para[key].unsqueeze(0)), dim=0)
                
     
    k = int(iter * 0.05)
    _, row_indices = torch.topk(mse_buf, k=k, dim=0, largest=False)
    column_indices = torch.arange(mse_buf.shape[1]).repeat(k, 1)
    top_indices = [row_indices, column_indices]
    obs_est = torch.mean(obs_buf[row_indices,column_indices,:], dim=0)
    state_est = torch.mean(states_buf[row_indices,column_indices,:], dim=0)
    state_est[:,-1] = state_prior[:,-1] + torch.tensor(1/T)
    return obs_est, state_est, top_indices, para_buf

# %%
para_err = 0.5
torch.manual_seed(seed)
para_true = []
para_temp = {
    key: torch.empty(test_num).uniform_(
        value * (1-para_err),
        value * (1+para_err)
    ).to(torch.device(device))
    for key, value in Random_mean.items()
}


para = {}
for t in range(T):
    para = {
        key: (para_temp[key] - para_temp[key] * torch.sin(torch.tensor(t/(3.1415926 * 3))) * 0.25).to(torch.device(device))
        for key, value in Random_mean.items()
        }
    para_true.append(para)

# %%
env = myVecEnv(space, test_num)
env.para_update(para_true[0])
train_cfg = LeggedRobotCfgPPO()
train_cfg_dict = class_to_dict(train_cfg)


env_transfer = myVecEnv(space)
runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_test_obs', device=env.device)
runner.load(f'rsl_output_main/model_100.pt')

policy = runner.get_inference_policy(device=env.device)

reward_history = []
act_buf = []
state_his_buf = []
death_buf = []

env_sample = myVecEnv(space, test_num)
state_est = env.states
obs_est = env.get_observations()
for t in range(T-1):
    actions = policy(obs_est.detach())
    obs, states, _, _, infos = env.step(actions.detach())
    reward_history.append((-infos['reward_original'] + infos['inv_cost']).tolist())
    death_buf.append((-infos['reward_original']).tolist())
    act_buf.append(env.act)
    state_his_buf.append(env.states)
    obs_est, state_buf, top_indices, para_buf = state_estimator(env_sample, actions, states, state_est, space, 1024)
    space, para_v = update_space(top_indices, para_buf, space) 

    runner.learn(num_learning_iterations=25, init_at_random_ep_len=False)
    policy = runner.get_inference_policy(device=env.device)
    env_transfer = myVecEnv(space)
    runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_test_obs', device=env.device)
    runner.load(f'rsl_test_obs/model_{int(t)* 25}.pt')
        

    if t < T - 1: env.para_update(para_true[t + 1])
    print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
env.reset()

reward_history = np.array(reward_history)
print(f'score     : {np.sum(reward_history, axis=0)/T       }')
print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
# Out:
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2270898 steps/s (collection: 0.662s, learning 3.667s)
#                Value function loss: 142.5378
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.63
#                        Mean reward: 45.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4641
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.33s
#                         Total time: 4.33s
#                                ETA: 108.2s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2303145 steps/s (collection: 0.666s, learning 3.603s)
#                Value function loss: 144.6782
#                     Surrogate loss: 0.0007
#              Mean action noise std: 4.69
#                        Mean reward: 46.00
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7657
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.27s
#                         Total time: 8.60s
#                                ETA: 103.2s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2317837 steps/s (collection: 0.685s, learning 3.557s)
#                Value function loss: 131.0451
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.76
#                        Mean reward: 45.80
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7668
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.24s
#                         Total time: 12.84s
#                                ETA: 98.4s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2303227 steps/s (collection: 0.681s, learning 3.587s)
#                Value function loss: 131.8155
#                     Surrogate loss: 0.0007
#              Mean action noise std: 4.81
#                        Mean reward: 45.82
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7668
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.27s
#                         Total time: 17.11s
#                                ETA: 94.1s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2273732 steps/s (collection: 0.648s, learning 3.675s)
#                Value function loss: 120.9523
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.87
#                        Mean reward: 45.80
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7668
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.32s
#                         Total time: 21.43s
#                                ETA: 90.0s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2426551 steps/s (collection: 0.655s, learning 3.396s)
#                Value function loss: 121.5071
#                     Surrogate loss: 0.0031
#              Mean action noise std: 4.94
#                        Mean reward: 46.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7649
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.05s
#                         Total time: 25.48s
#                                ETA: 84.9s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2422377 steps/s (collection: 0.631s, learning 3.427s)
#                Value function loss: 114.3146
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.00
#                        Mean reward: 45.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7639
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.06s
#                         Total time: 29.54s
#                                ETA: 80.2s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2464782 steps/s (collection: 0.635s, learning 3.353s)
#                Value function loss: 115.2126
#                     Surrogate loss: 0.0009
#              Mean action noise std: 5.08
#                        Mean reward: 46.04
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7645
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 3.99s
#                         Total time: 33.53s
#                                ETA: 75.4s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2469090 steps/s (collection: 0.622s, learning 3.359s)
#                Value function loss: 110.0399
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.15
#                        Mean reward: 45.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7633
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 3.98s
#                         Total time: 37.51s
#                                ETA: 70.9s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2476555 steps/s (collection: 0.628s, learning 3.341s)
#                Value function loss: 110.2140
#                     Surrogate loss: 0.0026
#              Mean action noise std: 5.21
#                        Mean reward: 45.59
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7630
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 3.97s
#                         Total time: 41.48s
#                                ETA: 66.4s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2472597 steps/s (collection: 0.627s, learning 3.348s)
#                Value function loss: 104.9139
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.28
#                        Mean reward: 45.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7605
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 3.98s
#                         Total time: 45.45s
#                                ETA: 62.0s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2442192 steps/s (collection: 0.632s, learning 3.393s)
#                Value function loss: 104.5630
#                     Surrogate loss: 0.0011
#              Mean action noise std: 5.35
#                        Mean reward: 45.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7586
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.03s
#                         Total time: 49.48s
#                                ETA: 57.7s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2355805 steps/s (collection: 0.658s, learning 3.515s)
#                Value function loss: 101.6371
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.43
#                        Mean reward: 45.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7586
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.17s
#                         Total time: 53.65s
#                                ETA: 53.7s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2424769 steps/s (collection: 0.660s, learning 3.394s)
#                Value function loss: 102.0143
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.50
#                        Mean reward: 45.26
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7595
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.05s
#                         Total time: 57.71s
#                                ETA: 49.5s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2434083 steps/s (collection: 0.681s, learning 3.357s)
#                Value function loss: 94.8475
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.56
#                        Mean reward: 45.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7599
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.04s
#                         Total time: 61.74s
#                                ETA: 45.3s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2446725 steps/s (collection: 0.629s, learning 3.388s)
#                Value function loss: 111.2999
#                     Surrogate loss: 0.0010
#              Mean action noise std: 5.64
#                        Mean reward: 45.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7597
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.02s
#                         Total time: 65.76s
#                                ETA: 41.1s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2336801 steps/s (collection: 0.670s, learning 3.537s)
#                Value function loss: 107.3011
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.72
#                        Mean reward: 45.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7585
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.21s
#                         Total time: 69.97s
#                                ETA: 37.0s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2352430 steps/s (collection: 0.642s, learning 3.537s)
#                Value function loss: 115.9443
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.80
#                        Mean reward: 45.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7565
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.18s
#                         Total time: 74.15s
#                                ETA: 33.0s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2337910 steps/s (collection: 0.635s, learning 3.569s)
#                Value function loss: 118.1301
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.88
#                        Mean reward: 45.37
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7555
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.20s
#                         Total time: 78.35s
#                                ETA: 28.9s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2395281 steps/s (collection: 0.635s, learning 3.469s)
#                Value function loss: 137.7706
#                     Surrogate loss: 0.0020
#              Mean action noise std: 5.96
#                        Mean reward: 45.76
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7562
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.10s
#                         Total time: 82.46s
#                                ETA: 24.7s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2404657 steps/s (collection: 0.632s, learning 3.456s)
#                Value function loss: 146.2068
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.04
#                        Mean reward: 45.68
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7553
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.09s
#                         Total time: 86.55s
#                                ETA: 20.6s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2404027 steps/s (collection: 0.636s, learning 3.453s)
#                Value function loss: 164.4678
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.11
#                        Mean reward: 45.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7534
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.09s
#                         Total time: 90.63s
#                                ETA: 16.5s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2399405 steps/s (collection: 0.635s, learning 3.462s)
#                Value function loss: 175.4398
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.20
#                        Mean reward: 45.37
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7524
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.10s
#                         Total time: 94.73s
#                                ETA: 12.4s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2418803 steps/s (collection: 0.631s, learning 3.433s)
#                Value function loss: 202.2828
#                     Surrogate loss: 0.0008
#              Mean action noise std: 6.28
#                        Mean reward: 45.45
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7526
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.06s
#                         Total time: 98.80s
#                                ETA: 8.2s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2434936 steps/s (collection: 0.633s, learning 3.404s)
#                Value function loss: 204.6421
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.35
#                        Mean reward: 45.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7535
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.04s
#                         Total time: 102.83s
#                                ETA: 4.1s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 3.0514750366210937
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2294454 steps/s (collection: 0.807s, learning 3.478s)
#                Value function loss: 131.6541
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.69
#                        Mean reward: 45.10
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4494
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.28s
#                         Total time: 4.28s
#                                ETA: 107.1s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2415837 steps/s (collection: 0.634s, learning 3.435s)
#                Value function loss: 138.1978
#                     Surrogate loss: 0.0015
#              Mean action noise std: 4.75
#                        Mean reward: 45.61
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7418
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.07s
#                         Total time: 8.35s
#                                ETA: 100.2s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2410539 steps/s (collection: 0.637s, learning 3.441s)
#                Value function loss: 131.5008
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.81
#                        Mean reward: 45.23
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7442
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.08s
#                         Total time: 12.43s
#                                ETA: 95.3s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2420598 steps/s (collection: 0.652s, learning 3.409s)
#                Value function loss: 141.5028
#                     Surrogate loss: 0.0007
#              Mean action noise std: 4.87
#                        Mean reward: 44.49
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7443
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.06s
#                         Total time: 16.49s
#                                ETA: 90.7s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2370536 steps/s (collection: 0.695s, learning 3.452s)
#                Value function loss: 139.7728
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.93
#                        Mean reward: 45.23
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7430
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.15s
#                         Total time: 20.64s
#                                ETA: 86.7s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2411694 steps/s (collection: 0.640s, learning 3.436s)
#                Value function loss: 159.1130
#                     Surrogate loss: 0.0015
#              Mean action noise std: 4.99
#                        Mean reward: 45.08
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7411
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.08s
#                         Total time: 24.72s
#                                ETA: 82.4s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2398222 steps/s (collection: 0.654s, learning 3.445s)
#                Value function loss: 151.4167
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.05
#                        Mean reward: 44.97
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7408
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.10s
#                         Total time: 28.81s
#                                ETA: 78.2s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2382538 steps/s (collection: 0.636s, learning 3.490s)
#                Value function loss: 167.8828
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.12
#                        Mean reward: 44.43
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7411
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.13s
#                         Total time: 32.94s
#                                ETA: 74.1s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2403691 steps/s (collection: 0.693s, learning 3.397s)
#                Value function loss: 157.9873
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.18
#                        Mean reward: 44.86
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7407
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.09s
#                         Total time: 37.03s
#                                ETA: 69.9s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2464789 steps/s (collection: 0.633s, learning 3.355s)
#                Value function loss: 177.2443
#                     Surrogate loss: 0.0014
#              Mean action noise std: 5.24
#                        Mean reward: 44.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7417
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 3.99s
#                         Total time: 41.02s
#                                ETA: 65.6s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2431349 steps/s (collection: 0.635s, learning 3.408s)
#                Value function loss: 163.6061
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.30
#                        Mean reward: 45.59
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7435
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.04s
#                         Total time: 45.06s
#                                ETA: 61.4s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2409359 steps/s (collection: 0.638s, learning 3.442s)
#                Value function loss: 179.9355
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.36
#                        Mean reward: 44.78
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7428
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.08s
#                         Total time: 49.14s
#                                ETA: 57.3s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2422982 steps/s (collection: 0.644s, learning 3.413s)
#                Value function loss: 164.9395
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.42
#                        Mean reward: 45.02
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7417
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.06s
#                         Total time: 53.20s
#                                ETA: 53.2s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2434253 steps/s (collection: 0.688s, learning 3.350s)
#                Value function loss: 183.3951
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.49
#                        Mean reward: 44.88
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7435
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.04s
#                         Total time: 57.24s
#                                ETA: 49.1s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2484671 steps/s (collection: 0.639s, learning 3.317s)
#                Value function loss: 168.7193
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.56
#                        Mean reward: 44.77
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7469
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 3.96s
#                         Total time: 61.19s
#                                ETA: 44.9s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2485319 steps/s (collection: 0.634s, learning 3.321s)
#                Value function loss: 188.6242
#                     Surrogate loss: 0.0008
#              Mean action noise std: 5.62
#                        Mean reward: 45.49
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7490
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 3.96s
#                         Total time: 65.15s
#                                ETA: 40.7s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2488440 steps/s (collection: 0.625s, learning 3.325s)
#                Value function loss: 167.2177
#                     Surrogate loss: 0.0008
#              Mean action noise std: 5.69
#                        Mean reward: 44.43
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7448
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 3.95s
#                         Total time: 69.10s
#                                ETA: 36.6s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2431900 steps/s (collection: 0.665s, learning 3.377s)
#                Value function loss: 185.3963
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.75
#                        Mean reward: 45.19
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7425
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.04s
#                         Total time: 73.14s
#                                ETA: 32.5s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2437363 steps/s (collection: 0.645s, learning 3.388s)
#                Value function loss: 171.5583
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.83
#                        Mean reward: 45.31
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7448
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.03s
#                         Total time: 77.18s
#                                ETA: 28.4s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2428952 steps/s (collection: 0.636s, learning 3.411s)
#                Value function loss: 191.4928
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.88
#                        Mean reward: 45.32
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7439
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.05s
#                         Total time: 81.22s
#                                ETA: 24.4s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2415854 steps/s (collection: 0.743s, learning 3.326s)
#                Value function loss: 176.1140
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.96
#                        Mean reward: 45.67
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7447
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.07s
#                         Total time: 85.29s
#                                ETA: 20.3s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2431512 steps/s (collection: 0.735s, learning 3.308s)
#                Value function loss: 198.8390
#                     Surrogate loss: 0.0008
#              Mean action noise std: 6.02
#                        Mean reward: 45.49
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7449
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.04s
#                         Total time: 89.33s
#                                ETA: 16.2s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2489039 steps/s (collection: 0.642s, learning 3.307s)
#                Value function loss: 180.8649
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.10
#                        Mean reward: 45.39
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7468
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 3.95s
#                         Total time: 93.28s
#                                ETA: 12.2s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2469020 steps/s (collection: 0.682s, learning 3.299s)
#                Value function loss: 204.3838
#                     Surrogate loss: 0.0005
#              Mean action noise std: 6.16
#                        Mean reward: 45.46
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7498
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 3.98s
#                         Total time: 97.27s
#                                ETA: 8.1s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2504879 steps/s (collection: 0.629s, learning 3.295s)
#                Value function loss: 183.7016
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.23
#                        Mean reward: 45.21
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7511
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 3.92s
#                         Total time: 101.19s
#                                ETA: 4.0s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 5.7853463363647455
# ################################################################################
#                         Learning iteration 25/50
#
#                        Computation: 2386012 steps/s (collection: 0.791s, learning 3.329s)
#                Value function loss: 185.9702
#                     Surrogate loss: 0.0034
#              Mean action noise std: 6.32
#                        Mean reward: 45.60
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4560
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.12s
#                         Total time: 4.12s
#                                ETA: 0.0s
#
# ################################################################################
#                         Learning iteration 26/50
#
#                        Computation: 2435555 steps/s (collection: 0.720s, learning 3.316s)
#                Value function loss: 227.0840
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.38
#                        Mean reward: 45.79
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7523
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.04s
#                         Total time: 8.16s
#                                ETA: -0.3s
#
# ################################################################################
#                         Learning iteration 27/50
#
#                        Computation: 2507407 steps/s (collection: 0.625s, learning 3.295s)
#                Value function loss: 213.1814
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.46
#                        Mean reward: 45.64
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7554
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 3.92s
#                         Total time: 12.08s
#                                ETA: -0.9s
#
# ################################################################################
#                         Learning iteration 28/50
#
#                        Computation: 2506154 steps/s (collection: 0.629s, learning 3.293s)
#                Value function loss: 271.9446
#                     Surrogate loss: 0.0007
#              Mean action noise std: 6.52
#                        Mean reward: 45.16
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7574
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 3.92s
#                         Total time: 16.00s
#                                ETA: -1.7s
#
# ################################################################################
#                         Learning iteration 29/50
#
#                        Computation: 2499795 steps/s (collection: 0.619s, learning 3.313s)
#                Value function loss: 256.4348
#                     Surrogate loss: 0.0005
#              Mean action noise std: 6.62
#                        Mean reward: 45.94
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7611
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 3.93s
#                         Total time: 19.93s
#                                ETA: -2.7s
#
# ################################################################################
#                         Learning iteration 30/50
#
#                        Computation: 2440361 steps/s (collection: 0.718s, learning 3.310s)
#                Value function loss: 315.5886
#                     Surrogate loss: 0.0009
#              Mean action noise std: 6.70
#                        Mean reward: 46.23
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7624
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.03s
#                         Total time: 23.96s
#                                ETA: -3.9s
#
# ################################################################################
#                         Learning iteration 31/50
#
#                        Computation: 2506790 steps/s (collection: 0.626s, learning 3.295s)
#                Value function loss: 280.0904
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.79
#                        Mean reward: 46.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7639
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 3.92s
#                         Total time: 27.88s
#                                ETA: -5.2s
#
# ################################################################################
#                         Learning iteration 32/50
#
#                        Computation: 2491562 steps/s (collection: 0.639s, learning 3.306s)
#                Value function loss: 336.2932
#                     Surrogate loss: 0.0008
#              Mean action noise std: 6.85
#                        Mean reward: 46.06
# ...
#                    Total timesteps: 78643200
#                     Iteration time: 4.12s
#                         Total time: 31.88s
#                                ETA: -31.3s
#
# ################################################################################
#                       Learning iteration 1433/1450
#
#                        Computation: 2461691 steps/s (collection: 0.646s, learning 3.347s)
#                Value function loss: 127.3690
#                     Surrogate loss: 0.0000
#              Mean action noise std: 2633.71
#                        Mean reward: 46.99
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7834
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 3.99s
#                         Total time: 35.88s
#                                ETA: -35.2s
#
# ################################################################################
#                       Learning iteration 1434/1450
#
#                        Computation: 2355827 steps/s (collection: 0.647s, learning 3.526s)
#                Value function loss: 134.1683
#                     Surrogate loss: -0.0000
#              Mean action noise std: 2636.60
#                        Mean reward: 47.07
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7835
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.17s
#                         Total time: 40.05s
#                                ETA: -39.3s
#
# ################################################################################
#                       Learning iteration 1435/1450
#
#                        Computation: 2372247 steps/s (collection: 0.693s, learning 3.451s)
#                Value function loss: 127.9771
#                     Surrogate loss: 0.0000
#              Mean action noise std: 2639.43
#                        Mean reward: 47.06
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7836
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.14s
#                         Total time: 44.19s
#                                ETA: -43.4s
#
# ################################################################################
#                       Learning iteration 1436/1450
#
#                        Computation: 2354847 steps/s (collection: 0.656s, learning 3.518s)
#                Value function loss: 139.1771
#                     Surrogate loss: 0.0021
#              Mean action noise std: 2641.84
#                        Mean reward: 47.09
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7839
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.17s
#                         Total time: 48.37s
#                                ETA: -47.5s
#
# ################################################################################
#                       Learning iteration 1437/1450
#
#                        Computation: 2358459 steps/s (collection: 0.688s, learning 3.480s)
#                Value function loss: 134.5520
#                     Surrogate loss: -0.0000
#              Mean action noise std: 2644.69
#                        Mean reward: 47.04
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7838
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.17s
#                         Total time: 52.54s
#                                ETA: -51.6s
#
# ################################################################################
#                       Learning iteration 1438/1450
#
#                        Computation: 2436234 steps/s (collection: 0.663s, learning 3.372s)
#                Value function loss: 146.6504
#                     Surrogate loss: -0.0001
#              Mean action noise std: 2647.68
#                        Mean reward: 47.05
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7838
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.04s
#                         Total time: 56.57s
#                                ETA: -55.5s
#
# ################################################################################
#                       Learning iteration 1439/1450
#
#                        Computation: 2445480 steps/s (collection: 0.645s, learning 3.374s)
#                Value function loss: 139.5260
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2650.51
#                        Mean reward: 47.05
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7838
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.02s
#                         Total time: 60.59s
#                                ETA: -59.5s
#
# ################################################################################
#                       Learning iteration 1440/1450
#
#                        Computation: 2440545 steps/s (collection: 0.658s, learning 3.369s)
#                Value function loss: 152.3981
#                     Surrogate loss: 0.0007
#              Mean action noise std: 2653.59
#                        Mean reward: 47.05
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7836
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.03s
#                         Total time: 64.62s
#                                ETA: -63.5s
#
# ################################################################################
#                       Learning iteration 1441/1450
#
#                        Computation: 2447873 steps/s (collection: 0.638s, learning 3.378s)
#                Value function loss: 143.9765
#                     Surrogate loss: -0.0000
#              Mean action noise std: 2656.35
#                        Mean reward: 47.04
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7840
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.02s
#                         Total time: 68.64s
#                                ETA: -67.4s
#
# ################################################################################
#                       Learning iteration 1442/1450
#
#                        Computation: 2448916 steps/s (collection: 0.660s, learning 3.354s)
#                Value function loss: 158.2553
#                     Surrogate loss: -0.0000
#              Mean action noise std: 2659.36
#                        Mean reward: 47.06
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7841
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.01s
#                         Total time: 72.65s
#                                ETA: -71.3s
#
# ################################################################################
#                       Learning iteration 1443/1450
#
#                        Computation: 2459382 steps/s (collection: 0.637s, learning 3.360s)
#                Value function loss: 148.0581
#                     Surrogate loss: 0.0005
#              Mean action noise std: 2662.00
#                        Mean reward: 47.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7839
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.00s
#                         Total time: 76.65s
#                                ETA: -75.3s
#
# ################################################################################
#                       Learning iteration 1444/1450
#
#                        Computation: 2441836 steps/s (collection: 0.653s, learning 3.373s)
#                Value function loss: 163.9261
#                     Surrogate loss: 0.0005
#              Mean action noise std: 2665.17
#                        Mean reward: 47.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7838
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.03s
#                         Total time: 80.67s
#                                ETA: -79.2s
#
# ################################################################################
#                       Learning iteration 1445/1450
#
#                        Computation: 2447183 steps/s (collection: 0.647s, learning 3.370s)
#                Value function loss: 152.9750
#                     Surrogate loss: -0.0000
#              Mean action noise std: 2667.94
#                        Mean reward: 47.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7841
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.02s
#                         Total time: 84.69s
#                                ETA: -83.2s
#
# ################################################################################
#                       Learning iteration 1446/1450
#
#                        Computation: 2450510 steps/s (collection: 0.658s, learning 3.354s)
#                Value function loss: 170.1502
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2671.06
#                        Mean reward: 47.04
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7841
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.01s
#                         Total time: 88.70s
#                                ETA: -87.1s
#
# ################################################################################
#                       Learning iteration 1447/1450
#
#                        Computation: 2445571 steps/s (collection: 0.640s, learning 3.380s)
#                Value function loss: 158.4271
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2673.75
#                        Mean reward: 47.13
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7846
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.02s
#                         Total time: 92.72s
#                                ETA: -91.1s
#
# ################################################################################
#                       Learning iteration 1448/1450
#
#                        Computation: 2450309 steps/s (collection: 0.659s, learning 3.353s)
#                Value function loss: 177.7033
#                     Surrogate loss: 0.0014
#              Mean action noise std: 2676.58
#                        Mean reward: 47.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7851
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.01s
#                         Total time: 96.73s
#                                ETA: -95.0s
#
# ################################################################################
#                       Learning iteration 1449/1450
#
#                        Computation: 2452194 steps/s (collection: 0.638s, learning 3.371s)
#                Value function loss: 165.0547
#                     Surrogate loss: -0.0000
#              Mean action noise std: 2679.31
#                        Mean reward: 47.21
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7859
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.01s
#                         Total time: 100.74s
#                                ETA: -98.9s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 207.50693027930086
# score     : [  61.75675422  102.01625531   58.54094306   60.45954254   60.29131526
#    64.04674343   60.9976653   146.99284159   60.43824378   64.40209013
#    60.27079699   60.69643497   59.19101258   58.76443686   59.93297943
#    60.63732934   90.51602144  137.91340125   59.52561599   60.38658418
#    69.30162694  312.00810375   60.33423998  263.15029588   60.13668397
#    61.12816426 1641.39044268   59.17595733   60.54813416   60.25807667
#    61.01017408 1349.54856677   59.47883149   59.55851199   59.70753643
#    59.21242663   59.42484685 1225.64403719   79.28898507   79.64909747
#    61.55336902   59.72370409   62.73880824   59.29919375   60.1649296
#    58.86548295  115.46613098  131.6773195    59.84757412   60.43082993
#   177.7114152  1154.60902614   67.22047815   62.30631894  389.28344981
#    58.5855079    65.60597413   59.28785874   58.78257727   58.76056058
#    90.33316969   70.02778511   60.15320153   62.66531289  102.04397744
#    60.36377683   61.0202574    64.40605816  102.98662984 1401.13235522
#    60.93104723   59.83381012   92.11087499  897.15250705 1358.13945052
#  2412.36007726   61.70765282   59.19489816   61.65103406   59.2735622
#    59.20211447 1605.47296643  569.84550692   59.14966636   62.58285634
#    60.2250553    60.11655489   59.55101601   70.003185     59.53827783
#    74.99422358   86.53501842  213.26747694   70.7931085    59.09631101
#    58.64644897   71.09439984   65.00702359   59.61741535   58.81470737]
# score.mean: 207.50693027930086

# %%
a = np.sum(reward_history, axis=0)/T

# %%
min(a)
# Out:
# 58.54094305684169

# %%
max(a)
# Out:
# 2412.3600772619247

# %%
np.std(a)
# Out:
# 414.6632713566415

# %%
exp_result = {
    'reward_total': reward_history,
    'reward_peo': death_buf,
    'state': state_his_buf,
    'action': act_buf
}

# %%
torch.save(exp_result, 'mid_budget_obs.pt')
