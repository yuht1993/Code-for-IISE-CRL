# %%
from rsl_rl.env import VecEnv
from rsl_rl.runners import OnPolicyRunner
import torch
import numpy as np
torch.set_printoptions(precision=5, linewidth=200, sci_mode=False)

N          = 100020
state_dim  = 8
action_dim = 5
T          = 60
budget     = 3600.
N_envs     = 1024 * 64
ΔT         = 1.0
device     = 'cuda'
usr_std = 0.01
test_num = 100
seed = 0


parameter_static = dict(N          = N,
                        B          = budget,
                        T          = T,                      
                        v_max      = 0.2/14,
                        cost_ti    = 0.0977,
                        cost_ta    = 0.02,
                        cost_v     = 0.07,
                        cost_poc_0 = 0.000369,
                        cost_poc_1 = 0.001057,                      
                        psr        = 0.7,                      
                        prs        = 1/7)

Random_mean = {"beta2" : 0.78735,
               "beta1" : 0.15747,
               "pei"   : 0.10714,
               "per"   : 0.04545,
               "alpha" : 0.6,
               "pid"   : 1.10/1000,
               "pid_plus" : 0.1221/1000,
               "pir"   :  1/8}

space = {
    key: [value, value * usr_std]
    for key, value in Random_mean.items()
}

Init_state = torch.tensor([[100000 / N, 20 / N, 0, 0, 0, 0, 1, 0]], 
                         dtype=torch.float32).to(torch.device(device))

# %%
class myVecEnv(VecEnv):
    def __init__(self, interval, n_envs = N_envs):
        self.B = parameter_static['B']  # total budget
        self.N = parameter_static['N']
        self.device = device
        self.init_state = Init_state
        self.states = self.init_state.repeat(n_envs, 1)
        self.num_envs = n_envs
        self.num_obs = state_dim
        self.num_privileged_obs = None
        self.num_actions = action_dim
        self.max_episode_length = parameter_static['T']
        
        torch.manual_seed(seed)
        self.parameter_random = {
            key: torch.empty(self.num_envs).normal_(
                interval[key][0],
                interval[key][1]
            ).to(torch.device(device))
            for key, value in Random_mean.items()
        }

        for key, value in Random_mean.items():
            indice = self.parameter_random[key] < 0
            self.parameter_random[key][indice] = -self.parameter_random[key][indice] 

        # optimization flags for pytorch JIT
        torch._C._jit_set_profiling_mode(False)
        torch._C._jit_set_profiling_executor(False)
        
        # allocate buffers
        self.privileged_obs_buf = None
        self.obs_buf = torch.zeros(self.num_envs, self.num_obs, device=self.device, dtype=torch.float)
        self.rew_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.float)
        self.reset_buf = torch.ones(self.num_envs, device=self.device, dtype=torch.long)
        self.episode_length_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.long)
        
        self.actions = torch.zeros(self.num_envs, self.num_actions, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_sums = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_acts = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.extras = {}
    
    def para_update(self, para):
        self.parameter_random = para
        
    def step(self, actions):
        # actions clip
        soft_bound = [-0.5, 1.5]
        out_of_limits = -(actions - soft_bound[0]).clip(max=0.)
        out_of_limits += (actions - soft_bound[1]).clip(min=0.)
        scale_action = -0.1
        reward_action = scale_action * torch.sum(out_of_limits, dim=1).clip(max=1.).to(self.device)
        self.actions = torch.clip(actions, 0., 1.).to(self.device)

        # update actions & states
        b, p = self.states[:, -2] * self.B, self.states[:, -1]
        inv_c = self.cost_function(self.actions)
        b -= inv_c
        b = torch.clip(b, 0., self.B).to(self.device)
        mask = (b > 0).float().unsqueeze(-1)
        self.act = self.actions * mask
        inv_c = self.cost_function(self.act)
        next_state, reward_original = self.transition(self.act)
        self.extras['reward_original'] = reward_original
        self.extras['inv_cost'] = inv_c
        self.episode_length_buf += 1
        p = self.episode_length_buf / self.max_episode_length
        self.states = torch.cat([next_state / self.N, (b / self.B).unsqueeze(-1), p.unsqueeze(-1)], dim=-1)
        
        # check termination
        self.reset_buf = self.episode_length_buf >= self.max_episode_length
        
        # compute reward
        r_mean = -6584
        r_std  =  7347
        reward = (reward_original - inv_c - r_mean) / r_std
        #if reward > 0: 
        #reward = torch.exp(reward)/10
        #reward = torch.exp((1e5 + reward_original - inv_c) / 5e4)
        self.rew_buf       = reward + reward_action
        self.episode_sums += reward + reward_action
        self.episode_acts += reward_action
        
        # compute resets
        env_ids = self.reset_buf.nonzero(as_tuple=False).flatten()
        self.reset_idx(env_ids)
        
        # compute observations
        return self.get_observations(), self.states, self.rew_buf, self.reset_buf, self.extras

    def reset_idx(self, env_ids):
        """Reset selected robots"""
        if len(env_ids) == 0:
            return
        
        assert len(env_ids) == self.num_envs
        # reset robot states
        self.states[env_ids] = self.init_state
        # reset buffers
        self.episode_length_buf[env_ids] = 0
        self.reset_buf[env_ids] = 1
        # fill extras
        self.extras["episode"] = {}
        self.extras["episode"]['rew_sum'] = torch.mean(self.episode_sums[env_ids]) / (self.max_episode_length * ΔT)
        self.extras["episode"]['rew_act'] = torch.mean(self.episode_acts[env_ids]) / (self.max_episode_length * ΔT)
        self.episode_sums[env_ids] = 0.
        self.episode_acts[env_ids] = 0.
    
    def reset(self):
        """ Reset all robots"""
        self.reset_idx(torch.arange(self.num_envs, device=self.device))
        return {}, {}
    
    def get_observations(self):
        o_mean = torch.tensor([[0.58712867, 0.06804276, 0.00308146, 0.25684301, 0.00261079, 0.08229331, 0.26572794, 0.51      ]], dtype=torch.float32).to(torch.device(self.device))
        o_std  = torch.tensor([[0.41484398, 0.07883003, 0.00389494, 0.292568  , 0.00394907, 0.06906768, 0.33943075, 0.28861739]], dtype=torch.float32).to(torch.device(self.device))
        self.obs_buf = (self.states - o_mean) / o_std
        return self.obs_buf
    
    def get_privileged_observations(self):
        return self.privileged_obs_buf

    def cost_function(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]

        cost_it  = it * u_it * parameter_static['cost_ti']
        cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
        cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
        per_poc  = ((st + et + at + rt) / self.N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
        cost_poc = (st + et + rt + at) * w * per_poc
        return cost_poc + cost_it + cost_v + cost_q
        
    def transition(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
        ht = st + et + at + it + rt

        st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * self.parameter_random['beta1'] + (et + at * (1 - u_aq)) * self.parameter_random['beta2']) / ht
        st_out_e = st_out * self.parameter_random['alpha']
        st_out_i = st_out * (1 - self.parameter_random['alpha'])
        st_out_r = u_sv * parameter_static['v_max'] * st * parameter_static['psr']
        et_out_r = et * self.parameter_random['per']
        et_out_i = et * self.parameter_random['pei']
        et_out_a = et * w * (1 - self.parameter_random['per'] - self.parameter_random['pei'])
        at_out_i = at * self.parameter_random['pei']
        at_out_r = at * self.parameter_random['per']
        it_out_r = it * self.parameter_random['pir'] * u_it
        it_out_d = it * self.parameter_random['pid'] * (1 - u_it) + it * u_it * self.parameter_random['pid_plus']
        rt_out_s = rt * parameter_static['prs']
        
        stn = st - st_out_e - st_out_i - st_out_r + rt_out_s
        etn = et - et_out_r - et_out_i - et_out_a + st_out_e
        atn = at - at_out_r - at_out_i + et_out_a
        itn = it - it_out_r - it_out_d + st_out_i + et_out_i + at_out_i
        dtn = dt + it_out_d
        rtn = rt + et_out_r + at_out_r + it_out_r + st_out_r - rt_out_s

        reward = -2.6 * st_out - 100 * it_out_d

        next_state = torch.stack([stn, etn, atn, itn, dtn, rtn], dim=-1)
        return next_state, reward

# %%
import inspect

class BaseConfig:
    def __init__(self) -> None:
        """ Initializes all member classes recursively. Ignores all namse starting with '__' (buit-in methods)."""
        self.init_member_classes(self)
    
    @staticmethod
    def init_member_classes(obj):
        # iterate over all attributes names
        for key in dir(obj):
            # disregard builtin attributes
            # if key.startswith("__"):
            if key=="__class__":
                continue
            # get the corresponding attribute object
            var =  getattr(obj, key)
            # check if it the attribute is a class
            if inspect.isclass(var):
                # instantate the class
                i_var = var()
                # set the attribute to the instance instead of the type
                setattr(obj, key, i_var)
                # recursively init members of the attribute
                BaseConfig.init_member_classes(i_var)

class LeggedRobotCfgPPO(BaseConfig):
    seed = 1
    runner_class_name = 'OnPolicyRunner'
    class policy:
        init_noise_std = 2
        actor_hidden_dims  = [64, 32, 16] 
        critic_hidden_dims = [64, 32, 16]
        activation = 'elu' # can be elu, relu, selu, crelu, lrelu, tanh, sigmoid
        # only for 'ActorCriticRecurrent':
        # rnn_type = 'lstm'
        # rnn_hidden_size = 512
        # rnn_num_layers = 1
        
    class algorithm:
        # training params
        value_loss_coef = 0.5
        use_clipped_value_loss = True
        clip_param = 0.2
        entropy_coef = 0.01
        num_learning_epochs = 5
        num_mini_batches = 64 # mini batch size = num_envs*nsteps / nminibatches
        learning_rate = 1.e-4
        schedule = 'adaptive' # could be adaptive, fixed
        gamma = 0.99
        lam = 0.95
        desired_kl = 0.01
        max_grad_norm = 1.

    class runner:
        policy_class_name = 'ActorCritic'
        algorithm_class_name = 'PPO'
        num_steps_per_env =  150 # per iteration
        max_iterations    = 100 # number of policy updates

        # logging
        save_interval = 100 # check for potential saves every this many iterations
        experiment_name = 'test'
        run_name = ''
        # load and resume
        resume = True
        load_run = -1 # -1 = last run
        checkpoint = -1 # -1 = last saved model
        resume_path = None # updated from load_run and chkpt
        
def class_to_dict(obj) -> dict:
    if not  hasattr(obj,"__dict__"):
        return obj
    result = {}
    for key in dir(obj):
        if key.startswith("_"):
            continue
        element = []
        val = getattr(obj, key)
        if isinstance(val, list):
            for item in val:
                element.append(class_to_dict(item))
        else:
            element = class_to_dict(val)
        result[key] = element
    return result

# %%
def para_sampling(intvl, num_sample=N_envs):
    parameter_random = {
        key: torch.empty(num_sample).normal_(
        intvl[key][0],
        intvl[key][1]
        ).to(torch.device(device))
        for key, value in Random_mean.items()
    }
    for key, value in Random_mean.items():
        indice = parameter_random[key] < 0
        parameter_random[key][indice] = -parameter_random[key][indice] 
    return parameter_random

def update_space(final_indices, para_buf, space):
    para_est = {}
    for key, tensor_values in para_buf.items():
        selected_values = torch.mean(tensor_values[final_indices[0], final_indices[1]]) 
        para_values = torch.mean(tensor_values[final_indices[0], final_indices[1]], dim=0)
        update_values = space[key][0] + 0.5 * (selected_values - space[key][0])
        space[key] = [update_values , update_values  * 0.1]
        para_est[key] = para_values
    return space, para_est


def cal_err(para_value, env_para):
    gap = []
    for key, value in env_para.items():
        gap_temp = torch.mean(torch.abs(para_value[key] - env_para[key])/(env_para[key]))
        gap.append(gap_temp)
    return sum(gap)/len(gap) # 所有值都在范围内，返回 0
    
def state_estimator(env_sample, action_sim, state_sim, state_prior, space, iter): 
    env_sample.reset()
    env_sample.states = state_prior  
    para_buf, mse_buf, obs_buf, states_buf = {}, {}, {}, {}
    for i in range(iter):
        para = para_sampling(space, test_num)
        env_sample.para_update(para)
        obs_sample, states_sample, _, _, _ = env_sample.step(action_sim.detach())  
        mse = torch.mean((state_sim[:,2:4] - states_sample[:,2:4]) ** 2, dim=1) 
        if i == 0:
            mse_buf = mse.unsqueeze(0)
            obs_buf = obs_sample.unsqueeze(0)
            states_buf = states_sample.unsqueeze(0)
            for key, values in para.items():
                para_buf[key] = para[key].unsqueeze(0)
        else:
            mse_buf = torch.cat((mse_buf, mse.unsqueeze(0)), dim=0)
            obs_buf = torch.cat((obs_buf, obs_sample.unsqueeze(0)),dim=0)
            states_buf = torch.cat((states_buf, states_sample.unsqueeze(0)), dim=0)
            for key, values in para.items():
                para_buf[key] = torch.cat((para_buf[key], para[key].unsqueeze(0)), dim=0)
                
     
    k = int(iter * 0.05)
    _, row_indices = torch.topk(mse_buf, k=k, dim=0, largest=False)
    column_indices = torch.arange(mse_buf.shape[1]).repeat(k, 1)
    top_indices = [row_indices, column_indices]
    obs_est = torch.mean(obs_buf[row_indices,column_indices,:], dim=0)
    state_est = torch.mean(states_buf[row_indices,column_indices,:], dim=0)
    state_est[:,-1] = state_prior[:,-1] + torch.tensor(1/T)
    return obs_est, state_est, top_indices, para_buf

# %%
para_err = 0.5
torch.manual_seed(seed)
para_true = []
para_temp = {
    key: torch.empty(test_num).uniform_(
        value * (1-para_err),
        value * (1+para_err)
    ).to(torch.device(device))
    for key, value in Random_mean.items()
}


para = {}
for t in range(T):
    para = {
        key: (para_temp[key] - para_temp[key] * torch.sin(torch.tensor(t/(3.1415926 * 3))) * 0.25).to(torch.device(device))
        for key, value in Random_mean.items()
        }
    para_true.append(para)

# %%
env = myVecEnv(space, test_num)
env.para_update(para_true[0])
train_cfg = LeggedRobotCfgPPO()
train_cfg_dict = class_to_dict(train_cfg)


env_transfer = myVecEnv(space)
runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_test_more_para', device=env.device)
runner.load(f'rsl_output_main/model_100.pt')

policy = runner.get_inference_policy(device=env.device)

reward_history = []
act_buf = []
state_his_buf = []
death_buf = []

env_sample = myVecEnv(space, test_num)
state_est = env.states
obs_est = env.get_observations()
for t in range(T-1):
    actions = policy(obs_est.detach())
    obs, states, _, _, infos = env.step(actions.detach())
    reward_history.append((-infos['reward_original'] + infos['inv_cost']).tolist())
    death_buf.append((-infos['reward_original']).tolist())
    act_buf.append(env.act)
    state_his_buf.append(env.states)
    obs_est, state_buf, top_indices, para_buf = state_estimator(env_sample, actions, states, state_est, space, 1024)
    space, para_v = update_space(top_indices, para_buf, space) 

    runner.learn(num_learning_iterations=25, init_at_random_ep_len=False)
    policy = runner.get_inference_policy(device=env.device)
    env_transfer = myVecEnv(space)
    runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_test_more_para', device=env.device)
    runner.load(f'rsl_test_more_para/model_{int(t)* 25}.pt')


    if t < T - 1: env.para_update(para_true[t + 1])
    print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
env.reset()

reward_history = np.array(reward_history)
print(f'score     : {np.sum(reward_history, axis=0)/T       }')
print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
# Out:
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2294402 steps/s (collection: 0.678s, learning 3.606s)
#                Value function loss: 142.5070
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.63
#                        Mean reward: 45.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4640
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.28s
#                         Total time: 4.28s
#                                ETA: 107.1s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2380251 steps/s (collection: 0.653s, learning 3.477s)
#                Value function loss: 147.5686
#                     Surrogate loss: 0.0009
#              Mean action noise std: 4.69
#                        Mean reward: 46.06
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7656
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.13s
#                         Total time: 8.41s
#                                ETA: 101.0s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2381984 steps/s (collection: 0.647s, learning 3.480s)
#                Value function loss: 132.6767
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.75
#                        Mean reward: 45.60
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7653
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.13s
#                         Total time: 12.54s
#                                ETA: 96.2s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2379699 steps/s (collection: 0.642s, learning 3.489s)
#                Value function loss: 135.5478
#                     Surrogate loss: 0.0005
#              Mean action noise std: 4.80
#                        Mean reward: 45.79
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7648
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.13s
#                         Total time: 16.67s
#                                ETA: 91.7s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2383706 steps/s (collection: 0.640s, learning 3.484s)
#                Value function loss: 126.2812
#                     Surrogate loss: 0.0003
#              Mean action noise std: 4.87
#                        Mean reward: 45.90
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7637
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.12s
#                         Total time: 20.80s
#                                ETA: 87.3s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2364266 steps/s (collection: 0.653s, learning 3.505s)
#                Value function loss: 126.9938
#                     Surrogate loss: 0.0003
#              Mean action noise std: 4.93
#                        Mean reward: 46.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7617
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.16s
#                         Total time: 24.95s
#                                ETA: 83.2s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2404055 steps/s (collection: 0.631s, learning 3.458s)
#                Value function loss: 118.4077
#                     Surrogate loss: 0.0003
#              Mean action noise std: 4.99
#                        Mean reward: 45.42
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7608
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.09s
#                         Total time: 29.04s
#                                ETA: 78.8s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2409356 steps/s (collection: 0.637s, learning 3.443s)
#                Value function loss: 121.0658
#                     Surrogate loss: 0.0020
#              Mean action noise std: 5.06
#                        Mean reward: 45.83
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7608
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.08s
#                         Total time: 33.12s
#                                ETA: 74.5s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2404657 steps/s (collection: 0.638s, learning 3.450s)
#                Value function loss: 114.1885
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.13
#                        Mean reward: 45.32
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7598
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.09s
#                         Total time: 37.21s
#                                ETA: 70.3s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2421777 steps/s (collection: 0.639s, learning 3.420s)
#                Value function loss: 115.8089
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.20
#                        Mean reward: 45.38
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7597
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.06s
#                         Total time: 41.27s
#                                ETA: 66.0s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2419430 steps/s (collection: 0.637s, learning 3.426s)
#                Value function loss: 110.3607
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.27
#                        Mean reward: 45.44
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7596
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.06s
#                         Total time: 45.33s
#                                ETA: 61.8s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2417617 steps/s (collection: 0.642s, learning 3.424s)
#                Value function loss: 110.7426
#                     Surrogate loss: 0.0019
#              Mean action noise std: 5.34
#                        Mean reward: 45.74
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7592
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.07s
#                         Total time: 49.40s
#                                ETA: 57.6s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2404087 steps/s (collection: 0.651s, learning 3.438s)
#                Value function loss: 106.4970
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.41
#                        Mean reward: 45.60
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7583
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.09s
#                         Total time: 53.49s
#                                ETA: 53.5s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2414060 steps/s (collection: 0.643s, learning 3.429s)
#                Value function loss: 109.4525
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.48
#                        Mean reward: 45.43
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7590
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.07s
#                         Total time: 57.56s
#                                ETA: 49.3s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2397059 steps/s (collection: 0.673s, learning 3.428s)
#                Value function loss: 111.8158
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.56
#                        Mean reward: 45.71
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7612
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.10s
#                         Total time: 61.66s
#                                ETA: 45.2s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2419416 steps/s (collection: 0.637s, learning 3.426s)
#                Value function loss: 126.7897
#                     Surrogate loss: 0.0007
#              Mean action noise std: 5.63
#                        Mean reward: 45.44
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7619
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.06s
#                         Total time: 65.73s
#                                ETA: 41.1s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2340130 steps/s (collection: 0.649s, learning 3.552s)
#                Value function loss: 129.5788
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.70
#                        Mean reward: 45.38
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7605
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.20s
#                         Total time: 69.93s
#                                ETA: 37.0s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2300815 steps/s (collection: 0.663s, learning 3.609s)
#                Value function loss: 145.4075
#                     Surrogate loss: 0.0009
#              Mean action noise std: 5.78
#                        Mean reward: 45.38
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7589
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.27s
#                         Total time: 74.20s
#                                ETA: 33.0s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2319206 steps/s (collection: 0.635s, learning 3.603s)
#                Value function loss: 144.4445
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.86
#                        Mean reward: 45.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7584
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.24s
#                         Total time: 78.44s
#                                ETA: 28.9s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2317025 steps/s (collection: 0.639s, learning 3.603s)
#                Value function loss: 161.1230
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.92
#                        Mean reward: 45.63
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7581
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.24s
#                         Total time: 82.68s
#                                ETA: 24.8s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2330737 steps/s (collection: 0.633s, learning 3.584s)
#                Value function loss: 154.8712
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.99
#                        Mean reward: 45.76
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7573
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.22s
#                         Total time: 86.90s
#                                ETA: 20.7s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2305644 steps/s (collection: 0.650s, learning 3.613s)
#                Value function loss: 174.4416
#                     Surrogate loss: 0.0007
#              Mean action noise std: 6.05
#                        Mean reward: 45.44
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7569
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.26s
#                         Total time: 91.16s
#                                ETA: 16.6s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2325238 steps/s (collection: 0.636s, learning 3.591s)
#                Value function loss: 166.8289
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.13
#                        Mean reward: 45.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7593
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.23s
#                         Total time: 95.39s
#                                ETA: 12.4s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2324674 steps/s (collection: 0.642s, learning 3.586s)
#                Value function loss: 192.8649
#                     Surrogate loss: 0.0005
#              Mean action noise std: 6.19
#                        Mean reward: 45.91
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7625
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.23s
#                         Total time: 99.62s
#                                ETA: 8.3s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2352411 steps/s (collection: 0.676s, learning 3.503s)
#                Value function loss: 181.8571
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.27
#                        Mean reward: 45.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7654
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.18s
#                         Total time: 103.80s
#                                ETA: 4.2s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 3.0514750366210937
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2337352 steps/s (collection: 0.719s, learning 3.487s)
#                Value function loss: 131.6456
#                     Surrogate loss: 0.0027
#              Mean action noise std: 4.70
#                        Mean reward: 44.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4359
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.21s
#                         Total time: 4.21s
#                                ETA: 105.1s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2380821 steps/s (collection: 0.636s, learning 3.493s)
#                Value function loss: 136.9544
#                     Surrogate loss: 0.0040
#              Mean action noise std: 4.77
#                        Mean reward: 44.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7179
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.13s
#                         Total time: 8.33s
#                                ETA: 100.0s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2369966 steps/s (collection: 0.653s, learning 3.495s)
#                Value function loss: 128.9314
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.83
#                        Mean reward: 43.45
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7161
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.15s
#                         Total time: 12.48s
#                                ETA: 95.7s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2370520 steps/s (collection: 0.649s, learning 3.498s)
#                Value function loss: 137.6627
#                     Surrogate loss: 0.0003
#              Mean action noise std: 4.88
#                        Mean reward: 43.28
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7164
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.15s
#                         Total time: 16.63s
#                                ETA: 91.5s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2376831 steps/s (collection: 0.639s, learning 3.497s)
#                Value function loss: 131.6738
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.95
#                        Mean reward: 43.76
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7196
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.14s
#                         Total time: 20.77s
#                                ETA: 87.2s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2372802 steps/s (collection: 0.643s, learning 3.500s)
#                Value function loss: 140.4173
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.02
#                        Mean reward: 44.63
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7199
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.14s
#                         Total time: 24.91s
#                                ETA: 83.0s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2419411 steps/s (collection: 0.639s, learning 3.424s)
#                Value function loss: 134.7849
#                     Surrogate loss: 0.0018
#              Mean action noise std: 5.04
#                        Mean reward: 44.31
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7213
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.06s
#                         Total time: 28.97s
#                                ETA: 78.6s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2398805 steps/s (collection: 0.670s, learning 3.428s)
#                Value function loss: 144.6826
#                     Surrogate loss: 0.0018
#              Mean action noise std: 5.12
#                        Mean reward: 43.68
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7206
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.10s
#                         Total time: 33.07s
#                                ETA: 74.4s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2411125 steps/s (collection: 0.650s, learning 3.427s)
#                Value function loss: 137.9728
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.19
#                        Mean reward: 43.57
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7189
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.08s
#                         Total time: 37.15s
#                                ETA: 70.2s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2401143 steps/s (collection: 0.651s, learning 3.443s)
#                Value function loss: 150.7724
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.27
#                        Mean reward: 43.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7198
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.09s
#                         Total time: 41.24s
#                                ETA: 66.0s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2409953 steps/s (collection: 0.654s, learning 3.425s)
#                Value function loss: 142.9349
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.34
#                        Mean reward: 44.06
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7197
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.08s
#                         Total time: 45.32s
#                                ETA: 61.8s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2415837 steps/s (collection: 0.648s, learning 3.421s)
#                Value function loss: 156.3711
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.42
#                        Mean reward: 44.09
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7189
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.07s
#                         Total time: 49.39s
#                                ETA: 57.6s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2415247 steps/s (collection: 0.644s, learning 3.426s)
#                Value function loss: 147.6172
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.48
#                        Mean reward: 43.32
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7182
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.07s
#                         Total time: 53.46s
#                                ETA: 53.5s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2399369 steps/s (collection: 0.650s, learning 3.447s)
#                Value function loss: 162.4660
#                     Surrogate loss: 0.0007
#              Mean action noise std: 5.56
#                        Mean reward: 43.57
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7184
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.10s
#                         Total time: 57.56s
#                                ETA: 49.3s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2425351 steps/s (collection: 0.636s, learning 3.417s)
#                Value function loss: 153.1788
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.64
#                        Mean reward: 43.67
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7203
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.05s
#                         Total time: 61.61s
#                                ETA: 45.2s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2423592 steps/s (collection: 0.639s, learning 3.417s)
#                Value function loss: 169.3204
#                     Surrogate loss: 0.0007
#              Mean action noise std: 5.71
#                        Mean reward: 43.91
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7199
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.06s
#                         Total time: 65.67s
#                                ETA: 41.0s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2415862 steps/s (collection: 0.654s, learning 3.415s)
#                Value function loss: 158.8048
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.79
#                        Mean reward: 42.79
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7184
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.07s
#                         Total time: 69.73s
#                                ETA: 36.9s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2409357 steps/s (collection: 0.649s, learning 3.431s)
#                Value function loss: 177.1844
#                     Surrogate loss: 0.0007
#              Mean action noise std: 5.87
#                        Mean reward: 43.64
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7200
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.08s
#                         Total time: 73.81s
#                                ETA: 32.8s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2418209 steps/s (collection: 0.650s, learning 3.415s)
#                Value function loss: 164.4198
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.95
#                        Mean reward: 44.30
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7219
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.07s
#                         Total time: 77.88s
#                                ETA: 28.7s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2409964 steps/s (collection: 0.654s, learning 3.425s)
#                Value function loss: 183.9677
#                     Surrogate loss: 0.0005
#              Mean action noise std: 6.02
#                        Mean reward: 44.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7228
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.08s
#                         Total time: 81.96s
#                                ETA: 24.6s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2419397 steps/s (collection: 0.650s, learning 3.413s)
#                Value function loss: 170.8951
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.09
#                        Mean reward: 44.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7233
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.06s
#                         Total time: 86.02s
#                                ETA: 20.5s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2398205 steps/s (collection: 0.678s, learning 3.421s)
#                Value function loss: 191.7144
#                     Surrogate loss: 0.0005
#              Mean action noise std: 6.16
#                        Mean reward: 44.50
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7221
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.10s
#                         Total time: 90.12s
#                                ETA: 16.4s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2407574 steps/s (collection: 0.662s, learning 3.421s)
#                Value function loss: 176.4988
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.22
#                        Mean reward: 44.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7207
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.08s
#                         Total time: 94.20s
#                                ETA: 12.3s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2418819 steps/s (collection: 0.654s, learning 3.410s)
#                Value function loss: 198.4272
#                     Surrogate loss: 0.0007
#              Mean action noise std: 6.30
#                        Mean reward: 44.06
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7205
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.06s
#                         Total time: 98.27s
#                                ETA: 8.2s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2425367 steps/s (collection: 0.641s, learning 3.412s)
#                Value function loss: 182.0411
#                     Surrogate loss: 0.0018
#              Mean action noise std: 6.38
#                        Mean reward: 44.10
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7217
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.05s
#                         Total time: 102.32s
#                                ETA: 4.1s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 5.772328285217285
# ################################################################################
#                         Learning iteration 25/50
#
#                        Computation: 2404049 steps/s (collection: 0.674s, learning 3.415s)
#                Value function loss: 182.7519
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.46
#                        Mean reward: 43.94
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4370
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.09s
#                         Total time: 4.09s
#                                ETA: 0.0s
#
# ################################################################################
#                         Learning iteration 26/50
#
#                        Computation: 2422965 steps/s (collection: 0.646s, learning 3.411s)
#                Value function loss: 211.4123
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.54
#                        Mean reward: 44.25
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7216
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.06s
#                         Total time: 8.15s
#                                ETA: -0.3s
#
# ################################################################################
#                         Learning iteration 27/50
#
#                        Computation: 2412895 steps/s (collection: 0.654s, learning 3.420s)
#                Value function loss: 197.3922
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.61
#                        Mean reward: 43.87
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7254
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.07s
#                         Total time: 12.22s
#                                ETA: -0.9s
#
# ################################################################################
#                         Learning iteration 28/50
#
#                        Computation: 2401726 steps/s (collection: 0.678s, learning 3.415s)
#                Value function loss: 227.6490
#                     Surrogate loss: 0.0011
#              Mean action noise std: 6.69
#                        Mean reward: 43.52
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7253
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.09s
#                         Total time: 16.31s
#                                ETA: -1.7s
#
# ################################################################################
#                         Learning iteration 29/50
#
#                        Computation: 2429550 steps/s (collection: 0.638s, learning 3.408s)
#                Value function loss: 206.5947
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.78
#                        Mean reward: 43.89
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7264
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.05s
#                         Total time: 20.36s
#                                ETA: -2.7s
#
# ################################################################################
#                         Learning iteration 30/50
#
#                        Computation: 2414081 steps/s (collection: 0.658s, learning 3.414s)
#                Value function loss: 235.8843
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.85
#                        Mean reward: 44.67
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7254
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.07s
#                         Total time: 24.43s
#                                ETA: -3.9s
#
# ################################################################################
#                         Learning iteration 31/50
#
#                        Computation: 2425366 steps/s (collection: 0.638s, learning 3.415s)
#                Value function loss: 213.0595
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.95
#                        Mean reward: 44.48
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7273
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.05s
#                         Total time: 28.48s
#                                ETA: -5.3s
#
# ################################################################################
#                         Learning iteration 32/50
#
#                        Computation: 2414081 steps/s (collection: 0.662s, learning 3.410s)
#                Value function loss: 247.5981
#                     Surrogate loss: 0.0006
#              Mean action noise std: 7.02
#                        Mean reward: 44.10
# ...
#                    Total timesteps: 78643200
#                     Iteration time: 4.13s
#                         Total time: 33.15s
#                                ETA: -32.5s
#
# ################################################################################
#                       Learning iteration 1433/1450
#
#                        Computation: 2398222 steps/s (collection: 0.670s, learning 3.429s)
#                Value function loss: 644.4221
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3274.92
#                        Mean reward: 46.59
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7713
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.10s
#                         Total time: 37.25s
#                                ETA: -36.6s
#
# ################################################################################
#                       Learning iteration 1434/1450
#
#                        Computation: 2408771 steps/s (collection: 0.656s, learning 3.425s)
#                Value function loss: 806.6789
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3278.04
#                        Mean reward: 46.61
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7716
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.08s
#                         Total time: 41.33s
#                                ETA: -40.6s
#
# ################################################################################
#                       Learning iteration 1435/1450
#
#                        Computation: 2375651 steps/s (collection: 0.669s, learning 3.469s)
#                Value function loss: 648.2493
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3280.95
#                        Mean reward: 46.57
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7714
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.14s
#                         Total time: 45.47s
#                                ETA: -44.6s
#
# ################################################################################
#                       Learning iteration 1436/1450
#
#                        Computation: 2371662 steps/s (collection: 0.710s, learning 3.435s)
#                Value function loss: 809.0976
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3283.83
#                        Mean reward: 46.32
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7710
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.14s
#                         Total time: 49.61s
#                                ETA: -48.7s
#
# ################################################################################
#                       Learning iteration 1437/1450
#
#                        Computation: 2408195 steps/s (collection: 0.661s, learning 3.421s)
#                Value function loss: 650.6409
#                     Surrogate loss: 0.0003
#              Mean action noise std: 3286.69
#                        Mean reward: 46.33
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7715
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.08s
#                         Total time: 53.69s
#                                ETA: -52.7s
#
# ################################################################################
#                       Learning iteration 1438/1450
#
#                        Computation: 2377950 steps/s (collection: 0.696s, learning 3.438s)
#                Value function loss: 822.1754
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3289.61
#                        Mean reward: 46.39
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7717
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.13s
#                         Total time: 57.83s
#                                ETA: -56.8s
#
# ################################################################################
#                       Learning iteration 1439/1450
#
#                        Computation: 2409343 steps/s (collection: 0.653s, learning 3.427s)
#                Value function loss: 642.0091
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3292.56
#                        Mean reward: 46.55
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7708
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.08s
#                         Total time: 61.91s
#                                ETA: -60.8s
#
# ################################################################################
#                       Learning iteration 1440/1450
#
#                        Computation: 2349613 steps/s (collection: 0.704s, learning 3.480s)
#                Value function loss: 793.2249
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3295.43
#                        Mean reward: 46.46
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7705
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.18s
#                         Total time: 66.09s
#                                ETA: -64.9s
#
# ################################################################################
#                       Learning iteration 1441/1450
#
#                        Computation: 2395308 steps/s (collection: 0.649s, learning 3.455s)
#                Value function loss: 571.7507
#                     Surrogate loss: 0.0003
#              Mean action noise std: 3298.22
#                        Mean reward: 46.36
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7711
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.10s
#                         Total time: 70.19s
#                                ETA: -68.9s
#
# ################################################################################
#                       Learning iteration 1442/1450
#
#                        Computation: 2401721 steps/s (collection: 0.658s, learning 3.435s)
#                Value function loss: 702.9544
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3301.21
#                        Mean reward: 46.35
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7716
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.09s
#                         Total time: 74.29s
#                                ETA: -72.9s
#
# ################################################################################
#                       Learning iteration 1443/1450
#
#                        Computation: 2404654 steps/s (collection: 0.652s, learning 3.436s)
#                Value function loss: 565.3015
#                     Surrogate loss: 0.0002
#              Mean action noise std: 3304.17
#                        Mean reward: 46.53
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7720
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.09s
#                         Total time: 78.38s
#                                ETA: -77.0s
#
# ################################################################################
#                       Learning iteration 1444/1450
#
#                        Computation: 2383121 steps/s (collection: 0.702s, learning 3.423s)
#                Value function loss: 706.0146
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3307.01
#                        Mean reward: 46.43
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7724
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.13s
#                         Total time: 82.50s
#                                ETA: -81.0s
#
# ################################################################################
#                       Learning iteration 1445/1450
#
#                        Computation: 2402896 steps/s (collection: 0.655s, learning 3.436s)
#                Value function loss: 567.8525
#                     Surrogate loss: 0.0004
#              Mean action noise std: 3309.81
#                        Mean reward: 46.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7725
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.09s
#                         Total time: 86.59s
#                                ETA: -85.0s
#
# ################################################################################
#                       Learning iteration 1446/1450
#
#                        Computation: 2402884 steps/s (collection: 0.652s, learning 3.439s)
#                Value function loss: 712.2418
#                     Surrogate loss: 0.0002
#              Mean action noise std: 3312.74
#                        Mean reward: 46.71
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7735
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.09s
#                         Total time: 90.68s
#                                ETA: -89.1s
#
# ################################################################################
#                       Learning iteration 1447/1450
#
#                        Computation: 2405242 steps/s (collection: 0.652s, learning 3.435s)
#                Value function loss: 572.1245
#                     Surrogate loss: 0.0008
#              Mean action noise std: 3315.41
#                        Mean reward: 46.76
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7743
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.09s
#                         Total time: 94.77s
#                                ETA: -93.1s
#
# ################################################################################
#                       Learning iteration 1448/1450
#
#                        Computation: 2377974 steps/s (collection: 0.702s, learning 3.432s)
#                Value function loss: 715.3114
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3318.33
#                        Mean reward: 46.69
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7741
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.13s
#                         Total time: 98.90s
#                                ETA: -97.1s
#
# ################################################################################
#                       Learning iteration 1449/1450
#
#                        Computation: 2399991 steps/s (collection: 0.666s, learning 3.430s)
#                Value function loss: 572.4951
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3321.27
#                        Mean reward: 46.55
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7732
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.10s
#                         Total time: 103.00s
#                                ETA: -101.2s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 910.7923412437807
# score     : [2683.86356239  427.19189233   68.82957921  104.85357376  110.27221828
#    70.13828564 3022.76731913 5994.66159225   74.6945069  2045.3587997
#    69.44721193  146.78365511   66.71911708  124.69743189   61.06791107
#    67.24642316 1551.10834374 1159.8246207    61.06643375  884.05285897
#   420.35423193  110.40288645   74.44570364 4681.8085007   538.83783998
#    59.47448527 2914.11823156   62.06705289   58.98507337  198.86213774
#    68.36973771 4850.53196078   74.49866107   62.14486692   72.42038503
#    59.00588106   62.44735056  154.53094537 3195.91740431   84.28975823
#    78.78165908   60.60678765   74.65800089   62.09437239   60.64828467
#   125.70507908   75.97127755 4610.58775851   70.68098061   65.55626145
#  5148.47296987 5448.59851284 4840.73525938 1297.45203577  472.09686298
#    90.9703411  3256.94972764   58.74554702   64.09577613   74.92795796
#    86.75907444   70.43143253   63.85192416   61.35359221 1721.66926003
#   361.96605031  317.74074843   65.27116382   71.47002374  257.8904378
#   107.95826548  531.04541714 6016.57688605 1075.51866874 4893.87230132
#   501.59224377   61.17152808   67.69057384   60.64393012   64.58972413
#    63.74537529  582.42767401  163.23237072   61.15003528  316.55955125
#   229.01787042  636.47226012   74.21189351  746.1275557    62.37890088
#  1047.53896955 2668.3693083  4476.18829424   91.05084393   78.85042316
#    65.57496704   66.71800265  288.69584436   72.90277132  192.46408236]
# score.mean: 910.7923412437807

# %%
a = np.sum(reward_history, axis=0)/T

# %%
min(a)
# Out:
# 58.74554702378809

# %%
max(a)
# Out:
# 6016.576886051893

# %%
np.std(a)
# Out:
# 1586.1799758081038

# %%
exp_result = {
    'reward_total': reward_history,
    'reward_peo': death_buf,
    'state': state_his_buf,
    'action': act_buf
}

# %%
torch.save(exp_result, 'more_para_result.pt')

# %%
for i in range(T-1):
    print(torch.mean(act_buf[i], dim=0))
# Out:
# tensor([0.00000, 0.00000, 1.00000, 0.80719, 1.00000], device='cuda:0')
# tensor([0.00000, 0.93121, 1.00000, 1.00000, 1.00000], device='cuda:0')
# tensor([0.00000, 0.94987, 1.00000, 1.00000, 1.00000], device='cuda:0')
# tensor([0.00000, 1.00000, 1.00000, 1.00000, 0.09498], device='cuda:0')
# tensor([0.00000, 0.39397, 1.00000, 1.00000, 0.50616], device='cuda:0')
# tensor([0.00000, 1.00000, 1.00000, 1.00000, 0.42892], device='cuda:0')
# tensor([0.00000, 1.00000, 1.00000, 1.00000, 0.57000], device='cuda:0')
# tensor([0.00000, 1.00000, 1.00000, 1.00000, 0.43000], device='cuda:0')
# tensor([0.00000, 1.00000, 1.00000, 1.00000, 0.74057], device='cuda:0')
# tensor([0.00000, 1.00000, 1.00000, 1.00000, 0.70698], device='cuda:0')
# tensor([0.00000, 1.00000, 1.00000, 1.00000, 0.70000], device='cuda:0')
# tensor([0.00000, 1.00000, 1.00000, 1.00000, 0.57000], device='cuda:0')
# tensor([0.00000, 0.57000, 1.00000, 1.00000, 0.61000], device='cuda:0')
# tensor([0.00000, 0.61000, 1.00000, 1.00000, 0.79000], device='cuda:0')
# tensor([0.00000, 0.79000, 1.00000, 1.00000, 0.60641], device='cuda:0')
# tensor([0.00000, 0.94000, 1.00000, 1.00000, 0.42000], device='cuda:0')
# tensor([0.00000, 0.96000, 1.00000, 1.00000, 0.58000], device='cuda:0')
# tensor([0.00000, 0.95000, 1.00000, 1.00000, 0.42000], device='cuda:0')
# tensor([0.00000, 0.97000, 1.00000, 1.00000, 0.59000], device='cuda:0')
# tensor([0.00000, 0.91000, 1.00000, 1.00000, 0.41000], device='cuda:0')
# tensor([0.00000, 0.94000, 1.00000, 1.00000, 0.76000], device='cuda:0')
# tensor([0.00000, 0.84000, 1.00000, 1.00000, 0.25000], device='cuda:0')
# tensor([0.00000, 0.89000, 1.00000, 1.00000, 0.76000], device='cuda:0')
# tensor([0.00000, 0.55000, 1.00000, 1.00000, 0.25000], device='cuda:0')
# tensor([0.00000, 0.85000, 1.00000, 1.00000, 0.76000], device='cuda:0')
# tensor([0.00000, 0.50000, 1.00000, 1.00000, 0.25000], device='cuda:0')
# tensor([0.00000, 0.86000, 1.00000, 1.00000, 0.76000], device='cuda:0')
# tensor([0.00000, 0.44000, 1.00000, 1.00000, 0.25000], device='cuda:0')
# tensor([0.00000, 0.86000, 1.00000, 1.00000, 0.75000], device='cuda:0')
# tensor([0.00000, 0.35000, 1.00000, 1.00000, 0.25000], device='cuda:0')
# tensor([0.00000, 0.81000, 1.00000, 1.00000, 0.75000], device='cuda:0')
# tensor([0.00000, 0.34000, 0.99000, 0.99000, 0.24000], device='cuda:0')
# tensor([0.00000, 0.80000, 0.99000, 0.99000, 0.75000], device='cuda:0')
# tensor([0.00000, 0.26000, 0.99000, 0.99000, 0.24000], device='cuda:0')
# tensor([0.00000, 0.78000, 0.99000, 0.99000, 0.75000], device='cuda:0')
# tensor([0.00000, 0.24000, 0.99000, 0.99000, 0.24000], device='cuda:0')
# tensor([0.00000, 0.75000, 0.99000, 0.99000, 0.75000], device='cuda:0')
# tensor([0.00000, 0.24000, 0.99000, 0.99000, 0.24000], device='cuda:0')
# tensor([0.03000, 0.76000, 0.99000, 0.99000, 0.75000], device='cuda:0')
# tensor([0.00000, 0.24000, 0.99000, 0.99000, 0.24000], device='cuda:0')
# tensor([0.03000, 0.68000, 0.89000, 0.89000, 0.70000], device='cuda:0')
# tensor([0.27000, 0.19000, 0.74000, 0.74000, 0.40000], device='cuda:0')
# tensor([0.01000, 0.49000, 0.63000, 0.63000, 0.24000], device='cuda:0')
# tensor([0.00000, 0.23000, 0.45000, 0.45000, 0.36000], device='cuda:0')
# tensor([0.00000, 0.19000, 0.36000, 0.36000, 0.10000], device='cuda:0')
# tensor([0.00000, 0.12000, 0.17000, 0.17000, 0.07000], device='cuda:0')
# tensor([0.00000, 0.00000, 0.03000, 0.03000, 0.00000], device='cuda:0')
# tensor([0., 0., 0., 0., 0.], device='cuda:0')
# tensor([0., 0., 0., 0., 0.], device='cuda:0')
# tensor([0., 0., 0., 0., 0.], device='cuda:0')
# tensor([0., 0., 0., 0., 0.], device='cuda:0')
# tensor([0., 0., 0., 0., 0.], device='cuda:0')
# tensor([0., 0., 0., 0., 0.], device='cuda:0')
# tensor([0., 0., 0., 0., 0.], device='cuda:0')
# tensor([0., 0., 0., 0., 0.], device='cuda:0')
# tensor([0., 0., 0., 0., 0.], device='cuda:0')
# tensor([0., 0., 0., 0., 0.], device='cuda:0')
# tensor([0., 0., 0., 0., 0.], device='cuda:0')
# tensor([0., 0., 0., 0., 0.], device='cuda:0')
