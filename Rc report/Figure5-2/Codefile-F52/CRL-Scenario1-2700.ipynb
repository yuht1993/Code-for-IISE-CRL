# %%
from rsl_rl.env import VecEnv
from rsl_rl.runners import OnPolicyRunner
import torch
import numpy as np
torch.set_printoptions(precision=5, linewidth=200, sci_mode=False)

N          = 100020
state_dim  = 8
action_dim = 5
T          = 60
budget     = 2700.
N_envs     = 1024 * 64
ΔT         = 1.0
device     = 'cuda'
usr_std = 0.1
test_num = 100
seed = 0

parameter_static = dict(N          = N,
                        B          = budget,
                        T          = T,
                        alpha      = 0.6,
                        v_max      = 0.2/14,
                        cost_ti    = 0.0977,
                        cost_ta    = 0.02,
                        cost_v     = 0.07,
                        cost_poc_0 = 0.000369,
                        cost_poc_1 = 0.001057,
                        pid        = 1.10/1000,
                        psr        = 0.7,
                        pid_plus   = 0.1221/1000,
                        pir        = 1/8,
                        prs        = 1/7)

Random_mean = {"beta2" : 0.78735,
               "beta1" : 0.15747,
               "pei"   : 0.10714,
               "per"   : 0.04545}

space = {"beta2" : [Random_mean['beta2'],Random_mean['beta2']*usr_std],
         "beta1" : [Random_mean['beta1'], Random_mean['beta1']*usr_std],
         "pei"   : [Random_mean['pei'], Random_mean['pei']*usr_std],
         "per"   : [Random_mean['per'], Random_mean['per']*usr_std]}

Init_state = torch.tensor([[100000 / N, 20 / N, 0, 0, 0, 0, 1, 0]], 
                         dtype=torch.float32).to(torch.device(device))

# %%
class myVecEnv(VecEnv):
    def __init__(self, interval, n_envs = N_envs):
        self.B = parameter_static['B']  # total budget
        self.N = parameter_static['N']
        self.device = device
        self.init_state = Init_state
        self.states = self.init_state.repeat(n_envs, 1)
        self.num_envs = n_envs
        self.num_obs = state_dim
        self.num_privileged_obs = None
        self.num_actions = action_dim
        self.max_episode_length = parameter_static['T']
        
        torch.manual_seed(seed)
        self.parameter_random = {
            key: torch.empty(self.num_envs).normal_(
                interval[key][0],
                interval[key][1]
            ).to(torch.device(device))
            for key, value in Random_mean.items()
        }

        for key, value in Random_mean.items():
            indice = self.parameter_random[key] < 0
            self.parameter_random[key][indice] = -self.parameter_random[key][indice] 

        # optimization flags for pytorch JIT
        torch._C._jit_set_profiling_mode(False)
        torch._C._jit_set_profiling_executor(False)
        
        # allocate buffers
        self.privileged_obs_buf = None
        self.obs_buf = torch.zeros(self.num_envs, self.num_obs, device=self.device, dtype=torch.float)
        self.rew_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.float)
        self.reset_buf = torch.ones(self.num_envs, device=self.device, dtype=torch.long)
        self.episode_length_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.long)
        
        self.actions = torch.zeros(self.num_envs, self.num_actions, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_sums = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_acts = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.extras = {}
    
    def para_update(self, para):
        self.parameter_random = para
        
    def step(self, actions):
        # actions clip
        soft_bound = [-0.5, 1.5]
        out_of_limits = -(actions - soft_bound[0]).clip(max=0.)
        out_of_limits += (actions - soft_bound[1]).clip(min=0.)
        scale_action = -0.1
        reward_action = scale_action * torch.sum(out_of_limits, dim=1).clip(max=1.).to(self.device)
        self.actions = torch.clip(actions, 0., 1.).to(self.device)

        # update actions & states
        b, p = self.states[:, -2] * self.B, self.states[:, -1]
        inv_c = self.cost_function(self.actions)
        b -= inv_c
        b = torch.clip(b, 0., self.B).to(self.device)
        mask = (b > 0).float().unsqueeze(-1)
        self.act = self.actions * mask
        inv_c = self.cost_function(self.act)
        next_state, reward_original = self.transition(self.act)
        self.extras['reward_original'] = reward_original
        self.extras['inv_cost'] = inv_c
        self.episode_length_buf += 1
        p = self.episode_length_buf / self.max_episode_length
        self.states = torch.cat([next_state / self.N, (b / self.B).unsqueeze(-1), p.unsqueeze(-1)], dim=-1)
        
        # check termination
        self.reset_buf = self.episode_length_buf >= self.max_episode_length
        
        # compute reward
        r_mean = -6584
        r_std  =  7347
        reward = (reward_original - inv_c - r_mean) / r_std
        #if reward > 0: 
        #reward = torch.exp(reward)/10
        #reward = torch.exp((1e5 + reward_original - inv_c) / 5e4)
        self.rew_buf       = reward + reward_action
        self.episode_sums += reward + reward_action
        self.episode_acts += reward_action
        
        # compute resets
        env_ids = self.reset_buf.nonzero(as_tuple=False).flatten()
        self.reset_idx(env_ids)
        
        # compute observations
        return self.get_observations(), self.states, self.rew_buf, self.reset_buf, self.extras

    def reset_idx(self, env_ids):
        """Reset selected robots"""
        if len(env_ids) == 0:
            return
        
        assert len(env_ids) == self.num_envs
        # reset robot states
        self.states[env_ids] = self.init_state
        # reset buffers
        self.episode_length_buf[env_ids] = 0
        self.reset_buf[env_ids] = 1
        # fill extras
        self.extras["episode"] = {}
        self.extras["episode"]['rew_sum'] = torch.mean(self.episode_sums[env_ids]) / (self.max_episode_length * ΔT)
        self.extras["episode"]['rew_act'] = torch.mean(self.episode_acts[env_ids]) / (self.max_episode_length * ΔT)
        self.episode_sums[env_ids] = 0.
        self.episode_acts[env_ids] = 0.
    
    def reset(self):
        """ Reset all robots"""
        self.reset_idx(torch.arange(self.num_envs, device=self.device))
        return {}, {}
    
    def get_observations(self):
        o_mean = torch.tensor([[0.58712867, 0.06804276, 0.00308146, 0.25684301, 0.00261079, 0.08229331, 0.26572794, 0.51      ]], dtype=torch.float32).to(torch.device(self.device))
        o_std  = torch.tensor([[0.41484398, 0.07883003, 0.00389494, 0.292568  , 0.00394907, 0.06906768, 0.33943075, 0.28861739]], dtype=torch.float32).to(torch.device(self.device))
        self.obs_buf = (self.states - o_mean) / o_std
        return self.obs_buf
    
    def get_privileged_observations(self):
        return self.privileged_obs_buf

    def cost_function(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]

        cost_it  = it * u_it * parameter_static['cost_ti']
        cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
        cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
        per_poc  = ((st + et + at + rt) / self.N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
        cost_poc = (st + et + rt + at) * w * per_poc
        return cost_poc + cost_it + cost_v + cost_q

    def transition(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
        ht = st + et + at + it + rt

        st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * self.parameter_random['beta1'] + (et + at * (1 - u_aq)) * self.parameter_random['beta2']) / ht
        st_out_e = st_out * parameter_static['alpha']
        st_out_i = st_out * (1 - parameter_static['alpha'])
        st_out_r = u_sv * parameter_static['v_max'] * st * parameter_static['psr']
        et_out_r = et * self.parameter_random['per']
        et_out_i = et * self.parameter_random['pei']
        et_out_a = et * w * (1 - self.parameter_random['per'] - self.parameter_random['pei'])
        at_out_i = at * self.parameter_random['pei']
        at_out_r = at * self.parameter_random['per']
        it_out_r = it * parameter_static['pir'] * u_it
        it_out_d = it * parameter_static['pid'] * (1 - u_it) + it * u_it * parameter_static['pid_plus']
        rt_out_s = rt * parameter_static['prs']
        
        stn = st - st_out_e - st_out_i - st_out_r + rt_out_s
        etn = et - et_out_r - et_out_i - et_out_a + st_out_e
        atn = at - at_out_r - at_out_i + et_out_a
        itn = it - it_out_r - it_out_d + st_out_i + et_out_i + at_out_i
        dtn = dt + it_out_d
        rtn = rt + et_out_r + at_out_r + it_out_r + st_out_r - rt_out_s

        reward = -2.6 * st_out - 100 * it_out_d

        next_state = torch.stack([stn, etn, atn, itn, dtn, rtn], dim=-1)
        return next_state, reward

# %%
import inspect

class BaseConfig:
    def __init__(self) -> None:
        """ Initializes all member classes recursively. Ignores all namse starting with '__' (buit-in methods)."""
        self.init_member_classes(self)
    
    @staticmethod
    def init_member_classes(obj):
        # iterate over all attributes names
        for key in dir(obj):
            # disregard builtin attributes
            # if key.startswith("__"):
            if key=="__class__":
                continue
            # get the corresponding attribute object
            var =  getattr(obj, key)
            # check if it the attribute is a class
            if inspect.isclass(var):
                # instantate the class
                i_var = var()
                # set the attribute to the instance instead of the type
                setattr(obj, key, i_var)
                # recursively init members of the attribute
                BaseConfig.init_member_classes(i_var)

class LeggedRobotCfgPPO(BaseConfig):
    seed = 1
    runner_class_name = 'OnPolicyRunner'
    class policy:
        init_noise_std = 2
        actor_hidden_dims  = [64, 32, 16] 
        critic_hidden_dims = [64, 32, 16]
        activation = 'elu' # can be elu, relu, selu, crelu, lrelu, tanh, sigmoid
        # only for 'ActorCriticRecurrent':
        # rnn_type = 'lstm'
        # rnn_hidden_size = 512
        # rnn_num_layers = 1
        
    class algorithm:
        # training params
        value_loss_coef = 0.5
        use_clipped_value_loss = True
        clip_param = 0.2
        entropy_coef = 0.01
        num_learning_epochs = 5
        num_mini_batches = 64 # mini batch size = num_envs*nsteps / nminibatches
        learning_rate = 1.e-4
        schedule = 'adaptive' # could be adaptive, fixed
        gamma = 0.99
        lam = 0.95
        desired_kl = 0.01
        max_grad_norm = 1.

    class runner:
        policy_class_name = 'ActorCritic'
        algorithm_class_name = 'PPO'
        num_steps_per_env =  150 # per iteration
        max_iterations    = 100 # number of policy updates

        # logging
        save_interval = 100 # check for potential saves every this many iterations
        experiment_name = 'test'
        run_name = ''
        # load and resume
        resume = True
        load_run = -1 # -1 = last run
        checkpoint = -1 # -1 = last saved model
        resume_path = None # updated from load_run and chkpt
        
def class_to_dict(obj) -> dict:
    if not  hasattr(obj,"__dict__"):
        return obj
    result = {}
    for key in dir(obj):
        if key.startswith("_"):
            continue
        element = []
        val = getattr(obj, key)
        if isinstance(val, list):
            for item in val:
                element.append(class_to_dict(item))
        else:
            element = class_to_dict(val)
        result[key] = element
    return result

# %%
def para_sampling(intvl, num_sample=N_envs):
    parameter_random = {
        key: torch.empty(num_sample).normal_(
        intvl[key][0],
        intvl[key][1]
        ).to(torch.device(device))
        for key, value in Random_mean.items()
    }
    for key, value in Random_mean.items():
        indice = parameter_random[key] < 0
        parameter_random[key][indice] = -parameter_random[key][indice] 
    return parameter_random

def update_space(final_indices, para_buf, space):
    para_est = {}
    for key, tensor_values in para_buf.items():
        selected_values = torch.mean(tensor_values[final_indices[0], final_indices[1]]) 
        para_values = torch.mean(tensor_values[final_indices[0], final_indices[1]], dim=0)
        update_values = space[key][0] + 0.5 * (selected_values - space[key][0])
        space[key] = [update_values , update_values  * 0.1]
        para_est[key] = para_values
    return space, para_est


def cal_err(para_value, env_para):
    gap = []
    for key, value in env_para.items():
        gap_temp = torch.mean(torch.abs(para_value[key] - env_para[key])/(env_para[key]))
        gap.append(gap_temp)
    return sum(gap)/len(gap) # 所有值都在范围内，返回 0
    
def state_estimator(env_sample, action_sim, state_sim, state_prior, space, iter): 
    env_sample.reset()
    env_sample.states = state_prior  
    para_buf, mse_buf, obs_buf, states_buf = {}, {}, {}, {}
    for i in range(iter):
        para = para_sampling(space, test_num)
        env_sample.para_update(para)
        obs_sample, states_sample, _, _, _ = env_sample.step(action_sim.detach())  
        mse = torch.mean((state_sim[:,2:4] - states_sample[:,2:4]) ** 2, dim=1) 
        if i == 0:
            mse_buf = mse.unsqueeze(0)
            obs_buf = obs_sample.unsqueeze(0)
            states_buf = states_sample.unsqueeze(0)
            for key, values in para.items():
                para_buf[key] = para[key].unsqueeze(0)
        else:
            mse_buf = torch.cat((mse_buf, mse.unsqueeze(0)), dim=0)
            obs_buf = torch.cat((obs_buf, obs_sample.unsqueeze(0)),dim=0)
            states_buf = torch.cat((states_buf, states_sample.unsqueeze(0)), dim=0)
            for key, values in para.items():
                para_buf[key] = torch.cat((para_buf[key], para[key].unsqueeze(0)), dim=0)
                
     
    k = int(iter * 0.05)
    _, row_indices = torch.topk(mse_buf, k=k, dim=0, largest=False)
    column_indices = torch.arange(mse_buf.shape[1]).repeat(k, 1)
    top_indices = [row_indices, column_indices]
    obs_est = torch.mean(obs_buf[row_indices,column_indices,:], dim=0)
    state_est = torch.mean(states_buf[row_indices,column_indices,:], dim=0)
    state_est[:,-1] = state_prior[:,-1] + torch.tensor(1/T)
    return obs_est, state_est, top_indices, para_buf

# %%
para_err = 0.5
torch.manual_seed(seed)
para_true = []
para_temp = {
    key: torch.empty(test_num).uniform_(
        value * (1-para_err),
        value * (1+para_err)
    ).to(torch.device(device))
    for key, value in Random_mean.items()
}


para = {}
for t in range(T):
    para = {
        key: (para_temp[key] + t * 0.5 *  para_temp[key] /T).to(torch.device(device)) if key == 'per' 
        else (para_temp[key] - t * 0.5 *  para_temp[key] /T).to(torch.device(device))
        for key, value in Random_mean.items()
        }
    para_true.append(para)

# %%
env = myVecEnv(space, test_num)
env.para_update(para_true[0])
train_cfg = LeggedRobotCfgPPO()
train_cfg_dict = class_to_dict(train_cfg)


env_transfer = myVecEnv(space)
runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_exp4_t1', device=env.device)
runner.load(f'rsl_low_budget2700/model_100.pt')

policy = runner.get_inference_policy(device=env.device)

reward_history = []
act_buf = []
state_his_buf = []
death_buf = []

env_sample = myVecEnv(space, test_num)
state_est = env.states
obs_est = env.get_observations()
for t in range(T-1):
    actions = policy(obs_est.detach())
    obs, states, _, _, infos = env.step(actions.detach())
    reward_history.append((-infos['reward_original'] + infos['inv_cost']).tolist())
    death_buf.append((-infos['reward_original']).tolist())
    act_buf.append(env.act)
    state_his_buf.append(env.states)
    obs_est, state_buf, top_indices, para_buf = state_estimator(env_sample, actions, states, state_est, space, 1024)
    space, para_v = update_space(top_indices, para_buf, space) 

    runner.learn(num_learning_iterations=25, init_at_random_ep_len=False)
    policy = runner.get_inference_policy(device=env.device)
    env_transfer = myVecEnv(space)
    runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_exp4_t1', device=env.device)
    runner.load(f'rsl_exp4_t1/model_{int(t)* 25}.pt')

    if t < T - 1: env.para_update(para_true[t + 1])
    print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')


reward_history = np.array(reward_history)
print(f'score     : {np.sum(reward_history, axis=0)/T       }')
print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
# Out:
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 1656866 steps/s (collection: 1.147s, learning 4.786s)
#                Value function loss: 322.4218
#                     Surrogate loss: -0.0005
#              Mean action noise std: 4.58
#                        Mean reward: 22.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2213
#               Mean episode rew_act: -0.0606
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 5.93s
#                         Total time: 5.93s
#                                ETA: 148.3s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2411719 steps/s (collection: 0.642s, learning 3.434s)
#                Value function loss: 359.3671
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.60
#                        Mean reward: 25.80
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3813
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.08s
#                         Total time: 10.01s
#                                ETA: 120.1s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2417637 steps/s (collection: 0.631s, learning 3.435s)
#                Value function loss: 348.5113
#                     Surrogate loss: -0.0003
#              Mean action noise std: 4.63
#                        Mean reward: 26.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4233
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.07s
#                         Total time: 14.08s
#                                ETA: 107.9s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2411129 steps/s (collection: 0.640s, learning 3.437s)
#                Value function loss: 405.0102
#                     Surrogate loss: -0.0005
#              Mean action noise std: 4.66
#                        Mean reward: 29.52
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4504
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.08s
#                         Total time: 18.15s
#                                ETA: 99.8s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2456197 steps/s (collection: 0.694s, learning 3.308s)
#                Value function loss: 382.5897
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.69
#                        Mean reward: 29.81
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4828
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.00s
#                         Total time: 22.15s
#                                ETA: 93.0s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2520252 steps/s (collection: 0.612s, learning 3.288s)
#                Value function loss: 440.3870
#                     Surrogate loss: -0.0000
#              Mean action noise std: 4.70
#                        Mean reward: 33.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5019
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 3.90s
#                         Total time: 26.06s
#                                ETA: 86.9s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2498526 steps/s (collection: 0.637s, learning 3.297s)
#                Value function loss: 410.1383
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.75
#                        Mean reward: 35.44
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5313
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 3.93s
#                         Total time: 29.99s
#                                ETA: 81.4s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2510620 steps/s (collection: 0.619s, learning 3.296s)
#                Value function loss: 478.5588
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.78
#                        Mean reward: 33.61
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5530
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 3.92s
#                         Total time: 33.91s
#                                ETA: 76.3s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2521539 steps/s (collection: 0.615s, learning 3.283s)
#                Value function loss: 428.9248
#                     Surrogate loss: -0.0000
#              Mean action noise std: 4.84
#                        Mean reward: 36.05
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5730
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 3.90s
#                         Total time: 37.80s
#                                ETA: 71.4s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2524125 steps/s (collection: 0.614s, learning 3.280s)
#                Value function loss: 500.3237
#                     Surrogate loss: 0.0003
#              Mean action noise std: 4.88
#                        Mean reward: 37.71
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5893
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 3.89s
#                         Total time: 41.70s
#                                ETA: 66.7s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2526710 steps/s (collection: 0.613s, learning 3.277s)
#                Value function loss: 441.3283
#                     Surrogate loss: 0.0001
#              Mean action noise std: 4.95
#                        Mean reward: 38.43
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6060
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 3.89s
#                         Total time: 45.59s
#                                ETA: 62.2s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2507429 steps/s (collection: 0.621s, learning 3.299s)
#                Value function loss: 510.4744
#                     Surrogate loss: -0.0000
#              Mean action noise std: 5.00
#                        Mean reward: 38.29
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6123
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 3.92s
#                         Total time: 49.51s
#                                ETA: 57.8s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2531252 steps/s (collection: 0.609s, learning 3.274s)
#                Value function loss: 450.6007
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.05
#                        Mean reward: 39.54
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6264
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 3.88s
#                         Total time: 53.39s
#                                ETA: 53.4s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2509342 steps/s (collection: 0.638s, learning 3.279s)
#                Value function loss: 532.2517
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.10
#                        Mean reward: 39.82
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6434
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 3.92s
#                         Total time: 57.31s
#                                ETA: 49.1s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2520894 steps/s (collection: 0.617s, learning 3.282s)
#                Value function loss: 465.3070
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.15
#                        Mean reward: 40.78
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6606
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 3.90s
#                         Total time: 61.21s
#                                ETA: 44.9s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2518961 steps/s (collection: 0.617s, learning 3.285s)
#                Value function loss: 546.2279
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.23
#                        Mean reward: 41.08
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6731
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 3.90s
#                         Total time: 65.11s
#                                ETA: 40.7s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2528006 steps/s (collection: 0.614s, learning 3.274s)
#                Value function loss: 467.9093
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.30
#                        Mean reward: 41.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6802
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 3.89s
#                         Total time: 69.00s
#                                ETA: 36.5s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2529303 steps/s (collection: 0.616s, learning 3.270s)
#                Value function loss: 546.1527
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.38
#                        Mean reward: 41.86
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6849
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 3.89s
#                         Total time: 72.89s
#                                ETA: 32.4s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2517032 steps/s (collection: 0.614s, learning 3.291s)
#                Value function loss: 437.7348
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.46
#                        Mean reward: 42.31
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6944
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 3.91s
#                         Total time: 76.79s
#                                ETA: 28.3s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2511260 steps/s (collection: 0.615s, learning 3.299s)
#                Value function loss: 493.0388
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.53
#                        Mean reward: 42.82
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6963
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 3.91s
#                         Total time: 80.71s
#                                ETA: 24.2s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2523475 steps/s (collection: 0.614s, learning 3.281s)
#                Value function loss: 412.2080
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.59
#                        Mean reward: 43.45
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6998
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 3.90s
#                         Total time: 84.60s
#                                ETA: 20.1s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2513183 steps/s (collection: 0.617s, learning 3.294s)
#                Value function loss: 468.8714
#                     Surrogate loss: 0.0007
#              Mean action noise std: 5.66
#                        Mean reward: 43.51
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6970
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 3.91s
#                         Total time: 88.52s
#                                ETA: 16.1s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2519607 steps/s (collection: 0.620s, learning 3.281s)
#                Value function loss: 396.4142
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.74
#                        Mean reward: 42.50
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6993
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 3.90s
#                         Total time: 92.42s
#                                ETA: 12.1s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2508703 steps/s (collection: 0.620s, learning 3.298s)
#                Value function loss: 458.4071
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.81
#                        Mean reward: 43.50
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7043
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 3.92s
#                         Total time: 96.34s
#                                ETA: 8.0s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2528003 steps/s (collection: 0.613s, learning 3.275s)
#                Value function loss: 375.8693
#                     Surrogate loss: 0.0012
#              Mean action noise std: 5.89
#                        Mean reward: 43.10
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7061
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 3.89s
#                         Total time: 100.22s
#                                ETA: 4.0s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 0.6743329617182413
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2390228 steps/s (collection: 0.822s, learning 3.291s)
#                Value function loss: 327.3710
#                     Surrogate loss: 0.0006
#              Mean action noise std: 4.61
#                        Mean reward: 25.46
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2461
#               Mean episode rew_act: -0.0606
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.11s
#                         Total time: 4.11s
#                                ETA: 102.8s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2505491 steps/s (collection: 0.613s, learning 3.310s)
#                Value function loss: 364.4170
#                     Surrogate loss: -0.0005
#              Mean action noise std: 4.63
#                        Mean reward: 27.31
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4174
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 3.92s
#                         Total time: 8.04s
#                                ETA: 96.4s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2501064 steps/s (collection: 0.622s, learning 3.308s)
#                Value function loss: 346.8902
#                     Surrogate loss: -0.0003
#              Mean action noise std: 4.66
#                        Mean reward: 28.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4540
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 3.93s
#                         Total time: 11.97s
#                                ETA: 91.7s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2513176 steps/s (collection: 0.624s, learning 3.287s)
#                Value function loss: 404.4808
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.69
#                        Mean reward: 30.89
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4783
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 3.91s
#                         Total time: 15.88s
#                                ETA: 87.3s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2527341 steps/s (collection: 0.615s, learning 3.274s)
#                Value function loss: 376.4221
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.73
#                        Mean reward: 30.91
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5041
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 3.89s
#                         Total time: 19.77s
#                                ETA: 83.0s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2506764 steps/s (collection: 0.623s, learning 3.298s)
#                Value function loss: 434.7913
#                     Surrogate loss: -0.0003
#              Mean action noise std: 4.74
#                        Mean reward: 33.94
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5171
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 3.92s
#                         Total time: 23.69s
#                                ETA: 79.0s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2526045 steps/s (collection: 0.610s, learning 3.281s)
#                Value function loss: 401.6631
#                     Surrogate loss: -0.0000
#              Mean action noise std: 4.78
#                        Mean reward: 35.60
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5393
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 3.89s
#                         Total time: 27.58s
#                                ETA: 74.9s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2510604 steps/s (collection: 0.628s, learning 3.287s)
#                Value function loss: 469.5479
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.81
#                        Mean reward: 33.16
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5548
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 3.92s
#                         Total time: 31.50s
#                                ETA: 70.9s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2519600 steps/s (collection: 0.622s, learning 3.279s)
#                Value function loss: 422.9465
#                     Surrogate loss: 0.0001
#              Mean action noise std: 4.85
#                        Mean reward: 35.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5719
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 3.90s
#                         Total time: 35.40s
#                                ETA: 66.9s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2491561 steps/s (collection: 0.633s, learning 3.312s)
#                Value function loss: 487.2394
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.89
#                        Mean reward: 36.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5790
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 3.95s
#                         Total time: 39.34s
#                                ETA: 62.9s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2494048 steps/s (collection: 0.634s, learning 3.307s)
#                Value function loss: 435.8377
#                     Surrogate loss: 0.0007
#              Mean action noise std: 4.95
#                        Mean reward: 37.83
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5939
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 3.94s
#                         Total time: 43.29s
#                                ETA: 59.0s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2514460 steps/s (collection: 0.618s, learning 3.291s)
#                Value function loss: 509.5033
#                     Surrogate loss: -0.0002
#              Mean action noise std: 4.99
#                        Mean reward: 38.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6067
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 3.91s
#                         Total time: 47.19s
#                                ETA: 55.1s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2513825 steps/s (collection: 0.610s, learning 3.300s)
#                Value function loss: 451.6245
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.04
#                        Mean reward: 39.75
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6250
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 3.91s
#                         Total time: 51.11s
#                                ETA: 51.1s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2505538 steps/s (collection: 0.615s, learning 3.308s)
#                Value function loss: 536.8285
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.09
#                        Mean reward: 39.74
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6426
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 3.92s
#                         Total time: 55.03s
#                                ETA: 47.2s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2504858 steps/s (collection: 0.622s, learning 3.302s)
#                Value function loss: 471.1708
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.15
#                        Mean reward: 40.66
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6610
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 3.92s
#                         Total time: 58.95s
#                                ETA: 43.2s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2518317 steps/s (collection: 0.614s, learning 3.289s)
#                Value function loss: 553.5072
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.22
#                        Mean reward: 40.50
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6691
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 3.90s
#                         Total time: 62.86s
#                                ETA: 39.3s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2511257 steps/s (collection: 0.619s, learning 3.295s)
#                Value function loss: 475.5479
#                     Surrogate loss: 0.0012
#              Mean action noise std: 5.29
#                        Mean reward: 40.83
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6742
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 3.91s
#                         Total time: 66.77s
#                                ETA: 35.3s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2482173 steps/s (collection: 0.646s, learning 3.314s)
#                Value function loss: 561.1116
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.36
#                        Mean reward: 41.77
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6797
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 3.96s
#                         Total time: 70.73s
#                                ETA: 31.4s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2494086 steps/s (collection: 0.654s, learning 3.287s)
#                Value function loss: 482.6307
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.44
#                        Mean reward: 41.79
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6885
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 3.94s
#                         Total time: 74.67s
#                                ETA: 27.5s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2520890 steps/s (collection: 0.614s, learning 3.285s)
#                Value function loss: 565.2870
#                     Surrogate loss: 0.0000
#              Mean action noise std: 5.51
#                        Mean reward: 42.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6906
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 3.90s
#                         Total time: 78.57s
#                                ETA: 23.6s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2516406 steps/s (collection: 0.618s, learning 3.288s)
#                Value function loss: 485.6324
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.56
#                        Mean reward: 43.04
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6971
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 3.91s
#                         Total time: 82.48s
#                                ETA: 19.6s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2522811 steps/s (collection: 0.615s, learning 3.281s)
#                Value function loss: 569.3765
#                     Surrogate loss: 0.0000
#              Mean action noise std: 5.64
#                        Mean reward: 43.46
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6996
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 3.90s
#                         Total time: 86.38s
#                                ETA: 15.7s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2508067 steps/s (collection: 0.633s, learning 3.286s)
#                Value function loss: 485.0392
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.72
#                        Mean reward: 42.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7026
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 3.92s
#                         Total time: 90.30s
#                                ETA: 11.8s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2469112 steps/s (collection: 0.698s, learning 3.283s)
#                Value function loss: 569.3574
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.80
#                        Mean reward: 43.55
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7086
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 3.98s
#                         Total time: 94.28s
#                                ETA: 7.9s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2506153 steps/s (collection: 0.617s, learning 3.305s)
#                Value function loss: 457.9909
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.88
#                        Mean reward: 43.42
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7120
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 3.92s
#                         Total time: 98.20s
#                                ETA: 3.9s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 3.975264170010884
# ################################################################################
#                         Learning iteration 25/50
#
#                        Computation: 2486530 steps/s (collection: 0.657s, learning 3.296s)
#                Value function loss: 446.1807
#                     Surrogate loss: 0.0010
#              Mean action noise std: 5.97
#                        Mean reward: 43.75
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4304
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 3.95s
#                         Total time: 3.95s
#                                ETA: 0.0s
#
# ################################################################################
#                         Learning iteration 26/50
#
#                        Computation: 2489711 steps/s (collection: 0.660s, learning 3.288s)
#                Value function loss: 518.3836
#                     Surrogate loss: 0.0000
#              Mean action noise std: 6.05
#                        Mean reward: 43.97
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7089
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 3.95s
#                         Total time: 7.90s
#                                ETA: -0.3s
#
# ################################################################################
#                         Learning iteration 27/50
#
#                        Computation: 2509342 steps/s (collection: 0.625s, learning 3.292s)
#                Value function loss: 435.8269
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.13
#                        Mean reward: 43.54
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7139
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 3.92s
#                         Total time: 11.82s
#                                ETA: -0.8s
#
# ################################################################################
#                         Learning iteration 28/50
#
#                        Computation: 2507427 steps/s (collection: 0.623s, learning 3.297s)
#                Value function loss: 527.2371
#                     Surrogate loss: 0.0009
#              Mean action noise std: 6.23
#                        Mean reward: 43.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7158
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 3.92s
#                         Total time: 15.74s
#                                ETA: -1.6s
#
# ################################################################################
#                         Learning iteration 29/50
#
#                        Computation: 2506153 steps/s (collection: 0.614s, learning 3.308s)
#                Value function loss: 445.4345
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.32
#                        Mean reward: 44.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7175
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 3.92s
#                         Total time: 19.66s
#                                ETA: -2.6s
#
# ################################################################################
#                         Learning iteration 30/50
#
#                        Computation: 2487164 steps/s (collection: 0.657s, learning 3.295s)
#                Value function loss: 537.6347
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.38
#                        Mean reward: 44.58
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7167
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 3.95s
#                         Total time: 23.61s
#                                ETA: -3.8s
#
# ################################################################################
#                         Learning iteration 31/50
#
#                        Computation: 2522167 steps/s (collection: 0.618s, learning 3.279s)
#                Value function loss: 455.2446
#                     Surrogate loss: 0.0004
#              Mean action noise std: 6.49
#                        Mean reward: 44.47
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7195
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 3.90s
#                         Total time: 27.51s
#                                ETA: -5.2s
#
# ################################################################################
#                         Learning iteration 32/50
#
#                        Computation: 2521521 steps/s (collection: 0.613s, learning 3.285s)
#                Value function loss: 549.9720
#                     Surrogate loss: 0.0006
#              Mean action noise std: 6.57
#                        Mean reward: 43.17
# ...
#                    Total timesteps: 78643200
#                     Iteration time: 3.86s
#                         Total time: 31.06s
#                                ETA: -30.5s
#
# ################################################################################
#                       Learning iteration 1433/1450
#
#                        Computation: 2542354 steps/s (collection: 0.619s, learning 3.247s)
#                Value function loss: 250.5694
#                     Surrogate loss: 0.0005
#              Mean action noise std: 2918.10
#                        Mean reward: 46.07
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7638
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 3.87s
#                         Total time: 34.92s
#                                ETA: -34.3s
#
# ################################################################################
#                       Learning iteration 1434/1450
#
#                        Computation: 2518961 steps/s (collection: 0.633s, learning 3.269s)
#                Value function loss: 267.8969
#                     Surrogate loss: 0.0010
#              Mean action noise std: 2920.54
#                        Mean reward: 46.39
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7639
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 3.90s
#                         Total time: 38.83s
#                                ETA: -38.1s
#
# ################################################################################
#                       Learning iteration 1435/1450
#
#                        Computation: 2512540 steps/s (collection: 0.652s, learning 3.260s)
#                Value function loss: 251.7715
#                     Surrogate loss: 0.0013
#              Mean action noise std: 2922.75
#                        Mean reward: 46.53
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7665
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 3.91s
#                         Total time: 42.74s
#                                ETA: -42.0s
#
# ################################################################################
#                       Learning iteration 1436/1450
#
#                        Computation: 2537769 steps/s (collection: 0.623s, learning 3.250s)
#                Value function loss: 269.9979
#                     Surrogate loss: 0.0005
#              Mean action noise std: 2925.49
#                        Mean reward: 46.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7669
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 3.87s
#                         Total time: 46.61s
#                                ETA: -45.8s
#
# ################################################################################
#                       Learning iteration 1437/1450
#
#                        Computation: 2534509 steps/s (collection: 0.632s, learning 3.246s)
#                Value function loss: 252.2814
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2928.00
#                        Mean reward: 46.31
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7660
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 3.88s
#                         Total time: 50.49s
#                                ETA: -49.6s
#
# ################################################################################
#                       Learning iteration 1438/1450
#
#                        Computation: 2531902 steps/s (collection: 0.623s, learning 3.259s)
#                Value function loss: 273.4172
#                     Surrogate loss: 0.0006
#              Mean action noise std: 2930.44
#                        Mean reward: 46.36
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7666
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 3.88s
#                         Total time: 54.37s
#                                ETA: -53.4s
#
# ################################################################################
#                       Learning iteration 1439/1450
#
#                        Computation: 2501702 steps/s (collection: 0.661s, learning 3.268s)
#                Value function loss: 255.7322
#                     Surrogate loss: 0.0015
#              Mean action noise std: 2932.54
#                        Mean reward: 46.30
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7661
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 3.93s
#                         Total time: 58.30s
#                                ETA: -57.2s
#
# ################################################################################
#                       Learning iteration 1440/1450
#
#                        Computation: 2547607 steps/s (collection: 0.619s, learning 3.239s)
#                Value function loss: 279.8871
#                     Surrogate loss: 0.0009
#              Mean action noise std: 2934.99
#                        Mean reward: 46.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7665
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 3.86s
#                         Total time: 62.16s
#                                ETA: -61.0s
#
# ################################################################################
#                       Learning iteration 1441/1450
#
#                        Computation: 2539077 steps/s (collection: 0.618s, learning 3.253s)
#                Value function loss: 266.9274
#                     Surrogate loss: 0.0009
#              Mean action noise std: 2937.23
#                        Mean reward: 46.32
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7665
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 3.87s
#                         Total time: 66.03s
#                                ETA: -64.8s
#
# ################################################################################
#                       Learning iteration 1442/1450
#
#                        Computation: 2521539 steps/s (collection: 0.646s, learning 3.252s)
#                Value function loss: 291.5328
#                     Surrogate loss: 0.0007
#              Mean action noise std: 2939.58
#                        Mean reward: 46.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7674
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 3.90s
#                         Total time: 69.93s
#                                ETA: -68.7s
#
# ################################################################################
#                       Learning iteration 1443/1450
#
#                        Computation: 2524119 steps/s (collection: 0.615s, learning 3.279s)
#                Value function loss: 278.9582
#                     Surrogate loss: 0.0015
#              Mean action noise std: 2941.55
#                        Mean reward: 46.44
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7693
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 3.89s
#                         Total time: 73.83s
#                                ETA: -72.5s
#
# ################################################################################
#                       Learning iteration 1444/1450
#
#                        Computation: 2536464 steps/s (collection: 0.623s, learning 3.252s)
#                Value function loss: 300.3014
#                     Surrogate loss: -0.0005
#              Mean action noise std: 2943.68
#                        Mean reward: 46.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7692
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 3.88s
#                         Total time: 77.70s
#                                ETA: -76.3s
#
# ################################################################################
#                       Learning iteration 1445/1450
#
#                        Computation: 2528006 steps/s (collection: 0.622s, learning 3.266s)
#                Value function loss: 271.6256
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2946.07
#                        Mean reward: 46.60
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7684
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 3.89s
#                         Total time: 81.59s
#                                ETA: -80.1s
#
# ################################################################################
#                       Learning iteration 1446/1450
#
#                        Computation: 2517674 steps/s (collection: 0.639s, learning 3.265s)
#                Value function loss: 294.6823
#                     Surrogate loss: 0.0005
#              Mean action noise std: 2948.54
#                        Mean reward: 46.28
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7673
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 3.90s
#                         Total time: 85.49s
#                                ETA: -84.0s
#
# ################################################################################
#                       Learning iteration 1447/1450
#
#                        Computation: 2535811 steps/s (collection: 0.618s, learning 3.258s)
#                Value function loss: 272.2477
#                     Surrogate loss: 0.0011
#              Mean action noise std: 2950.81
#                        Mean reward: 46.48
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7662
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 3.88s
#                         Total time: 89.37s
#                                ETA: -87.8s
#
# ################################################################################
#                       Learning iteration 1448/1450
#
#                        Computation: 2538420 steps/s (collection: 0.625s, learning 3.247s)
#                Value function loss: 296.7073
#                     Surrogate loss: 0.0005
#              Mean action noise std: 2953.37
#                        Mean reward: 46.30
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7650
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 3.87s
#                         Total time: 93.24s
#                                ETA: -91.6s
#
# ################################################################################
#                       Learning iteration 1449/1450
#
#                        Computation: 2537116 steps/s (collection: 0.622s, learning 3.252s)
#                Value function loss: 280.6881
#                     Surrogate loss: 0.0005
#              Mean action noise std: 2955.83
#                        Mean reward: 46.21
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7641
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 3.87s
#                         Total time: 97.12s
#                                ETA: -95.4s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 648.363047725906
# score     : [  48.874343    935.59663297   44.67907394   44.74099366   45.72507434
#   183.7357236    48.81707718  777.44425224   42.85230034  140.15973349
#    43.38614912   44.20263648   42.32992269   42.10986875   41.93256225
#    43.76651998   89.25825306 1509.2067817    40.50242967   44.69028154
#   874.0916745  1766.04978841   44.89413471 2332.62701804   45.04144592
#    44.19627277 4154.6165205    42.18061518   42.03657416   43.90638759
#    43.06525218 4123.18499762   41.50696297   41.13012558   40.8811617
#    44.06314086   40.70405806 2389.89443893   72.69557472  388.27991687
#    46.56147952   41.06056939   49.88926901   42.30068632   41.01647381
#    45.43764346 1167.36622558  358.5315039    42.93799953   48.1620752
#  3166.38496101 3265.00123024  217.62629398   61.12394625 1605.67868087
#    43.89789638 1051.39133711   43.50174254   42.62447436   46.75228234
#   395.17764521  544.42452401   41.37178162   83.70674909  530.49295251
#    43.20764942   48.59795456  749.31870669  572.29811265 4442.693765
#    44.80276621   43.61232244   66.59806989 3710.50032835 4655.66720193
#  5247.15171089   60.03282006   42.91732196   49.04986739   40.75429699
#    43.13868604 4670.56524213 2177.50054786   42.41837589   47.7475781
#    42.39990018   43.60548991   41.13256371  172.83816507   41.29107491
#    51.49305996 1095.78217349 1301.58195731  242.51663222   42.36376637
#    43.80516872  262.92129126  676.89163706   42.01779582   45.61367766]
# score.mean: 648.363047725906

# %%
exp_result = {
    'reward_total': reward_history,
    'reward_peo': death_buf,
    'state': state_his_buf,
    'action': act_buf
}
torch.save(exp_result, 'exp4-t2700.pt')

# %%
run_result = torch.load('exp4-t2700.pt', weights_only=False)
death_mean = torch.mean(run_result['state'][-1][:,4]) * N
print(death_mean)

def infections(states, action, para, i):
    st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
    u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
    ht = st + et + at + it + rt

    st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * para['beta1'][i] + (et + at * (1 - u_aq)) * para['beta2'][i]) / ht
    st_out_e = st_out * parameter_static['alpha']
    st_out_i = st_out * (1 - parameter_static['alpha'])
    et_out_a = et * w * (1 - para['per'] - para['pei'])
    return et_out_a, st_out_e, st_out_i


init_state = torch.tensor([[100000, 20 , 0, 0, 0, 0]], dtype=torch.float32).to(torch.device(device))
s_i = torch.zeros(100).to(torch.device('cuda:0'))
s_a = torch.zeros(100).to(torch.device('cuda:0'))
s_t = torch.zeros(100).to(torch.device('cuda:0'))
for i in range(test_num):
    for t in range(T):
        if t == 0:
            sa_temp, se_temp, si_temp = infections(init_state, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        if t > 0 and t < T-1:
            sa_temp, se_temp, si_temp = infections(run_result['state'][t-1][i][:6].unsqueeze(0)*N, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        s_i[i] += si_temp[0]
        s_a[i] += sa_temp[0]
        s_t[i] += se_temp[0]
print([torch.mean(s_i), torch.mean(s_a)+torch.mean(s_i), torch.mean(s_t)])
# Out:
# tensor(40.56087, device='cuda:0')
# [tensor(5443.28906, device='cuda:0'), tensor(5526.48730, device='cuda:0'), tensor(8164.93408, device='cuda:0')]
