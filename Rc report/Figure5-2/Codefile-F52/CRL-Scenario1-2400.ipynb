# %%
from rsl_rl.env import VecEnv
from rsl_rl.runners import OnPolicyRunner
import torch
import numpy as np
torch.set_printoptions(precision=5, linewidth=200, sci_mode=False)

N          = 100020
state_dim  = 8
action_dim = 5
T          = 60
budget     = 2400.
N_envs     = 1024 * 64
ΔT         = 1.0
device     = 'cuda'
usr_std = 0.1
test_num = 100
seed = 0

parameter_static = dict(N          = N,
                        B          = budget,
                        T          = T,
                        alpha      = 0.6,
                        v_max      = 0.2/14,
                        cost_ti    = 0.0977,
                        cost_ta    = 0.02,
                        cost_v     = 0.07,
                        cost_poc_0 = 0.000369,
                        cost_poc_1 = 0.001057,
                        pid        = 1.10/1000,
                        psr        = 0.7,
                        pid_plus   = 0.1221/1000,
                        pir        = 1/8,
                        prs        = 1/7)

Random_mean = {"beta2" : 0.78735,
               "beta1" : 0.15747,
               "pei"   : 0.10714,
               "per"   : 0.04545}

space = {"beta2" : [Random_mean['beta2'],Random_mean['beta2']*usr_std],
         "beta1" : [Random_mean['beta1'], Random_mean['beta1']*usr_std],
         "pei"   : [Random_mean['pei'], Random_mean['pei']*usr_std],
         "per"   : [Random_mean['per'], Random_mean['per']*usr_std]}

Init_state = torch.tensor([[100000 / N, 20 / N, 0, 0, 0, 0, 1, 0]], 
                         dtype=torch.float32).to(torch.device(device))

# %%
class myVecEnv(VecEnv):
    def __init__(self, interval, n_envs = N_envs):
        self.B = parameter_static['B']  # total budget
        self.N = parameter_static['N']
        self.device = device
        self.init_state = Init_state
        self.states = self.init_state.repeat(n_envs, 1)
        self.num_envs = n_envs
        self.num_obs = state_dim
        self.num_privileged_obs = None
        self.num_actions = action_dim
        self.max_episode_length = parameter_static['T']
        
        torch.manual_seed(seed)
        self.parameter_random = {
            key: torch.empty(self.num_envs).normal_(
                interval[key][0],
                interval[key][1]
            ).to(torch.device(device))
            for key, value in Random_mean.items()
        }

        for key, value in Random_mean.items():
            indice = self.parameter_random[key] < 0
            self.parameter_random[key][indice] = -self.parameter_random[key][indice] 

        # optimization flags for pytorch JIT
        torch._C._jit_set_profiling_mode(False)
        torch._C._jit_set_profiling_executor(False)
        
        # allocate buffers
        self.privileged_obs_buf = None
        self.obs_buf = torch.zeros(self.num_envs, self.num_obs, device=self.device, dtype=torch.float)
        self.rew_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.float)
        self.reset_buf = torch.ones(self.num_envs, device=self.device, dtype=torch.long)
        self.episode_length_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.long)
        
        self.actions = torch.zeros(self.num_envs, self.num_actions, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_sums = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_acts = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.extras = {}
    
    def para_update(self, para):
        self.parameter_random = para
        
    def step(self, actions):
        # actions clip
        soft_bound = [-0.5, 1.5]
        out_of_limits = -(actions - soft_bound[0]).clip(max=0.)
        out_of_limits += (actions - soft_bound[1]).clip(min=0.)
        scale_action = -0.1
        reward_action = scale_action * torch.sum(out_of_limits, dim=1).clip(max=1.).to(self.device)
        self.actions = torch.clip(actions, 0., 1.).to(self.device)

        # update actions & states
        b, p = self.states[:, -2] * self.B, self.states[:, -1]
        inv_c = self.cost_function(self.actions)
        b -= inv_c
        b = torch.clip(b, 0., self.B).to(self.device)
        mask = (b > 0).float().unsqueeze(-1)
        self.act = self.actions * mask
        inv_c = self.cost_function(self.act)
        next_state, reward_original = self.transition(self.act)
        self.extras['reward_original'] = reward_original
        self.extras['inv_cost'] = inv_c
        self.episode_length_buf += 1
        p = self.episode_length_buf / self.max_episode_length
        self.states = torch.cat([next_state / self.N, (b / self.B).unsqueeze(-1), p.unsqueeze(-1)], dim=-1)
        
        # check termination
        self.reset_buf = self.episode_length_buf >= self.max_episode_length
        
        # compute reward
        r_mean = -6584
        r_std  =  7347
        reward = (reward_original - inv_c - r_mean) / r_std
        #if reward > 0: 
        #reward = torch.exp(reward)/10
        #reward = torch.exp((1e5 + reward_original - inv_c) / 5e4)
        self.rew_buf       = reward + reward_action
        self.episode_sums += reward + reward_action
        self.episode_acts += reward_action
        
        # compute resets
        env_ids = self.reset_buf.nonzero(as_tuple=False).flatten()
        self.reset_idx(env_ids)
        
        # compute observations
        return self.get_observations(), self.states, self.rew_buf, self.reset_buf, self.extras

    def reset_idx(self, env_ids):
        """Reset selected robots"""
        if len(env_ids) == 0:
            return
        
        assert len(env_ids) == self.num_envs
        # reset robot states
        self.states[env_ids] = self.init_state
        # reset buffers
        self.episode_length_buf[env_ids] = 0
        self.reset_buf[env_ids] = 1
        # fill extras
        self.extras["episode"] = {}
        self.extras["episode"]['rew_sum'] = torch.mean(self.episode_sums[env_ids]) / (self.max_episode_length * ΔT)
        self.extras["episode"]['rew_act'] = torch.mean(self.episode_acts[env_ids]) / (self.max_episode_length * ΔT)
        self.episode_sums[env_ids] = 0.
        self.episode_acts[env_ids] = 0.
    
    def reset(self):
        """ Reset all robots"""
        self.reset_idx(torch.arange(self.num_envs, device=self.device))
        return {}, {}
    
    def get_observations(self):
        o_mean = torch.tensor([[0.58712867, 0.06804276, 0.00308146, 0.25684301, 0.00261079, 0.08229331, 0.26572794, 0.51      ]], dtype=torch.float32).to(torch.device(self.device))
        o_std  = torch.tensor([[0.41484398, 0.07883003, 0.00389494, 0.292568  , 0.00394907, 0.06906768, 0.33943075, 0.28861739]], dtype=torch.float32).to(torch.device(self.device))
        self.obs_buf = (self.states - o_mean) / o_std
        return self.obs_buf
    
    def get_privileged_observations(self):
        return self.privileged_obs_buf

    def cost_function(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]

        cost_it  = it * u_it * parameter_static['cost_ti']
        cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
        cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
        per_poc  = ((st + et + at + rt) / self.N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
        cost_poc = (st + et + rt + at) * w * per_poc
        return cost_poc + cost_it + cost_v + cost_q

    def transition(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
        ht = st + et + at + it + rt

        st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * self.parameter_random['beta1'] + (et + at * (1 - u_aq)) * self.parameter_random['beta2']) / ht
        st_out_e = st_out * parameter_static['alpha']
        st_out_i = st_out * (1 - parameter_static['alpha'])
        st_out_r = u_sv * parameter_static['v_max'] * st * parameter_static['psr']
        et_out_r = et * self.parameter_random['per']
        et_out_i = et * self.parameter_random['pei']
        et_out_a = et * w * (1 - self.parameter_random['per'] - self.parameter_random['pei'])
        at_out_i = at * self.parameter_random['pei']
        at_out_r = at * self.parameter_random['per']
        it_out_r = it * parameter_static['pir'] * u_it
        it_out_d = it * parameter_static['pid'] * (1 - u_it) + it * u_it * parameter_static['pid_plus']
        rt_out_s = rt * parameter_static['prs']
        
        stn = st - st_out_e - st_out_i - st_out_r + rt_out_s
        etn = et - et_out_r - et_out_i - et_out_a + st_out_e
        atn = at - at_out_r - at_out_i + et_out_a
        itn = it - it_out_r - it_out_d + st_out_i + et_out_i + at_out_i
        dtn = dt + it_out_d
        rtn = rt + et_out_r + at_out_r + it_out_r + st_out_r - rt_out_s

        reward = -2.6 * st_out - 100 * it_out_d

        next_state = torch.stack([stn, etn, atn, itn, dtn, rtn], dim=-1)
        return next_state, reward

# %%
import inspect

class BaseConfig:
    def __init__(self) -> None:
        """ Initializes all member classes recursively. Ignores all namse starting with '__' (buit-in methods)."""
        self.init_member_classes(self)
    
    @staticmethod
    def init_member_classes(obj):
        # iterate over all attributes names
        for key in dir(obj):
            # disregard builtin attributes
            # if key.startswith("__"):
            if key=="__class__":
                continue
            # get the corresponding attribute object
            var =  getattr(obj, key)
            # check if it the attribute is a class
            if inspect.isclass(var):
                # instantate the class
                i_var = var()
                # set the attribute to the instance instead of the type
                setattr(obj, key, i_var)
                # recursively init members of the attribute
                BaseConfig.init_member_classes(i_var)

class LeggedRobotCfgPPO(BaseConfig):
    seed = 1
    runner_class_name = 'OnPolicyRunner'
    class policy:
        init_noise_std = 2
        actor_hidden_dims  = [64, 32, 16] 
        critic_hidden_dims = [64, 32, 16]
        activation = 'elu' # can be elu, relu, selu, crelu, lrelu, tanh, sigmoid
        # only for 'ActorCriticRecurrent':
        # rnn_type = 'lstm'
        # rnn_hidden_size = 512
        # rnn_num_layers = 1
        
    class algorithm:
        # training params
        value_loss_coef = 0.5
        use_clipped_value_loss = True
        clip_param = 0.2
        entropy_coef = 0.01
        num_learning_epochs = 5
        num_mini_batches = 64 # mini batch size = num_envs*nsteps / nminibatches
        learning_rate = 1.e-4
        schedule = 'adaptive' # could be adaptive, fixed
        gamma = 0.99
        lam = 0.95
        desired_kl = 0.01
        max_grad_norm = 1.

    class runner:
        policy_class_name = 'ActorCritic'
        algorithm_class_name = 'PPO'
        num_steps_per_env =  150 # per iteration
        max_iterations    = 100 # number of policy updates

        # logging
        save_interval = 100 # check for potential saves every this many iterations
        experiment_name = 'test'
        run_name = ''
        # load and resume
        resume = True
        load_run = -1 # -1 = last run
        checkpoint = -1 # -1 = last saved model
        resume_path = None # updated from load_run and chkpt
        
def class_to_dict(obj) -> dict:
    if not  hasattr(obj,"__dict__"):
        return obj
    result = {}
    for key in dir(obj):
        if key.startswith("_"):
            continue
        element = []
        val = getattr(obj, key)
        if isinstance(val, list):
            for item in val:
                element.append(class_to_dict(item))
        else:
            element = class_to_dict(val)
        result[key] = element
    return result

# %%
def para_sampling(intvl, num_sample=N_envs):
    parameter_random = {
        key: torch.empty(num_sample).normal_(
        intvl[key][0],
        intvl[key][1]
        ).to(torch.device(device))
        for key, value in Random_mean.items()
    }
    for key, value in Random_mean.items():
        indice = parameter_random[key] < 0
        parameter_random[key][indice] = -parameter_random[key][indice] 
    return parameter_random

def update_space(final_indices, para_buf, space):
    para_est = {}
    for key, tensor_values in para_buf.items():
        selected_values = torch.mean(tensor_values[final_indices[0], final_indices[1]]) 
        para_values = torch.mean(tensor_values[final_indices[0], final_indices[1]], dim=0)
        update_values = space[key][0] + 0.5 * (selected_values - space[key][0])
        space[key] = [update_values , update_values  * 0.1]
        para_est[key] = para_values
    return space, para_est


def cal_err(para_value, env_para):
    gap = []
    for key, value in env_para.items():
        gap_temp = torch.mean(torch.abs(para_value[key] - env_para[key])/(env_para[key]))
        gap.append(gap_temp)
    return sum(gap)/len(gap) # 所有值都在范围内，返回 0
    
def state_estimator(env_sample, action_sim, state_sim, state_prior, space, iter): 
    env_sample.reset()
    env_sample.states = state_prior  
    para_buf, mse_buf, obs_buf, states_buf = {}, {}, {}, {}
    for i in range(iter):
        para = para_sampling(space, test_num)
        env_sample.para_update(para)
        obs_sample, states_sample, _, _, _ = env_sample.step(action_sim.detach())  
        mse = torch.mean((state_sim[:,2:4] - states_sample[:,2:4]) ** 2, dim=1) 
        if i == 0:
            mse_buf = mse.unsqueeze(0)
            obs_buf = obs_sample.unsqueeze(0)
            states_buf = states_sample.unsqueeze(0)
            for key, values in para.items():
                para_buf[key] = para[key].unsqueeze(0)
        else:
            mse_buf = torch.cat((mse_buf, mse.unsqueeze(0)), dim=0)
            obs_buf = torch.cat((obs_buf, obs_sample.unsqueeze(0)),dim=0)
            states_buf = torch.cat((states_buf, states_sample.unsqueeze(0)), dim=0)
            for key, values in para.items():
                para_buf[key] = torch.cat((para_buf[key], para[key].unsqueeze(0)), dim=0)
                
     
    k = int(iter * 0.05)
    _, row_indices = torch.topk(mse_buf, k=k, dim=0, largest=False)
    column_indices = torch.arange(mse_buf.shape[1]).repeat(k, 1)
    top_indices = [row_indices, column_indices]
    obs_est = torch.mean(obs_buf[row_indices,column_indices,:], dim=0)
    state_est = torch.mean(states_buf[row_indices,column_indices,:], dim=0)
    state_est[:,-1] = state_prior[:,-1] + torch.tensor(1/T)
    return obs_est, state_est, top_indices, para_buf

# %%
para_err = 0.5
torch.manual_seed(seed)
para_true = []
para_temp = {
    key: torch.empty(test_num).uniform_(
        value * (1-para_err),
        value * (1+para_err)
    ).to(torch.device(device))
    for key, value in Random_mean.items()
}


para = {}
for t in range(T):
    para = {
        key: (para_temp[key] + t * 0.5 *  para_temp[key] /T).to(torch.device(device)) if key == 'per' 
        else (para_temp[key] - t * 0.5 *  para_temp[key] /T).to(torch.device(device))
        for key, value in Random_mean.items()
        }
    para_true.append(para)

# %%
env = myVecEnv(space, test_num)
env.para_update(para_true[0])
train_cfg = LeggedRobotCfgPPO()
train_cfg_dict = class_to_dict(train_cfg)


env_transfer = myVecEnv(space)
runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_exp4_t1', device=env.device)
runner.load(f'rsl_low_budget2400/model_100.pt')

policy = runner.get_inference_policy(device=env.device)

reward_history = []
act_buf = []
state_his_buf = []
death_buf = []

env_sample = myVecEnv(space, test_num)
state_est = env.states
obs_est = env.get_observations()
for t in range(T-1):
    actions = policy(obs_est.detach())
    obs, states, _, _, infos = env.step(actions.detach())
    reward_history.append((-infos['reward_original'] + infos['inv_cost']).tolist())
    death_buf.append((-infos['reward_original']).tolist())
    act_buf.append(env.act)
    state_his_buf.append(env.states)
    obs_est, state_buf, top_indices, para_buf = state_estimator(env_sample, actions, states, state_est, space, 1024)
    space, para_v = update_space(top_indices, para_buf, space) 

    runner.learn(num_learning_iterations=25, init_at_random_ep_len=False)
    policy = runner.get_inference_policy(device=env.device)
    env_transfer = myVecEnv(space)
    runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_exp4_t1', device=env.device)
    runner.load(f'rsl_exp4_t1/model_{int(t)* 25}.pt')

    if t < T - 1: env.para_update(para_true[t + 1])
    print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')


reward_history = np.array(reward_history)
print(f'score     : {np.sum(reward_history, axis=0)/T       }')
print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
# Out:
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2294271 steps/s (collection: 0.735s, learning 3.550s)
#                Value function loss: 166.0491
#                     Surrogate loss: -0.0005
#              Mean action noise std: 4.57
#                        Mean reward: 24.86
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2323
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.28s
#                         Total time: 4.28s
#                                ETA: 107.1s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2414838 steps/s (collection: 0.647s, learning 3.424s)
#                Value function loss: 166.3252
#                     Surrogate loss: -0.0006
#              Mean action noise std: 4.58
#                        Mean reward: 26.31
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3938
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.07s
#                         Total time: 8.36s
#                                ETA: 100.3s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2434365 steps/s (collection: 0.645s, learning 3.393s)
#                Value function loss: 168.0929
#                     Surrogate loss: -0.0004
#              Mean action noise std: 4.61
#                        Mean reward: 27.53
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4280
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.04s
#                         Total time: 12.39s
#                                ETA: 95.0s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2425262 steps/s (collection: 0.653s, learning 3.400s)
#                Value function loss: 184.3450
#                     Surrogate loss: -0.0004
#              Mean action noise std: 4.63
#                        Mean reward: 28.73
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4531
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.05s
#                         Total time: 16.45s
#                                ETA: 90.5s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2450697 steps/s (collection: 0.644s, learning 3.367s)
#                Value function loss: 182.5639
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4.67
#                        Mean reward: 30.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4810
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.01s
#                         Total time: 20.46s
#                                ETA: 85.9s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2424772 steps/s (collection: 0.645s, learning 3.409s)
#                Value function loss: 200.7753
#                     Surrogate loss: -0.0003
#              Mean action noise std: 4.69
#                        Mean reward: 33.02
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4983
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.05s
#                         Total time: 24.51s
#                                ETA: 81.7s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2446726 steps/s (collection: 0.637s, learning 3.381s)
#                Value function loss: 195.0674
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.72
#                        Mean reward: 34.51
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5218
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.02s
#                         Total time: 28.53s
#                                ETA: 77.4s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2443326 steps/s (collection: 0.653s, learning 3.370s)
#                Value function loss: 220.5702
#                     Surrogate loss: 0.0004
#              Mean action noise std: 4.75
#                        Mean reward: 33.01
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5407
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.02s
#                         Total time: 32.55s
#                                ETA: 73.2s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2455747 steps/s (collection: 0.651s, learning 3.352s)
#                Value function loss: 207.2154
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.80
#                        Mean reward: 33.67
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5533
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.00s
#                         Total time: 36.56s
#                                ETA: 69.1s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2441145 steps/s (collection: 0.658s, learning 3.369s)
#                Value function loss: 227.3587
#                     Surrogate loss: 0.0008
#              Mean action noise std: 4.84
#                        Mean reward: 37.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5613
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.03s
#                         Total time: 40.58s
#                                ETA: 64.9s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2427358 steps/s (collection: 0.681s, learning 3.368s)
#                Value function loss: 212.8727
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4.89
#                        Mean reward: 36.09
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5746
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.05s
#                         Total time: 44.63s
#                                ETA: 60.9s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2427969 steps/s (collection: 0.645s, learning 3.403s)
#                Value function loss: 237.1847
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.93
#                        Mean reward: 36.34
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5811
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.05s
#                         Total time: 48.68s
#                                ETA: 56.8s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2438114 steps/s (collection: 0.669s, learning 3.363s)
#                Value function loss: 223.0424
#                     Surrogate loss: 0.0004
#              Mean action noise std: 4.98
#                        Mean reward: 36.21
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5894
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.03s
#                         Total time: 52.71s
#                                ETA: 52.7s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2430215 steps/s (collection: 0.656s, learning 3.389s)
#                Value function loss: 248.1957
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.03
#                        Mean reward: 36.94
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5982
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.05s
#                         Total time: 56.76s
#                                ETA: 48.7s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2455076 steps/s (collection: 0.655s, learning 3.350s)
#                Value function loss: 225.9137
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.08
#                        Mean reward: 37.36
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6050
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.00s
#                         Total time: 60.76s
#                                ETA: 44.6s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2421618 steps/s (collection: 0.645s, learning 3.414s)
#                Value function loss: 240.6575
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.14
#                        Mean reward: 36.88
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6092
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.06s
#                         Total time: 64.82s
#                                ETA: 40.5s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2334624 steps/s (collection: 0.641s, learning 3.570s)
#                Value function loss: 219.2236
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.19
#                        Mean reward: 36.34
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6100
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.21s
#                         Total time: 69.03s
#                                ETA: 36.5s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2332793 steps/s (collection: 0.670s, learning 3.544s)
#                Value function loss: 236.7052
#                     Surrogate loss: 0.0010
#              Mean action noise std: 5.24
#                        Mean reward: 37.84
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6107
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.21s
#                         Total time: 73.25s
#                                ETA: 32.6s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2334757 steps/s (collection: 0.640s, learning 3.570s)
#                Value function loss: 216.7438
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.30
#                        Mean reward: 37.75
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6121
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.21s
#                         Total time: 77.46s
#                                ETA: 28.5s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2329300 steps/s (collection: 0.643s, learning 3.577s)
#                Value function loss: 237.2032
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.34
#                        Mean reward: 38.11
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6096
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.22s
#                         Total time: 81.68s
#                                ETA: 24.5s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2330171 steps/s (collection: 0.639s, learning 3.579s)
#                Value function loss: 223.8593
#                     Surrogate loss: 0.0007
#              Mean action noise std: 5.40
#                        Mean reward: 38.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6152
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.22s
#                         Total time: 85.90s
#                                ETA: 20.5s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2334844 steps/s (collection: 0.667s, learning 3.543s)
#                Value function loss: 243.5801
#                     Surrogate loss: 0.0012
#              Mean action noise std: 5.46
#                        Mean reward: 39.06
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6217
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.21s
#                         Total time: 90.11s
#                                ETA: 16.4s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2335794 steps/s (collection: 0.652s, learning 3.557s)
#                Value function loss: 214.8837
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.52
#                        Mean reward: 37.28
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6268
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.21s
#                         Total time: 94.32s
#                                ETA: 12.3s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2405797 steps/s (collection: 0.643s, learning 3.443s)
#                Value function loss: 234.2015
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.58
#                        Mean reward: 39.68
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6325
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.09s
#                         Total time: 98.40s
#                                ETA: 8.2s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2414075 steps/s (collection: 0.649s, learning 3.423s)
#                Value function loss: 214.1966
#                     Surrogate loss: 0.0009
#              Mean action noise std: 5.65
#                        Mean reward: 39.27
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6347
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.07s
#                         Total time: 102.47s
#                                ETA: 4.1s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 0.6743329617182413
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2401722 steps/s (collection: 0.675s, learning 3.418s)
#                Value function loss: 157.0478
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.60
#                        Mean reward: 26.16
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2497
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.09s
#                         Total time: 4.09s
#                                ETA: 102.3s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2400489 steps/s (collection: 0.666s, learning 3.429s)
#                Value function loss: 174.5448
#                     Surrogate loss: -0.0006
#              Mean action noise std: 4.62
#                        Mean reward: 27.92
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4230
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.10s
#                         Total time: 8.19s
#                                ETA: 98.3s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2414730 steps/s (collection: 0.643s, learning 3.428s)
#                Value function loss: 175.1277
#                     Surrogate loss: -0.0003
#              Mean action noise std: 4.64
#                        Mean reward: 29.00
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4570
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.07s
#                         Total time: 12.26s
#                                ETA: 94.0s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2410548 steps/s (collection: 0.650s, learning 3.428s)
#                Value function loss: 198.0400
#                     Surrogate loss: -0.0004
#              Mean action noise std: 4.67
#                        Mean reward: 30.42
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4807
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.08s
#                         Total time: 16.34s
#                                ETA: 89.9s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2416292 steps/s (collection: 0.654s, learning 3.414s)
#                Value function loss: 186.9703
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.71
#                        Mean reward: 31.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5076
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.07s
#                         Total time: 20.41s
#                                ETA: 85.7s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2448552 steps/s (collection: 0.652s, learning 3.363s)
#                Value function loss: 213.1437
#                     Surrogate loss: -0.0002
#              Mean action noise std: 4.73
#                        Mean reward: 34.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5228
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.01s
#                         Total time: 24.42s
#                                ETA: 81.4s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2442281 steps/s (collection: 0.664s, learning 3.361s)
#                Value function loss: 199.3139
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.76
#                        Mean reward: 35.71
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5457
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.03s
#                         Total time: 28.45s
#                                ETA: 77.2s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2447445 steps/s (collection: 0.660s, learning 3.356s)
#                Value function loss: 236.0477
#                     Surrogate loss: 0.0003
#              Mean action noise std: 4.79
#                        Mean reward: 34.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5648
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.02s
#                         Total time: 32.46s
#                                ETA: 73.0s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2455865 steps/s (collection: 0.648s, learning 3.355s)
#                Value function loss: 210.4218
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.83
#                        Mean reward: 34.73
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5766
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.00s
#                         Total time: 36.46s
#                                ETA: 68.9s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2451025 steps/s (collection: 0.659s, learning 3.352s)
#                Value function loss: 241.9700
#                     Surrogate loss: 0.0003
#              Mean action noise std: 4.87
#                        Mean reward: 37.64
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5814
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.01s
#                         Total time: 40.48s
#                                ETA: 64.8s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2441062 steps/s (collection: 0.658s, learning 3.369s)
#                Value function loss: 215.4375
#                     Surrogate loss: 0.0004
#              Mean action noise std: 4.92
#                        Mean reward: 37.06
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5909
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.03s
#                         Total time: 44.50s
#                                ETA: 60.7s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2458764 steps/s (collection: 0.648s, learning 3.350s)
#                Value function loss: 250.8922
#                     Surrogate loss: -0.0002
#              Mean action noise std: 4.96
#                        Mean reward: 37.28
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5973
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.00s
#                         Total time: 48.50s
#                                ETA: 56.6s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2448740 steps/s (collection: 0.650s, learning 3.364s)
#                Value function loss: 224.8716
#                     Surrogate loss: -0.0000
#              Mean action noise std: 5.00
#                        Mean reward: 38.15
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6089
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.01s
#                         Total time: 52.52s
#                                ETA: 52.5s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2457447 steps/s (collection: 0.659s, learning 3.341s)
#                Value function loss: 261.6472
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.04
#                        Mean reward: 38.88
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6223
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.00s
#                         Total time: 56.52s
#                                ETA: 48.4s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2461720 steps/s (collection: 0.642s, learning 3.352s)
#                Value function loss: 230.5144
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.07
#                        Mean reward: 39.60
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6342
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 3.99s
#                         Total time: 60.51s
#                                ETA: 44.4s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2462020 steps/s (collection: 0.651s, learning 3.342s)
#                Value function loss: 263.5007
#                     Surrogate loss: 0.0008
#              Mean action noise std: 5.12
#                        Mean reward: 38.97
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6398
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 3.99s
#                         Total time: 64.50s
#                                ETA: 40.3s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2443642 steps/s (collection: 0.668s, learning 3.355s)
#                Value function loss: 227.2296
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.18
#                        Mean reward: 38.46
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6419
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.02s
#                         Total time: 68.52s
#                                ETA: 36.3s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2465487 steps/s (collection: 0.641s, learning 3.346s)
#                Value function loss: 254.9773
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.22
#                        Mean reward: 39.79
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6439
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 3.99s
#                         Total time: 72.51s
#                                ETA: 32.2s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2436706 steps/s (collection: 0.643s, learning 3.392s)
#                Value function loss: 228.2811
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.28
#                        Mean reward: 39.84
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6485
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.03s
#                         Total time: 76.55s
#                                ETA: 28.2s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2458033 steps/s (collection: 0.645s, learning 3.354s)
#                Value function loss: 253.8094
#                     Surrogate loss: 0.0010
#              Mean action noise std: 5.32
#                        Mean reward: 40.46
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6480
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.00s
#                         Total time: 80.55s
#                                ETA: 24.2s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2452486 steps/s (collection: 0.661s, learning 3.347s)
#                Value function loss: 226.8350
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.39
#                        Mean reward: 39.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6506
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.01s
#                         Total time: 84.55s
#                                ETA: 20.1s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2466232 steps/s (collection: 0.642s, learning 3.344s)
#                Value function loss: 265.7198
#                     Surrogate loss: 0.0005
#              Mean action noise std: 5.44
#                        Mean reward: 40.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6537
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 3.99s
#                         Total time: 88.54s
#                                ETA: 16.1s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2446735 steps/s (collection: 0.662s, learning 3.356s)
#                Value function loss: 235.5469
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.52
#                        Mean reward: 39.57
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6553
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.02s
#                         Total time: 92.56s
#                                ETA: 12.1s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2461893 steps/s (collection: 0.648s, learning 3.345s)
#                Value function loss: 260.2474
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.57
#                        Mean reward: 41.25
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6579
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 3.99s
#                         Total time: 96.55s
#                                ETA: 8.0s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2461956 steps/s (collection: 0.653s, learning 3.340s)
#                Value function loss: 227.9286
#                     Surrogate loss: 0.0014
#              Mean action noise std: 5.65
#                        Mean reward: 40.04
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6531
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 3.99s
#                         Total time: 100.54s
#                                ETA: 4.0s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 3.975276669502258
# ################################################################################
#                         Learning iteration 25/50
#
#                        Computation: 2412808 steps/s (collection: 0.714s, learning 3.360s)
#                Value function loss: 229.9449
#                     Surrogate loss: 0.0017
#              Mean action noise std: 5.72
#                        Mean reward: 40.30
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3940
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.07s
#                         Total time: 4.07s
#                                ETA: 0.0s
#
# ################################################################################
#                         Learning iteration 26/50
#
#                        Computation: 2456203 steps/s (collection: 0.650s, learning 3.352s)
#                Value function loss: 263.6494
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.79
#                        Mean reward: 40.57
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6495
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.00s
#                         Total time: 8.08s
#                                ETA: -0.3s
#
# ################################################################################
#                         Learning iteration 27/50
#
#                        Computation: 2466502 steps/s (collection: 0.644s, learning 3.342s)
#                Value function loss: 237.8968
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.85
#                        Mean reward: 39.74
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6553
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 3.99s
#                         Total time: 12.06s
#                                ETA: -0.9s
#
# ################################################################################
#                         Learning iteration 28/50
#
#                        Computation: 2447343 steps/s (collection: 0.671s, learning 3.345s)
#                Value function loss: 280.1582
#                     Surrogate loss: 0.0005
#              Mean action noise std: 5.90
#                        Mean reward: 39.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6547
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.02s
#                         Total time: 16.08s
#                                ETA: -1.7s
#
# ################################################################################
#                         Learning iteration 29/50
#
#                        Computation: 2443796 steps/s (collection: 0.660s, learning 3.362s)
#                Value function loss: 243.0085
#                     Surrogate loss: 0.0013
#              Mean action noise std: 5.97
#                        Mean reward: 39.82
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6574
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.02s
#                         Total time: 20.10s
#                                ETA: -2.7s
#
# ################################################################################
#                         Learning iteration 30/50
#
#                        Computation: 2443571 steps/s (collection: 0.665s, learning 3.358s)
#                Value function loss: 285.8637
#                     Surrogate loss: -0.0001
#              Mean action noise std: 6.02
#                        Mean reward: 41.19
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6550
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.02s
#                         Total time: 24.12s
#                                ETA: -3.9s
#
# ################################################################################
#                         Learning iteration 31/50
#
#                        Computation: 2454273 steps/s (collection: 0.653s, learning 3.352s)
#                Value function loss: 246.6793
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.10
#                        Mean reward: 41.13
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6567
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.01s
#                         Total time: 28.13s
#                                ETA: -5.3s
#
# ################################################################################
#                         Learning iteration 32/50
#
#                        Computation: 2467706 steps/s (collection: 0.640s, learning 3.343s)
#                Value function loss: 295.9354
#                     Surrogate loss: 0.0019
#              Mean action noise std: 6.16
#                        Mean reward: 39.94
# ...
#                    Total timesteps: 78643200
#                     Iteration time: 4.07s
#                         Total time: 32.76s
#                                ETA: -32.2s
#
# ################################################################################
#                       Learning iteration 1433/1450
#
#                        Computation: 2449718 steps/s (collection: 0.655s, learning 3.358s)
#                Value function loss: 457.1822
#                     Surrogate loss: 0.0005
#              Mean action noise std: 2981.90
#                        Mean reward: 45.66
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7469
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.01s
#                         Total time: 36.77s
#                                ETA: -36.1s
#
# ################################################################################
#                       Learning iteration 1434/1450
#
#                        Computation: 2450584 steps/s (collection: 0.649s, learning 3.362s)
#                Value function loss: 563.0091
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2984.77
#                        Mean reward: 45.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7470
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.01s
#                         Total time: 40.78s
#                                ETA: -40.0s
#
# ################################################################################
#                       Learning iteration 1435/1450
#
#                        Computation: 2422360 steps/s (collection: 0.651s, learning 3.407s)
#                Value function loss: 464.4363
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2987.70
#                        Mean reward: 46.05
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7473
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.06s
#                         Total time: 44.84s
#                                ETA: -44.0s
#
# ################################################################################
#                       Learning iteration 1436/1450
#
#                        Computation: 2453762 steps/s (collection: 0.647s, learning 3.359s)
#                Value function loss: 571.2451
#                     Surrogate loss: 0.0002
#              Mean action noise std: 2990.54
#                        Mean reward: 45.55
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7472
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.01s
#                         Total time: 48.85s
#                                ETA: -48.0s
#
# ################################################################################
#                       Learning iteration 1437/1450
#
#                        Computation: 2452368 steps/s (collection: 0.671s, learning 3.337s)
#                Value function loss: 470.0963
#                     Surrogate loss: 0.0000
#              Mean action noise std: 2993.44
#                        Mean reward: 45.70
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7472
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.01s
#                         Total time: 52.85s
#                                ETA: -51.9s
#
# ################################################################################
#                       Learning iteration 1438/1450
#
#                        Computation: 2443138 steps/s (collection: 0.663s, learning 3.361s)
#                Value function loss: 578.5914
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2996.36
#                        Mean reward: 45.66
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7472
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.02s
#                         Total time: 56.88s
#                                ETA: -55.8s
#
# ################################################################################
#                       Learning iteration 1439/1450
#
#                        Computation: 2408088 steps/s (collection: 0.687s, learning 3.395s)
#                Value function loss: 475.9570
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2999.37
#                        Mean reward: 45.81
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7471
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.08s
#                         Total time: 60.96s
#                                ETA: -59.9s
#
# ################################################################################
#                       Learning iteration 1440/1450
#
#                        Computation: 2453793 steps/s (collection: 0.647s, learning 3.359s)
#                Value function loss: 586.9453
#                     Surrogate loss: 0.0004
#              Mean action noise std: 3002.27
#                        Mean reward: 45.67
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7467
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.01s
#                         Total time: 64.97s
#                                ETA: -63.8s
#
# ################################################################################
#                       Learning iteration 1441/1450
#
#                        Computation: 2450131 steps/s (collection: 0.675s, learning 3.337s)
#                Value function loss: 481.8532
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3005.14
#                        Mean reward: 45.80
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7466
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.01s
#                         Total time: 68.98s
#                                ETA: -67.7s
#
# ################################################################################
#                       Learning iteration 1442/1450
#
#                        Computation: 2468833 steps/s (collection: 0.642s, learning 3.340s)
#                Value function loss: 594.5553
#                     Surrogate loss: 0.0002
#              Mean action noise std: 3008.06
#                        Mean reward: 45.77
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7469
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 3.98s
#                         Total time: 72.96s
#                                ETA: -71.6s
#
# ################################################################################
#                       Learning iteration 1443/1450
#
#                        Computation: 2462436 steps/s (collection: 0.653s, learning 3.339s)
#                Value function loss: 487.4327
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3011.02
#                        Mean reward: 45.59
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7473
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 3.99s
#                         Total time: 76.95s
#                                ETA: -75.6s
#
# ################################################################################
#                       Learning iteration 1444/1450
#
#                        Computation: 2474019 steps/s (collection: 0.648s, learning 3.325s)
#                Value function loss: 603.9860
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3013.91
#                        Mean reward: 45.88
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7472
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 3.97s
#                         Total time: 80.93s
#                                ETA: -79.5s
#
# ################################################################################
#                       Learning iteration 1445/1450
#
#                        Computation: 2465753 steps/s (collection: 0.661s, learning 3.326s)
#                Value function loss: 493.0037
#                     Surrogate loss: 0.0011
#              Mean action noise std: 3016.70
#                        Mean reward: 45.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7470
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 3.99s
#                         Total time: 84.91s
#                                ETA: -83.4s
#
# ################################################################################
#                       Learning iteration 1446/1450
#
#                        Computation: 2470355 steps/s (collection: 0.648s, learning 3.332s)
#                Value function loss: 610.8367
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3019.43
#                        Mean reward: 45.43
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7469
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 3.98s
#                         Total time: 88.89s
#                                ETA: -87.3s
#
# ################################################################################
#                       Learning iteration 1447/1450
#
#                        Computation: 2437313 steps/s (collection: 0.692s, learning 3.342s)
#                Value function loss: 499.0864
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3022.31
#                        Mean reward: 45.94
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7472
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.03s
#                         Total time: 92.93s
#                                ETA: -91.3s
#
# ################################################################################
#                       Learning iteration 1448/1450
#
#                        Computation: 2477837 steps/s (collection: 0.645s, learning 3.322s)
#                Value function loss: 620.2218
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3025.15
#                        Mean reward: 45.87
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7476
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 3.97s
#                         Total time: 96.89s
#                                ETA: -95.2s
#
# ################################################################################
#                       Learning iteration 1449/1450
#
#                        Computation: 2464958 steps/s (collection: 0.661s, learning 3.327s)
#                Value function loss: 506.9848
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3028.02
#                        Mean reward: 45.82
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7480
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 3.99s
#                         Total time: 100.88s
#                                ETA: -99.1s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 1490.014298641493
# score     : [ 498.77706676 3530.2232029   105.54171226   79.74331626  115.09696639
#   992.25939906  232.04930113 3530.62547642  147.85303751  335.84687297
#   226.52513859  520.10096196   47.04425963  218.20188837  183.45510158
#   145.33191186 2289.18890936 4395.09942196   77.20736185  292.2950087
#  1112.34802907 4899.56583093  177.73445737 5348.98715181  215.35216918
#   156.5286442  5804.36752707   58.16988737   92.79821469  170.01094337
#   196.95466813 5698.24617469   54.74040179   88.81070763  116.59391787
#    66.90911077   74.55086025 5496.66626981 1086.88435423 2497.82519943
#   348.38131894  170.12123975  404.7449137    53.51063691   57.12858622
#   119.69754491 3867.62776594 3928.20302914  114.6014999   132.75919236
#  4262.02936932 5213.15763645 1023.95315971  498.95224849 5030.23222968
#    70.79425572 2635.39280715   50.31901712  129.36881706  120.73910591
#  2640.88455577 2554.73240269   63.42927539  196.38451137 2490.7646543
#   187.88445749  224.90357724  497.87560809 3058.41313321 5914.52361266
#   203.93526465  127.20027741 5250.85599117 5759.67738883 5868.24699103
#  6353.42292506  134.55297489   52.3775154   377.67774059   49.27066209
#    53.81113186 6024.43518689 5706.2373985    51.55195564  330.77548287
#   153.88922193  215.83818063   86.0266407   857.21660184  102.57804453
#  1908.93195677 3884.29464286 4466.15882235 1416.61094421   60.39107559
#    79.93173737 1056.9657475   780.14101723   59.97128541   90.43406057]
# score.mean: 1490.014298641493

# %%
exp_result = {
    'reward_total': reward_history,
    'reward_peo': death_buf,
    'state': state_his_buf,
    'action': act_buf
}
torch.save(exp_result, 'exp4-t2400.pt')

# %%
run_result = torch.load('exp4-t2400.pt', weights_only=False)
death_mean = torch.mean(run_result['state'][-1][:,4]) * N
print(death_mean)

def infections(states, action, para, i):
    st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
    u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
    ht = st + et + at + it + rt

    st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * para['beta1'][i] + (et + at * (1 - u_aq)) * para['beta2'][i]) / ht
    st_out_e = st_out * parameter_static['alpha']
    st_out_i = st_out * (1 - parameter_static['alpha'])
    et_out_a = et * w * (1 - para['per'] - para['pei'])
    return et_out_a, st_out_e, st_out_i


init_state = torch.tensor([[100000, 20 , 0, 0, 0, 0]], dtype=torch.float32).to(torch.device(device))
s_i = torch.zeros(100).to(torch.device('cuda:0'))
s_a = torch.zeros(100).to(torch.device('cuda:0'))
s_t = torch.zeros(100).to(torch.device('cuda:0'))
for i in range(test_num):
    for t in range(T):
        if t == 0:
            sa_temp, se_temp, si_temp = infections(init_state, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        if t > 0 and t < T-1:
            sa_temp, se_temp, si_temp = infections(run_result['state'][t-1][i][:6].unsqueeze(0)*N, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        s_i[i] += si_temp[0]
        s_a[i] += sa_temp[0]
        s_t[i] += se_temp[0]
print([torch.mean(s_i), torch.mean(s_a)+torch.mean(s_i), torch.mean(s_t)])
# Out:
# tensor(141.05647, device='cuda:0')
# [tensor(11858.29980, device='cuda:0'), tensor(11950.66016, device='cuda:0'), tensor(17787.45117, device='cuda:0')]
