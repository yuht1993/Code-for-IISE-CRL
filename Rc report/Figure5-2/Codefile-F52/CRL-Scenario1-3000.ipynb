# %%
from rsl_rl.env import VecEnv
from rsl_rl.runners import OnPolicyRunner
import torch
import numpy as np
torch.set_printoptions(precision=5, linewidth=200, sci_mode=False)

N          = 100020
state_dim  = 8
action_dim = 5
T          = 60
budget     = 3000.
N_envs     = 1024 * 64
ΔT         = 1.0
device     = 'cuda'
usr_std = 0.1
test_num = 100
seed = 0

parameter_static = dict(N          = N,
                        B          = budget,
                        T          = T,
                        alpha      = 0.6,
                        v_max      = 0.2/14,
                        cost_ti    = 0.0977,
                        cost_ta    = 0.02,
                        cost_v     = 0.07,
                        cost_poc_0 = 0.000369,
                        cost_poc_1 = 0.001057,
                        pid        = 1.10/1000,
                        psr        = 0.7,
                        pid_plus   = 0.1221/1000,
                        pir        = 1/8,
                        prs        = 1/7)

Random_mean = {"beta2" : 0.78735,
               "beta1" : 0.15747,
               "pei"   : 0.10714,
               "per"   : 0.04545}

space = {"beta2" : [Random_mean['beta2'],Random_mean['beta2']*usr_std],
         "beta1" : [Random_mean['beta1'], Random_mean['beta1']*usr_std],
         "pei"   : [Random_mean['pei'], Random_mean['pei']*usr_std],
         "per"   : [Random_mean['per'], Random_mean['per']*usr_std]}

Init_state = torch.tensor([[100000 / N, 20 / N, 0, 0, 0, 0, 1, 0]], 
                         dtype=torch.float32).to(torch.device(device))

# %%
class myVecEnv(VecEnv):
    def __init__(self, interval, n_envs = N_envs):
        self.B = parameter_static['B']  # total budget
        self.N = parameter_static['N']
        self.device = device
        self.init_state = Init_state
        self.states = self.init_state.repeat(n_envs, 1)
        self.num_envs = n_envs
        self.num_obs = state_dim
        self.num_privileged_obs = None
        self.num_actions = action_dim
        self.max_episode_length = parameter_static['T']
        
        torch.manual_seed(seed)
        self.parameter_random = {
            key: torch.empty(self.num_envs).normal_(
                interval[key][0],
                interval[key][1]
            ).to(torch.device(device))
            for key, value in Random_mean.items()
        }

        for key, value in Random_mean.items():
            indice = self.parameter_random[key] < 0
            self.parameter_random[key][indice] = -self.parameter_random[key][indice] 

        # optimization flags for pytorch JIT
        torch._C._jit_set_profiling_mode(False)
        torch._C._jit_set_profiling_executor(False)
        
        # allocate buffers
        self.privileged_obs_buf = None
        self.obs_buf = torch.zeros(self.num_envs, self.num_obs, device=self.device, dtype=torch.float)
        self.rew_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.float)
        self.reset_buf = torch.ones(self.num_envs, device=self.device, dtype=torch.long)
        self.episode_length_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.long)
        
        self.actions = torch.zeros(self.num_envs, self.num_actions, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_sums = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_acts = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.extras = {}
    
    def para_update(self, para):
        self.parameter_random = para
        
    def step(self, actions):
        # actions clip
        soft_bound = [-0.5, 1.5]
        out_of_limits = -(actions - soft_bound[0]).clip(max=0.)
        out_of_limits += (actions - soft_bound[1]).clip(min=0.)
        scale_action = -0.1
        reward_action = scale_action * torch.sum(out_of_limits, dim=1).clip(max=1.).to(self.device)
        self.actions = torch.clip(actions, 0., 1.).to(self.device)

        # update actions & states
        b, p = self.states[:, -2] * self.B, self.states[:, -1]
        inv_c = self.cost_function(self.actions)
        b -= inv_c
        b = torch.clip(b, 0., self.B).to(self.device)
        mask = (b > 0).float().unsqueeze(-1)
        self.act = self.actions * mask
        inv_c = self.cost_function(self.act)
        next_state, reward_original = self.transition(self.act)
        self.extras['reward_original'] = reward_original
        self.extras['inv_cost'] = inv_c
        self.episode_length_buf += 1
        p = self.episode_length_buf / self.max_episode_length
        self.states = torch.cat([next_state / self.N, (b / self.B).unsqueeze(-1), p.unsqueeze(-1)], dim=-1)
        
        # check termination
        self.reset_buf = self.episode_length_buf >= self.max_episode_length
        
        # compute reward
        r_mean = -6584
        r_std  =  7347
        reward = (reward_original - inv_c - r_mean) / r_std
        #if reward > 0: 
        #reward = torch.exp(reward)/10
        #reward = torch.exp((1e5 + reward_original - inv_c) / 5e4)
        self.rew_buf       = reward + reward_action
        self.episode_sums += reward + reward_action
        self.episode_acts += reward_action
        
        # compute resets
        env_ids = self.reset_buf.nonzero(as_tuple=False).flatten()
        self.reset_idx(env_ids)
        
        # compute observations
        return self.get_observations(), self.states, self.rew_buf, self.reset_buf, self.extras

    def reset_idx(self, env_ids):
        """Reset selected robots"""
        if len(env_ids) == 0:
            return
        
        assert len(env_ids) == self.num_envs
        # reset robot states
        self.states[env_ids] = self.init_state
        # reset buffers
        self.episode_length_buf[env_ids] = 0
        self.reset_buf[env_ids] = 1
        # fill extras
        self.extras["episode"] = {}
        self.extras["episode"]['rew_sum'] = torch.mean(self.episode_sums[env_ids]) / (self.max_episode_length * ΔT)
        self.extras["episode"]['rew_act'] = torch.mean(self.episode_acts[env_ids]) / (self.max_episode_length * ΔT)
        self.episode_sums[env_ids] = 0.
        self.episode_acts[env_ids] = 0.
    
    def reset(self):
        """ Reset all robots"""
        self.reset_idx(torch.arange(self.num_envs, device=self.device))
        return {}, {}
    
    def get_observations(self):
        o_mean = torch.tensor([[0.58712867, 0.06804276, 0.00308146, 0.25684301, 0.00261079, 0.08229331, 0.26572794, 0.51      ]], dtype=torch.float32).to(torch.device(self.device))
        o_std  = torch.tensor([[0.41484398, 0.07883003, 0.00389494, 0.292568  , 0.00394907, 0.06906768, 0.33943075, 0.28861739]], dtype=torch.float32).to(torch.device(self.device))
        self.obs_buf = (self.states - o_mean) / o_std
        return self.obs_buf
    
    def get_privileged_observations(self):
        return self.privileged_obs_buf

    def cost_function(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]

        cost_it  = it * u_it * parameter_static['cost_ti']
        cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
        cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
        per_poc  = ((st + et + at + rt) / self.N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
        cost_poc = (st + et + rt + at) * w * per_poc
        return cost_poc + cost_it + cost_v + cost_q

    def transition(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
        ht = st + et + at + it + rt

        st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * self.parameter_random['beta1'] + (et + at * (1 - u_aq)) * self.parameter_random['beta2']) / ht
        st_out_e = st_out * parameter_static['alpha']
        st_out_i = st_out * (1 - parameter_static['alpha'])
        st_out_r = u_sv * parameter_static['v_max'] * st * parameter_static['psr']
        et_out_r = et * self.parameter_random['per']
        et_out_i = et * self.parameter_random['pei']
        et_out_a = et * w * (1 - self.parameter_random['per'] - self.parameter_random['pei'])
        at_out_i = at * self.parameter_random['pei']
        at_out_r = at * self.parameter_random['per']
        it_out_r = it * parameter_static['pir'] * u_it
        it_out_d = it * parameter_static['pid'] * (1 - u_it) + it * u_it * parameter_static['pid_plus']
        rt_out_s = rt * parameter_static['prs']
        
        stn = st - st_out_e - st_out_i - st_out_r + rt_out_s
        etn = et - et_out_r - et_out_i - et_out_a + st_out_e
        atn = at - at_out_r - at_out_i + et_out_a
        itn = it - it_out_r - it_out_d + st_out_i + et_out_i + at_out_i
        dtn = dt + it_out_d
        rtn = rt + et_out_r + at_out_r + it_out_r + st_out_r - rt_out_s

        reward = -2.6 * st_out - 100 * it_out_d

        next_state = torch.stack([stn, etn, atn, itn, dtn, rtn], dim=-1)
        return next_state, reward

# %%
import inspect

class BaseConfig:
    def __init__(self) -> None:
        """ Initializes all member classes recursively. Ignores all namse starting with '__' (buit-in methods)."""
        self.init_member_classes(self)
    
    @staticmethod
    def init_member_classes(obj):
        # iterate over all attributes names
        for key in dir(obj):
            # disregard builtin attributes
            # if key.startswith("__"):
            if key=="__class__":
                continue
            # get the corresponding attribute object
            var =  getattr(obj, key)
            # check if it the attribute is a class
            if inspect.isclass(var):
                # instantate the class
                i_var = var()
                # set the attribute to the instance instead of the type
                setattr(obj, key, i_var)
                # recursively init members of the attribute
                BaseConfig.init_member_classes(i_var)

class LeggedRobotCfgPPO(BaseConfig):
    seed = 1
    runner_class_name = 'OnPolicyRunner'
    class policy:
        init_noise_std = 2
        actor_hidden_dims  = [64, 32, 16] 
        critic_hidden_dims = [64, 32, 16]
        activation = 'elu' # can be elu, relu, selu, crelu, lrelu, tanh, sigmoid
        # only for 'ActorCriticRecurrent':
        # rnn_type = 'lstm'
        # rnn_hidden_size = 512
        # rnn_num_layers = 1
        
    class algorithm:
        # training params
        value_loss_coef = 0.5
        use_clipped_value_loss = True
        clip_param = 0.2
        entropy_coef = 0.01
        num_learning_epochs = 5
        num_mini_batches = 64 # mini batch size = num_envs*nsteps / nminibatches
        learning_rate = 1.e-4
        schedule = 'adaptive' # could be adaptive, fixed
        gamma = 0.99
        lam = 0.95
        desired_kl = 0.01
        max_grad_norm = 1.

    class runner:
        policy_class_name = 'ActorCritic'
        algorithm_class_name = 'PPO'
        num_steps_per_env =  150 # per iteration
        max_iterations    = 100 # number of policy updates

        # logging
        save_interval = 100 # check for potential saves every this many iterations
        experiment_name = 'test'
        run_name = ''
        # load and resume
        resume = True
        load_run = -1 # -1 = last run
        checkpoint = -1 # -1 = last saved model
        resume_path = None # updated from load_run and chkpt
        
def class_to_dict(obj) -> dict:
    if not  hasattr(obj,"__dict__"):
        return obj
    result = {}
    for key in dir(obj):
        if key.startswith("_"):
            continue
        element = []
        val = getattr(obj, key)
        if isinstance(val, list):
            for item in val:
                element.append(class_to_dict(item))
        else:
            element = class_to_dict(val)
        result[key] = element
    return result

# %%
def para_sampling(intvl, num_sample=N_envs):
    parameter_random = {
        key: torch.empty(num_sample).normal_(
        intvl[key][0],
        intvl[key][1]
        ).to(torch.device(device))
        for key, value in Random_mean.items()
    }
    for key, value in Random_mean.items():
        indice = parameter_random[key] < 0
        parameter_random[key][indice] = -parameter_random[key][indice] 
    return parameter_random

def update_space(final_indices, para_buf, space):
    para_est = {}
    for key, tensor_values in para_buf.items():
        selected_values = torch.mean(tensor_values[final_indices[0], final_indices[1]]) 
        para_values = torch.mean(tensor_values[final_indices[0], final_indices[1]], dim=0)
        update_values = space[key][0] + 0.5 * (selected_values - space[key][0])
        space[key] = [update_values , update_values  * 0.1]
        para_est[key] = para_values
    return space, para_est


def cal_err(para_value, env_para):
    gap = []
    for key, value in env_para.items():
        gap_temp = torch.mean(torch.abs(para_value[key] - env_para[key])/(env_para[key]))
        gap.append(gap_temp)
    return sum(gap)/len(gap) # 所有值都在范围内，返回 0
    
def state_estimator(env_sample, action_sim, state_sim, state_prior, space, iter): 
    env_sample.reset()
    env_sample.states = state_prior  
    para_buf, mse_buf, obs_buf, states_buf = {}, {}, {}, {}
    for i in range(iter):
        para = para_sampling(space, test_num)
        env_sample.para_update(para)
        obs_sample, states_sample, _, _, _ = env_sample.step(action_sim.detach())  
        mse = torch.mean((state_sim[:,2:4] - states_sample[:,2:4]) ** 2, dim=1) 
        if i == 0:
            mse_buf = mse.unsqueeze(0)
            obs_buf = obs_sample.unsqueeze(0)
            states_buf = states_sample.unsqueeze(0)
            for key, values in para.items():
                para_buf[key] = para[key].unsqueeze(0)
        else:
            mse_buf = torch.cat((mse_buf, mse.unsqueeze(0)), dim=0)
            obs_buf = torch.cat((obs_buf, obs_sample.unsqueeze(0)),dim=0)
            states_buf = torch.cat((states_buf, states_sample.unsqueeze(0)), dim=0)
            for key, values in para.items():
                para_buf[key] = torch.cat((para_buf[key], para[key].unsqueeze(0)), dim=0)
                
     
    k = int(iter * 0.05)
    _, row_indices = torch.topk(mse_buf, k=k, dim=0, largest=False)
    column_indices = torch.arange(mse_buf.shape[1]).repeat(k, 1)
    top_indices = [row_indices, column_indices]
    obs_est = torch.mean(obs_buf[row_indices,column_indices,:], dim=0)
    state_est = torch.mean(states_buf[row_indices,column_indices,:], dim=0)
    state_est[:,-1] = state_prior[:,-1] + torch.tensor(1/T)
    return obs_est, state_est, top_indices, para_buf

# %%
para_err = 0.5
torch.manual_seed(seed)
para_true = []
para_temp = {
    key: torch.empty(test_num).uniform_(
        value * (1-para_err),
        value * (1+para_err)
    ).to(torch.device(device))
    for key, value in Random_mean.items()
}


para = {}
for t in range(T):
    para = {
        key: (para_temp[key] + t * 0.5 *  para_temp[key] /T).to(torch.device(device)) if key == 'per' 
        else (para_temp[key] - t * 0.5 *  para_temp[key] /T).to(torch.device(device))
        for key, value in Random_mean.items()
        }
    para_true.append(para)

# %%
env = myVecEnv(space, test_num)
env.para_update(para_true[0])
train_cfg = LeggedRobotCfgPPO()
train_cfg_dict = class_to_dict(train_cfg)


env_transfer = myVecEnv(space)
runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_exp4_t1', device=env.device)
runner.load(f'rsl_low_budget3000/model_100.pt')

policy = runner.get_inference_policy(device=env.device)

reward_history = []
act_buf = []
state_his_buf = []
death_buf = []

env_sample = myVecEnv(space, test_num)
state_est = env.states
obs_est = env.get_observations()
for t in range(T-1):
    actions = policy(obs_est.detach())
    obs, states, _, _, infos = env.step(actions.detach())
    reward_history.append((-infos['reward_original'] + infos['inv_cost']).tolist())
    death_buf.append((-infos['reward_original']).tolist())
    act_buf.append(env.act)
    state_his_buf.append(env.states)
    obs_est, state_buf, top_indices, para_buf = state_estimator(env_sample, actions, states, state_est, space, 1024)
    space, para_v = update_space(top_indices, para_buf, space) 

    runner.learn(num_learning_iterations=25, init_at_random_ep_len=False)
    policy = runner.get_inference_policy(device=env.device)
    env_transfer = myVecEnv(space)
    runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_exp4_t1', device=env.device)
    runner.load(f'rsl_exp4_t1/model_{int(t)* 25}.pt')

    if t < T - 1: env.para_update(para_true[t + 1])
    print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')


reward_history = np.array(reward_history)
print(f'score     : {np.sum(reward_history, axis=0)/T       }')
print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
# Out:
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2326219 steps/s (collection: 0.655s, learning 3.571s)
#                Value function loss: 240.0202
#                     Surrogate loss: -0.0002
#              Mean action noise std: 4.48
#                        Mean reward: 38.18
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3681
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.23s
#                         Total time: 4.23s
#                                ETA: 105.6s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2415885 steps/s (collection: 0.658s, learning 3.411s)
#                Value function loss: 270.5890
#                     Surrogate loss: -0.0004
#              Mean action noise std: 4.51
#                        Mean reward: 38.94
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6122
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.07s
#                         Total time: 8.29s
#                                ETA: 99.5s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2446418 steps/s (collection: 0.642s, learning 3.376s)
#                Value function loss: 247.4682
#                     Surrogate loss: -0.0000
#              Mean action noise std: 4.55
#                        Mean reward: 39.78
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6328
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.02s
#                         Total time: 12.31s
#                                ETA: 94.4s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2442774 steps/s (collection: 0.651s, learning 3.373s)
#                Value function loss: 279.7865
#                     Surrogate loss: 0.0001
#              Mean action noise std: 4.58
#                        Mean reward: 39.18
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6466
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.02s
#                         Total time: 16.34s
#                                ETA: 89.9s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2448866 steps/s (collection: 0.642s, learning 3.372s)
#                Value function loss: 251.9759
#                     Surrogate loss: -0.0000
#              Mean action noise std: 4.63
#                        Mean reward: 40.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6569
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.01s
#                         Total time: 20.35s
#                                ETA: 85.5s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2405829 steps/s (collection: 0.641s, learning 3.445s)
#                Value function loss: 287.0494
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.66
#                        Mean reward: 41.62
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6607
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.09s
#                         Total time: 24.44s
#                                ETA: 81.5s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2433752 steps/s (collection: 0.651s, learning 3.388s)
#                Value function loss: 261.6251
#                     Surrogate loss: 0.0006
#              Mean action noise std: 4.72
#                        Mean reward: 42.29
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6722
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.04s
#                         Total time: 28.48s
#                                ETA: 77.3s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2425959 steps/s (collection: 0.645s, learning 3.407s)
#                Value function loss: 301.2382
#                     Surrogate loss: -0.0002
#              Mean action noise std: 4.76
#                        Mean reward: 41.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6810
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.05s
#                         Total time: 32.53s
#                                ETA: 73.2s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2448466 steps/s (collection: 0.650s, learning 3.365s)
#                Value function loss: 268.8100
#                     Surrogate loss: 0.0001
#              Mean action noise std: 4.82
#                        Mean reward: 41.64
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6877
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.01s
#                         Total time: 36.54s
#                                ETA: 69.0s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2453116 steps/s (collection: 0.643s, learning 3.364s)
#                Value function loss: 309.7396
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.85
#                        Mean reward: 43.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6913
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.01s
#                         Total time: 40.55s
#                                ETA: 64.9s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2455826 steps/s (collection: 0.641s, learning 3.362s)
#                Value function loss: 275.9300
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.91
#                        Mean reward: 43.62
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6973
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.00s
#                         Total time: 44.55s
#                                ETA: 60.8s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2446961 steps/s (collection: 0.645s, learning 3.372s)
#                Value function loss: 317.8051
#                     Surrogate loss: 0.0006
#              Mean action noise std: 4.95
#                        Mean reward: 42.91
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6997
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.02s
#                         Total time: 48.57s
#                                ETA: 56.7s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2461934 steps/s (collection: 0.641s, learning 3.352s)
#                Value function loss: 281.7951
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.01
#                        Mean reward: 43.62
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7054
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 3.99s
#                         Total time: 52.56s
#                                ETA: 52.6s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2453637 steps/s (collection: 0.645s, learning 3.362s)
#                Value function loss: 330.4603
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.07
#                        Mean reward: 44.11
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7127
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.01s
#                         Total time: 56.57s
#                                ETA: 48.5s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2450715 steps/s (collection: 0.641s, learning 3.371s)
#                Value function loss: 293.0906
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.12
#                        Mean reward: 44.32
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7224
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.01s
#                         Total time: 60.58s
#                                ETA: 44.4s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2439023 steps/s (collection: 0.647s, learning 3.384s)
#                Value function loss: 342.0592
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.18
#                        Mean reward: 44.19
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7284
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.03s
#                         Total time: 64.61s
#                                ETA: 40.4s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2322316 steps/s (collection: 0.662s, learning 3.571s)
#                Value function loss: 297.7295
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.25
#                        Mean reward: 44.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7316
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.23s
#                         Total time: 68.85s
#                                ETA: 36.4s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2332729 steps/s (collection: 0.664s, learning 3.550s)
#                Value function loss: 347.1354
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.31
#                        Mean reward: 44.54
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7342
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.21s
#                         Total time: 73.06s
#                                ETA: 32.5s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2329173 steps/s (collection: 0.656s, learning 3.564s)
#                Value function loss: 302.5802
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.38
#                        Mean reward: 44.50
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7383
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.22s
#                         Total time: 77.28s
#                                ETA: 28.5s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2338129 steps/s (collection: 0.644s, learning 3.560s)
#                Value function loss: 352.8736
#                     Surrogate loss: 0.0007
#              Mean action noise std: 5.43
#                        Mean reward: 45.39
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7389
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.20s
#                         Total time: 81.48s
#                                ETA: 24.4s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2323658 steps/s (collection: 0.657s, learning 3.574s)
#                Value function loss: 305.8706
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.51
#                        Mean reward: 45.51
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7413
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.23s
#                         Total time: 85.72s
#                                ETA: 20.4s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2350250 steps/s (collection: 0.649s, learning 3.533s)
#                Value function loss: 356.5928
#                     Surrogate loss: 0.0007
#              Mean action noise std: 5.57
#                        Mean reward: 45.64
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7434
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.18s
#                         Total time: 89.90s
#                                ETA: 16.3s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2324557 steps/s (collection: 0.668s, learning 3.561s)
#                Value function loss: 308.9095
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.66
#                        Mean reward: 45.34
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7463
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.23s
#                         Total time: 94.13s
#                                ETA: 12.3s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2390119 steps/s (collection: 0.642s, learning 3.471s)
#                Value function loss: 360.3045
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.72
#                        Mean reward: 45.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7482
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.11s
#                         Total time: 98.24s
#                                ETA: 8.2s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2416043 steps/s (collection: 0.647s, learning 3.422s)
#                Value function loss: 308.0931
#                     Surrogate loss: 0.0008
#              Mean action noise std: 5.80
#                        Mean reward: 45.23
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7472
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.07s
#                         Total time: 102.31s
#                                ETA: 4.1s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 3.0514750366210937
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2391067 steps/s (collection: 0.686s, learning 3.425s)
#                Value function loss: 241.3107
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.53
#                        Mean reward: 38.98
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3768
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.11s
#                         Total time: 4.11s
#                                ETA: 102.8s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2418502 steps/s (collection: 0.645s, learning 3.419s)
#                Value function loss: 273.6232
#                     Surrogate loss: -0.0002
#              Mean action noise std: 4.55
#                        Mean reward: 39.89
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6263
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.06s
#                         Total time: 8.18s
#                                ETA: 98.1s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2419815 steps/s (collection: 0.643s, learning 3.419s)
#                Value function loss: 247.6838
#                     Surrogate loss: -0.0000
#              Mean action noise std: 4.60
#                        Mean reward: 40.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6426
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.06s
#                         Total time: 12.24s
#                                ETA: 93.8s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2417690 steps/s (collection: 0.646s, learning 3.420s)
#                Value function loss: 279.4521
#                     Surrogate loss: 0.0006
#              Mean action noise std: 4.63
#                        Mean reward: 39.43
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6524
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.07s
#                         Total time: 16.30s
#                                ETA: 89.7s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2420165 steps/s (collection: 0.642s, learning 3.419s)
#                Value function loss: 249.6322
#                     Surrogate loss: -0.0000
#              Mean action noise std: 4.68
#                        Mean reward: 39.92
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6602
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.06s
#                         Total time: 20.37s
#                                ETA: 85.5s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2448299 steps/s (collection: 0.655s, learning 3.360s)
#                Value function loss: 283.6637
#                     Surrogate loss: -0.0000
#              Mean action noise std: 4.71
#                        Mean reward: 41.57
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6619
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.02s
#                         Total time: 24.38s
#                                ETA: 81.3s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2460378 steps/s (collection: 0.642s, learning 3.353s)
#                Value function loss: 258.7252
#                     Surrogate loss: 0.0010
#              Mean action noise std: 4.76
#                        Mean reward: 42.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6728
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.00s
#                         Total time: 28.38s
#                                ETA: 77.0s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2438189 steps/s (collection: 0.665s, learning 3.367s)
#                Value function loss: 297.5766
#                     Surrogate loss: -0.0002
#              Mean action noise std: 4.80
#                        Mean reward: 41.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6818
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.03s
#                         Total time: 32.41s
#                                ETA: 72.9s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2464277 steps/s (collection: 0.642s, learning 3.348s)
#                Value function loss: 265.1323
#                     Surrogate loss: 0.0001
#              Mean action noise std: 4.86
#                        Mean reward: 41.50
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6864
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 3.99s
#                         Total time: 36.40s
#                                ETA: 68.8s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2462739 steps/s (collection: 0.644s, learning 3.348s)
#                Value function loss: 305.9618
#                     Surrogate loss: 0.0004
#              Mean action noise std: 4.89
#                        Mean reward: 43.19
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6903
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 3.99s
#                         Total time: 40.39s
#                                ETA: 64.6s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2452607 steps/s (collection: 0.646s, learning 3.362s)
#                Value function loss: 272.8695
#                     Surrogate loss: 0.0001
#              Mean action noise std: 4.95
#                        Mean reward: 43.53
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6961
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.01s
#                         Total time: 44.40s
#                                ETA: 60.5s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2453693 steps/s (collection: 0.655s, learning 3.351s)
#                Value function loss: 313.5746
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4.99
#                        Mean reward: 42.55
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6970
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.01s
#                         Total time: 48.40s
#                                ETA: 56.5s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2455286 steps/s (collection: 0.654s, learning 3.350s)
#                Value function loss: 279.5049
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.05
#                        Mean reward: 43.48
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7030
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.00s
#                         Total time: 52.41s
#                                ETA: 52.4s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2457349 steps/s (collection: 0.649s, learning 3.351s)
#                Value function loss: 327.3806
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.10
#                        Mean reward: 43.96
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7107
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.00s
#                         Total time: 56.41s
#                                ETA: 48.4s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2464969 steps/s (collection: 0.649s, learning 3.339s)
#                Value function loss: 290.2485
#                     Surrogate loss: 0.0015
#              Mean action noise std: 5.17
#                        Mean reward: 44.43
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7204
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 3.99s
#                         Total time: 60.40s
#                                ETA: 44.3s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2446740 steps/s (collection: 0.670s, learning 3.347s)
#                Value function loss: 337.1234
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.22
#                        Mean reward: 44.08
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7247
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.02s
#                         Total time: 64.41s
#                                ETA: 40.3s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2448608 steps/s (collection: 0.673s, learning 3.342s)
#                Value function loss: 294.6299
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.29
#                        Mean reward: 44.09
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7279
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.01s
#                         Total time: 68.43s
#                                ETA: 36.2s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2462670 steps/s (collection: 0.643s, learning 3.348s)
#                Value function loss: 343.3259
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.35
#                        Mean reward: 44.37
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7313
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 3.99s
#                         Total time: 72.42s
#                                ETA: 32.2s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2431966 steps/s (collection: 0.692s, learning 3.350s)
#                Value function loss: 300.3412
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.42
#                        Mean reward: 44.49
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7363
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.04s
#                         Total time: 76.46s
#                                ETA: 28.2s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2446466 steps/s (collection: 0.668s, learning 3.350s)
#                Value function loss: 350.5846
#                     Surrogate loss: 0.0005
#              Mean action noise std: 5.47
#                        Mean reward: 45.10
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7377
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.02s
#                         Total time: 80.48s
#                                ETA: 24.1s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2453156 steps/s (collection: 0.642s, learning 3.365s)
#                Value function loss: 303.2907
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.55
#                        Mean reward: 45.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7390
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.01s
#                         Total time: 84.49s
#                                ETA: 20.1s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2464584 steps/s (collection: 0.649s, learning 3.340s)
#                Value function loss: 351.0509
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.58
#                        Mean reward: 45.36
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7389
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 3.99s
#                         Total time: 88.48s
#                                ETA: 16.1s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2458551 steps/s (collection: 0.668s, learning 3.330s)
#                Value function loss: 307.1188
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.67
#                        Mean reward: 45.30
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7435
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.00s
#                         Total time: 92.48s
#                                ETA: 12.1s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2451665 steps/s (collection: 0.674s, learning 3.335s)
#                Value function loss: 358.9176
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.73
#                        Mean reward: 45.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7475
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.01s
#                         Total time: 96.49s
#                                ETA: 8.0s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2443479 steps/s (collection: 0.667s, learning 3.356s)
#                Value function loss: 307.3245
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.80
#                        Mean reward: 45.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7459
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.02s
#                         Total time: 100.51s
#                                ETA: 4.0s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 5.791558738708496
# ################################################################################
#                         Learning iteration 25/50
#
#                        Computation: 2453595 steps/s (collection: 0.671s, learning 3.336s)
#                Value function loss: 304.9982
#                     Surrogate loss: 0.0015
#              Mean action noise std: 5.89
#                        Mean reward: 45.45
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4506
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.01s
#                         Total time: 4.01s
#                                ETA: 0.0s
#
# ################################################################################
#                         Learning iteration 26/50
#
#                        Computation: 2451062 steps/s (collection: 0.642s, learning 3.368s)
#                Value function loss: 344.9686
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.97
#                        Mean reward: 45.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7425
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.01s
#                         Total time: 8.02s
#                                ETA: -0.3s
#
# ################################################################################
#                         Learning iteration 27/50
#
#                        Computation: 2462042 steps/s (collection: 0.642s, learning 3.351s)
#                Value function loss: 291.0222
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.05
#                        Mean reward: 45.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7433
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 3.99s
#                         Total time: 12.01s
#                                ETA: -0.9s
#
# ################################################################################
#                         Learning iteration 28/50
#
#                        Computation: 2469398 steps/s (collection: 0.638s, learning 3.342s)
#                Value function loss: 331.9876
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.12
#                        Mean reward: 44.50
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7419
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 3.98s
#                         Total time: 15.99s
#                                ETA: -1.7s
#
# ################################################################################
#                         Learning iteration 29/50
#
#                        Computation: 2474689 steps/s (collection: 0.637s, learning 3.336s)
#                Value function loss: 287.2183
#                     Surrogate loss: 0.0007
#              Mean action noise std: 6.19
#                        Mean reward: 44.85
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7405
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 3.97s
#                         Total time: 19.96s
#                                ETA: -2.7s
#
# ################################################################################
#                         Learning iteration 30/50
#
#                        Computation: 2442451 steps/s (collection: 0.644s, learning 3.380s)
#                Value function loss: 335.0094
#                     Surrogate loss: 0.0017
#              Mean action noise std: 6.25
#                        Mean reward: 45.15
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7395
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.02s
#                         Total time: 23.99s
#                                ETA: -3.9s
#
# ################################################################################
#                         Learning iteration 31/50
#
#                        Computation: 2447754 steps/s (collection: 0.668s, learning 3.348s)
#                Value function loss: 293.0281
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.34
#                        Mean reward: 45.51
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7430
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.02s
#                         Total time: 28.00s
#                                ETA: -5.3s
#
# ################################################################################
#                         Learning iteration 32/50
#
#                        Computation: 2470487 steps/s (collection: 0.640s, learning 3.339s)
#                Value function loss: 343.0415
#                     Surrogate loss: 0.0013
#              Mean action noise std: 6.41
#                        Mean reward: 44.77
# ...
#                    Total timesteps: 78643200
#                     Iteration time: 4.20s
#                         Total time: 33.58s
#                                ETA: -33.0s
#
# ################################################################################
#                       Learning iteration 1433/1450
#
#                        Computation: 2350206 steps/s (collection: 0.695s, learning 3.488s)
#                Value function loss: 186.2612
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3171.25
#                        Mean reward: 46.53
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7698
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.18s
#                         Total time: 37.76s
#                                ETA: -37.1s
#
# ################################################################################
#                       Learning iteration 1434/1450
#
#                        Computation: 2346029 steps/s (collection: 0.700s, learning 3.490s)
#                Value function loss: 192.2426
#                     Surrogate loss: -0.0000
#              Mean action noise std: 3174.05
#                        Mean reward: 46.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7700
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.19s
#                         Total time: 41.95s
#                                ETA: -41.2s
#
# ################################################################################
#                       Learning iteration 1435/1450
#
#                        Computation: 2324395 steps/s (collection: 0.724s, learning 3.505s)
#                Value function loss: 190.8447
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3176.88
#                        Mean reward: 46.48
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7701
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.23s
#                         Total time: 46.18s
#                                ETA: -45.3s
#
# ################################################################################
#                       Learning iteration 1436/1450
#
#                        Computation: 2353325 steps/s (collection: 0.707s, learning 3.470s)
#                Value function loss: 199.4326
#                     Surrogate loss: 0.0028
#              Mean action noise std: 3178.78
#                        Mean reward: 46.48
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7704
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.18s
#                         Total time: 50.36s
#                                ETA: -49.4s
#
# ################################################################################
#                       Learning iteration 1437/1450
#
#                        Computation: 2353752 steps/s (collection: 0.699s, learning 3.477s)
#                Value function loss: 196.1688
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3181.45
#                        Mean reward: 46.37
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7681
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.18s
#                         Total time: 54.54s
#                                ETA: -53.6s
#
# ################################################################################
#                       Learning iteration 1438/1450
#
#                        Computation: 2322810 steps/s (collection: 0.738s, learning 3.494s)
#                Value function loss: 205.0603
#                     Surrogate loss: -0.0000
#              Mean action noise std: 3184.35
#                        Mean reward: 46.30
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7666
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.23s
#                         Total time: 58.77s
#                                ETA: -57.7s
#
# ################################################################################
#                       Learning iteration 1439/1450
#
#                        Computation: 2345773 steps/s (collection: 0.691s, learning 3.499s)
#                Value function loss: 203.3340
#                     Surrogate loss: -0.0000
#              Mean action noise std: 3187.07
#                        Mean reward: 46.44
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7671
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.19s
#                         Total time: 62.96s
#                                ETA: -61.8s
#
# ################################################################################
#                       Learning iteration 1440/1450
#
#                        Computation: 2344507 steps/s (collection: 0.703s, learning 3.490s)
#                Value function loss: 211.8176
#                     Surrogate loss: 0.0003
#              Mean action noise std: 3190.18
#                        Mean reward: 46.46
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7674
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.19s
#                         Total time: 67.15s
#                                ETA: -65.9s
#
# ################################################################################
#                       Learning iteration 1441/1450
#
#                        Computation: 2352467 steps/s (collection: 0.704s, learning 3.475s)
#                Value function loss: 208.7986
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3192.90
#                        Mean reward: 46.47
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7672
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.18s
#                         Total time: 71.33s
#                                ETA: -70.0s
#
# ################################################################################
#                       Learning iteration 1442/1450
#
#                        Computation: 2365002 steps/s (collection: 0.684s, learning 3.472s)
#                Value function loss: 218.2049
#                     Surrogate loss: 0.0025
#              Mean action noise std: 3195.03
#                        Mean reward: 46.49
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7685
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.16s
#                         Total time: 75.49s
#                                ETA: -74.1s
#
# ################################################################################
#                       Learning iteration 1443/1450
#
#                        Computation: 2349280 steps/s (collection: 0.695s, learning 3.489s)
#                Value function loss: 214.1436
#                     Surrogate loss: -0.0000
#              Mean action noise std: 3197.76
#                        Mean reward: 46.49
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7691
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.18s
#                         Total time: 79.67s
#                                ETA: -78.2s
#
# ################################################################################
#                       Learning iteration 1444/1450
#
#                        Computation: 2342850 steps/s (collection: 0.707s, learning 3.489s)
#                Value function loss: 223.0460
#                     Surrogate loss: -0.0000
#              Mean action noise std: 3200.74
#                        Mean reward: 46.47
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7694
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.20s
#                         Total time: 83.87s
#                                ETA: -82.4s
#
# ################################################################################
#                       Learning iteration 1445/1450
#
#                        Computation: 2340780 steps/s (collection: 0.707s, learning 3.493s)
#                Value function loss: 218.4647
#                     Surrogate loss: 0.0002
#              Mean action noise std: 3203.62
#                        Mean reward: 46.50
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7696
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.20s
#                         Total time: 88.07s
#                                ETA: -86.5s
#
# ################################################################################
#                       Learning iteration 1446/1450
#
#                        Computation: 2355347 steps/s (collection: 0.697s, learning 3.476s)
#                Value function loss: 229.7000
#                     Surrogate loss: 0.0003
#              Mean action noise std: 3206.70
#                        Mean reward: 46.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7697
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.17s
#                         Total time: 92.24s
#                                ETA: -90.6s
#
# ################################################################################
#                       Learning iteration 1447/1450
#
#                        Computation: 2352284 steps/s (collection: 0.697s, learning 3.482s)
#                Value function loss: 223.5463
#                     Surrogate loss: 0.0024
#              Mean action noise std: 3208.79
#                        Mean reward: 46.47
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7698
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.18s
#                         Total time: 96.42s
#                                ETA: -94.7s
#
# ################################################################################
#                       Learning iteration 1448/1450
#
#                        Computation: 2353651 steps/s (collection: 0.696s, learning 3.481s)
#                Value function loss: 231.0533
#                     Surrogate loss: -0.0000
#              Mean action noise std: 3211.74
#                        Mean reward: 46.29
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7667
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.18s
#                         Total time: 100.60s
#                                ETA: -98.8s
#
# ################################################################################
#                       Learning iteration 1449/1450
#
#                        Computation: 2347232 steps/s (collection: 0.676s, learning 3.512s)
#                Value function loss: 225.1643
#                     Surrogate loss: -0.0000
#              Mean action noise std: 3214.67
#                        Mean reward: 46.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7655
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.19s
#                         Total time: 104.79s
#                                ETA: -102.9s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 217.27506801481297
# score     : [  65.14302439   85.90904086   52.22423131   51.7417334    54.45094764
#    64.06027182   53.45011138   97.89612781   56.27616289   63.94781373
#    57.14397333   64.68992138   50.43789652   56.68568453   56.2007839
#    53.89083616  156.6389312   191.28506437   51.57928981   53.57775513
#    72.87136946  154.96055973   56.35334341  285.20264308   52.04868023
#    54.8035107  1634.1055696    50.92810647   51.06304622   54.66140847
#    54.60179636  356.42568269   50.05524596   52.6050736    54.31784784
#    51.01479042   51.37723271  592.01358983   90.31299926   74.08631694
#    63.92583496   55.236717     65.77010768   50.65282018   50.04917109
#    51.84176347  131.90989645  146.31880205   54.06408218   53.87108247
#   191.4794651   268.17185334   63.22647957   74.19204293  268.31723745
#    50.25747446   95.24544902   49.70678832   55.62335302   52.48848343
#   171.44406449   72.37456219   52.41258934   56.38135117   70.44579446
#    55.42300927   55.0883636    71.79782312   71.91577518  522.15702879
#    57.25039586   52.34460043  339.50690887  894.2616634  3359.11808392
#  4221.95683872   60.59580823   50.71004132   60.04328541   49.87933096
#    50.55204162 2445.33728313  411.42637221   51.3146193    60.92565592
#    56.12048075   55.32673871   51.86773548   82.75051607   53.64401247
#   129.19214838   90.6038652   167.92571145   77.51578336   51.05418421
#    51.31254369   66.78275351  103.19037148   50.4948357    51.67451142]
# score.mean: 217.27506801481297

# %%
exp_result = {
    'reward_total': reward_history,
    'reward_peo': death_buf,
    'state': state_his_buf,
    'action': act_buf
}
torch.save(exp_result, 'exp4-t3000.pt')

# %%
run_result = torch.load('exp4-t3000.pt', weights_only=False)
death_mean = torch.mean(run_result['state'][-1][:,4]) * N
print(death_mean)

def infections(states, action, para, i):
    st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
    u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
    ht = st + et + at + it + rt

    st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * para['beta1'][i] + (et + at * (1 - u_aq)) * para['beta2'][i]) / ht
    st_out_e = st_out * parameter_static['alpha']
    st_out_i = st_out * (1 - parameter_static['alpha'])
    et_out_a = et * w * (1 - para['per'] - para['pei'])
    return et_out_a, st_out_e, st_out_i


init_state = torch.tensor([[100000, 20 , 0, 0, 0, 0]], dtype=torch.float32).to(torch.device(device))
s_i = torch.zeros(100).to(torch.device('cuda:0'))
s_a = torch.zeros(100).to(torch.device('cuda:0'))
s_t = torch.zeros(100).to(torch.device('cuda:0'))
for i in range(test_num):
    for t in range(T):
        if t == 0:
            sa_temp, se_temp, si_temp = infections(init_state, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        if t > 0 and t < T-1:
            sa_temp, se_temp, si_temp = infections(run_result['state'][t-1][i][:6].unsqueeze(0)*N, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        s_i[i] += si_temp[0]
        s_a[i] += sa_temp[0]
        s_t[i] += se_temp[0]
print([torch.mean(s_i), torch.mean(s_a)+torch.mean(s_i), torch.mean(s_t)])
# Out:
# tensor(8.50519, device='cuda:0')
# [tensor(1616.82471, device='cuda:0'), tensor(1655.72009, device='cuda:0'), tensor(2425.23682, device='cuda:0')]
