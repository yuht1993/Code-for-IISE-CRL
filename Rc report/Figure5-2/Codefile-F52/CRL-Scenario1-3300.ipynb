# %%
from rsl_rl.env import VecEnv
from rsl_rl.runners import OnPolicyRunner
import torch
import numpy as np
torch.set_printoptions(precision=5, linewidth=200, sci_mode=False)

N          = 100020
state_dim  = 8
action_dim = 5
T          = 60
budget     = 3300.
N_envs     = 1024 * 64
ΔT         = 1.0
device     = 'cuda'
usr_std = 0.1
test_num = 100
seed = 0

parameter_static = dict(N          = N,
                        B          = budget,
                        T          = T,
                        alpha      = 0.6,
                        v_max      = 0.2/14,
                        cost_ti    = 0.0977,
                        cost_ta    = 0.02,
                        cost_v     = 0.07,
                        cost_poc_0 = 0.000369,
                        cost_poc_1 = 0.001057,
                        pid        = 1.10/1000,
                        psr        = 0.7,
                        pid_plus   = 0.1221/1000,
                        pir        = 1/8,
                        prs        = 1/7)

Random_mean = {"beta2" : 0.78735,
               "beta1" : 0.15747,
               "pei"   : 0.10714,
               "per"   : 0.04545}

space = {"beta2" : [Random_mean['beta2'],Random_mean['beta2']*usr_std],
         "beta1" : [Random_mean['beta1'], Random_mean['beta1']*usr_std],
         "pei"   : [Random_mean['pei'], Random_mean['pei']*usr_std],
         "per"   : [Random_mean['per'], Random_mean['per']*usr_std]}

Init_state = torch.tensor([[100000 / N, 20 / N, 0, 0, 0, 0, 1, 0]], 
                         dtype=torch.float32).to(torch.device(device))

# %%
class myVecEnv(VecEnv):
    def __init__(self, interval, n_envs = N_envs):
        self.B = parameter_static['B']  # total budget
        self.N = parameter_static['N']
        self.device = device
        self.init_state = Init_state
        self.states = self.init_state.repeat(n_envs, 1)
        self.num_envs = n_envs
        self.num_obs = state_dim
        self.num_privileged_obs = None
        self.num_actions = action_dim
        self.max_episode_length = parameter_static['T']
        
        torch.manual_seed(seed)
        self.parameter_random = {
            key: torch.empty(self.num_envs).normal_(
                interval[key][0],
                interval[key][1]
            ).to(torch.device(device))
            for key, value in Random_mean.items()
        }

        for key, value in Random_mean.items():
            indice = self.parameter_random[key] < 0
            self.parameter_random[key][indice] = -self.parameter_random[key][indice] 

        # optimization flags for pytorch JIT
        torch._C._jit_set_profiling_mode(False)
        torch._C._jit_set_profiling_executor(False)
        
        # allocate buffers
        self.privileged_obs_buf = None
        self.obs_buf = torch.zeros(self.num_envs, self.num_obs, device=self.device, dtype=torch.float)
        self.rew_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.float)
        self.reset_buf = torch.ones(self.num_envs, device=self.device, dtype=torch.long)
        self.episode_length_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.long)
        
        self.actions = torch.zeros(self.num_envs, self.num_actions, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_sums = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_acts = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.extras = {}
    
    def para_update(self, para):
        self.parameter_random = para
        
    def step(self, actions):
        # actions clip
        soft_bound = [-0.5, 1.5]
        out_of_limits = -(actions - soft_bound[0]).clip(max=0.)
        out_of_limits += (actions - soft_bound[1]).clip(min=0.)
        scale_action = -0.1
        reward_action = scale_action * torch.sum(out_of_limits, dim=1).clip(max=1.).to(self.device)
        self.actions = torch.clip(actions, 0., 1.).to(self.device)

        # update actions & states
        b, p = self.states[:, -2] * self.B, self.states[:, -1]
        inv_c = self.cost_function(self.actions)
        b -= inv_c
        b = torch.clip(b, 0., self.B).to(self.device)
        mask = (b > 0).float().unsqueeze(-1)
        self.act = self.actions * mask
        inv_c = self.cost_function(self.act)
        next_state, reward_original = self.transition(self.act)
        self.extras['reward_original'] = reward_original
        self.extras['inv_cost'] = inv_c
        self.episode_length_buf += 1
        p = self.episode_length_buf / self.max_episode_length
        self.states = torch.cat([next_state / self.N, (b / self.B).unsqueeze(-1), p.unsqueeze(-1)], dim=-1)
        
        # check termination
        self.reset_buf = self.episode_length_buf >= self.max_episode_length
        
        # compute reward
        r_mean = -6584
        r_std  =  7347
        reward = (reward_original - inv_c - r_mean) / r_std
        #if reward > 0: 
        #reward = torch.exp(reward)/10
        #reward = torch.exp((1e5 + reward_original - inv_c) / 5e4)
        self.rew_buf       = reward + reward_action
        self.episode_sums += reward + reward_action
        self.episode_acts += reward_action
        
        # compute resets
        env_ids = self.reset_buf.nonzero(as_tuple=False).flatten()
        self.reset_idx(env_ids)
        
        # compute observations
        return self.get_observations(), self.states, self.rew_buf, self.reset_buf, self.extras

    def reset_idx(self, env_ids):
        """Reset selected robots"""
        if len(env_ids) == 0:
            return
        
        assert len(env_ids) == self.num_envs
        # reset robot states
        self.states[env_ids] = self.init_state
        # reset buffers
        self.episode_length_buf[env_ids] = 0
        self.reset_buf[env_ids] = 1
        # fill extras
        self.extras["episode"] = {}
        self.extras["episode"]['rew_sum'] = torch.mean(self.episode_sums[env_ids]) / (self.max_episode_length * ΔT)
        self.extras["episode"]['rew_act'] = torch.mean(self.episode_acts[env_ids]) / (self.max_episode_length * ΔT)
        self.episode_sums[env_ids] = 0.
        self.episode_acts[env_ids] = 0.
    
    def reset(self):
        """ Reset all robots"""
        self.reset_idx(torch.arange(self.num_envs, device=self.device))
        return {}, {}
    
    def get_observations(self):
        o_mean = torch.tensor([[0.58712867, 0.06804276, 0.00308146, 0.25684301, 0.00261079, 0.08229331, 0.26572794, 0.51      ]], dtype=torch.float32).to(torch.device(self.device))
        o_std  = torch.tensor([[0.41484398, 0.07883003, 0.00389494, 0.292568  , 0.00394907, 0.06906768, 0.33943075, 0.28861739]], dtype=torch.float32).to(torch.device(self.device))
        self.obs_buf = (self.states - o_mean) / o_std
        return self.obs_buf
    
    def get_privileged_observations(self):
        return self.privileged_obs_buf

    def cost_function(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]

        cost_it  = it * u_it * parameter_static['cost_ti']
        cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
        cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
        per_poc  = ((st + et + at + rt) / self.N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
        cost_poc = (st + et + rt + at) * w * per_poc
        return cost_poc + cost_it + cost_v + cost_q

    def transition(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
        ht = st + et + at + it + rt

        st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * self.parameter_random['beta1'] + (et + at * (1 - u_aq)) * self.parameter_random['beta2']) / ht
        st_out_e = st_out * parameter_static['alpha']
        st_out_i = st_out * (1 - parameter_static['alpha'])
        st_out_r = u_sv * parameter_static['v_max'] * st * parameter_static['psr']
        et_out_r = et * self.parameter_random['per']
        et_out_i = et * self.parameter_random['pei']
        et_out_a = et * w * (1 - self.parameter_random['per'] - self.parameter_random['pei'])
        at_out_i = at * self.parameter_random['pei']
        at_out_r = at * self.parameter_random['per']
        it_out_r = it * parameter_static['pir'] * u_it
        it_out_d = it * parameter_static['pid'] * (1 - u_it) + it * u_it * parameter_static['pid_plus']
        rt_out_s = rt * parameter_static['prs']
        
        stn = st - st_out_e - st_out_i - st_out_r + rt_out_s
        etn = et - et_out_r - et_out_i - et_out_a + st_out_e
        atn = at - at_out_r - at_out_i + et_out_a
        itn = it - it_out_r - it_out_d + st_out_i + et_out_i + at_out_i
        dtn = dt + it_out_d
        rtn = rt + et_out_r + at_out_r + it_out_r + st_out_r - rt_out_s

        reward = -2.6 * st_out - 100 * it_out_d

        next_state = torch.stack([stn, etn, atn, itn, dtn, rtn], dim=-1)
        return next_state, reward

# %%
import inspect

class BaseConfig:
    def __init__(self) -> None:
        """ Initializes all member classes recursively. Ignores all namse starting with '__' (buit-in methods)."""
        self.init_member_classes(self)
    
    @staticmethod
    def init_member_classes(obj):
        # iterate over all attributes names
        for key in dir(obj):
            # disregard builtin attributes
            # if key.startswith("__"):
            if key=="__class__":
                continue
            # get the corresponding attribute object
            var =  getattr(obj, key)
            # check if it the attribute is a class
            if inspect.isclass(var):
                # instantate the class
                i_var = var()
                # set the attribute to the instance instead of the type
                setattr(obj, key, i_var)
                # recursively init members of the attribute
                BaseConfig.init_member_classes(i_var)

class LeggedRobotCfgPPO(BaseConfig):
    seed = 1
    runner_class_name = 'OnPolicyRunner'
    class policy:
        init_noise_std = 2
        actor_hidden_dims  = [64, 32, 16] 
        critic_hidden_dims = [64, 32, 16]
        activation = 'elu' # can be elu, relu, selu, crelu, lrelu, tanh, sigmoid
        # only for 'ActorCriticRecurrent':
        # rnn_type = 'lstm'
        # rnn_hidden_size = 512
        # rnn_num_layers = 1
        
    class algorithm:
        # training params
        value_loss_coef = 0.5
        use_clipped_value_loss = True
        clip_param = 0.2
        entropy_coef = 0.01
        num_learning_epochs = 5
        num_mini_batches = 64 # mini batch size = num_envs*nsteps / nminibatches
        learning_rate = 1.e-4
        schedule = 'adaptive' # could be adaptive, fixed
        gamma = 0.99
        lam = 0.95
        desired_kl = 0.01
        max_grad_norm = 1.

    class runner:
        policy_class_name = 'ActorCritic'
        algorithm_class_name = 'PPO'
        num_steps_per_env =  150 # per iteration
        max_iterations    = 100 # number of policy updates

        # logging
        save_interval = 100 # check for potential saves every this many iterations
        experiment_name = 'test'
        run_name = ''
        # load and resume
        resume = True
        load_run = -1 # -1 = last run
        checkpoint = -1 # -1 = last saved model
        resume_path = None # updated from load_run and chkpt
        
def class_to_dict(obj) -> dict:
    if not  hasattr(obj,"__dict__"):
        return obj
    result = {}
    for key in dir(obj):
        if key.startswith("_"):
            continue
        element = []
        val = getattr(obj, key)
        if isinstance(val, list):
            for item in val:
                element.append(class_to_dict(item))
        else:
            element = class_to_dict(val)
        result[key] = element
    return result

# %%
def para_sampling(intvl, num_sample=N_envs):
    parameter_random = {
        key: torch.empty(num_sample).normal_(
        intvl[key][0],
        intvl[key][1]
        ).to(torch.device(device))
        for key, value in Random_mean.items()
    }
    for key, value in Random_mean.items():
        indice = parameter_random[key] < 0
        parameter_random[key][indice] = -parameter_random[key][indice] 
    return parameter_random

def update_space(final_indices, para_buf, space):
    para_est = {}
    for key, tensor_values in para_buf.items():
        selected_values = torch.mean(tensor_values[final_indices[0], final_indices[1]]) 
        para_values = torch.mean(tensor_values[final_indices[0], final_indices[1]], dim=0)
        update_values = space[key][0] + 0.5 * (selected_values - space[key][0])
        space[key] = [update_values , update_values  * 0.1]
        para_est[key] = para_values
    return space, para_est


def cal_err(para_value, env_para):
    gap = []
    for key, value in env_para.items():
        gap_temp = torch.mean(torch.abs(para_value[key] - env_para[key])/(env_para[key]))
        gap.append(gap_temp)
    return sum(gap)/len(gap) # 所有值都在范围内，返回 0
    
def state_estimator(env_sample, action_sim, state_sim, state_prior, space, iter): 
    env_sample.reset()
    env_sample.states = state_prior  
    para_buf, mse_buf, obs_buf, states_buf = {}, {}, {}, {}
    for i in range(iter):
        para = para_sampling(space, test_num)
        env_sample.para_update(para)
        obs_sample, states_sample, _, _, _ = env_sample.step(action_sim.detach())  
        mse = torch.mean((state_sim[:,2:4] - states_sample[:,2:4]) ** 2, dim=1) 
        if i == 0:
            mse_buf = mse.unsqueeze(0)
            obs_buf = obs_sample.unsqueeze(0)
            states_buf = states_sample.unsqueeze(0)
            for key, values in para.items():
                para_buf[key] = para[key].unsqueeze(0)
        else:
            mse_buf = torch.cat((mse_buf, mse.unsqueeze(0)), dim=0)
            obs_buf = torch.cat((obs_buf, obs_sample.unsqueeze(0)),dim=0)
            states_buf = torch.cat((states_buf, states_sample.unsqueeze(0)), dim=0)
            for key, values in para.items():
                para_buf[key] = torch.cat((para_buf[key], para[key].unsqueeze(0)), dim=0)
                
     
    k = int(iter * 0.05)
    _, row_indices = torch.topk(mse_buf, k=k, dim=0, largest=False)
    column_indices = torch.arange(mse_buf.shape[1]).repeat(k, 1)
    top_indices = [row_indices, column_indices]
    obs_est = torch.mean(obs_buf[row_indices,column_indices,:], dim=0)
    state_est = torch.mean(states_buf[row_indices,column_indices,:], dim=0)
    state_est[:,-1] = state_prior[:,-1] + torch.tensor(1/T)
    return obs_est, state_est, top_indices, para_buf

# %%
para_err = 0.5
torch.manual_seed(seed)
para_true = []
para_temp = {
    key: torch.empty(test_num).uniform_(
        value * (1-para_err),
        value * (1+para_err)
    ).to(torch.device(device))
    for key, value in Random_mean.items()
}


para = {}
for t in range(T):
    para = {
        key: (para_temp[key] + t * 0.5 *  para_temp[key] /T).to(torch.device(device)) if key == 'per' 
        else (para_temp[key] - t * 0.5 *  para_temp[key] /T).to(torch.device(device))
        for key, value in Random_mean.items()
        }
    para_true.append(para)

# %%
env = myVecEnv(space, test_num)
env.para_update(para_true[0])
train_cfg = LeggedRobotCfgPPO()
train_cfg_dict = class_to_dict(train_cfg)


env_transfer = myVecEnv(space)
runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_exp4_t1', device=env.device)
runner.load(f'rsl_low_budget3000/model_100.pt')

policy = runner.get_inference_policy(device=env.device)

reward_history = []
act_buf = []
state_his_buf = []
death_buf = []

env_sample = myVecEnv(space, test_num)
state_est = env.states
obs_est = env.get_observations()
for t in range(T-1):
    actions = policy(obs_est.detach())
    obs, states, _, _, infos = env.step(actions.detach())
    reward_history.append((-infos['reward_original'] + infos['inv_cost']).tolist())
    death_buf.append((-infos['reward_original']).tolist())
    act_buf.append(env.act)
    state_his_buf.append(env.states)
    obs_est, state_buf, top_indices, para_buf = state_estimator(env_sample, actions, states, state_est, space, 1024)
    space, para_v = update_space(top_indices, para_buf, space) 

    runner.learn(num_learning_iterations=25, init_at_random_ep_len=False)
    policy = runner.get_inference_policy(device=env.device)
    env_transfer = myVecEnv(space)
    runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_exp4_t1', device=env.device)
    runner.load(f'rsl_exp4_t1/model_{int(t)* 25}.pt')

    if t < T - 1: env.para_update(para_true[t + 1])
    print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')


reward_history = np.array(reward_history)
print(f'score     : {np.sum(reward_history, axis=0)/T       }')
print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
# Out:
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2193651 steps/s (collection: 0.862s, learning 3.619s)
#                Value function loss: 258.6931
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.49
#                        Mean reward: 41.13
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4053
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.48s
#                         Total time: 4.48s
#                                ETA: 112.0s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2330079 steps/s (collection: 0.681s, learning 3.538s)
#                Value function loss: 295.4633
#                     Surrogate loss: -0.0005
#              Mean action noise std: 4.52
#                        Mean reward: 42.64
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6721
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.22s
#                         Total time: 8.70s
#                                ETA: 104.4s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2272341 steps/s (collection: 0.722s, learning 3.604s)
#                Value function loss: 266.0389
#                     Surrogate loss: 0.0001
#              Mean action noise std: 4.56
#                        Mean reward: 42.97
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6904
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.33s
#                         Total time: 13.03s
#                                ETA: 99.9s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2269621 steps/s (collection: 0.686s, learning 3.645s)
#                Value function loss: 303.6201
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.59
#                        Mean reward: 42.33
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7011
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.33s
#                         Total time: 17.36s
#                                ETA: 95.5s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2303929 steps/s (collection: 0.706s, learning 3.561s)
#                Value function loss: 267.7214
#                     Surrogate loss: 0.0001
#              Mean action noise std: 4.64
#                        Mean reward: 43.29
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7109
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.27s
#                         Total time: 21.62s
#                                ETA: 90.8s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2308267 steps/s (collection: 0.686s, learning 3.573s)
#                Value function loss: 306.2271
#                     Surrogate loss: 0.0005
#              Mean action noise std: 4.67
#                        Mean reward: 44.60
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7159
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.26s
#                         Total time: 25.88s
#                                ETA: 86.3s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2336224 steps/s (collection: 0.670s, learning 3.538s)
#                Value function loss: 270.5964
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.73
#                        Mean reward: 44.79
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7263
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.21s
#                         Total time: 30.09s
#                                ETA: 81.7s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2332427 steps/s (collection: 0.696s, learning 3.518s)
#                Value function loss: 312.2998
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.78
#                        Mean reward: 44.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7343
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.21s
#                         Total time: 34.31s
#                                ETA: 77.2s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2346613 steps/s (collection: 0.668s, learning 3.521s)
#                Value function loss: 271.2533
#                     Surrogate loss: 0.0003
#              Mean action noise std: 4.84
#                        Mean reward: 44.95
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7395
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.19s
#                         Total time: 38.49s
#                                ETA: 72.7s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2336199 steps/s (collection: 0.691s, learning 3.517s)
#                Value function loss: 312.2701
#                     Surrogate loss: 0.0003
#              Mean action noise std: 4.88
#                        Mean reward: 45.38
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7433
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.21s
#                         Total time: 42.70s
#                                ETA: 68.3s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2356368 steps/s (collection: 0.669s, learning 3.503s)
#                Value function loss: 276.9416
#                     Surrogate loss: 0.0005
#              Mean action noise std: 4.95
#                        Mean reward: 45.99
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7488
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.17s
#                         Total time: 46.87s
#                                ETA: 63.9s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2354315 steps/s (collection: 0.675s, learning 3.501s)
#                Value function loss: 295.8358
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.00
#                        Mean reward: 45.58
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7506
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.18s
#                         Total time: 51.05s
#                                ETA: 59.6s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2342740 steps/s (collection: 0.680s, learning 3.516s)
#                Value function loss: 249.2402
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.07
#                        Mean reward: 45.73
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7518
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.20s
#                         Total time: 55.25s
#                                ETA: 55.2s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2344955 steps/s (collection: 0.669s, learning 3.523s)
#                Value function loss: 286.3774
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.12
#                        Mean reward: 46.00
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7547
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.19s
#                         Total time: 59.44s
#                                ETA: 50.9s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2356010 steps/s (collection: 0.678s, learning 3.495s)
#                Value function loss: 247.7446
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.19
#                        Mean reward: 45.97
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7588
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.17s
#                         Total time: 63.61s
#                                ETA: 46.6s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2276826 steps/s (collection: 0.673s, learning 3.645s)
#                Value function loss: 290.5377
#                     Surrogate loss: 0.0007
#              Mean action noise std: 5.25
#                        Mean reward: 46.11
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7611
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.32s
#                         Total time: 67.93s
#                                ETA: 42.5s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2262931 steps/s (collection: 0.677s, learning 3.667s)
#                Value function loss: 257.1286
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.33
#                        Mean reward: 45.89
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7618
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.34s
#                         Total time: 72.27s
#                                ETA: 38.3s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2278876 steps/s (collection: 0.671s, learning 3.643s)
#                Value function loss: 304.0577
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.39
#                        Mean reward: 46.01
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7622
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.31s
#                         Total time: 76.59s
#                                ETA: 34.0s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2276819 steps/s (collection: 0.673s, learning 3.645s)
#                Value function loss: 269.6772
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.47
#                        Mean reward: 46.02
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7640
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.32s
#                         Total time: 80.90s
#                                ETA: 29.8s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2267562 steps/s (collection: 0.673s, learning 3.662s)
#                Value function loss: 317.5745
#                     Surrogate loss: 0.0008
#              Mean action noise std: 5.52
#                        Mean reward: 46.36
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7634
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.34s
#                         Total time: 85.24s
#                                ETA: 25.6s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2275546 steps/s (collection: 0.671s, learning 3.649s)
#                Value function loss: 277.9705
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.61
#                        Mean reward: 46.31
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7640
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.32s
#                         Total time: 89.56s
#                                ETA: 21.3s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2264358 steps/s (collection: 0.684s, learning 3.657s)
#                Value function loss: 328.2360
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.65
#                        Mean reward: 46.30
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7635
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.34s
#                         Total time: 93.90s
#                                ETA: 17.1s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2306534 steps/s (collection: 0.684s, learning 3.578s)
#                Value function loss: 286.8645
#                     Surrogate loss: 0.0012
#              Mean action noise std: 5.74
#                        Mean reward: 46.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7651
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.26s
#                         Total time: 98.16s
#                                ETA: 12.8s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2315066 steps/s (collection: 0.681s, learning 3.566s)
#                Value function loss: 341.6605
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.81
#                        Mean reward: 46.28
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7670
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.25s
#                         Total time: 102.41s
#                                ETA: 8.5s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2326230 steps/s (collection: 0.678s, learning 3.548s)
#                Value function loss: 294.1627
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.90
#                        Mean reward: 46.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7672
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.23s
#                         Total time: 106.63s
#                                ETA: 4.3s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 3.0514750366210937
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2281274 steps/s (collection: 0.723s, learning 3.586s)
#                Value function loss: 259.0881
#                     Surrogate loss: -0.0000
#              Mean action noise std: 4.53
#                        Mean reward: 41.64
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4115
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.31s
#                         Total time: 4.31s
#                                ETA: 107.7s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2310104 steps/s (collection: 0.692s, learning 3.564s)
#                Value function loss: 292.8996
#                     Surrogate loss: 0.0006
#              Mean action noise std: 4.56
#                        Mean reward: 43.09
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6819
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.26s
#                         Total time: 8.56s
#                                ETA: 102.8s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2313175 steps/s (collection: 0.676s, learning 3.574s)
#                Value function loss: 261.2287
#                     Surrogate loss: 0.0001
#              Mean action noise std: 4.61
#                        Mean reward: 43.02
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6970
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.25s
#                         Total time: 12.81s
#                                ETA: 98.2s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2313847 steps/s (collection: 0.673s, learning 3.575s)
#                Value function loss: 297.7562
#                     Surrogate loss: -0.0004
#              Mean action noise std: 4.64
#                        Mean reward: 42.84
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7070
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.25s
#                         Total time: 17.06s
#                                ETA: 93.8s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2328653 steps/s (collection: 0.693s, learning 3.529s)
#                Value function loss: 259.8051
#                     Surrogate loss: 0.0001
#              Mean action noise std: 4.69
#                        Mean reward: 43.60
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7166
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.22s
#                         Total time: 21.28s
#                                ETA: 89.4s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2355360 steps/s (collection: 0.673s, learning 3.500s)
#                Value function loss: 294.6954
#                     Surrogate loss: 0.0006
#              Mean action noise std: 4.73
#                        Mean reward: 44.47
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7199
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.17s
#                         Total time: 25.46s
#                                ETA: 84.9s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2325071 steps/s (collection: 0.693s, learning 3.535s)
#                Value function loss: 262.3976
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.79
#                        Mean reward: 44.82
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7274
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.23s
#                         Total time: 29.69s
#                                ETA: 80.6s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2346097 steps/s (collection: 0.684s, learning 3.506s)
#                Value function loss: 303.2047
#                     Surrogate loss: -0.0000
#              Mean action noise std: 4.84
#                        Mean reward: 44.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7337
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.19s
#                         Total time: 33.88s
#                                ETA: 76.2s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2339804 steps/s (collection: 0.695s, learning 3.507s)
#                Value function loss: 266.7091
#                     Surrogate loss: 0.0003
#              Mean action noise std: 4.91
#                        Mean reward: 44.75
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7375
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.20s
#                         Total time: 38.08s
#                                ETA: 71.9s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2351685 steps/s (collection: 0.689s, learning 3.491s)
#                Value function loss: 308.7021
#                     Surrogate loss: 0.0001
#              Mean action noise std: 4.96
#                        Mean reward: 45.34
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7404
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.18s
#                         Total time: 42.26s
#                                ETA: 67.6s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2324614 steps/s (collection: 0.713s, learning 3.516s)
#                Value function loss: 271.0500
#                     Surrogate loss: 0.0012
#              Mean action noise std: 5.02
#                        Mean reward: 45.86
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7454
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.23s
#                         Total time: 46.49s
#                                ETA: 63.4s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2333867 steps/s (collection: 0.688s, learning 3.524s)
#                Value function loss: 314.2972
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.07
#                        Mean reward: 45.50
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7473
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.21s
#                         Total time: 50.70s
#                                ETA: 59.1s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2365835 steps/s (collection: 0.668s, learning 3.487s)
#                Value function loss: 273.7063
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.14
#                        Mean reward: 45.68
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7493
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.16s
#                         Total time: 54.85s
#                                ETA: 54.9s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2354347 steps/s (collection: 0.669s, learning 3.507s)
#                Value function loss: 320.6805
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.16
#                        Mean reward: 45.79
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7526
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.18s
#                         Total time: 59.03s
#                                ETA: 50.6s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2350572 steps/s (collection: 0.681s, learning 3.501s)
#                Value function loss: 278.8356
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.24
#                        Mean reward: 45.62
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7537
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.18s
#                         Total time: 63.21s
#                                ETA: 46.4s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2359354 steps/s (collection: 0.678s, learning 3.488s)
#                Value function loss: 324.2824
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.29
#                        Mean reward: 45.71
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7531
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.17s
#                         Total time: 67.38s
#                                ETA: 42.1s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2351147 steps/s (collection: 0.670s, learning 3.511s)
#                Value function loss: 283.1973
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.36
#                        Mean reward: 45.68
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7552
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.18s
#                         Total time: 71.56s
#                                ETA: 37.9s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2350699 steps/s (collection: 0.674s, learning 3.508s)
#                Value function loss: 331.0304
#                     Surrogate loss: 0.0008
#              Mean action noise std: 5.43
#                        Mean reward: 45.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7563
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.18s
#                         Total time: 75.74s
#                                ETA: 33.7s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2347547 steps/s (collection: 0.684s, learning 3.503s)
#                Value function loss: 288.4460
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.52
#                        Mean reward: 45.67
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7580
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.19s
#                         Total time: 79.93s
#                                ETA: 29.4s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2362227 steps/s (collection: 0.681s, learning 3.481s)
#                Value function loss: 337.3218
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.57
#                        Mean reward: 45.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7576
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.16s
#                         Total time: 84.09s
#                                ETA: 25.2s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2368105 steps/s (collection: 0.671s, learning 3.480s)
#                Value function loss: 292.3430
#                     Surrogate loss: 0.0014
#              Mean action noise std: 5.66
#                        Mean reward: 46.24
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7587
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.15s
#                         Total time: 88.24s
#                                ETA: 21.0s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2341145 steps/s (collection: 0.706s, learning 3.493s)
#                Value function loss: 342.9370
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.71
#                        Mean reward: 46.18
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7581
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.20s
#                         Total time: 92.44s
#                                ETA: 16.8s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2362690 steps/s (collection: 0.681s, learning 3.480s)
#                Value function loss: 298.5210
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.79
#                        Mean reward: 45.96
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7601
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.16s
#                         Total time: 96.60s
#                                ETA: 12.6s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2358415 steps/s (collection: 0.684s, learning 3.484s)
#                Value function loss: 349.4656
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.85
#                        Mean reward: 46.07
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7625
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.17s
#                         Total time: 100.77s
#                                ETA: 8.4s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2357118 steps/s (collection: 0.679s, learning 3.492s)
#                Value function loss: 300.6474
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.93
#                        Mean reward: 46.06
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7629
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.17s
#                         Total time: 104.94s
#                                ETA: 4.2s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 5.767946174621582
# ################################################################################
#                         Learning iteration 25/50
#
#                        Computation: 2350679 steps/s (collection: 0.703s, learning 3.479s)
#                Value function loss: 301.1211
#                     Surrogate loss: 0.0011
#              Mean action noise std: 6.02
#                        Mean reward: 46.16
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4623
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.18s
#                         Total time: 4.18s
#                                ETA: 0.0s
#
# ################################################################################
#                         Learning iteration 26/50
#
#                        Computation: 2365580 steps/s (collection: 0.671s, learning 3.484s)
#                Value function loss: 337.0396
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.09
#                        Mean reward: 46.36
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7618
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.16s
#                         Total time: 8.34s
#                                ETA: -0.3s
#
# ################################################################################
#                         Learning iteration 27/50
#
#                        Computation: 2355350 steps/s (collection: 0.676s, learning 3.498s)
#                Value function loss: 277.7043
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.18
#                        Mean reward: 46.25
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7627
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.17s
#                         Total time: 12.51s
#                                ETA: -0.9s
#
# ################################################################################
#                         Learning iteration 28/50
#
#                        Computation: 2342870 steps/s (collection: 0.711s, learning 3.485s)
#                Value function loss: 317.1673
#                     Surrogate loss: 0.0007
#              Mean action noise std: 6.24
#                        Mean reward: 45.97
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7631
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.20s
#                         Total time: 16.71s
#                                ETA: -1.7s
#
# ################################################################################
#                         Learning iteration 29/50
#
#                        Computation: 2361882 steps/s (collection: 0.675s, learning 3.487s)
#                Value function loss: 259.1715
#                     Surrogate loss: 0.0016
#              Mean action noise std: 6.33
#                        Mean reward: 46.16
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7650
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.16s
#                         Total time: 20.87s
#                                ETA: -2.8s
#
# ################################################################################
#                         Learning iteration 30/50
#
#                        Computation: 2358487 steps/s (collection: 0.677s, learning 3.491s)
#                Value function loss: 293.6786
#                     Surrogate loss: -0.0002
#              Mean action noise std: 6.40
#                        Mean reward: 46.50
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7662
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.17s
#                         Total time: 25.04s
#                                ETA: -4.0s
#
# ################################################################################
#                         Learning iteration 31/50
#
#                        Computation: 2361652 steps/s (collection: 0.670s, learning 3.492s)
#                Value function loss: 256.0290
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.50
#                        Mean reward: 46.43
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7687
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.16s
#                         Total time: 29.20s
#                                ETA: -5.5s
#
# ################################################################################
#                         Learning iteration 32/50
#
#                        Computation: 2340860 steps/s (collection: 0.694s, learning 3.506s)
#                Value function loss: 297.3861
#                     Surrogate loss: 0.0007
#              Mean action noise std: 6.55
#                        Mean reward: 46.17
# ...
#                    Total timesteps: 78643200
#                     Iteration time: 4.15s
#                         Total time: 33.26s
#                                ETA: -32.7s
#
# ################################################################################
#                       Learning iteration 1433/1450
#
#                        Computation: 2350361 steps/s (collection: 0.715s, learning 3.468s)
#                Value function loss: 132.4077
#                     Surrogate loss: 0.0007
#              Mean action noise std: 2330.04
#                        Mean reward: 46.99
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7839
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.18s
#                         Total time: 37.44s
#                                ETA: -36.8s
#
# ################################################################################
#                       Learning iteration 1434/1450
#
#                        Computation: 2357305 steps/s (collection: 0.688s, learning 3.482s)
#                Value function loss: 141.7787
#                     Surrogate loss: 0.0002
#              Mean action noise std: 2330.18
#                        Mean reward: 47.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7841
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.17s
#                         Total time: 41.61s
#                                ETA: -40.9s
#
# ################################################################################
#                       Learning iteration 1435/1450
#
#                        Computation: 2366168 steps/s (collection: 0.678s, learning 3.477s)
#                Value function loss: 135.0142
#                     Surrogate loss: -0.0001
#              Mean action noise std: 2330.52
#                        Mean reward: 47.23
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7842
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.15s
#                         Total time: 45.77s
#                                ETA: -44.9s
#
# ################################################################################
#                       Learning iteration 1436/1450
#
#                        Computation: 2353427 steps/s (collection: 0.702s, learning 3.475s)
#                Value function loss: 144.2655
#                     Surrogate loss: -0.0001
#              Mean action noise std: 2330.72
#                        Mean reward: 47.11
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7839
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.18s
#                         Total time: 49.94s
#                                ETA: -49.0s
#
# ################################################################################
#                       Learning iteration 1437/1450
#
#                        Computation: 2382128 steps/s (collection: 0.673s, learning 3.453s)
#                Value function loss: 137.7419
#                     Surrogate loss: -0.0001
#              Mean action noise std: 2330.93
#                        Mean reward: 47.24
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7838
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.13s
#                         Total time: 54.07s
#                                ETA: -53.1s
#
# ################################################################################
#                       Learning iteration 1438/1450
#
#                        Computation: 2364124 steps/s (collection: 0.706s, learning 3.452s)
#                Value function loss: 149.4875
#                     Surrogate loss: -0.0002
#              Mean action noise std: 2331.09
#                        Mean reward: 47.18
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7835
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.16s
#                         Total time: 58.23s
#                                ETA: -57.2s
#
# ################################################################################
#                       Learning iteration 1439/1450
#
#                        Computation: 2378400 steps/s (collection: 0.670s, learning 3.463s)
#                Value function loss: 140.3396
#                     Surrogate loss: -0.0001
#              Mean action noise std: 2331.22
#                        Mean reward: 47.18
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7834
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.13s
#                         Total time: 62.36s
#                                ETA: -61.2s
#
# ################################################################################
#                       Learning iteration 1440/1450
#
#                        Computation: 2357070 steps/s (collection: 0.708s, learning 3.462s)
#                Value function loss: 148.6513
#                     Surrogate loss: -0.0003
#              Mean action noise std: 2331.31
#                        Mean reward: 47.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7831
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.17s
#                         Total time: 66.53s
#                                ETA: -65.3s
#
# ################################################################################
#                       Learning iteration 1441/1450
#
#                        Computation: 2374921 steps/s (collection: 0.675s, learning 3.464s)
#                Value function loss: 140.0510
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2331.41
#                        Mean reward: 47.19
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7834
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.14s
#                         Total time: 70.67s
#                                ETA: -69.4s
#
# ################################################################################
#                       Learning iteration 1442/1450
#
#                        Computation: 2360455 steps/s (collection: 0.713s, learning 3.451s)
#                Value function loss: 146.2521
#                     Surrogate loss: -0.0001
#              Mean action noise std: 2331.59
#                        Mean reward: 47.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7838
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.16s
#                         Total time: 74.84s
#                                ETA: -73.5s
#
# ################################################################################
#                       Learning iteration 1443/1450
#
#                        Computation: 2377293 steps/s (collection: 0.671s, learning 3.464s)
#                Value function loss: 138.4614
#                     Surrogate loss: -0.0001
#              Mean action noise std: 2331.82
#                        Mean reward: 47.23
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7835
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.14s
#                         Total time: 78.97s
#                                ETA: -77.6s
#
# ################################################################################
#                       Learning iteration 1444/1450
#
#                        Computation: 2356439 steps/s (collection: 0.713s, learning 3.458s)
#                Value function loss: 145.7834
#                     Surrogate loss: -0.0000
#              Mean action noise std: 2331.95
#                        Mean reward: 46.99
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7832
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.17s
#                         Total time: 83.14s
#                                ETA: -81.6s
#
# ################################################################################
#                       Learning iteration 1445/1450
#
#                        Computation: 2371200 steps/s (collection: 0.677s, learning 3.468s)
#                Value function loss: 140.0514
#                     Surrogate loss: 0.0005
#              Mean action noise std: 2332.10
#                        Mean reward: 47.18
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7826
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.15s
#                         Total time: 87.29s
#                                ETA: -85.7s
#
# ################################################################################
#                       Learning iteration 1446/1450
#
#                        Computation: 2373186 steps/s (collection: 0.679s, learning 3.463s)
#                Value function loss: 148.2522
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2332.25
#                        Mean reward: 47.13
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7828
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.14s
#                         Total time: 91.43s
#                                ETA: -89.8s
#
# ################################################################################
#                       Learning iteration 1447/1450
#
#                        Computation: 2358198 steps/s (collection: 0.678s, learning 3.490s)
#                Value function loss: 142.2438
#                     Surrogate loss: -0.0001
#              Mean action noise std: 2332.44
#                        Mean reward: 47.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7831
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.17s
#                         Total time: 95.60s
#                                ETA: -93.9s
#
# ################################################################################
#                       Learning iteration 1448/1450
#
#                        Computation: 2349210 steps/s (collection: 0.712s, learning 3.473s)
#                Value function loss: 151.5594
#                     Surrogate loss: -0.0000
#              Mean action noise std: 2332.65
#                        Mean reward: 47.21
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7826
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.18s
#                         Total time: 99.78s
#                                ETA: -98.0s
#
# ################################################################################
#                       Learning iteration 1449/1450
#
#                        Computation: 2382131 steps/s (collection: 0.664s, learning 3.462s)
#                Value function loss: 143.0621
#                     Surrogate loss: -0.0000
#              Mean action noise std: 2332.86
#                        Mean reward: 47.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7826
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.13s
#                         Total time: 103.91s
#                                ETA: -102.0s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 201.58024447047492
# score     : [  57.74083102   63.47082887   53.73410765   53.54436457   54.01788691
#    60.77685244   55.31278858   72.04097345   54.85897719   61.33292967
#    56.40855739   55.79518217   53.23069263   53.92261845   54.71351202
#    56.14616802  151.52178705  278.71276189   53.52865074   54.31258711
#    64.37268123   92.25963186   56.28161391  352.55281062   54.40539256
#    55.02450605  774.08770343   53.29222486   53.57575832   56.2775345
#    55.72020834  730.30723993   53.48049706   54.08464005   53.7564062
#    53.27017563   53.6190081   513.90486257   63.11840193   64.69974194
#    58.69869919   54.171865     57.34802742   53.24969796   53.56521922
#    53.68238181   71.4553562   167.23697156   54.13495862   54.93874835
#   264.61616398  352.74833607   58.21508735   57.20387251  418.72171482
#    53.59346475   83.29766046   53.38529717   53.98469317   53.85988605
#   213.64264251   68.30128134   53.76848074   55.83722622   65.52855573
#    55.59085651   55.03842318   63.98319205   81.04634089  777.0329457
#    54.06782344   53.93067925  664.1441969   796.50934382 2077.99339585
#  3886.52731869   55.62245718   53.26381207   55.93269974   53.52904493
#    53.23298948 1909.40039611  874.93774936   54.16942349   58.28499396
#    55.93599046   55.66000228   53.78229024   66.3382907    53.67437161
#    81.58481898   90.18353258  197.86305324   73.00162459   53.40492192
#    53.52074209   58.67791406   74.62669041   53.51101715   53.62071902]
# score.mean: 201.58024447047492

# %%
exp_result = {
    'reward_total': reward_history,
    'reward_peo': death_buf,
    'state': state_his_buf,
    'action': act_buf
}
torch.save(exp_result, 'exp4-t3300.pt')

# %%
run_result = torch.load('exp4-t3300.pt', weights_only=False)
death_mean = torch.mean(run_result['state'][-1][:,4]) * N
print(death_mean)

def infections(states, action, para, i):
    st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
    u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
    ht = st + et + at + it + rt

    st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * para['beta1'][i] + (et + at * (1 - u_aq)) * para['beta2'][i]) / ht
    st_out_e = st_out * parameter_static['alpha']
    st_out_i = st_out * (1 - parameter_static['alpha'])
    et_out_a = et * w * (1 - para['per'] - para['pei'])
    return et_out_a, st_out_e, st_out_i


init_state = torch.tensor([[100000, 20 , 0, 0, 0, 0]], dtype=torch.float32).to(torch.device(device))
s_i = torch.zeros(100).to(torch.device('cuda:0'))
s_a = torch.zeros(100).to(torch.device('cuda:0'))
s_t = torch.zeros(100).to(torch.device('cuda:0'))
for i in range(test_num):
    for t in range(T):
        if t == 0:
            sa_temp, se_temp, si_temp = infections(init_state, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        if t > 0 and t < T-1:
            sa_temp, se_temp, si_temp = infections(run_result['state'][t-1][i][:6].unsqueeze(0)*N, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        s_i[i] += si_temp[0]
        s_a[i] += sa_temp[0]
        s_t[i] += se_temp[0]
print([torch.mean(s_i), torch.mean(s_a)+torch.mean(s_i), torch.mean(s_t)])
# Out:
# tensor(6.64784, device='cuda:0')
# [tensor(1467.67468, device='cuda:0'), tensor(1504.89795, device='cuda:0'), tensor(2201.51196, device='cuda:0')]

# %%
run_result = torch.load('exp4-t3300.pt', weights_only=False)
act_buf = run_result['action']
state_his_buf = run_result['state']
def res_alloc(states, action):
    states = states * N
    st, et, at, it, dt, rt = states[0], states[1], states[2], states[3], states[4], states[5]
    u_sv, u_it, u_aq, u_iq, w = action[0], action[1], action[2], action[3], action[4]

    cost_it  = it * u_it * parameter_static['cost_ti']
    cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
    cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
    per_poc  = ((st + et + at + rt) / N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
    cost_poc = (st + et + rt + at) * w * per_poc
    all_cost = cost_poc + cost_it + cost_v + cost_q
    return cost_poc, cost_it, cost_v, cost_q, all_cost
cost_it = 0
cost_v = 0
cost_q = 0
cost_poc = 0
all_cost = 0

for i in range(100):
    c_poc, c_it, c_v, c_q, c_all = res_alloc(Init_state[0], act_buf[0][i,:])
    cost_it += c_it
    cost_v += c_v
    cost_q += c_q
    cost_poc += c_poc
    all_cost += c_all

for t in range(57):
    for i in range(100):
        c_poc, c_it, c_v, c_q, c_all = res_alloc(state_his_buf[t][i,:], act_buf[t+1][i,:])
        cost_it += c_it
        cost_v += c_v
        cost_q += c_q
        cost_poc += c_poc
        all_cost += c_all
[cost_it/all_cost, cost_v/all_cost, cost_q/all_cost, cost_poc/all_cost]
# Out:
# [tensor(0.01036, device='cuda:0'),
#  tensor(0., device='cuda:0'),
#  tensor(0.00383, device='cuda:0'),
#  tensor(0.98581, device='cuda:0')]
