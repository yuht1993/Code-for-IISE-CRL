# %%
from rsl_rl.env import VecEnv
from rsl_rl.runners import OnPolicyRunner
import torch
import numpy as np
torch.set_printoptions(precision=5, linewidth=200, sci_mode=False)

N          = 100020
state_dim  = 8
action_dim = 5
T          = 60
budget     = 3600.
N_envs     = 1024 * 64
ΔT         = 1.0
device     = 'cuda'
usr_std = 0.1
test_num = 100
seed = 0

parameter_static = dict(N          = N,
                        B          = budget,
                        T          = T,
                        alpha      = 0.6,
                        v_max      = 0.2/14,
                        cost_ti    = 0.0977,
                        cost_ta    = 0.02,
                        cost_v     = 0.07,
                        cost_poc_0 = 0.000369,
                        cost_poc_1 = 0.001057,
                        pid        = 1.10/1000,
                        psr        = 0.7,
                        pid_plus   = 0.1221/1000,
                        pir        = 1/8,
                        prs        = 1/7)

Random_mean = {"beta2" : 0.78735,
               "beta1" : 0.15747,
               "pei"   : 0.10714,
               "per"   : 0.04545}

space = {"beta2" : [Random_mean['beta2'],Random_mean['beta2']*usr_std],
         "beta1" : [Random_mean['beta1'], Random_mean['beta1']*usr_std],
         "pei"   : [Random_mean['pei'], Random_mean['pei']*usr_std],
         "per"   : [Random_mean['per'], Random_mean['per']*usr_std]}

Init_state = torch.tensor([[100000 / N, 20 / N, 0, 0, 0, 0, 1, 0]], 
                         dtype=torch.float32).to(torch.device(device))

# %%
class myVecEnv(VecEnv):
    def __init__(self, interval, n_envs = N_envs):
        self.B = parameter_static['B']  # total budget
        self.N = parameter_static['N']
        self.device = device
        self.init_state = Init_state
        self.states = self.init_state.repeat(n_envs, 1)
        self.num_envs = n_envs
        self.num_obs = state_dim
        self.num_privileged_obs = None
        self.num_actions = action_dim
        self.max_episode_length = parameter_static['T']
        
        torch.manual_seed(seed)
        self.parameter_random = {
            key: torch.empty(self.num_envs).normal_(
                interval[key][0],
                interval[key][1]
            ).to(torch.device(device))
            for key, value in Random_mean.items()
        }

        for key, value in Random_mean.items():
            indice = self.parameter_random[key] < 0
            self.parameter_random[key][indice] = -self.parameter_random[key][indice] 

        # optimization flags for pytorch JIT
        torch._C._jit_set_profiling_mode(False)
        torch._C._jit_set_profiling_executor(False)
        
        # allocate buffers
        self.privileged_obs_buf = None
        self.obs_buf = torch.zeros(self.num_envs, self.num_obs, device=self.device, dtype=torch.float)
        self.rew_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.float)
        self.reset_buf = torch.ones(self.num_envs, device=self.device, dtype=torch.long)
        self.episode_length_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.long)
        
        self.actions = torch.zeros(self.num_envs, self.num_actions, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_sums = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_acts = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.extras = {}
    
    def para_update(self, para):
        self.parameter_random = para
        
    def step(self, actions):
        # actions clip
        soft_bound = [-0.5, 1.5]
        out_of_limits = -(actions - soft_bound[0]).clip(max=0.)
        out_of_limits += (actions - soft_bound[1]).clip(min=0.)
        scale_action = -0.1
        reward_action = scale_action * torch.sum(out_of_limits, dim=1).clip(max=1.).to(self.device)
        self.actions = torch.clip(actions, 0., 1.).to(self.device)

        # update actions & states
        b, p = self.states[:, -2] * self.B, self.states[:, -1]
        inv_c = self.cost_function(self.actions)
        b -= inv_c
        b = torch.clip(b, 0., self.B).to(self.device)
        mask = (b > 0).float().unsqueeze(-1)
        self.act = self.actions * mask
        inv_c = self.cost_function(self.act)
        next_state, reward_original = self.transition(self.act)
        self.extras['reward_original'] = reward_original
        self.extras['inv_cost'] = inv_c
        self.episode_length_buf += 1
        p = self.episode_length_buf / self.max_episode_length
        self.states = torch.cat([next_state / self.N, (b / self.B).unsqueeze(-1), p.unsqueeze(-1)], dim=-1)
        
        # check termination
        self.reset_buf = self.episode_length_buf >= self.max_episode_length
        
        # compute reward
        r_mean = -6584
        r_std  =  7347
        reward = (reward_original - inv_c - r_mean) / r_std
        #if reward > 0: 
        #reward = torch.exp(reward)/10
        #reward = torch.exp((1e5 + reward_original - inv_c) / 5e4)
        self.rew_buf       = reward + reward_action
        self.episode_sums += reward + reward_action
        self.episode_acts += reward_action
        
        # compute resets
        env_ids = self.reset_buf.nonzero(as_tuple=False).flatten()
        self.reset_idx(env_ids)
        
        # compute observations
        return self.get_observations(), self.states, self.rew_buf, self.reset_buf, self.extras

    def reset_idx(self, env_ids):
        """Reset selected robots"""
        if len(env_ids) == 0:
            return
        
        assert len(env_ids) == self.num_envs
        # reset robot states
        self.states[env_ids] = self.init_state
        # reset buffers
        self.episode_length_buf[env_ids] = 0
        self.reset_buf[env_ids] = 1
        # fill extras
        self.extras["episode"] = {}
        self.extras["episode"]['rew_sum'] = torch.mean(self.episode_sums[env_ids]) / (self.max_episode_length * ΔT)
        self.extras["episode"]['rew_act'] = torch.mean(self.episode_acts[env_ids]) / (self.max_episode_length * ΔT)
        self.episode_sums[env_ids] = 0.
        self.episode_acts[env_ids] = 0.
    
    def reset(self):
        """ Reset all robots"""
        self.reset_idx(torch.arange(self.num_envs, device=self.device))
        return {}, {}
    
    def get_observations(self):
        o_mean = torch.tensor([[0.58712867, 0.06804276, 0.00308146, 0.25684301, 0.00261079, 0.08229331, 0.26572794, 0.51      ]], dtype=torch.float32).to(torch.device(self.device))
        o_std  = torch.tensor([[0.41484398, 0.07883003, 0.00389494, 0.292568  , 0.00394907, 0.06906768, 0.33943075, 0.28861739]], dtype=torch.float32).to(torch.device(self.device))
        self.obs_buf = (self.states - o_mean) / o_std
        return self.obs_buf
    
    def get_privileged_observations(self):
        return self.privileged_obs_buf

    def cost_function(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]

        cost_it  = it * u_it * parameter_static['cost_ti']
        cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
        cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
        per_poc  = ((st + et + at + rt) / self.N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
        cost_poc = (st + et + rt + at) * w * per_poc
        return cost_poc + cost_it + cost_v + cost_q

    def transition(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
        ht = st + et + at + it + rt

        st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * self.parameter_random['beta1'] + (et + at * (1 - u_aq)) * self.parameter_random['beta2']) / ht
        st_out_e = st_out * parameter_static['alpha']
        st_out_i = st_out * (1 - parameter_static['alpha'])
        st_out_r = u_sv * parameter_static['v_max'] * st * parameter_static['psr']
        et_out_r = et * self.parameter_random['per']
        et_out_i = et * self.parameter_random['pei']
        et_out_a = et * w * (1 - self.parameter_random['per'] - self.parameter_random['pei'])
        at_out_i = at * self.parameter_random['pei']
        at_out_r = at * self.parameter_random['per']
        it_out_r = it * parameter_static['pir'] * u_it
        it_out_d = it * parameter_static['pid'] * (1 - u_it) + it * u_it * parameter_static['pid_plus']
        rt_out_s = rt * parameter_static['prs']
        
        stn = st - st_out_e - st_out_i - st_out_r + rt_out_s
        etn = et - et_out_r - et_out_i - et_out_a + st_out_e
        atn = at - at_out_r - at_out_i + et_out_a
        itn = it - it_out_r - it_out_d + st_out_i + et_out_i + at_out_i
        dtn = dt + it_out_d
        rtn = rt + et_out_r + at_out_r + it_out_r + st_out_r - rt_out_s

        reward = -2.6 * st_out - 100 * it_out_d

        next_state = torch.stack([stn, etn, atn, itn, dtn, rtn], dim=-1)
        return next_state, reward

# %%
import inspect

class BaseConfig:
    def __init__(self) -> None:
        """ Initializes all member classes recursively. Ignores all namse starting with '__' (buit-in methods)."""
        self.init_member_classes(self)
    
    @staticmethod
    def init_member_classes(obj):
        # iterate over all attributes names
        for key in dir(obj):
            # disregard builtin attributes
            # if key.startswith("__"):
            if key=="__class__":
                continue
            # get the corresponding attribute object
            var =  getattr(obj, key)
            # check if it the attribute is a class
            if inspect.isclass(var):
                # instantate the class
                i_var = var()
                # set the attribute to the instance instead of the type
                setattr(obj, key, i_var)
                # recursively init members of the attribute
                BaseConfig.init_member_classes(i_var)

class LeggedRobotCfgPPO(BaseConfig):
    seed = 1
    runner_class_name = 'OnPolicyRunner'
    class policy:
        init_noise_std = 2
        actor_hidden_dims  = [64, 32, 16] 
        critic_hidden_dims = [64, 32, 16]
        activation = 'elu' # can be elu, relu, selu, crelu, lrelu, tanh, sigmoid
        # only for 'ActorCriticRecurrent':
        # rnn_type = 'lstm'
        # rnn_hidden_size = 512
        # rnn_num_layers = 1
        
    class algorithm:
        # training params
        value_loss_coef = 0.5
        use_clipped_value_loss = True
        clip_param = 0.2
        entropy_coef = 0.01
        num_learning_epochs = 5
        num_mini_batches = 64 # mini batch size = num_envs*nsteps / nminibatches
        learning_rate = 1.e-4
        schedule = 'adaptive' # could be adaptive, fixed
        gamma = 0.99
        lam = 0.95
        desired_kl = 0.01
        max_grad_norm = 1.

    class runner:
        policy_class_name = 'ActorCritic'
        algorithm_class_name = 'PPO'
        num_steps_per_env =  150 # per iteration
        max_iterations    = 100 # number of policy updates

        # logging
        save_interval = 100 # check for potential saves every this many iterations
        experiment_name = 'test'
        run_name = ''
        # load and resume
        resume = True
        load_run = -1 # -1 = last run
        checkpoint = -1 # -1 = last saved model
        resume_path = None # updated from load_run and chkpt
        
def class_to_dict(obj) -> dict:
    if not  hasattr(obj,"__dict__"):
        return obj
    result = {}
    for key in dir(obj):
        if key.startswith("_"):
            continue
        element = []
        val = getattr(obj, key)
        if isinstance(val, list):
            for item in val:
                element.append(class_to_dict(item))
        else:
            element = class_to_dict(val)
        result[key] = element
    return result

# %%
def para_sampling(intvl, num_sample=N_envs):
    parameter_random = {
        key: torch.empty(num_sample).normal_(
        intvl[key][0],
        intvl[key][1]
        ).to(torch.device(device))
        for key, value in Random_mean.items()
    }
    for key, value in Random_mean.items():
        indice = parameter_random[key] < 0
        parameter_random[key][indice] = -parameter_random[key][indice] 
    return parameter_random

def update_space(final_indices, para_buf, space):
    para_est = {}
    for key, tensor_values in para_buf.items():
        selected_values = torch.mean(tensor_values[final_indices[0], final_indices[1]]) 
        para_values = torch.mean(tensor_values[final_indices[0], final_indices[1]], dim=0)
        update_values = space[key][0] + 0.5 * (selected_values - space[key][0])
        space[key] = [update_values , update_values  * 0.1]
        para_est[key] = para_values
    return space, para_est


def cal_err(para_value, env_para):
    gap = []
    for key, value in env_para.items():
        gap_temp = torch.mean(torch.abs(para_value[key] - env_para[key])/(env_para[key]))
        gap.append(gap_temp)
    return sum(gap)/len(gap) # 所有值都在范围内，返回 0
    
def state_estimator(env_sample, action_sim, state_sim, state_prior, space, iter): 
    env_sample.reset()
    env_sample.states = state_prior  
    para_buf, mse_buf, obs_buf, states_buf = {}, {}, {}, {}
    for i in range(iter):
        para = para_sampling(space, test_num)
        env_sample.para_update(para)
        obs_sample, states_sample, _, _, _ = env_sample.step(action_sim.detach())  
        mse = torch.mean((state_sim[:,2:4] - states_sample[:,2:4]) ** 2, dim=1) 
        if i == 0:
            mse_buf = mse.unsqueeze(0)
            obs_buf = obs_sample.unsqueeze(0)
            states_buf = states_sample.unsqueeze(0)
            for key, values in para.items():
                para_buf[key] = para[key].unsqueeze(0)
        else:
            mse_buf = torch.cat((mse_buf, mse.unsqueeze(0)), dim=0)
            obs_buf = torch.cat((obs_buf, obs_sample.unsqueeze(0)),dim=0)
            states_buf = torch.cat((states_buf, states_sample.unsqueeze(0)), dim=0)
            for key, values in para.items():
                para_buf[key] = torch.cat((para_buf[key], para[key].unsqueeze(0)), dim=0)
                
     
    k = int(iter * 0.05)
    _, row_indices = torch.topk(mse_buf, k=k, dim=0, largest=False)
    column_indices = torch.arange(mse_buf.shape[1]).repeat(k, 1)
    top_indices = [row_indices, column_indices]
    obs_est = torch.mean(obs_buf[row_indices,column_indices,:], dim=0)
    state_est = torch.mean(states_buf[row_indices,column_indices,:], dim=0)
    state_est[:,-1] = state_prior[:,-1] + torch.tensor(1/T)
    return obs_est, state_est, top_indices, para_buf

# %%
para_err = 0.5
torch.manual_seed(seed)
para_true = []
para_temp = {
    key: torch.empty(test_num).uniform_(
        value * (1-para_err),
        value * (1+para_err)
    ).to(torch.device(device))
    for key, value in Random_mean.items()
}


para = {}
for t in range(T):
    para = {
        key: (para_temp[key] + t * 0.5 *  para_temp[key] /T).to(torch.device(device)) if key == 'per' 
        else (para_temp[key] - t * 0.5 *  para_temp[key] /T).to(torch.device(device))
        for key, value in Random_mean.items()
        }
    para_true.append(para)

# %%
env = myVecEnv(space, test_num)
env.para_update(para_true[0])
train_cfg = LeggedRobotCfgPPO()
train_cfg_dict = class_to_dict(train_cfg)


env_transfer = myVecEnv(space)
runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_exp4_t1', device=env.device)
runner.load(f'rsl_low_budget3600/model_100.pt')

policy = runner.get_inference_policy(device=env.device)

reward_history = []
act_buf = []
state_his_buf = []
death_buf = []

env_sample = myVecEnv(space, test_num)
state_est = env.states
obs_est = env.get_observations()
for t in range(T-1):
    actions = policy(obs_est.detach())
    obs, states, _, _, infos = env.step(actions.detach())
    reward_history.append((-infos['reward_original'] + infos['inv_cost']).tolist())
    death_buf.append((-infos['reward_original']).tolist())
    act_buf.append(env.act)
    state_his_buf.append(env.states)
    obs_est, state_buf, top_indices, para_buf = state_estimator(env_sample, actions, states, state_est, space, 1024)
    space, para_v = update_space(top_indices, para_buf, space) 

    runner.learn(num_learning_iterations=25, init_at_random_ep_len=False)
    policy = runner.get_inference_policy(device=env.device)
    env_transfer = myVecEnv(space)
    runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_exp4_t1', device=env.device)
    runner.load(f'rsl_exp4_t1/model_{int(t)* 25}.pt')

    if t < T - 1: env.para_update(para_true[t + 1])
    print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')


reward_history = np.array(reward_history)
print(f'score     : {np.sum(reward_history, axis=0)/T       }')
print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
# Out:
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2283759 steps/s (collection: 0.723s, learning 3.581s)
#                Value function loss: 408.0237
#                     Surrogate loss: -0.0005
#              Mean action noise std: 4.58
#                        Mean reward: 35.59
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3477
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.30s
#                         Total time: 4.30s
#                                ETA: 107.6s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2384882 steps/s (collection: 0.640s, learning 3.482s)
#                Value function loss: 472.6038
#                     Surrogate loss: -0.0007
#              Mean action noise std: 4.61
#                        Mean reward: 37.48
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5877
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.12s
#                         Total time: 8.43s
#                                ETA: 101.1s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2374535 steps/s (collection: 0.634s, learning 3.506s)
#                Value function loss: 424.4876
#                     Surrogate loss: -0.0002
#              Mean action noise std: 4.65
#                        Mean reward: 38.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6207
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.14s
#                         Total time: 12.57s
#                                ETA: 96.3s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2386609 steps/s (collection: 0.642s, learning 3.477s)
#                Value function loss: 510.8386
#                     Surrogate loss: -0.0008
#              Mean action noise std: 4.68
#                        Mean reward: 39.54
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6438
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.12s
#                         Total time: 16.69s
#                                ETA: 91.8s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2396474 steps/s (collection: 0.635s, learning 3.467s)
#                Value function loss: 447.4936
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4.73
#                        Mean reward: 41.73
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6645
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.10s
#                         Total time: 20.79s
#                                ETA: 87.3s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2375107 steps/s (collection: 0.640s, learning 3.499s)
#                Value function loss: 538.1613
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.78
#                        Mean reward: 42.35
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6789
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.14s
#                         Total time: 24.93s
#                                ETA: 83.1s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2377399 steps/s (collection: 0.647s, learning 3.488s)
#                Value function loss: 462.4356
#                     Surrogate loss: 0.0001
#              Mean action noise std: 4.84
#                        Mean reward: 43.39
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6927
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.13s
#                         Total time: 29.06s
#                                ETA: 78.9s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2407595 steps/s (collection: 0.641s, learning 3.442s)
#                Value function loss: 557.8743
#                     Surrogate loss: -0.0003
#              Mean action noise std: 4.89
#                        Mean reward: 42.23
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7031
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.08s
#                         Total time: 33.14s
#                                ETA: 74.6s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2408184 steps/s (collection: 0.639s, learning 3.443s)
#                Value function loss: 475.3486
#                     Surrogate loss: 0.0003
#              Mean action noise std: 4.95
#                        Mean reward: 43.49
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7140
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.08s
#                         Total time: 37.23s
#                                ETA: 70.3s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2408183 steps/s (collection: 0.645s, learning 3.437s)
#                Value function loss: 572.2616
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.00
#                        Mean reward: 44.33
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7199
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.08s
#                         Total time: 41.31s
#                                ETA: 66.1s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2398807 steps/s (collection: 0.649s, learning 3.449s)
#                Value function loss: 482.2721
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.08
#                        Mean reward: 44.48
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7252
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.10s
#                         Total time: 45.41s
#                                ETA: 61.9s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2402314 steps/s (collection: 0.658s, learning 3.434s)
#                Value function loss: 579.9318
#                     Surrogate loss: 0.0000
#              Mean action noise std: 5.13
#                        Mean reward: 44.75
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7281
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.09s
#                         Total time: 49.50s
#                                ETA: 57.7s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2408773 steps/s (collection: 0.656s, learning 3.425s)
#                Value function loss: 488.5457
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.20
#                        Mean reward: 44.91
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7335
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.08s
#                         Total time: 53.58s
#                                ETA: 53.6s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2404072 steps/s (collection: 0.650s, learning 3.439s)
#                Value function loss: 590.8313
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.27
#                        Mean reward: 45.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7387
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.09s
#                         Total time: 57.67s
#                                ETA: 49.4s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2409951 steps/s (collection: 0.641s, learning 3.438s)
#                Value function loss: 496.8900
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.34
#                        Mean reward: 44.86
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7429
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.08s
#                         Total time: 61.75s
#                                ETA: 45.3s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2417042 steps/s (collection: 0.641s, learning 3.426s)
#                Value function loss: 599.7043
#                     Surrogate loss: 0.0000
#              Mean action noise std: 5.42
#                        Mean reward: 44.85
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7437
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.07s
#                         Total time: 65.81s
#                                ETA: 41.1s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2354119 steps/s (collection: 0.644s, learning 3.532s)
#                Value function loss: 502.4112
#                     Surrogate loss: 0.0014
#              Mean action noise std: 5.50
#                        Mean reward: 44.81
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7474
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.18s
#                         Total time: 69.99s
#                                ETA: 37.1s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2314865 steps/s (collection: 0.643s, learning 3.603s)
#                Value function loss: 605.3280
#                     Surrogate loss: -0.0000
#              Mean action noise std: 5.58
#                        Mean reward: 45.34
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7504
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.25s
#                         Total time: 74.24s
#                                ETA: 33.0s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2300816 steps/s (collection: 0.665s, learning 3.607s)
#                Value function loss: 504.4911
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.67
#                        Mean reward: 45.51
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7535
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.27s
#                         Total time: 78.51s
#                                ETA: 28.9s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2319222 steps/s (collection: 0.648s, learning 3.590s)
#                Value function loss: 604.2374
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.75
#                        Mean reward: 45.77
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7538
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.24s
#                         Total time: 82.75s
#                                ETA: 24.8s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2306739 steps/s (collection: 0.644s, learning 3.617s)
#                Value function loss: 500.5249
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.84
#                        Mean reward: 45.73
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7547
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.26s
#                         Total time: 87.01s
#                                ETA: 20.7s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2313235 steps/s (collection: 0.643s, learning 3.606s)
#                Value function loss: 597.6833
#                     Surrogate loss: 0.0000
#              Mean action noise std: 5.91
#                        Mean reward: 45.78
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7540
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.25s
#                         Total time: 91.26s
#                                ETA: 16.6s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2313235 steps/s (collection: 0.655s, learning 3.594s)
#                Value function loss: 497.1629
#                     Surrogate loss: 0.0004
#              Mean action noise std: 6.00
#                        Mean reward: 45.69
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7541
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.25s
#                         Total time: 95.51s
#                                ETA: 12.5s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2313778 steps/s (collection: 0.651s, learning 3.597s)
#                Value function loss: 597.2923
#                     Surrogate loss: 0.0005
#              Mean action noise std: 6.09
#                        Mean reward: 45.57
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7556
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.25s
#                         Total time: 99.76s
#                                ETA: 8.3s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2360885 steps/s (collection: 0.643s, learning 3.521s)
#                Value function loss: 494.7940
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.17
#                        Mean reward: 45.25
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7540
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.16s
#                         Total time: 103.92s
#                                ETA: 4.2s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 0.6743329617182413
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2353559 steps/s (collection: 0.678s, learning 3.499s)
#                Value function loss: 407.2849
#                     Surrogate loss: -0.0003
#              Mean action noise std: 4.62
#                        Mean reward: 37.09
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3661
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.18s
#                         Total time: 4.18s
#                                ETA: 104.4s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2363717 steps/s (collection: 0.668s, learning 3.491s)
#                Value function loss: 480.8782
#                     Surrogate loss: -0.0004
#              Mean action noise std: 4.65
#                        Mean reward: 39.32
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6162
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.16s
#                         Total time: 8.34s
#                                ETA: 100.0s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2367122 steps/s (collection: 0.653s, learning 3.500s)
#                Value function loss: 421.5910
#                     Surrogate loss: -0.0001
#              Mean action noise std: 4.70
#                        Mean reward: 39.95
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6437
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.15s
#                         Total time: 12.49s
#                                ETA: 95.7s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2364283 steps/s (collection: 0.657s, learning 3.501s)
#                Value function loss: 508.3864
#                     Surrogate loss: -0.0006
#              Mean action noise std: 4.73
#                        Mean reward: 40.73
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6637
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.16s
#                         Total time: 16.65s
#                                ETA: 91.6s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2377973 steps/s (collection: 0.641s, learning 3.493s)
#                Value function loss: 421.0310
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4.79
#                        Mean reward: 42.31
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6800
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.13s
#                         Total time: 20.78s
#                                ETA: 87.3s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2376826 steps/s (collection: 0.651s, learning 3.485s)
#                Value function loss: 490.7421
#                     Surrogate loss: 0.0007
#              Mean action noise std: 4.83
#                        Mean reward: 43.24
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6900
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.14s
#                         Total time: 24.92s
#                                ETA: 83.1s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2380269 steps/s (collection: 0.658s, learning 3.472s)
#                Value function loss: 411.5168
#                     Surrogate loss: 0.0001
#              Mean action noise std: 4.89
#                        Mean reward: 43.83
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7022
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.13s
#                         Total time: 29.05s
#                                ETA: 78.8s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2391241 steps/s (collection: 0.648s, learning 3.463s)
#                Value function loss: 492.4899
#                     Surrogate loss: -0.0004
#              Mean action noise std: 4.93
#                        Mean reward: 42.70
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7108
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.11s
#                         Total time: 33.16s
#                                ETA: 74.6s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2414082 steps/s (collection: 0.638s, learning 3.434s)
#                Value function loss: 418.4193
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.00
#                        Mean reward: 43.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7203
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.07s
#                         Total time: 37.23s
#                                ETA: 70.3s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2409361 steps/s (collection: 0.650s, learning 3.430s)
#                Value function loss: 501.4421
#                     Surrogate loss: -0.0002
#              Mean action noise std: 5.05
#                        Mean reward: 44.64
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7265
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.08s
#                         Total time: 41.31s
#                                ETA: 66.1s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2407595 steps/s (collection: 0.637s, learning 3.446s)
#                Value function loss: 424.1806
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.12
#                        Mean reward: 44.92
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7332
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.08s
#                         Total time: 45.39s
#                                ETA: 61.9s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2402900 steps/s (collection: 0.640s, learning 3.451s)
#                Value function loss: 509.9055
#                     Surrogate loss: -0.0000
#              Mean action noise std: 5.17
#                        Mean reward: 45.30
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7371
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.09s
#                         Total time: 49.48s
#                                ETA: 57.7s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2414673 steps/s (collection: 0.637s, learning 3.434s)
#                Value function loss: 431.2860
#                     Surrogate loss: 0.0008
#              Mean action noise std: 5.25
#                        Mean reward: 45.38
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7419
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.07s
#                         Total time: 53.55s
#                                ETA: 53.6s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2412900 steps/s (collection: 0.634s, learning 3.440s)
#                Value function loss: 520.7570
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.32
#                        Mean reward: 45.52
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7462
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.07s
#                         Total time: 57.63s
#                                ETA: 49.4s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2407008 steps/s (collection: 0.635s, learning 3.449s)
#                Value function loss: 439.7139
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.39
#                        Mean reward: 45.15
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7491
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.08s
#                         Total time: 61.71s
#                                ETA: 45.3s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2411719 steps/s (collection: 0.647s, learning 3.429s)
#                Value function loss: 529.0613
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.46
#                        Mean reward: 45.34
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7502
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.08s
#                         Total time: 65.79s
#                                ETA: 41.1s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2421198 steps/s (collection: 0.633s, learning 3.427s)
#                Value function loss: 445.0231
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.54
#                        Mean reward: 45.26
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7521
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.06s
#                         Total time: 69.85s
#                                ETA: 37.0s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2417042 steps/s (collection: 0.638s, learning 3.429s)
#                Value function loss: 534.4972
#                     Surrogate loss: 0.0000
#              Mean action noise std: 5.61
#                        Mean reward: 45.45
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7533
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.07s
#                         Total time: 73.92s
#                                ETA: 32.9s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2399974 steps/s (collection: 0.650s, learning 3.446s)
#                Value function loss: 448.2644
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.70
#                        Mean reward: 45.52
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7550
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.10s
#                         Total time: 78.01s
#                                ETA: 28.7s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2405836 steps/s (collection: 0.660s, learning 3.426s)
#                Value function loss: 538.0777
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.76
#                        Mean reward: 45.94
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7555
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.09s
#                         Total time: 82.10s
#                                ETA: 24.6s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2418821 steps/s (collection: 0.643s, learning 3.421s)
#                Value function loss: 447.0750
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.84
#                        Mean reward: 45.52
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7535
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.06s
#                         Total time: 86.16s
#                                ETA: 20.5s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2407596 steps/s (collection: 0.661s, learning 3.422s)
#                Value function loss: 532.5630
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.91
#                        Mean reward: 45.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7512
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.08s
#                         Total time: 90.25s
#                                ETA: 16.4s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2422983 steps/s (collection: 0.636s, learning 3.421s)
#                Value function loss: 446.5297
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.00
#                        Mean reward: 45.58
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7518
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.06s
#                         Total time: 94.30s
#                                ETA: 12.3s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2401728 steps/s (collection: 0.663s, learning 3.430s)
#                Value function loss: 535.8692
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.08
#                        Mean reward: 45.70
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7536
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.09s
#                         Total time: 98.40s
#                                ETA: 8.2s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2402314 steps/s (collection: 0.649s, learning 3.443s)
#                Value function loss: 450.7473
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.16
#                        Mean reward: 45.29
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7544
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.09s
#                         Total time: 102.49s
#                                ETA: 4.1s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 3.975264170010884
# ################################################################################
#                         Learning iteration 25/50
#
#                        Computation: 2405834 steps/s (collection: 0.669s, learning 3.417s)
#                Value function loss: 448.6436
#                     Surrogate loss: 0.0004
#              Mean action noise std: 6.25
#                        Mean reward: 45.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4564
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.09s
#                         Total time: 4.09s
#                                ETA: 0.0s
#
# ################################################################################
#                         Learning iteration 26/50
#
#                        Computation: 2407008 steps/s (collection: 0.649s, learning 3.435s)
#                Value function loss: 505.3535
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.33
#                        Mean reward: 45.74
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7518
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.08s
#                         Total time: 8.17s
#                                ETA: -0.3s
#
# ################################################################################
#                         Learning iteration 27/50
#
#                        Computation: 2402300 steps/s (collection: 0.642s, learning 3.450s)
#                Value function loss: 407.8134
#                     Surrogate loss: 0.0010
#              Mean action noise std: 6.42
#                        Mean reward: 45.77
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7533
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.09s
#                         Total time: 12.26s
#                                ETA: -0.9s
#
# ################################################################################
#                         Learning iteration 28/50
#
#                        Computation: 2492828 steps/s (collection: 0.656s, learning 3.287s)
#                Value function loss: 478.7980
#                     Surrogate loss: -0.0000
#              Mean action noise std: 6.52
#                        Mean reward: 45.51
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7546
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 3.94s
#                         Total time: 16.21s
#                                ETA: -1.7s
#
# ################################################################################
#                         Learning iteration 29/50
#
#                        Computation: 2518318 steps/s (collection: 0.618s, learning 3.285s)
#                Value function loss: 371.9739
#                     Surrogate loss: 0.0005
#              Mean action noise std: 6.62
#                        Mean reward: 45.44
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7563
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 3.90s
#                         Total time: 20.11s
#                                ETA: -2.7s
#
# ################################################################################
#                         Learning iteration 30/50
#
#                        Computation: 2497891 steps/s (collection: 0.622s, learning 3.313s)
#                Value function loss: 435.9261
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.71
#                        Mean reward: 46.01
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7555
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 3.94s
#                         Total time: 24.04s
#                                ETA: -3.9s
#
# ################################################################################
#                         Learning iteration 31/50
#
#                        Computation: 2510956 steps/s (collection: 0.626s, learning 3.289s)
#                Value function loss: 354.9265
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.82
#                        Mean reward: 46.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7575
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 3.92s
#                         Total time: 27.96s
#                                ETA: -5.2s
#
# ################################################################################
#                         Learning iteration 32/50
#
#                        Computation: 2518972 steps/s (collection: 0.619s, learning 3.283s)
#                Value function loss: 409.0374
#                     Surrogate loss: 0.0010
#              Mean action noise std: 6.92
#                        Mean reward: 45.55
# ...
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 3.91s
#                         Total time: 31.28s
#                                ETA: -30.7s
#
# ################################################################################
#                       Learning iteration 1433/1450
#
#                        Computation: 2545613 steps/s (collection: 0.616s, learning 3.245s)
#                Value function loss: 157.9974
#                     Surrogate loss: 0.0000
#              Mean action noise std: 2424.66
#                        Mean reward: 46.06
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7654
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 3.86s
#                         Total time: 35.14s
#                                ETA: -34.5s
#
# ################################################################################
#                       Learning iteration 1434/1450
#
#                        Computation: 2542292 steps/s (collection: 0.627s, learning 3.239s)
#                Value function loss: 160.3815
#                     Surrogate loss: 0.0016
#              Mean action noise std: 2426.45
#                        Mean reward: 46.10
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7659
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 3.87s
#                         Total time: 39.00s
#                                ETA: -38.3s
#
# ################################################################################
#                       Learning iteration 1435/1450
#
#                        Computation: 2515727 steps/s (collection: 0.636s, learning 3.271s)
#                Value function loss: 157.1334
#                     Surrogate loss: -0.0000
#              Mean action noise std: 2429.34
#                        Mean reward: 45.84
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7629
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 3.91s
#                         Total time: 42.91s
#                                ETA: -42.1s
#
# ################################################################################
#                       Learning iteration 1436/1450
#
#                        Computation: 2523494 steps/s (collection: 0.639s, learning 3.256s)
#                Value function loss: 159.7801
#                     Surrogate loss: -0.0000
#              Mean action noise std: 2432.41
#                        Mean reward: 45.81
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7612
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 3.90s
#                         Total time: 46.81s
#                                ETA: -46.0s
#
# ################################################################################
#                       Learning iteration 1437/1450
#
#                        Computation: 2545615 steps/s (collection: 0.619s, learning 3.242s)
#                Value function loss: 159.9079
#                     Surrogate loss: 0.0002
#              Mean action noise std: 2435.14
#                        Mean reward: 45.81
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7607
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 3.86s
#                         Total time: 50.67s
#                                ETA: -49.8s
#
# ################################################################################
#                       Learning iteration 1438/1450
#
#                        Computation: 2529307 steps/s (collection: 0.623s, learning 3.263s)
#                Value function loss: 155.6407
#                     Surrogate loss: 0.0009
#              Mean action noise std: 2437.91
#                        Mean reward: 45.82
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7605
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 3.89s
#                         Total time: 54.56s
#                                ETA: -53.6s
#
# ################################################################################
#                       Learning iteration 1439/1450
#
#                        Computation: 2526040 steps/s (collection: 0.633s, learning 3.258s)
#                Value function loss: 152.9635
#                     Surrogate loss: 0.0007
#              Mean action noise std: 2440.23
#                        Mean reward: 45.90
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7616
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 3.89s
#                         Total time: 58.45s
#                                ETA: -57.4s
#
# ################################################################################
#                       Learning iteration 1440/1450
#
#                        Computation: 2512543 steps/s (collection: 0.628s, learning 3.284s)
#                Value function loss: 155.5421
#                     Surrogate loss: -0.0000
#              Mean action noise std: 2443.25
#                        Mean reward: 45.88
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7622
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 3.91s
#                         Total time: 62.36s
#                                ETA: -61.2s
#
# ################################################################################
#                       Learning iteration 1441/1450
#
#                        Computation: 2507408 steps/s (collection: 0.643s, learning 3.277s)
#                Value function loss: 155.0199
#                     Surrogate loss: 0.0008
#              Mean action noise std: 2445.81
#                        Mean reward: 46.00
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7637
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 3.92s
#                         Total time: 66.28s
#                                ETA: -65.1s
#
# ################################################################################
#                       Learning iteration 1442/1450
#
#                        Computation: 2518316 steps/s (collection: 0.646s, learning 3.257s)
#                Value function loss: 157.7350
#                     Surrogate loss: 0.0035
#              Mean action noise std: 2446.44
#                        Mean reward: 45.96
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7643
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 3.90s
#                         Total time: 70.18s
#                                ETA: -68.9s
#
# ################################################################################
#                       Learning iteration 1443/1450
#
#                        Computation: 2535161 steps/s (collection: 0.618s, learning 3.259s)
#                Value function loss: 155.0839
#                     Surrogate loss: 0.0004
#              Mean action noise std: 2448.98
#                        Mean reward: 45.82
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7626
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 3.88s
#                         Total time: 74.06s
#                                ETA: -72.7s
#
# ################################################################################
#                       Learning iteration 1444/1450
#
#                        Computation: 2520913 steps/s (collection: 0.625s, learning 3.274s)
#                Value function loss: 157.2909
#                     Surrogate loss: -0.0000
#              Mean action noise std: 2451.92
#                        Mean reward: 45.83
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7620
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 3.90s
#                         Total time: 77.96s
#                                ETA: -76.6s
#
# ################################################################################
#                       Learning iteration 1445/1450
#
#                        Computation: 2531900 steps/s (collection: 0.619s, learning 3.263s)
#                Value function loss: 157.4487
#                     Surrogate loss: 0.0000
#              Mean action noise std: 2454.75
#                        Mean reward: 46.01
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7627
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 3.88s
#                         Total time: 81.84s
#                                ETA: -80.4s
#
# ################################################################################
#                       Learning iteration 1446/1450
#
#                        Computation: 2518299 steps/s (collection: 0.621s, learning 3.282s)
#                Value function loss: 161.1371
#                     Surrogate loss: -0.0000
#              Mean action noise std: 2457.69
#                        Mean reward: 45.92
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7637
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 3.90s
#                         Total time: 85.75s
#                                ETA: -84.2s
#
# ################################################################################
#                       Learning iteration 1447/1450
#
#                        Computation: 2532957 steps/s (collection: 0.623s, learning 3.258s)
#                Value function loss: 158.9646
#                     Surrogate loss: 0.0024
#              Mean action noise std: 2459.27
#                        Mean reward: 46.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7645
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 3.88s
#                         Total time: 89.63s
#                                ETA: -88.0s
#
# ################################################################################
#                       Learning iteration 1448/1450
#
#                        Computation: 2476539 steps/s (collection: 0.621s, learning 3.348s)
#                Value function loss: 161.6020
#                     Surrogate loss: 0.0018
#              Mean action noise std: 2461.21
#                        Mean reward: 46.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7649
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 3.97s
#                         Total time: 93.60s
#                                ETA: -91.9s
#
# ################################################################################
#                       Learning iteration 1449/1450
#
#                        Computation: 2373961 steps/s (collection: 0.638s, learning 3.503s)
#                Value function loss: 155.5653
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2464.02
#                        Mean reward: 46.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7650
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.14s
#                         Total time: 97.74s
#                                ETA: -96.0s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 83.39826727111388
# score     : [ 62.81671044  75.70585791  59.215112    59.30065455  60.47762745
#   67.97099201  62.52379577  87.24852676  61.94911486  66.91756029
#   61.0965078   61.47204349  61.15309157  59.63455686  60.34340717
#   62.69621226  71.15499105  87.14543698  59.42009898  60.3305903
#   69.02844157 117.73839633  61.51841505 103.40068884  61.48721328
#   63.33561333 158.78496197  61.2422386   59.56429284  61.21558659
#   60.675429   191.38973462  59.45248238  60.06023816  59.50747071
#   61.18369612  59.62438032 151.55729671  69.9675214   70.95211415
#   63.56893374  60.0191333   64.05883093  61.17748476  59.41303028
#   59.86162596  81.56642147  75.16668488  60.37957533  62.34870775
#   87.60612327 169.68637028  69.38803928  63.8738804   97.63008603
#   59.69285162  65.34670924  59.16548273  59.61875829  59.99842509
#   73.54359803  71.70658617  59.84080977  65.72219944  74.2551024
#   61.62788416  62.79097402  67.19797953  77.87785491 360.90917117
#   59.39758348  60.48857833  74.15680178 183.34969284 294.32633588
#  461.01703537  64.04612063  61.27674702  63.22674089  59.49826116
#   61.14598615 283.30697041 114.59820112  61.00608366  65.19443113
#   61.29130752  61.50925319  60.07735139  68.64157368  59.67701405
#   68.87726016  78.16492502  86.38605566  70.08106236  58.8419308
#   59.47376099  71.21111513  65.30636798  59.26760851  59.68615612]
# score.mean: 83.39826727111388

# %%
exp_result = {
    'reward_total': reward_history,
    'reward_peo': death_buf,
    'state': state_his_buf,
    'action': act_buf
}
torch.save(exp_result, 'exp4-t3600.pt')

# %%
run_result = torch.load('exp4-t3600.pt', weights_only=False)
death_mean = torch.mean(run_result['state'][-1][:,4]) * N
print(death_mean)

def infections(states, action, para, i):
    st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
    u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
    ht = st + et + at + it + rt

    st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * para['beta1'][i] + (et + at * (1 - u_aq)) * para['beta2'][i]) / ht
    st_out_e = st_out * parameter_static['alpha']
    st_out_i = st_out * (1 - parameter_static['alpha'])
    et_out_a = et * w * (1 - para['per'] - para['pei'])
    return et_out_a, st_out_e, st_out_i


init_state = torch.tensor([[100000, 20 , 0, 0, 0, 0]], dtype=torch.float32).to(torch.device(device))
s_i = torch.zeros(100).to(torch.device('cuda:0'))
s_a = torch.zeros(100).to(torch.device('cuda:0'))
s_t = torch.zeros(100).to(torch.device('cuda:0'))
for i in range(test_num):
    for t in range(T):
        if t == 0:
            sa_temp, se_temp, si_temp = infections(init_state, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        if t > 0 and t < T-1:
            sa_temp, se_temp, si_temp = infections(run_result['state'][t-1][i][:6].unsqueeze(0)*N, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        s_i[i] += si_temp[0]
        s_a[i] += sa_temp[0]
        s_t[i] += se_temp[0]
print([torch.mean(s_i), torch.mean(s_a)+torch.mean(s_i), torch.mean(s_t)])
# Out:
# tensor(1.54240, device='cuda:0')
# [tensor(239.22290, device='cuda:0'), tensor(324.16559, device='cuda:0'), tensor(358.83438, device='cuda:0')]

# %%
run_result = torch.load('exp4-t3600.pt', weights_only=False)
act_buf = run_result['action']
state_his_buf = run_result['state']
def res_alloc(states, action):
    states = states * N
    st, et, at, it, dt, rt = states[0], states[1], states[2], states[3], states[4], states[5]
    u_sv, u_it, u_aq, u_iq, w = action[0], action[1], action[2], action[3], action[4]

    cost_it  = it * u_it * parameter_static['cost_ti']
    cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
    cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
    per_poc  = ((st + et + at + rt) / N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
    cost_poc = (st + et + rt + at) * w * per_poc
    all_cost = cost_poc + cost_it + cost_v + cost_q
    return cost_poc, cost_it, cost_v, cost_q, all_cost
cost_it = 0
cost_v = 0
cost_q = 0
cost_poc = 0
all_cost = 0

for i in range(100):
    c_poc, c_it, c_v, c_q, c_all = res_alloc(Init_state[0], act_buf[0][i,:])
    cost_it += c_it
    cost_v += c_v
    cost_q += c_q
    cost_poc += c_poc
    all_cost += c_all

for t in range(57):
    for i in range(100):
        c_poc, c_it, c_v, c_q, c_all = res_alloc(state_his_buf[t][i,:], act_buf[t+1][i,:])
        cost_it += c_it
        cost_v += c_v
        cost_q += c_q
        cost_poc += c_poc
        all_cost += c_all
[cost_it/all_cost, cost_v/all_cost, cost_q/all_cost, cost_poc/all_cost]
# Out:
# [tensor(0.02471, device='cuda:0'),
#  tensor(0., device='cuda:0'),
#  tensor(0.01195, device='cuda:0'),
#  tensor(0.96334, device='cuda:0')]
