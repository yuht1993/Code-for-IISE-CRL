# %%
from rsl_rl.env import VecEnv
from rsl_rl.runners import OnPolicyRunner
import torch
import numpy as np
torch.set_printoptions(precision=5, linewidth=200, sci_mode=False)

N          = 100020
state_dim  = 8
action_dim = 5
T          = 60
budget     = 2100.
N_envs     = 1024 * 64
ΔT         = 1.0
device     = 'cuda'
usr_std = 0.1
test_num = 100
seed = 0

parameter_static = dict(N          = N,
                        B          = budget,
                        T          = T,
                        alpha      = 0.6,
                        v_max      = 0.2/14,
                        cost_ti    = 0.0977,
                        cost_ta    = 0.02,
                        cost_v     = 0.07,
                        cost_poc_0 = 0.000369,
                        cost_poc_1 = 0.001057,
                        pid        = 1.10/1000,
                        psr        = 0.7,
                        pid_plus   = 0.1221/1000,
                        pir        = 1/8,
                        prs        = 1/7)

Random_mean = {"beta2" : 0.78735,
               "beta1" : 0.15747,
               "pei"   : 0.10714,
               "per"   : 0.04545}

space = {"beta2" : [Random_mean['beta2'],Random_mean['beta2']*usr_std],
         "beta1" : [Random_mean['beta1'], Random_mean['beta1']*usr_std],
         "pei"   : [Random_mean['pei'], Random_mean['pei']*usr_std],
         "per"   : [Random_mean['per'], Random_mean['per']*usr_std]}

Init_state = torch.tensor([[100000 / N, 20 / N, 0, 0, 0, 0, 1, 0]], 
                         dtype=torch.float32).to(torch.device(device))

# %%
class myVecEnv(VecEnv):
    def __init__(self, interval, n_envs = N_envs):
        self.B = parameter_static['B']  # total budget
        self.N = parameter_static['N']
        self.device = device
        self.init_state = Init_state
        self.states = self.init_state.repeat(n_envs, 1)
        self.num_envs = n_envs
        self.num_obs = state_dim
        self.num_privileged_obs = None
        self.num_actions = action_dim
        self.max_episode_length = parameter_static['T']
        
        torch.manual_seed(seed)
        self.parameter_random = {
            key: torch.empty(self.num_envs).normal_(
                interval[key][0],
                interval[key][1]
            ).to(torch.device(device))
            for key, value in Random_mean.items()
        }

        for key, value in Random_mean.items():
            indice = self.parameter_random[key] < 0
            self.parameter_random[key][indice] = -self.parameter_random[key][indice] 

        # optimization flags for pytorch JIT
        torch._C._jit_set_profiling_mode(False)
        torch._C._jit_set_profiling_executor(False)
        
        # allocate buffers
        self.privileged_obs_buf = None
        self.obs_buf = torch.zeros(self.num_envs, self.num_obs, device=self.device, dtype=torch.float)
        self.rew_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.float)
        self.reset_buf = torch.ones(self.num_envs, device=self.device, dtype=torch.long)
        self.episode_length_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.long)
        
        self.actions = torch.zeros(self.num_envs, self.num_actions, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_sums = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_acts = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.extras = {}
    
    def para_update(self, para):
        self.parameter_random = para
        
    def step(self, actions):
        # actions clip
        soft_bound = [-0.5, 1.5]
        out_of_limits = -(actions - soft_bound[0]).clip(max=0.)
        out_of_limits += (actions - soft_bound[1]).clip(min=0.)
        scale_action = -0.1
        reward_action = scale_action * torch.sum(out_of_limits, dim=1).clip(max=1.).to(self.device)
        self.actions = torch.clip(actions, 0., 1.).to(self.device)

        # update actions & states
        b, p = self.states[:, -2] * self.B, self.states[:, -1]
        inv_c = self.cost_function(self.actions)
        b -= inv_c
        b = torch.clip(b, 0., self.B).to(self.device)
        mask = (b > 0).float().unsqueeze(-1)
        self.act = self.actions * mask
        inv_c = self.cost_function(self.act)
        next_state, reward_original = self.transition(self.act)
        self.extras['reward_original'] = reward_original
        self.extras['inv_cost'] = inv_c
        self.episode_length_buf += 1
        p = self.episode_length_buf / self.max_episode_length
        self.states = torch.cat([next_state / self.N, (b / self.B).unsqueeze(-1), p.unsqueeze(-1)], dim=-1)
        
        # check termination
        self.reset_buf = self.episode_length_buf >= self.max_episode_length
        
        # compute reward
        r_mean = -6584
        r_std  =  7347
        reward = (reward_original - inv_c - r_mean) / r_std
        #if reward > 0: 
        #reward = torch.exp(reward)/10
        #reward = torch.exp((1e5 + reward_original - inv_c) / 5e4)
        self.rew_buf       = reward + reward_action
        self.episode_sums += reward + reward_action
        self.episode_acts += reward_action
        
        # compute resets
        env_ids = self.reset_buf.nonzero(as_tuple=False).flatten()
        self.reset_idx(env_ids)
        
        # compute observations
        return self.get_observations(), self.states, self.rew_buf, self.reset_buf, self.extras

    def reset_idx(self, env_ids):
        """Reset selected robots"""
        if len(env_ids) == 0:
            return
        
        assert len(env_ids) == self.num_envs
        # reset robot states
        self.states[env_ids] = self.init_state
        # reset buffers
        self.episode_length_buf[env_ids] = 0
        self.reset_buf[env_ids] = 1
        # fill extras
        self.extras["episode"] = {}
        self.extras["episode"]['rew_sum'] = torch.mean(self.episode_sums[env_ids]) / (self.max_episode_length * ΔT)
        self.extras["episode"]['rew_act'] = torch.mean(self.episode_acts[env_ids]) / (self.max_episode_length * ΔT)
        self.episode_sums[env_ids] = 0.
        self.episode_acts[env_ids] = 0.
    
    def reset(self):
        """ Reset all robots"""
        self.reset_idx(torch.arange(self.num_envs, device=self.device))
        return {}, {}
    
    def get_observations(self):
        o_mean = torch.tensor([[0.58712867, 0.06804276, 0.00308146, 0.25684301, 0.00261079, 0.08229331, 0.26572794, 0.51      ]], dtype=torch.float32).to(torch.device(self.device))
        o_std  = torch.tensor([[0.41484398, 0.07883003, 0.00389494, 0.292568  , 0.00394907, 0.06906768, 0.33943075, 0.28861739]], dtype=torch.float32).to(torch.device(self.device))
        self.obs_buf = (self.states - o_mean) / o_std
        return self.obs_buf
    
    def get_privileged_observations(self):
        return self.privileged_obs_buf

    def cost_function(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]

        cost_it  = it * u_it * parameter_static['cost_ti']
        cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
        cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
        per_poc  = ((st + et + at + rt) / self.N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
        cost_poc = (st + et + rt + at) * w * per_poc
        return cost_poc + cost_it + cost_v + cost_q

    def transition(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
        ht = st + et + at + it + rt

        st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * self.parameter_random['beta1'] + (et + at * (1 - u_aq)) * self.parameter_random['beta2']) / ht
        st_out_e = st_out * parameter_static['alpha']
        st_out_i = st_out * (1 - parameter_static['alpha'])
        st_out_r = u_sv * parameter_static['v_max'] * st * parameter_static['psr']
        et_out_r = et * self.parameter_random['per']
        et_out_i = et * self.parameter_random['pei']
        et_out_a = et * w * (1 - self.parameter_random['per'] - self.parameter_random['pei'])
        at_out_i = at * self.parameter_random['pei']
        at_out_r = at * self.parameter_random['per']
        it_out_r = it * parameter_static['pir'] * u_it
        it_out_d = it * parameter_static['pid'] * (1 - u_it) + it * u_it * parameter_static['pid_plus']
        rt_out_s = rt * parameter_static['prs']
        
        stn = st - st_out_e - st_out_i - st_out_r + rt_out_s
        etn = et - et_out_r - et_out_i - et_out_a + st_out_e
        atn = at - at_out_r - at_out_i + et_out_a
        itn = it - it_out_r - it_out_d + st_out_i + et_out_i + at_out_i
        dtn = dt + it_out_d
        rtn = rt + et_out_r + at_out_r + it_out_r + st_out_r - rt_out_s

        reward = -2.6 * st_out - 100 * it_out_d

        next_state = torch.stack([stn, etn, atn, itn, dtn, rtn], dim=-1)
        return next_state, reward

# %%
import inspect

class BaseConfig:
    def __init__(self) -> None:
        """ Initializes all member classes recursively. Ignores all namse starting with '__' (buit-in methods)."""
        self.init_member_classes(self)
    
    @staticmethod
    def init_member_classes(obj):
        # iterate over all attributes names
        for key in dir(obj):
            # disregard builtin attributes
            # if key.startswith("__"):
            if key=="__class__":
                continue
            # get the corresponding attribute object
            var =  getattr(obj, key)
            # check if it the attribute is a class
            if inspect.isclass(var):
                # instantate the class
                i_var = var()
                # set the attribute to the instance instead of the type
                setattr(obj, key, i_var)
                # recursively init members of the attribute
                BaseConfig.init_member_classes(i_var)

class LeggedRobotCfgPPO(BaseConfig):
    seed = 1
    runner_class_name = 'OnPolicyRunner'
    class policy:
        init_noise_std = 2
        actor_hidden_dims  = [64, 32, 16] 
        critic_hidden_dims = [64, 32, 16]
        activation = 'elu' # can be elu, relu, selu, crelu, lrelu, tanh, sigmoid
        # only for 'ActorCriticRecurrent':
        # rnn_type = 'lstm'
        # rnn_hidden_size = 512
        # rnn_num_layers = 1
        
    class algorithm:
        # training params
        value_loss_coef = 0.5
        use_clipped_value_loss = True
        clip_param = 0.2
        entropy_coef = 0.01
        num_learning_epochs = 5
        num_mini_batches = 64 # mini batch size = num_envs*nsteps / nminibatches
        learning_rate = 1.e-4
        schedule = 'adaptive' # could be adaptive, fixed
        gamma = 0.99
        lam = 0.95
        desired_kl = 0.01
        max_grad_norm = 1.

    class runner:
        policy_class_name = 'ActorCritic'
        algorithm_class_name = 'PPO'
        num_steps_per_env =  150 # per iteration
        max_iterations    = 100 # number of policy updates

        # logging
        save_interval = 100 # check for potential saves every this many iterations
        experiment_name = 'test'
        run_name = ''
        # load and resume
        resume = True
        load_run = -1 # -1 = last run
        checkpoint = -1 # -1 = last saved model
        resume_path = None # updated from load_run and chkpt
        
def class_to_dict(obj) -> dict:
    if not  hasattr(obj,"__dict__"):
        return obj
    result = {}
    for key in dir(obj):
        if key.startswith("_"):
            continue
        element = []
        val = getattr(obj, key)
        if isinstance(val, list):
            for item in val:
                element.append(class_to_dict(item))
        else:
            element = class_to_dict(val)
        result[key] = element
    return result

# %%
def para_sampling(intvl, num_sample=N_envs):
    parameter_random = {
        key: torch.empty(num_sample).normal_(
        intvl[key][0],
        intvl[key][1]
        ).to(torch.device(device))
        for key, value in Random_mean.items()
    }
    for key, value in Random_mean.items():
        indice = parameter_random[key] < 0
        parameter_random[key][indice] = -parameter_random[key][indice] 
    return parameter_random

def update_space(final_indices, para_buf, space):
    para_est = {}
    for key, tensor_values in para_buf.items():
        selected_values = torch.mean(tensor_values[final_indices[0], final_indices[1]]) 
        para_values = torch.mean(tensor_values[final_indices[0], final_indices[1]], dim=0)
        update_values = space[key][0] + 0.5 * (selected_values - space[key][0])
        space[key] = [update_values , update_values  * 0.1]
        para_est[key] = para_values
    return space, para_est


def cal_err(para_value, env_para):
    gap = []
    for key, value in env_para.items():
        gap_temp = torch.mean(torch.abs(para_value[key] - env_para[key])/(env_para[key]))
        gap.append(gap_temp)
    return sum(gap)/len(gap) # 所有值都在范围内，返回 0
    
def state_estimator(env_sample, action_sim, state_sim, state_prior, space, iter): 
    env_sample.reset()
    env_sample.states = state_prior  
    para_buf, mse_buf, obs_buf, states_buf = {}, {}, {}, {}
    for i in range(iter):
        para = para_sampling(space, test_num)
        env_sample.para_update(para)
        obs_sample, states_sample, _, _, _ = env_sample.step(action_sim.detach())  
        mse = torch.mean((state_sim[:,2:4] - states_sample[:,2:4]) ** 2, dim=1) 
        if i == 0:
            mse_buf = mse.unsqueeze(0)
            obs_buf = obs_sample.unsqueeze(0)
            states_buf = states_sample.unsqueeze(0)
            for key, values in para.items():
                para_buf[key] = para[key].unsqueeze(0)
        else:
            mse_buf = torch.cat((mse_buf, mse.unsqueeze(0)), dim=0)
            obs_buf = torch.cat((obs_buf, obs_sample.unsqueeze(0)),dim=0)
            states_buf = torch.cat((states_buf, states_sample.unsqueeze(0)), dim=0)
            for key, values in para.items():
                para_buf[key] = torch.cat((para_buf[key], para[key].unsqueeze(0)), dim=0)
                
     
    k = int(iter * 0.05)
    _, row_indices = torch.topk(mse_buf, k=k, dim=0, largest=False)
    column_indices = torch.arange(mse_buf.shape[1]).repeat(k, 1)
    top_indices = [row_indices, column_indices]
    obs_est = torch.mean(obs_buf[row_indices,column_indices,:], dim=0)
    state_est = torch.mean(states_buf[row_indices,column_indices,:], dim=0)
    state_est[:,-1] = state_prior[:,-1] + torch.tensor(1/T)
    return obs_est, state_est, top_indices, para_buf

# %%
para_err = 0.5
torch.manual_seed(seed)
para_true = []
para_temp = {
    key: torch.empty(test_num).uniform_(
        value * (1-para_err),
        value * (1+para_err)
    ).to(torch.device(device))
    for key, value in Random_mean.items()
}


para = {}
for t in range(T):
    para = {
        key: (para_temp[key] + t * 0.5 *  para_temp[key] /T).to(torch.device(device)) if key == 'per' 
        else (para_temp[key] - t * 0.5 *  para_temp[key] /T).to(torch.device(device))
        for key, value in Random_mean.items()
        }
    para_true.append(para)

# %%
env = myVecEnv(space, test_num)
env.para_update(para_true[0])
train_cfg = LeggedRobotCfgPPO()
train_cfg_dict = class_to_dict(train_cfg)


env_transfer = myVecEnv(space)
runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_exp4_t1', device=env.device)
runner.load(f'rsl_low_budget2100/model_100.pt')

policy = runner.get_inference_policy(device=env.device)

reward_history = []
act_buf = []
state_his_buf = []
death_buf = []

env_sample = myVecEnv(space, test_num)
state_est = env.states
obs_est = env.get_observations()
for t in range(T-1):
    actions = policy(obs_est.detach())
    obs, states, _, _, infos = env.step(actions.detach())
    reward_history.append((-infos['reward_original'] + infos['inv_cost']).tolist())
    death_buf.append((-infos['reward_original']).tolist())
    act_buf.append(env.act)
    state_his_buf.append(env.states)
    obs_est, state_buf, top_indices, para_buf = state_estimator(env_sample, actions, states, state_est, space, 1024)
    space, para_v = update_space(top_indices, para_buf, space) 

    runner.learn(num_learning_iterations=25, init_at_random_ep_len=False)
    policy = runner.get_inference_policy(device=env.device)
    env_transfer = myVecEnv(space)
    runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_exp4_t1', device=env.device)
    runner.load(f'rsl_exp4_t1/model_{int(t)* 25}.pt')

    if t < T - 1: env.para_update(para_true[t + 1])
    print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')


reward_history = np.array(reward_history)
print(f'score     : {np.sum(reward_history, axis=0)/T       }')
print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
# Out:
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2028245 steps/s (collection: 0.717s, learning 4.130s)
#                Value function loss: 182.1511
#                     Surrogate loss: -0.0004
#              Mean action noise std: 5.31
#                        Mean reward: 8.95
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0821
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.85s
#                         Total time: 4.85s
#                                ETA: 121.2s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2316976 steps/s (collection: 0.653s, learning 3.590s)
#                Value function loss: 187.5371
#                     Surrogate loss: -0.0004
#              Mean action noise std: 5.34
#                        Mean reward: 9.28
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1449
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.24s
#                         Total time: 9.09s
#                                ETA: 109.1s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2323236 steps/s (collection: 0.670s, learning 3.561s)
#                Value function loss: 195.7297
#                     Surrogate loss: -0.0003
#              Mean action noise std: 5.38
#                        Mean reward: 9.38
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1676
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.23s
#                         Total time: 13.32s
#                                ETA: 102.1s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2316886 steps/s (collection: 0.658s, learning 3.585s)
#                Value function loss: 200.8608
#                     Surrogate loss: -0.0003
#              Mean action noise std: 5.41
#                        Mean reward: 11.94
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1819
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.24s
#                         Total time: 17.56s
#                                ETA: 96.6s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2330488 steps/s (collection: 0.647s, learning 3.572s)
#                Value function loss: 204.0089
#                     Surrogate loss: -0.0002
#              Mean action noise std: 5.45
#                        Mean reward: 11.66
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1925
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.22s
#                         Total time: 21.78s
#                                ETA: 91.5s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2332665 steps/s (collection: 0.651s, learning 3.563s)
#                Value function loss: 209.8466
#                     Surrogate loss: -0.0000
#              Mean action noise std: 5.48
#                        Mean reward: 14.53
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2008
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.21s
#                         Total time: 26.00s
#                                ETA: 86.7s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2358464 steps/s (collection: 0.644s, learning 3.524s)
#                Value function loss: 212.0153
#                     Surrogate loss: -0.0002
#              Mean action noise std: 5.53
#                        Mean reward: 14.61
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2128
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.17s
#                         Total time: 30.16s
#                                ETA: 81.9s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2362603 steps/s (collection: 0.661s, learning 3.500s)
#                Value function loss: 221.2863
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.56
#                        Mean reward: 15.77
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2302
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.16s
#                         Total time: 34.33s
#                                ETA: 77.2s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2402921 steps/s (collection: 0.645s, learning 3.446s)
#                Value function loss: 217.7309
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.60
#                        Mean reward: 14.47
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2455
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.09s
#                         Total time: 38.42s
#                                ETA: 72.6s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2411168 steps/s (collection: 0.650s, learning 3.427s)
#                Value function loss: 224.7798
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.65
#                        Mean reward: 18.75
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2576
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.08s
#                         Total time: 42.49s
#                                ETA: 68.0s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2389205 steps/s (collection: 0.664s, learning 3.450s)
#                Value function loss: 221.2860
#                     Surrogate loss: -0.0002
#              Mean action noise std: 5.70
#                        Mean reward: 17.13
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2749
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.11s
#                         Total time: 46.61s
#                                ETA: 63.6s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2385398 steps/s (collection: 0.668s, learning 3.453s)
#                Value function loss: 228.9000
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.74
#                        Mean reward: 20.81
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2900
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.12s
#                         Total time: 50.73s
#                                ETA: 59.2s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2405454 steps/s (collection: 0.643s, learning 3.444s)
#                Value function loss: 229.1550
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.78
#                        Mean reward: 21.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3143
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.09s
#                         Total time: 54.82s
#                                ETA: 54.8s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2392858 steps/s (collection: 0.670s, learning 3.438s)
#                Value function loss: 237.6961
#                     Surrogate loss: -0.0002
#              Mean action noise std: 5.82
#                        Mean reward: 21.78
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3325
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.11s
#                         Total time: 58.92s
#                                ETA: 50.5s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2415486 steps/s (collection: 0.661s, learning 3.409s)
#                Value function loss: 232.1950
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.86
#                        Mean reward: 21.00
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3510
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.07s
#                         Total time: 62.99s
#                                ETA: 46.2s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2444055 steps/s (collection: 0.655s, learning 3.367s)
#                Value function loss: 235.4149
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.90
#                        Mean reward: 21.98
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3605
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.02s
#                         Total time: 67.02s
#                                ETA: 41.9s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2442832 steps/s (collection: 0.647s, learning 3.377s)
#                Value function loss: 229.5971
#                     Surrogate loss: -0.0000
#              Mean action noise std: 5.95
#                        Mean reward: 23.36
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3727
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.02s
#                         Total time: 71.04s
#                                ETA: 37.6s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2418268 steps/s (collection: 0.665s, learning 3.400s)
#                Value function loss: 237.1702
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.98
#                        Mean reward: 24.52
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3838
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.07s
#                         Total time: 75.10s
#                                ETA: 33.4s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2414381 steps/s (collection: 0.688s, learning 3.384s)
#                Value function loss: 233.5214
#                     Surrogate loss: 0.0000
#              Mean action noise std: 6.03
#                        Mean reward: 24.68
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3972
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.07s
#                         Total time: 79.18s
#                                ETA: 29.2s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2441267 steps/s (collection: 0.655s, learning 3.372s)
#                Value function loss: 241.3496
#                     Surrogate loss: 0.0007
#              Mean action noise std: 6.08
#                        Mean reward: 26.05
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4069
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.03s
#                         Total time: 83.20s
#                                ETA: 25.0s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2440874 steps/s (collection: 0.650s, learning 3.378s)
#                Value function loss: 236.1324
#                     Surrogate loss: 0.0000
#              Mean action noise std: 6.15
#                        Mean reward: 26.57
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4193
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.03s
#                         Total time: 87.23s
#                                ETA: 20.8s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2422040 steps/s (collection: 0.656s, learning 3.403s)
#                Value function loss: 239.3295
#                     Surrogate loss: 0.0007
#              Mean action noise std: 6.20
#                        Mean reward: 27.77
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4249
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.06s
#                         Total time: 91.29s
#                                ETA: 16.6s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2436418 steps/s (collection: 0.654s, learning 3.380s)
#                Value function loss: 236.9211
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.27
#                        Mean reward: 25.77
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4370
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.03s
#                         Total time: 95.32s
#                                ETA: 12.4s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2442427 steps/s (collection: 0.653s, learning 3.372s)
#                Value function loss: 243.4812
#                     Surrogate loss: 0.0005
#              Mean action noise std: 6.33
#                        Mean reward: 27.62
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4437
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.02s
#                         Total time: 99.35s
#                                ETA: 8.3s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2423895 steps/s (collection: 0.672s, learning 3.384s)
#                Value function loss: 239.6434
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.40
#                        Mean reward: 28.21
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4492
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.06s
#                         Total time: 103.40s
#                                ETA: 4.1s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 3.0514750366210937
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2411316 steps/s (collection: 0.702s, learning 3.375s)
#                Value function loss: 184.4682
#                     Surrogate loss: -0.0003
#              Mean action noise std: 5.35
#                        Mean reward: 10.19
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0957
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.08s
#                         Total time: 4.08s
#                                ETA: 101.9s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2450582 steps/s (collection: 0.646s, learning 3.366s)
#                Value function loss: 191.6773
#                     Surrogate loss: -0.0003
#              Mean action noise std: 5.38
#                        Mean reward: 10.38
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1653
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.01s
#                         Total time: 8.09s
#                                ETA: 97.1s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2443643 steps/s (collection: 0.648s, learning 3.375s)
#                Value function loss: 197.4002
#                     Surrogate loss: -0.0002
#              Mean action noise std: 5.41
#                        Mean reward: 10.23
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1847
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.02s
#                         Total time: 12.11s
#                                ETA: 92.9s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2415307 steps/s (collection: 0.666s, learning 3.404s)
#                Value function loss: 204.1232
#                     Surrogate loss: -0.0003
#              Mean action noise std: 5.45
#                        Mean reward: 13.08
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1989
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.07s
#                         Total time: 16.18s
#                                ETA: 89.0s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2445222 steps/s (collection: 0.650s, learning 3.370s)
#                Value function loss: 205.2023
#                     Surrogate loss: 0.0000
#              Mean action noise std: 5.49
#                        Mean reward: 12.99
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2124
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.02s
#                         Total time: 20.20s
#                                ETA: 84.8s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2418017 steps/s (collection: 0.683s, learning 3.382s)
#                Value function loss: 211.6450
#                     Surrogate loss: -0.0003
#              Mean action noise std: 5.52
#                        Mean reward: 15.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2223
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.07s
#                         Total time: 24.27s
#                                ETA: 80.9s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2441119 steps/s (collection: 0.651s, learning 3.376s)
#                Value function loss: 212.7546
#                     Surrogate loss: -0.0002
#              Mean action noise std: 5.57
#                        Mean reward: 16.01
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2378
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.03s
#                         Total time: 28.29s
#                                ETA: 76.8s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2429808 steps/s (collection: 0.649s, learning 3.396s)
#                Value function loss: 218.0832
#                     Surrogate loss: 0.0008
#              Mean action noise std: 5.60
#                        Mean reward: 16.13
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2502
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.05s
#                         Total time: 32.34s
#                                ETA: 72.8s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2428831 steps/s (collection: 0.675s, learning 3.373s)
#                Value function loss: 216.7166
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.64
#                        Mean reward: 16.42
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2675
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.05s
#                         Total time: 36.39s
#                                ETA: 68.7s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2433975 steps/s (collection: 0.666s, learning 3.373s)
#                Value function loss: 222.5778
#                     Surrogate loss: -0.0002
#              Mean action noise std: 5.69
#                        Mean reward: 19.38
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2823
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.04s
#                         Total time: 40.43s
#                                ETA: 64.7s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2441193 steps/s (collection: 0.651s, learning 3.376s)
#                Value function loss: 214.9152
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.74
#                        Mean reward: 17.96
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2940
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.03s
#                         Total time: 44.45s
#                                ETA: 60.6s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2429281 steps/s (collection: 0.673s, learning 3.374s)
#                Value function loss: 221.8183
#                     Surrogate loss: -0.0002
#              Mean action noise std: 5.78
#                        Mean reward: 21.63
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3053
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.05s
#                         Total time: 48.50s
#                                ETA: 56.6s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2451945 steps/s (collection: 0.649s, learning 3.360s)
#                Value function loss: 220.2430
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.83
#                        Mean reward: 22.06
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3286
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.01s
#                         Total time: 52.51s
#                                ETA: 52.5s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2437366 steps/s (collection: 0.653s, learning 3.380s)
#                Value function loss: 222.8575
#                     Surrogate loss: -0.0002
#              Mean action noise std: 5.87
#                        Mean reward: 22.49
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3443
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.03s
#                         Total time: 56.54s
#                                ETA: 48.5s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2432279 steps/s (collection: 0.667s, learning 3.374s)
#                Value function loss: 211.9699
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.91
#                        Mean reward: 21.83
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3570
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.04s
#                         Total time: 60.58s
#                                ETA: 44.4s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2439212 steps/s (collection: 0.650s, learning 3.380s)
#                Value function loss: 219.0982
#                     Surrogate loss: -0.0000
#              Mean action noise std: 5.96
#                        Mean reward: 22.84
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3686
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.03s
#                         Total time: 64.61s
#                                ETA: 40.4s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2445727 steps/s (collection: 0.653s, learning 3.366s)
#                Value function loss: 209.1313
#                     Surrogate loss: 0.0005
#              Mean action noise std: 5.96
#                        Mean reward: 24.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3791
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.02s
#                         Total time: 68.63s
#                                ETA: 36.3s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2428343 steps/s (collection: 0.664s, learning 3.384s)
#                Value function loss: 209.2773
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.00
#                        Mean reward: 23.02
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3775
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.05s
#                         Total time: 72.68s
#                                ETA: 32.3s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2439881 steps/s (collection: 0.649s, learning 3.380s)
#                Value function loss: 201.5406
#                     Surrogate loss: -0.0001
#              Mean action noise std: 6.05
#                        Mean reward: 22.96
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3764
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.03s
#                         Total time: 76.71s
#                                ETA: 28.3s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2436513 steps/s (collection: 0.653s, learning 3.381s)
#                Value function loss: 207.3112
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.10
#                        Mean reward: 24.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3866
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.03s
#                         Total time: 80.74s
#                                ETA: 24.2s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2431124 steps/s (collection: 0.667s, learning 3.376s)
#                Value function loss: 202.9779
#                     Surrogate loss: 0.0000
#              Mean action noise std: 6.16
#                        Mean reward: 24.77
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.3985
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.04s
#                         Total time: 84.79s
#                                ETA: 20.2s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2433532 steps/s (collection: 0.662s, learning 3.377s)
#                Value function loss: 212.5081
#                     Surrogate loss: 0.0007
#              Mean action noise std: 6.21
#                        Mean reward: 26.79
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4071
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.04s
#                         Total time: 88.83s
#                                ETA: 16.2s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2430094 steps/s (collection: 0.647s, learning 3.398s)
#                Value function loss: 213.7364
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.28
#                        Mean reward: 25.05
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4240
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.05s
#                         Total time: 92.87s
#                                ETA: 12.1s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2403022 steps/s (collection: 0.651s, learning 3.440s)
#                Value function loss: 220.6756
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.34
#                        Mean reward: 27.63
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4310
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.09s
#                         Total time: 96.96s
#                                ETA: 8.1s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2419692 steps/s (collection: 0.648s, learning 3.415s)
#                Value function loss: 217.9017
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.41
#                        Mean reward: 26.91
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4367
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.06s
#                         Total time: 101.03s
#                                ETA: 4.0s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 5.755296681722005
# ################################################################################
#                         Learning iteration 25/50
#
#                        Computation: 2364987 steps/s (collection: 0.725s, learning 3.432s)
#                Value function loss: 217.1791
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.49
#                        Mean reward: 27.47
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.2658
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.16s
#                         Total time: 4.16s
#                                ETA: 0.0s
#
# ################################################################################
#                         Learning iteration 26/50
#
#                        Computation: 2386576 steps/s (collection: 0.655s, learning 3.464s)
#                Value function loss: 221.6220
#                     Surrogate loss: 0.0004
#              Mean action noise std: 6.55
#                        Mean reward: 27.36
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4361
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.12s
#                         Total time: 8.28s
#                                ETA: -0.3s
#
# ################################################################################
#                         Learning iteration 27/50
#
#                        Computation: 2407055 steps/s (collection: 0.653s, learning 3.431s)
#                Value function loss: 228.5637
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.62
#                        Mean reward: 26.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4382
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.08s
#                         Total time: 12.36s
#                                ETA: -0.9s
#
# ################################################################################
#                         Learning iteration 28/50
#
#                        Computation: 2406066 steps/s (collection: 0.647s, learning 3.439s)
#                Value function loss: 227.3354
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.68
#                        Mean reward: 26.68
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4398
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.09s
#                         Total time: 16.45s
#                                ETA: -1.7s
#
# ################################################################################
#                         Learning iteration 29/50
#
#                        Computation: 2399043 steps/s (collection: 0.658s, learning 3.439s)
#                Value function loss: 235.2773
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.75
#                        Mean reward: 27.25
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4437
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.10s
#                         Total time: 20.54s
#                                ETA: -2.7s
#
# ################################################################################
#                         Learning iteration 30/50
#
#                        Computation: 2419773 steps/s (collection: 0.654s, learning 3.408s)
#                Value function loss: 235.6976
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.81
#                        Mean reward: 29.46
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4464
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.06s
#                         Total time: 24.61s
#                                ETA: -4.0s
#
# ################################################################################
#                         Learning iteration 31/50
#
#                        Computation: 2420479 steps/s (collection: 0.661s, learning 3.401s)
#                Value function loss: 242.7693
#                     Surrogate loss: 0.0013
#              Mean action noise std: 6.90
#                        Mean reward: 29.67
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4544
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.06s
#                         Total time: 28.67s
#                                ETA: -5.4s
#
# ################################################################################
#                         Learning iteration 32/50
#
#                        Computation: 2432433 steps/s (collection: 0.650s, learning 3.392s)
#                Value function loss: 240.3468
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.97
#                        Mean reward: 27.93
# ...
#                    Total timesteps: 78643200
#                     Iteration time: 4.04s
#                         Total time: 32.41s
#                                ETA: -31.8s
#
# ################################################################################
#                       Learning iteration 1433/1450
#
#                        Computation: 2445428 steps/s (collection: 0.637s, learning 3.383s)
#                Value function loss: 280.0621
#                     Surrogate loss: 0.0000
#              Mean action noise std: 2798.40
#                        Mean reward: 40.09
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6554
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.02s
#                         Total time: 36.43s
#                                ETA: -35.8s
#
# ################################################################################
#                       Learning iteration 1434/1450
#
#                        Computation: 2445200 steps/s (collection: 0.659s, learning 3.361s)
#                Value function loss: 302.4622
#                     Surrogate loss: 0.0003
#              Mean action noise std: 2801.48
#                        Mean reward: 40.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6560
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.02s
#                         Total time: 40.45s
#                                ETA: -39.7s
#
# ################################################################################
#                       Learning iteration 1435/1450
#
#                        Computation: 2455472 steps/s (collection: 0.645s, learning 3.358s)
#                Value function loss: 279.5405
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2804.19
#                        Mean reward: 40.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6556
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.00s
#                         Total time: 44.46s
#                                ETA: -43.7s
#
# ################################################################################
#                       Learning iteration 1436/1450
#
#                        Computation: 2456997 steps/s (collection: 0.669s, learning 3.332s)
#                Value function loss: 300.1343
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2807.23
#                        Mean reward: 40.18
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6553
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.00s
#                         Total time: 48.46s
#                                ETA: -47.6s
#
# ################################################################################
#                       Learning iteration 1437/1450
#
#                        Computation: 2457335 steps/s (collection: 0.652s, learning 3.348s)
#                Value function loss: 279.7776
#                     Surrogate loss: 0.0002
#              Mean action noise std: 2809.87
#                        Mean reward: 40.49
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6558
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.00s
#                         Total time: 52.46s
#                                ETA: -51.5s
#
# ################################################################################
#                       Learning iteration 1438/1450
#
#                        Computation: 2461067 steps/s (collection: 0.666s, learning 3.328s)
#                Value function loss: 304.7783
#                     Surrogate loss: 0.0002
#              Mean action noise std: 2813.09
#                        Mean reward: 40.30
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6563
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 3.99s
#                         Total time: 56.45s
#                                ETA: -55.4s
#
# ################################################################################
#                       Learning iteration 1439/1450
#
#                        Computation: 2482242 steps/s (collection: 0.637s, learning 3.323s)
#                Value function loss: 289.5840
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2815.76
#                        Mean reward: 40.54
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6571
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 3.96s
#                         Total time: 60.41s
#                                ETA: -59.3s
#
# ################################################################################
#                       Learning iteration 1440/1450
#
#                        Computation: 2471187 steps/s (collection: 0.665s, learning 3.313s)
#                Value function loss: 305.9043
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2818.74
#                        Mean reward: 40.11
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6568
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 3.98s
#                         Total time: 64.39s
#                                ETA: -63.2s
#
# ################################################################################
#                       Learning iteration 1441/1450
#
#                        Computation: 2474618 steps/s (collection: 0.630s, learning 3.342s)
#                Value function loss: 293.9673
#                     Surrogate loss: 0.0003
#              Mean action noise std: 2821.24
#                        Mean reward: 40.66
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6568
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 3.97s
#                         Total time: 68.36s
#                                ETA: -67.1s
#
# ################################################################################
#                       Learning iteration 1442/1450
#
#                        Computation: 2458195 steps/s (collection: 0.673s, learning 3.326s)
#                Value function loss: 299.1734
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2824.35
#                        Mean reward: 40.28
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6565
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.00s
#                         Total time: 72.36s
#                                ETA: -71.1s
#
# ################################################################################
#                       Learning iteration 1443/1450
#
#                        Computation: 2468477 steps/s (collection: 0.663s, learning 3.319s)
#                Value function loss: 280.6365
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2827.04
#                        Mean reward: 40.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6568
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 3.98s
#                         Total time: 76.35s
#                                ETA: -75.0s
#
# ################################################################################
#                       Learning iteration 1444/1450
#
#                        Computation: 2483048 steps/s (collection: 0.648s, learning 3.311s)
#                Value function loss: 309.8613
#                     Surrogate loss: 0.0002
#              Mean action noise std: 2830.11
#                        Mean reward: 40.59
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6566
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 3.96s
#                         Total time: 80.31s
#                                ETA: -78.9s
#
# ################################################################################
#                       Learning iteration 1445/1450
#
#                        Computation: 2483832 steps/s (collection: 0.648s, learning 3.310s)
#                Value function loss: 284.7959
#                     Surrogate loss: 0.0019
#              Mean action noise std: 2832.43
#                        Mean reward: 40.37
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6566
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 3.96s
#                         Total time: 84.26s
#                                ETA: -82.7s
#
# ################################################################################
#                       Learning iteration 1446/1450
#
#                        Computation: 2472161 steps/s (collection: 0.665s, learning 3.311s)
#                Value function loss: 286.8543
#                     Surrogate loss: 0.0000
#              Mean action noise std: 2835.36
#                        Mean reward: 40.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6563
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 3.98s
#                         Total time: 88.24s
#                                ETA: -86.7s
#
# ################################################################################
#                       Learning iteration 1447/1450
#
#                        Computation: 2493405 steps/s (collection: 0.643s, learning 3.300s)
#                Value function loss: 313.6569
#                     Surrogate loss: 0.0000
#              Mean action noise std: 2838.27
#                        Mean reward: 39.99
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6556
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 3.94s
#                         Total time: 92.18s
#                                ETA: -90.5s
#
# ################################################################################
#                       Learning iteration 1448/1450
#
#                        Computation: 2474051 steps/s (collection: 0.679s, learning 3.295s)
#                Value function loss: 285.3450
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2841.34
#                        Mean reward: 40.11
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6550
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 3.97s
#                         Total time: 96.16s
#                                ETA: -94.4s
#
# ################################################################################
#                       Learning iteration 1449/1450
#
#                        Computation: 2485569 steps/s (collection: 0.636s, learning 3.319s)
#                Value function loss: 442.0899
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2844.26
#                        Mean reward: 40.47
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.6549
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 3.95s
#                         Total time: 100.11s
#                                ETA: -98.3s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 3723.2300367628536
# score     : [5511.02156287 6825.42339846  783.98373885  751.00702682 1357.26542079
#  4916.44352169 3555.61296897 5390.56304137 2050.6464533  5293.74975549
#  2509.01412336 4770.09781365  130.79851387 3101.77160425 2928.79308971
#  1538.77539934 6275.30019156 6487.57952992  774.28613194 3827.69225105
#  5913.89102608 7451.36647711 2165.66227377 7478.08514074 2738.17687347
#  1676.58023769 7257.98250284  216.73250861  659.97362784 2304.52169252
#  2547.31429086 8101.22775968  249.76340312  693.77869323 1799.94675841
#   375.73886666  788.95712819 7163.10586217 5748.85560643 6472.60678123
#  5327.85865698 2425.84799118 5701.37405057  262.47089022  236.66302933
#  1240.26278117 7128.218566   6410.35688035 1303.18084801 2500.81295478
#  5917.58233465 6777.94504725 5179.48614353 5430.11086389 7143.24928389
#   350.62463176 6643.71448954  141.62133426 1672.87913338 1532.01434038
#  6198.26907164 5711.84073162  499.04662937 1869.13258185 5540.33855092
#  3451.66289082 2941.98944012 5646.24236323 5334.91113586 7773.83072472
#  2793.14195564 1895.07233602 7057.26519272 7749.1781408  6777.11854502
#  7902.41110687 2872.22597316  223.980742   4822.52842035  213.08233685
#   287.79175685 7309.47938693 7521.14010337  266.15425787 5286.97713931
#  2212.82899391 3063.61320262  991.63502154 5294.64566781 1635.01537942
#  6279.85005382 6849.74856154 6238.50479479 5866.50911477  197.69398674
#   504.84986206 3599.88212264 6421.86183578  339.10727807  972.07898782]
# score.mean: 3723.2300367628536

# %%
exp_result = {
    'reward_total': reward_history,
    'reward_peo': death_buf,
    'state': state_his_buf,
    'action': act_buf
}
torch.save(exp_result, 'exp4-t2100.pt')

# %%
run_result = torch.load('exp4-t2100.pt', weights_only=False)
death_mean = torch.mean(run_result['state'][-1][:,4]) * N
print(death_mean)

def infections(states, action, para, i):
    st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
    u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
    ht = st + et + at + it + rt

    st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * para['beta1'][i] + (et + at * (1 - u_aq)) * para['beta2'][i]) / ht
    st_out_e = st_out * parameter_static['alpha']
    st_out_i = st_out * (1 - parameter_static['alpha'])
    et_out_a = et * w * (1 - para['per'] - para['pei'])
    return et_out_a, st_out_e, st_out_i


init_state = torch.tensor([[100000, 20 , 0, 0, 0, 0]], dtype=torch.float32).to(torch.device(device))
s_i = torch.zeros(100).to(torch.device('cuda:0'))
s_a = torch.zeros(100).to(torch.device('cuda:0'))
s_t = torch.zeros(100).to(torch.device('cuda:0'))
for i in range(test_num):
    for t in range(T):
        if t == 0:
            sa_temp, se_temp, si_temp = infections(init_state, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        if t > 0 and t < T-1:
            sa_temp, se_temp, si_temp = infections(run_result['state'][t-1][i][:6].unsqueeze(0)*N, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        s_i[i] += si_temp[0]
        s_a[i] += sa_temp[0]
        s_t[i] += se_temp[0]
print([torch.mean(s_i), torch.mean(s_a)+torch.mean(s_i), torch.mean(s_t)])
# Out:
# tensor(534.93585, device='cuda:0')
# [tensor(26593.29102, device='cuda:0'), tensor(26760.56641, device='cuda:0'), tensor(39889.93750, device='cuda:0')]
