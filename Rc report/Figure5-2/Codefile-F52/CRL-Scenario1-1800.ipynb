# %%
from rsl_rl.env import VecEnv
from rsl_rl.runners import OnPolicyRunner
import torch
import numpy as np
torch.set_printoptions(precision=5, linewidth=200, sci_mode=False)

N          = 100020
state_dim  = 8
action_dim = 5
T          = 60
budget     = 1800.
N_envs     = 1024 * 64
ΔT         = 1.0
device     = 'cuda'
usr_std = 0.1
test_num = 100
seed = 0

parameter_static = dict(N          = N,
                        B          = budget,
                        T          = T,
                        alpha      = 0.6,
                        v_max      = 0.2/14,
                        cost_ti    = 0.0977,
                        cost_ta    = 0.02,
                        cost_v     = 0.07,
                        cost_poc_0 = 0.000369,
                        cost_poc_1 = 0.001057,
                        pid        = 1.10/1000,
                        psr        = 0.7,
                        pid_plus   = 0.1221/1000,
                        pir        = 1/8,
                        prs        = 1/7)

Random_mean = {"beta2" : 0.78735,
               "beta1" : 0.15747,
               "pei"   : 0.10714,
               "per"   : 0.04545}

space = {"beta2" : [Random_mean['beta2'],Random_mean['beta2']*usr_std],
         "beta1" : [Random_mean['beta1'], Random_mean['beta1']*usr_std],
         "pei"   : [Random_mean['pei'], Random_mean['pei']*usr_std],
         "per"   : [Random_mean['per'], Random_mean['per']*usr_std]}

Init_state = torch.tensor([[100000 / N, 20 / N, 0, 0, 0, 0, 1, 0]], 
                         dtype=torch.float32).to(torch.device(device))

# %%
class myVecEnv(VecEnv):
    def __init__(self, interval, n_envs = N_envs):
        self.B = parameter_static['B']  # total budget
        self.N = parameter_static['N']
        self.device = device
        self.init_state = Init_state
        self.states = self.init_state.repeat(n_envs, 1)
        self.num_envs = n_envs
        self.num_obs = state_dim
        self.num_privileged_obs = None
        self.num_actions = action_dim
        self.max_episode_length = parameter_static['T']
        
        torch.manual_seed(seed)
        self.parameter_random = {
            key: torch.empty(self.num_envs).normal_(
                interval[key][0],
                interval[key][1]
            ).to(torch.device(device))
            for key, value in Random_mean.items()
        }

        for key, value in Random_mean.items():
            indice = self.parameter_random[key] < 0
            self.parameter_random[key][indice] = -self.parameter_random[key][indice] 

        # optimization flags for pytorch JIT
        torch._C._jit_set_profiling_mode(False)
        torch._C._jit_set_profiling_executor(False)
        
        # allocate buffers
        self.privileged_obs_buf = None
        self.obs_buf = torch.zeros(self.num_envs, self.num_obs, device=self.device, dtype=torch.float)
        self.rew_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.float)
        self.reset_buf = torch.ones(self.num_envs, device=self.device, dtype=torch.long)
        self.episode_length_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.long)
        
        self.actions = torch.zeros(self.num_envs, self.num_actions, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_sums = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_acts = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.extras = {}
    
    def para_update(self, para):
        self.parameter_random = para
        
    def step(self, actions):
        # actions clip
        soft_bound = [-0.5, 1.5]
        out_of_limits = -(actions - soft_bound[0]).clip(max=0.)
        out_of_limits += (actions - soft_bound[1]).clip(min=0.)
        scale_action = -0.1
        reward_action = scale_action * torch.sum(out_of_limits, dim=1).clip(max=1.).to(self.device)
        self.actions = torch.clip(actions, 0., 1.).to(self.device)

        # update actions & states
        b, p = self.states[:, -2] * self.B, self.states[:, -1]
        inv_c = self.cost_function(self.actions)
        b -= inv_c
        b = torch.clip(b, 0., self.B).to(self.device)
        mask = (b > 0).float().unsqueeze(-1)
        self.act = self.actions * mask
        inv_c = self.cost_function(self.act)
        next_state, reward_original = self.transition(self.act)
        self.extras['reward_original'] = reward_original
        self.extras['inv_cost'] = inv_c
        self.episode_length_buf += 1
        p = self.episode_length_buf / self.max_episode_length
        self.states = torch.cat([next_state / self.N, (b / self.B).unsqueeze(-1), p.unsqueeze(-1)], dim=-1)
        
        # check termination
        self.reset_buf = self.episode_length_buf >= self.max_episode_length
        
        # compute reward
        r_mean = -6584
        r_std  =  7347
        reward = (reward_original - inv_c - r_mean) / r_std
        #if reward > 0: 
        #reward = torch.exp(reward)/10
        #reward = torch.exp((1e5 + reward_original - inv_c) / 5e4)
        self.rew_buf       = reward + reward_action
        self.episode_sums += reward + reward_action
        self.episode_acts += reward_action
        
        # compute resets
        env_ids = self.reset_buf.nonzero(as_tuple=False).flatten()
        self.reset_idx(env_ids)
        
        # compute observations
        return self.get_observations(), self.states, self.rew_buf, self.reset_buf, self.extras

    def reset_idx(self, env_ids):
        """Reset selected robots"""
        if len(env_ids) == 0:
            return
        
        assert len(env_ids) == self.num_envs
        # reset robot states
        self.states[env_ids] = self.init_state
        # reset buffers
        self.episode_length_buf[env_ids] = 0
        self.reset_buf[env_ids] = 1
        # fill extras
        self.extras["episode"] = {}
        self.extras["episode"]['rew_sum'] = torch.mean(self.episode_sums[env_ids]) / (self.max_episode_length * ΔT)
        self.extras["episode"]['rew_act'] = torch.mean(self.episode_acts[env_ids]) / (self.max_episode_length * ΔT)
        self.episode_sums[env_ids] = 0.
        self.episode_acts[env_ids] = 0.
    
    def reset(self):
        """ Reset all robots"""
        self.reset_idx(torch.arange(self.num_envs, device=self.device))
        return {}, {}
    
    def get_observations(self):
        o_mean = torch.tensor([[0.58712867, 0.06804276, 0.00308146, 0.25684301, 0.00261079, 0.08229331, 0.26572794, 0.51      ]], dtype=torch.float32).to(torch.device(self.device))
        o_std  = torch.tensor([[0.41484398, 0.07883003, 0.00389494, 0.292568  , 0.00394907, 0.06906768, 0.33943075, 0.28861739]], dtype=torch.float32).to(torch.device(self.device))
        self.obs_buf = (self.states - o_mean) / o_std
        return self.obs_buf
    
    def get_privileged_observations(self):
        return self.privileged_obs_buf

    def cost_function(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]

        cost_it  = it * u_it * parameter_static['cost_ti']
        cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
        cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
        per_poc  = ((st + et + at + rt) / self.N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
        cost_poc = (st + et + rt + at) * w * per_poc
        return cost_poc + cost_it + cost_v + cost_q

    def transition(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
        ht = st + et + at + it + rt

        st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * self.parameter_random['beta1'] + (et + at * (1 - u_aq)) * self.parameter_random['beta2']) / ht
        st_out_e = st_out * parameter_static['alpha']
        st_out_i = st_out * (1 - parameter_static['alpha'])
        st_out_r = u_sv * parameter_static['v_max'] * st * parameter_static['psr']
        et_out_r = et * self.parameter_random['per']
        et_out_i = et * self.parameter_random['pei']
        et_out_a = et * w * (1 - self.parameter_random['per'] - self.parameter_random['pei'])
        at_out_i = at * self.parameter_random['pei']
        at_out_r = at * self.parameter_random['per']
        it_out_r = it * parameter_static['pir'] * u_it
        it_out_d = it * parameter_static['pid'] * (1 - u_it) + it * u_it * parameter_static['pid_plus']
        rt_out_s = rt * parameter_static['prs']
        
        stn = st - st_out_e - st_out_i - st_out_r + rt_out_s
        etn = et - et_out_r - et_out_i - et_out_a + st_out_e
        atn = at - at_out_r - at_out_i + et_out_a
        itn = it - it_out_r - it_out_d + st_out_i + et_out_i + at_out_i
        dtn = dt + it_out_d
        rtn = rt + et_out_r + at_out_r + it_out_r + st_out_r - rt_out_s

        reward = -2.6 * st_out - 100 * it_out_d

        next_state = torch.stack([stn, etn, atn, itn, dtn, rtn], dim=-1)
        return next_state, reward

# %%
import inspect

class BaseConfig:
    def __init__(self) -> None:
        """ Initializes all member classes recursively. Ignores all namse starting with '__' (buit-in methods)."""
        self.init_member_classes(self)
    
    @staticmethod
    def init_member_classes(obj):
        # iterate over all attributes names
        for key in dir(obj):
            # disregard builtin attributes
            # if key.startswith("__"):
            if key=="__class__":
                continue
            # get the corresponding attribute object
            var =  getattr(obj, key)
            # check if it the attribute is a class
            if inspect.isclass(var):
                # instantate the class
                i_var = var()
                # set the attribute to the instance instead of the type
                setattr(obj, key, i_var)
                # recursively init members of the attribute
                BaseConfig.init_member_classes(i_var)

class LeggedRobotCfgPPO(BaseConfig):
    seed = 1
    runner_class_name = 'OnPolicyRunner'
    class policy:
        init_noise_std = 2
        actor_hidden_dims  = [64, 32, 16] 
        critic_hidden_dims = [64, 32, 16]
        activation = 'elu' # can be elu, relu, selu, crelu, lrelu, tanh, sigmoid
        # only for 'ActorCriticRecurrent':
        # rnn_type = 'lstm'
        # rnn_hidden_size = 512
        # rnn_num_layers = 1
        
    class algorithm:
        # training params
        value_loss_coef = 0.5
        use_clipped_value_loss = True
        clip_param = 0.2
        entropy_coef = 0.01
        num_learning_epochs = 5
        num_mini_batches = 64 # mini batch size = num_envs*nsteps / nminibatches
        learning_rate = 1.e-4
        schedule = 'adaptive' # could be adaptive, fixed
        gamma = 0.99
        lam = 0.95
        desired_kl = 0.01
        max_grad_norm = 1.

    class runner:
        policy_class_name = 'ActorCritic'
        algorithm_class_name = 'PPO'
        num_steps_per_env =  150 # per iteration
        max_iterations    = 100 # number of policy updates

        # logging
        save_interval = 100 # check for potential saves every this many iterations
        experiment_name = 'test'
        run_name = ''
        # load and resume
        resume = True
        load_run = -1 # -1 = last run
        checkpoint = -1 # -1 = last saved model
        resume_path = None # updated from load_run and chkpt
        
def class_to_dict(obj) -> dict:
    if not  hasattr(obj,"__dict__"):
        return obj
    result = {}
    for key in dir(obj):
        if key.startswith("_"):
            continue
        element = []
        val = getattr(obj, key)
        if isinstance(val, list):
            for item in val:
                element.append(class_to_dict(item))
        else:
            element = class_to_dict(val)
        result[key] = element
    return result

# %%
def para_sampling(intvl, num_sample=N_envs):
    parameter_random = {
        key: torch.empty(num_sample).normal_(
        intvl[key][0],
        intvl[key][1]
        ).to(torch.device(device))
        for key, value in Random_mean.items()
    }
    for key, value in Random_mean.items():
        indice = parameter_random[key] < 0
        parameter_random[key][indice] = -parameter_random[key][indice] 
    return parameter_random

def update_space(final_indices, para_buf, space):
    para_est = {}
    for key, tensor_values in para_buf.items():
        selected_values = torch.mean(tensor_values[final_indices[0], final_indices[1]]) 
        para_values = torch.mean(tensor_values[final_indices[0], final_indices[1]], dim=0)
        update_values = space[key][0] + 0.5 * (selected_values - space[key][0])
        space[key] = [update_values , update_values  * 0.1]
        para_est[key] = para_values
    return space, para_est


def cal_err(para_value, env_para):
    gap = []
    for key, value in env_para.items():
        gap_temp = torch.mean(torch.abs(para_value[key] - env_para[key])/(env_para[key]))
        gap.append(gap_temp)
    return sum(gap)/len(gap) # 所有值都在范围内，返回 0
    
def state_estimator(env_sample, action_sim, state_sim, state_prior, space, iter): 
    env_sample.reset()
    env_sample.states = state_prior  
    para_buf, mse_buf, obs_buf, states_buf = {}, {}, {}, {}
    for i in range(iter):
        para = para_sampling(space, test_num)
        env_sample.para_update(para)
        obs_sample, states_sample, _, _, _ = env_sample.step(action_sim.detach())  
        mse = torch.mean((state_sim[:,2:4] - states_sample[:,2:4]) ** 2, dim=1) 
        if i == 0:
            mse_buf = mse.unsqueeze(0)
            obs_buf = obs_sample.unsqueeze(0)
            states_buf = states_sample.unsqueeze(0)
            for key, values in para.items():
                para_buf[key] = para[key].unsqueeze(0)
        else:
            mse_buf = torch.cat((mse_buf, mse.unsqueeze(0)), dim=0)
            obs_buf = torch.cat((obs_buf, obs_sample.unsqueeze(0)),dim=0)
            states_buf = torch.cat((states_buf, states_sample.unsqueeze(0)), dim=0)
            for key, values in para.items():
                para_buf[key] = torch.cat((para_buf[key], para[key].unsqueeze(0)), dim=0)
                
     
    k = int(iter * 0.05)
    _, row_indices = torch.topk(mse_buf, k=k, dim=0, largest=False)
    column_indices = torch.arange(mse_buf.shape[1]).repeat(k, 1)
    top_indices = [row_indices, column_indices]
    obs_est = torch.mean(obs_buf[row_indices,column_indices,:], dim=0)
    state_est = torch.mean(states_buf[row_indices,column_indices,:], dim=0)
    state_est[:,-1] = state_prior[:,-1] + torch.tensor(1/T)
    return obs_est, state_est, top_indices, para_buf

# %%
para_err = 0.5
torch.manual_seed(seed)
para_true = []
para_temp = {
    key: torch.empty(test_num).uniform_(
        value * (1-para_err),
        value * (1+para_err)
    ).to(torch.device(device))
    for key, value in Random_mean.items()
}


para = {}
for t in range(T):
    para = {
        key: (para_temp[key] + t * 0.5 *  para_temp[key] /T).to(torch.device(device)) if key == 'per' 
        else (para_temp[key] - t * 0.5 *  para_temp[key] /T).to(torch.device(device))
        for key, value in Random_mean.items()
        }
    para_true.append(para)

# %%
env = myVecEnv(space, test_num)
env.para_update(para_true[0])
train_cfg = LeggedRobotCfgPPO()
train_cfg_dict = class_to_dict(train_cfg)


env_transfer = myVecEnv(space)
runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_exp4_t1', device=env.device)
runner.load(f'rsl_low_budget1800/model_100.pt')

policy = runner.get_inference_policy(device=env.device)

reward_history = []
act_buf = []
state_his_buf = []
death_buf = []

env_sample = myVecEnv(space, test_num)
state_est = env.states
obs_est = env.get_observations()
for t in range(T-1):
    actions = policy(obs_est.detach())
    obs, states, _, _, infos = env.step(actions.detach())
    reward_history.append((-infos['reward_original'] + infos['inv_cost']).tolist())
    death_buf.append((-infos['reward_original']).tolist())
    act_buf.append(env.act)
    state_his_buf.append(env.states)
    obs_est, state_buf, top_indices, para_buf = state_estimator(env_sample, actions, states, state_est, space, 1024)
    space, para_v = update_space(top_indices, para_buf, space) 

    runner.learn(num_learning_iterations=25, init_at_random_ep_len=False)
    policy = runner.get_inference_policy(device=env.device)
    env_transfer = myVecEnv(space)
    runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_exp4_t1', device=env.device)
    runner.load(f'rsl_exp4_t1/model_{int(t)* 25}.pt')

    if t < T - 1: env.para_update(para_true[t + 1])
    print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')


reward_history = np.array(reward_history)
print(f'score     : {np.sum(reward_history, axis=0)/T       }')
print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
# Out:
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2128989 steps/s (collection: 0.845s, learning 3.772s)
#                Value function loss: 192.5386
#                     Surrogate loss: -0.0000
#              Mean action noise std: 5.69
#                        Mean reward: -5.04
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0479
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.62s
#                         Total time: 4.62s
#                                ETA: 115.4s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2300068 steps/s (collection: 0.656s, learning 3.618s)
#                Value function loss: 178.3812
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.76
#                        Mean reward: -3.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0753
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.27s
#                         Total time: 8.89s
#                                ETA: 106.7s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2293645 steps/s (collection: 0.656s, learning 3.630s)
#                Value function loss: 185.9427
#                     Surrogate loss: 0.0000
#              Mean action noise std: 5.82
#                        Mean reward: -4.18
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0660
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.29s
#                         Total time: 13.18s
#                                ETA: 101.0s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2308001 steps/s (collection: 0.660s, learning 3.599s)
#                Value function loss: 173.5705
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.89
#                        Mean reward: -3.37
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0622
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.26s
#                         Total time: 17.44s
#                                ETA: 95.9s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2294194 steps/s (collection: 0.668s, learning 3.617s)
#                Value function loss: 177.4344
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.97
#                        Mean reward: -3.00
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0592
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.28s
#                         Total time: 21.72s
#                                ETA: 91.2s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2298760 steps/s (collection: 0.661s, learning 3.615s)
#                Value function loss: 162.0889
#                     Surrogate loss: -0.0000
#              Mean action noise std: 6.03
#                        Mean reward: -1.50
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0548
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.28s
#                         Total time: 26.00s
#                                ETA: 86.7s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2304145 steps/s (collection: 0.652s, learning 3.614s)
#                Value function loss: 175.2037
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.10
#                        Mean reward: -1.69
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0428
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.27s
#                         Total time: 30.26s
#                                ETA: 82.1s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2321351 steps/s (collection: 0.656s, learning 3.579s)
#                Value function loss: 161.4447
#                     Surrogate loss: -0.0000
#              Mean action noise std: 6.16
#                        Mean reward: -0.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0320
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.23s
#                         Total time: 34.50s
#                                ETA: 77.6s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2326278 steps/s (collection: 0.685s, learning 3.541s)
#                Value function loss: 173.9588
#                     Surrogate loss: -0.0000
#              Mean action noise std: 6.22
#                        Mean reward: -0.82
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0199
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.23s
#                         Total time: 38.72s
#                                ETA: 73.1s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2338289 steps/s (collection: 0.670s, learning 3.534s)
#                Value function loss: 163.5224
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.30
#                        Mean reward: 0.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0137
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.20s
#                         Total time: 42.93s
#                                ETA: 68.7s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2347098 steps/s (collection: 0.653s, learning 3.536s)
#                Value function loss: 162.0153
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.37
#                        Mean reward: 0.39
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0071
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.19s
#                         Total time: 47.12s
#                                ETA: 64.3s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2342894 steps/s (collection: 0.664s, learning 3.532s)
#                Value function loss: 153.8792
#                     Surrogate loss: -0.0000
#              Mean action noise std: 6.43
#                        Mean reward: 2.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0011
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.20s
#                         Total time: 51.31s
#                                ETA: 59.9s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2337332 steps/s (collection: 0.674s, learning 3.532s)
#                Value function loss: 154.5315
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.50
#                        Mean reward: 2.36
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0123
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.21s
#                         Total time: 55.52s
#                                ETA: 55.5s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2352426 steps/s (collection: 0.652s, learning 3.527s)
#                Value function loss: 156.8885
#                     Surrogate loss: -0.0001
#              Mean action noise std: 6.56
#                        Mean reward: 1.99
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0214
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.18s
#                         Total time: 59.70s
#                                ETA: 51.2s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2364769 steps/s (collection: 0.661s, learning 3.496s)
#                Value function loss: 169.6371
#                     Surrogate loss: 0.0004
#              Mean action noise std: 6.62
#                        Mean reward: 3.77
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0329
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.16s
#                         Total time: 63.85s
#                                ETA: 46.8s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2364982 steps/s (collection: 0.653s, learning 3.503s)
#                Value function loss: 167.3378
#                     Surrogate loss: -0.0001
#              Mean action noise std: 6.69
#                        Mean reward: 3.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0411
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.16s
#                         Total time: 68.01s
#                                ETA: 42.5s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2365882 steps/s (collection: 0.666s, learning 3.489s)
#                Value function loss: 165.3677
#                     Surrogate loss: 0.0004
#              Mean action noise std: 6.73
#                        Mean reward: 4.53
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0519
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.16s
#                         Total time: 72.17s
#                                ETA: 38.2s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2376883 steps/s (collection: 0.662s, learning 3.473s)
#                Value function loss: 176.8982
#                     Surrogate loss: 0.0000
#              Mean action noise std: 6.79
#                        Mean reward: 6.29
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0753
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.14s
#                         Total time: 76.30s
#                                ETA: 33.9s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2355112 steps/s (collection: 0.669s, learning 3.505s)
#                Value function loss: 180.6658
#                     Surrogate loss: -0.0001
#              Mean action noise std: 6.85
#                        Mean reward: 6.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1027
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.17s
#                         Total time: 80.48s
#                                ETA: 29.6s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2361321 steps/s (collection: 0.667s, learning 3.496s)
#                Value function loss: 180.6955
#                     Surrogate loss: -0.0000
#              Mean action noise std: 6.92
#                        Mean reward: 8.16
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1093
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.16s
#                         Total time: 84.64s
#                                ETA: 25.4s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2377792 steps/s (collection: 0.650s, learning 3.484s)
#                Value function loss: 181.3492
#                     Surrogate loss: -0.0000
#              Mean action noise std: 6.98
#                        Mean reward: 8.30
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1178
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.13s
#                         Total time: 88.77s
#                                ETA: 21.1s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2366915 steps/s (collection: 0.658s, learning 3.495s)
#                Value function loss: 175.0117
#                     Surrogate loss: 0.0000
#              Mean action noise std: 7.04
#                        Mean reward: 7.52
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1239
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.15s
#                         Total time: 92.93s
#                                ETA: 16.9s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2375179 steps/s (collection: 0.650s, learning 3.489s)
#                Value function loss: 183.1960
#                     Surrogate loss: 0.0004
#              Mean action noise std: 7.11
#                        Mean reward: 7.02
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1328
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.14s
#                         Total time: 97.07s
#                                ETA: 12.7s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2369618 steps/s (collection: 0.659s, learning 3.489s)
#                Value function loss: 175.0221
#                     Surrogate loss: -0.0001
#              Mean action noise std: 7.18
#                        Mean reward: 10.13
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1403
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.15s
#                         Total time: 101.21s
#                                ETA: 8.4s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2394872 steps/s (collection: 0.647s, learning 3.458s)
#                Value function loss: 193.4501
#                     Surrogate loss: 0.0007
#              Mean action noise std: 7.25
#                        Mean reward: 11.23
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1512
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.10s
#                         Total time: 105.32s
#                                ETA: 4.2s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 3.0514750366210937
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2360732 steps/s (collection: 0.692s, learning 3.472s)
#                Value function loss: 178.1012
#                     Surrogate loss: 0.0010
#              Mean action noise std: 5.75
#                        Mean reward: -4.55
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0419
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.16s
#                         Total time: 4.16s
#                                ETA: 104.1s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2374681 steps/s (collection: 0.654s, learning 3.485s)
#                Value function loss: 172.8453
#                     Surrogate loss: 0.0000
#              Mean action noise std: 5.82
#                        Mean reward: -2.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0645
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.14s
#                         Total time: 8.30s
#                                ETA: 99.6s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2388857 steps/s (collection: 0.649s, learning 3.466s)
#                Value function loss: 178.6086
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.88
#                        Mean reward: -3.75
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0552
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.12s
#                         Total time: 12.42s
#                                ETA: 95.2s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2384302 steps/s (collection: 0.659s, learning 3.464s)
#                Value function loss: 161.1610
#                     Surrogate loss: 0.0008
#              Mean action noise std: 5.95
#                        Mean reward: -2.91
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0532
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.12s
#                         Total time: 16.54s
#                                ETA: 91.0s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2378420 steps/s (collection: 0.661s, learning 3.472s)
#                Value function loss: 163.0467
#                     Surrogate loss: -0.0002
#              Mean action noise std: 6.03
#                        Mean reward: -2.54
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0509
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.13s
#                         Total time: 20.68s
#                                ETA: 86.8s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2376406 steps/s (collection: 0.668s, learning 3.469s)
#                Value function loss: 152.0158
#                     Surrogate loss: -0.0000
#              Mean action noise std: 6.10
#                        Mean reward: -1.09
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0466
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.14s
#                         Total time: 24.81s
#                                ETA: 82.7s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2385534 steps/s (collection: 0.661s, learning 3.460s)
#                Value function loss: 151.0830
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.16
#                        Mean reward: -1.57
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0368
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.12s
#                         Total time: 28.93s
#                                ETA: 78.5s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2367305 steps/s (collection: 0.676s, learning 3.476s)
#                Value function loss: 143.0591
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.22
#                        Mean reward: -1.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0331
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.15s
#                         Total time: 33.09s
#                                ETA: 74.4s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2385060 steps/s (collection: 0.674s, learning 3.448s)
#                Value function loss: 148.9223
#                     Surrogate loss: -0.0000
#              Mean action noise std: 6.29
#                        Mean reward: -1.25
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0291
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.12s
#                         Total time: 37.21s
#                                ETA: 70.3s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2381988 steps/s (collection: 0.660s, learning 3.467s)
#                Value function loss: 140.1661
#                     Surrogate loss: -0.0000
#              Mean action noise std: 6.37
#                        Mean reward: -0.49
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0235
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.13s
#                         Total time: 41.33s
#                                ETA: 66.1s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2389624 steps/s (collection: 0.657s, learning 3.456s)
#                Value function loss: 141.7156
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.44
#                        Mean reward: -0.27
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0189
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.11s
#                         Total time: 45.45s
#                                ETA: 62.0s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2387399 steps/s (collection: 0.660s, learning 3.458s)
#                Value function loss: 135.1965
#                     Surrogate loss: 0.0012
#              Mean action noise std: 6.52
#                        Mean reward: 1.35
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0146
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.12s
#                         Total time: 49.57s
#                                ETA: 57.8s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2388197 steps/s (collection: 0.657s, learning 3.459s)
#                Value function loss: 151.5227
#                     Surrogate loss: -0.0001
#              Mean action noise std: 6.58
#                        Mean reward: 1.68
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.0041
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.12s
#                         Total time: 53.68s
#                                ETA: 53.7s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2386748 steps/s (collection: 0.667s, learning 3.452s)
#                Value function loss: 135.9214
#                     Surrogate loss: -0.0001
#              Mean action noise std: 6.64
#                        Mean reward: 1.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0052
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.12s
#                         Total time: 57.80s
#                                ETA: 49.5s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2388176 steps/s (collection: 0.652s, learning 3.464s)
#                Value function loss: 139.7467
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.70
#                        Mean reward: 2.61
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0178
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.12s
#                         Total time: 61.92s
#                                ETA: 45.4s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2385264 steps/s (collection: 0.665s, learning 3.456s)
#                Value function loss: 130.2308
#                     Surrogate loss: 0.0015
#              Mean action noise std: 6.77
#                        Mean reward: 2.30
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0258
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.12s
#                         Total time: 66.04s
#                                ETA: 41.3s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2360186 steps/s (collection: 0.661s, learning 3.504s)
#                Value function loss: 142.8038
#                     Surrogate loss: -0.0000
#              Mean action noise std: 6.85
#                        Mean reward: 3.80
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0371
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.17s
#                         Total time: 70.20s
#                                ETA: 37.2s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2415290 steps/s (collection: 0.697s, learning 3.373s)
#                Value function loss: 129.8113
#                     Surrogate loss: -0.0000
#              Mean action noise std: 6.92
#                        Mean reward: 3.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0442
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.07s
#                         Total time: 74.27s
#                                ETA: 33.0s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2459716 steps/s (collection: 0.644s, learning 3.353s)
#                Value function loss: 139.2883
#                     Surrogate loss: -0.0001
#              Mean action noise std: 6.97
#                        Mean reward: 3.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0517
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.00s
#                         Total time: 78.27s
#                                ETA: 28.8s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2471204 steps/s (collection: 0.633s, learning 3.344s)
#                Value function loss: 132.2797
#                     Surrogate loss: 0.0001
#              Mean action noise std: 7.04
#                        Mean reward: 5.44
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0603
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 3.98s
#                         Total time: 82.25s
#                                ETA: 24.7s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2458533 steps/s (collection: 0.650s, learning 3.349s)
#                Value function loss: 147.2209
#                     Surrogate loss: 0.0011
#              Mean action noise std: 7.11
#                        Mean reward: 6.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0737
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.00s
#                         Total time: 86.25s
#                                ETA: 20.5s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2459951 steps/s (collection: 0.636s, learning 3.360s)
#                Value function loss: 134.0872
#                     Surrogate loss: -0.0001
#              Mean action noise std: 7.18
#                        Mean reward: 5.35
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0802
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.00s
#                         Total time: 90.24s
#                                ETA: 16.4s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2445358 steps/s (collection: 0.641s, learning 3.379s)
#                Value function loss: 143.1881
#                     Surrogate loss: 0.0002
#              Mean action noise std: 7.26
#                        Mean reward: 5.45
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0898
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.02s
#                         Total time: 94.26s
#                                ETA: 12.3s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2446701 steps/s (collection: 0.634s, learning 3.384s)
#                Value function loss: 131.2088
#                     Surrogate loss: 0.0013
#              Mean action noise std: 7.33
#                        Mean reward: 7.59
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0976
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.02s
#                         Total time: 98.28s
#                                ETA: 8.2s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2437128 steps/s (collection: 0.629s, learning 3.405s)
#                Value function loss: 149.1357
#                     Surrogate loss: -0.0000
#              Mean action noise std: 7.40
#                        Mean reward: 7.15
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1065
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.03s
#                         Total time: 102.31s
#                                ETA: 4.1s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 5.791564661661783
# ################################################################################
#                         Learning iteration 25/50
#
#                        Computation: 2434414 steps/s (collection: 0.668s, learning 3.370s)
#                Value function loss: 143.9128
#                     Surrogate loss: 0.0013
#              Mean action noise std: 7.48
#                        Mean reward: 6.87
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.0705
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.04s
#                         Total time: 4.04s
#                                ETA: 0.0s
#
# ################################################################################
#                         Learning iteration 26/50
#
#                        Computation: 2453320 steps/s (collection: 0.634s, learning 3.373s)
#                Value function loss: 135.0969
#                     Surrogate loss: -0.0001
#              Mean action noise std: 7.54
#                        Mean reward: 7.89
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1175
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.01s
#                         Total time: 8.05s
#                                ETA: -0.3s
#
# ################################################################################
#                         Learning iteration 27/50
#
#                        Computation: 2444435 steps/s (collection: 0.637s, learning 3.384s)
#                Value function loss: 148.6977
#                     Surrogate loss: 0.0001
#              Mean action noise std: 7.60
#                        Mean reward: 6.73
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1250
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.02s
#                         Total time: 12.07s
#                                ETA: -0.9s
#
# ################################################################################
#                         Learning iteration 28/50
#
#                        Computation: 2435196 steps/s (collection: 0.649s, learning 3.388s)
#                Value function loss: 139.2539
#                     Surrogate loss: -0.0001
#              Mean action noise std: 7.68
#                        Mean reward: 7.25
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1297
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.04s
#                         Total time: 16.10s
#                                ETA: -1.7s
#
# ################################################################################
#                         Learning iteration 29/50
#
#                        Computation: 2451748 steps/s (collection: 0.633s, learning 3.376s)
#                Value function loss: 152.5273
#                     Surrogate loss: 0.0002
#              Mean action noise std: 7.77
#                        Mean reward: 9.06
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1354
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.01s
#                         Total time: 20.11s
#                                ETA: -2.7s
#
# ################################################################################
#                         Learning iteration 30/50
#
#                        Computation: 2458383 steps/s (collection: 0.637s, learning 3.362s)
#                Value function loss: 137.5988
#                     Surrogate loss: 0.0007
#              Mean action noise std: 7.84
#                        Mean reward: 10.66
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1415
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.00s
#                         Total time: 24.11s
#                                ETA: -3.9s
#
# ################################################################################
#                         Learning iteration 31/50
#
#                        Computation: 2446625 steps/s (collection: 0.646s, learning 3.372s)
#                Value function loss: 156.5410
#                     Surrogate loss: 0.0001
#              Mean action noise std: 7.93
#                        Mean reward: 10.18
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.1527
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.02s
#                         Total time: 28.13s
#                                ETA: -5.3s
#
# ################################################################################
#                         Learning iteration 32/50
#
#                        Computation: 2445987 steps/s (collection: 0.663s, learning 3.356s)
#                Value function loss: 144.7931
#                     Surrogate loss: 0.0013
#              Mean action noise std: 8.00
#                        Mean reward: 11.48
# ...
#                    Total timesteps: 78643200
#                     Iteration time: 3.96s
#                         Total time: 31.92s
#                                ETA: -31.3s
#
# ################################################################################
#                       Learning iteration 1433/1450
#
#                        Computation: 2449003 steps/s (collection: 0.672s, learning 3.342s)
#                Value function loss: 209.9711
#                     Surrogate loss: 0.0002
#              Mean action noise std: 2804.20
#                        Mean reward: 33.49
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5407
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.01s
#                         Total time: 35.93s
#                                ETA: -35.3s
#
# ################################################################################
#                       Learning iteration 1434/1450
#
#                        Computation: 2473607 steps/s (collection: 0.647s, learning 3.327s)
#                Value function loss: 220.5706
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2807.13
#                        Mean reward: 33.69
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5409
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 3.97s
#                         Total time: 39.90s
#                                ETA: -39.2s
#
# ################################################################################
#                       Learning iteration 1435/1450
#
#                        Computation: 2447611 steps/s (collection: 0.677s, learning 3.339s)
#                Value function loss: 213.2326
#                     Surrogate loss: 0.0000
#              Mean action noise std: 2810.01
#                        Mean reward: 33.60
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5412
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.02s
#                         Total time: 43.92s
#                                ETA: -43.1s
#
# ################################################################################
#                       Learning iteration 1436/1450
#
#                        Computation: 2477197 steps/s (collection: 0.641s, learning 3.328s)
#                Value function loss: 222.6732
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2812.95
#                        Mean reward: 33.38
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5415
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 3.97s
#                         Total time: 47.89s
#                                ETA: -47.0s
#
# ################################################################################
#                       Learning iteration 1437/1450
#
#                        Computation: 2450961 steps/s (collection: 0.676s, learning 3.335s)
#                Value function loss: 216.1215
#                     Surrogate loss: 0.0003
#              Mean action noise std: 2815.84
#                        Mean reward: 33.18
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5412
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.01s
#                         Total time: 51.90s
#                                ETA: -51.0s
#
# ################################################################################
#                       Learning iteration 1438/1450
#
#                        Computation: 2462366 steps/s (collection: 0.647s, learning 3.345s)
#                Value function loss: 223.3103
#                     Surrogate loss: 0.0002
#              Mean action noise std: 2818.89
#                        Mean reward: 33.60
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5405
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 3.99s
#                         Total time: 55.89s
#                                ETA: -54.9s
#
# ################################################################################
#                       Learning iteration 1439/1450
#
#                        Computation: 2415876 steps/s (collection: 0.711s, learning 3.358s)
#                Value function loss: 216.5175
#                     Surrogate loss: 0.0000
#              Mean action noise std: 2821.74
#                        Mean reward: 33.31
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5405
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.07s
#                         Total time: 59.96s
#                                ETA: -58.9s
#
# ################################################################################
#                       Learning iteration 1440/1450
#
#                        Computation: 2465405 steps/s (collection: 0.648s, learning 3.339s)
#                Value function loss: 224.0053
#                     Surrogate loss: 0.0002
#              Mean action noise std: 2824.66
#                        Mean reward: 33.34
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5406
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 3.99s
#                         Total time: 63.95s
#                                ETA: -62.8s
#
# ################################################################################
#                       Learning iteration 1441/1450
#
#                        Computation: 2436803 steps/s (collection: 0.687s, learning 3.347s)
#                Value function loss: 218.6489
#                     Surrogate loss: 0.0003
#              Mean action noise std: 2827.42
#                        Mean reward: 33.76
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5404
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.03s
#                         Total time: 67.98s
#                                ETA: -66.8s
#
# ################################################################################
#                       Learning iteration 1442/1450
#
#                        Computation: 2432693 steps/s (collection: 0.659s, learning 3.381s)
#                Value function loss: 221.0723
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2830.40
#                        Mean reward: 33.44
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5401
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.04s
#                         Total time: 72.02s
#                                ETA: -70.7s
#
# ################################################################################
#                       Learning iteration 1443/1450
#
#                        Computation: 2375450 steps/s (collection: 0.638s, learning 3.500s)
#                Value function loss: 209.4438
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2833.32
#                        Mean reward: 33.57
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5391
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.14s
#                         Total time: 76.16s
#                                ETA: -74.8s
#
# ################################################################################
#                       Learning iteration 1444/1450
#
#                        Computation: 2337143 steps/s (collection: 0.680s, learning 3.526s)
#                Value function loss: 217.2155
#                     Surrogate loss: 0.0003
#              Mean action noise std: 2836.36
#                        Mean reward: 33.54
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5392
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.21s
#                         Total time: 80.37s
#                                ETA: -78.9s
#
# ################################################################################
#                       Learning iteration 1445/1450
#
#                        Computation: 2354939 steps/s (collection: 0.652s, learning 3.523s)
#                Value function loss: 210.6618
#                     Surrogate loss: 0.0000
#              Mean action noise std: 2839.37
#                        Mean reward: 33.73
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5390
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.17s
#                         Total time: 84.54s
#                                ETA: -83.0s
#
# ################################################################################
#                       Learning iteration 1446/1450
#
#                        Computation: 2380191 steps/s (collection: 0.636s, learning 3.494s)
#                Value function loss: 217.9461
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2842.28
#                        Mean reward: 33.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5385
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.13s
#                         Total time: 88.67s
#                                ETA: -87.1s
#
# ################################################################################
#                       Learning iteration 1447/1450
#
#                        Computation: 2340831 steps/s (collection: 0.692s, learning 3.508s)
#                Value function loss: 212.6258
#                     Surrogate loss: 0.0000
#              Mean action noise std: 2845.21
#                        Mean reward: 33.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5371
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.20s
#                         Total time: 92.87s
#                                ETA: -91.2s
#
# ################################################################################
#                       Learning iteration 1448/1450
#
#                        Computation: 2366415 steps/s (collection: 0.653s, learning 3.501s)
#                Value function loss: 217.6288
#                     Surrogate loss: 0.0002
#              Mean action noise std: 2848.20
#                        Mean reward: 32.76
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5365
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.15s
#                         Total time: 97.03s
#                                ETA: -95.3s
#
# ################################################################################
#                       Learning iteration 1449/1450
#
#                        Computation: 2378667 steps/s (collection: 0.634s, learning 3.499s)
#                Value function loss: 211.7429
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2851.12
#                        Mean reward: 33.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5368
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.13s
#                         Total time: 101.16s
#                                ETA: -99.3s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 4733.97641835922
# score     : [6224.59364506 7747.710079   1698.59857105 1563.74141475 1982.89354198
#  6231.46187253 4485.19393801 7624.98054625 3768.59650884 6449.20666957
#  3569.38021661 5296.29544151  166.36740013 3787.52080731 3890.7802581
#  3179.29574385 7749.26673807 8239.90564283 1007.16166255 4985.84970602
#  7395.41071394 8276.2218655  3268.70342422 8578.04062471 2989.53217013
#  3709.10478115 8726.74323098  337.20057391 1515.4357752  3302.38008799
#  3216.7683005  8527.34241047  340.78237045 1223.16252097 2490.00442948
#   838.69339137 1126.62008341 8789.6093852  7332.51493123 7572.20277084
#  6228.90122366 3144.18829887 6566.29125803  348.49999058  320.59221974
#  2603.99225194 8090.14383357 8233.3609877  1994.14314142 3658.42384574
#  7999.39489498 8443.32110729 6678.13453161 6241.86007112 8587.8077673
#   872.32539996 7486.93756987  194.7387011  2708.66216404 2354.60581743
#  7855.00086362 7181.50139666  557.63368131 3938.72871459 7161.42440414
#  4166.50883442 4323.23943566 7035.41532609 7363.17802747 8907.98907394
#  4103.47325334 2491.75774609 8089.54767507 8666.32272704 8517.85010109
#  8946.5232927  4624.74475737  471.02675175 5885.08331657  272.33342321
#   327.74336722 8820.04041233 8891.25354487  382.90347937 6134.16624834
#  2997.88049134 3800.96885728 1315.17306239 7008.18002605 2427.32915794
#  7967.70422134 8003.97638229 7989.85734882 7404.74236856  474.10943986
#  1190.74777472 6387.86697591 7292.20351591  428.7730747  1631.13996292]
# score.mean: 4733.97641835922

# %%
exp_result = {
    'reward_total': reward_history,
    'reward_peo': death_buf,
    'state': state_his_buf,
    'action': act_buf
}
torch.save(exp_result, 'exp4-t1800.pt')

# %%
run_result = torch.load('exp4-t1800.pt', weights_only=False)
death_mean = torch.mean(run_result['state'][-1][:,4]) * N
print(death_mean)

def infections(states, action, para, i):
    st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
    u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
    ht = st + et + at + it + rt

    st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * para['beta1'][i] + (et + at * (1 - u_aq)) * para['beta2'][i]) / ht
    st_out_e = st_out * parameter_static['alpha']
    st_out_i = st_out * (1 - parameter_static['alpha'])
    et_out_a = et * w * (1 - para['per'] - para['pei'])
    return et_out_a, st_out_e, st_out_i


init_state = torch.tensor([[100000, 20 , 0, 0, 0, 0]], dtype=torch.float32).to(torch.device(device))
s_i = torch.zeros(100).to(torch.device('cuda:0'))
s_a = torch.zeros(100).to(torch.device('cuda:0'))
s_t = torch.zeros(100).to(torch.device('cuda:0'))
for i in range(test_num):
    for t in range(T):
        if t == 0:
            sa_temp, se_temp, si_temp = infections(init_state, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        if t > 0 and t < T-1:
            sa_temp, se_temp, si_temp = infections(run_result['state'][t-1][i][:6].unsqueeze(0)*N, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        s_i[i] += si_temp[0]
        s_a[i] += sa_temp[0]
        s_t[i] += se_temp[0]
print([torch.mean(s_i), torch.mean(s_a)+torch.mean(s_i), torch.mean(s_t)])
# Out:
# tensor(855.15857, device='cuda:0')
# [tensor(30959.87109, device='cuda:0'), tensor(31103.35938, device='cuda:0'), tensor(46439.80859, device='cuda:0')]
