# %%
from rsl_rl.env import VecEnv
from rsl_rl.runners import OnPolicyRunner
import torch
import numpy as np
torch.set_printoptions(precision=5, linewidth=200, sci_mode=False)

N          = 100020
state_dim  = 8
action_dim = 5
T          = 60
budget     = 3600.
N_envs     = 1024 * 64
ΔT         = 1.0
device     = 'cuda'
usr_std = 0.01
test_num = 100
seed = 0

parameter_static = dict(N          = N,
                        B          = budget,
                        T          = T,
                        alpha      = 0.6,
                        v_max      = 0.2/14,
                        cost_ti    = 0.0977,
                        cost_ta    = 0.02,
                        cost_v     = 0.07,
                        cost_poc_0 = 0.000369,
                        cost_poc_1 = 0.001057,
                        pid        = 1.10/1000,
                        psr        = 0.7,
                        pid_plus   = 0.1221/1000,
                        pir        = 1/8,
                        prs        = 1/7)

Random_mean = {"beta2" : 0.78735,
               "beta1" : 0.15747,
               "pei"   : 0.10714,
               "per"   : 0.04545}

space = {"beta2" : [Random_mean['beta2'],Random_mean['beta2']*usr_std],
         "beta1" : [Random_mean['beta1'], Random_mean['beta1']*usr_std],
         "pei"   : [Random_mean['pei'], Random_mean['pei']*usr_std],
         "per"   : [Random_mean['per'], Random_mean['per']*usr_std]}

Init_state = torch.tensor([[100000 / N, 20 / N, 0, 0, 0, 0, 1, 0]], 
                         dtype=torch.float32).to(torch.device(device))

# %%
class myVecEnv(VecEnv):
    def __init__(self, interval, n_envs = N_envs):
        self.B = parameter_static['B']  # total budget
        self.N = parameter_static['N']
        self.device = device
        self.init_state = Init_state
        self.states = self.init_state.repeat(n_envs, 1)
        self.num_envs = n_envs
        self.num_obs = state_dim
        self.num_privileged_obs = None
        self.num_actions = action_dim
        self.max_episode_length = parameter_static['T']
        
        torch.manual_seed(seed)
        self.parameter_random = {
            key: torch.empty(self.num_envs).normal_(
                interval[key][0],
                interval[key][1]
            ).to(torch.device(device))
            for key, value in Random_mean.items()
        }

        for key, value in Random_mean.items():
            indice = self.parameter_random[key] < 0
            self.parameter_random[key][indice] = -self.parameter_random[key][indice] 

        # optimization flags for pytorch JIT
        torch._C._jit_set_profiling_mode(False)
        torch._C._jit_set_profiling_executor(False)
        
        # allocate buffers
        self.privileged_obs_buf = None
        self.obs_buf = torch.zeros(self.num_envs, self.num_obs, device=self.device, dtype=torch.float)
        self.rew_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.float)
        self.reset_buf = torch.ones(self.num_envs, device=self.device, dtype=torch.long)
        self.episode_length_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.long)
        
        self.actions = torch.zeros(self.num_envs, self.num_actions, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_sums = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_acts = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.extras = {}
    
    def para_update(self, para):
        self.parameter_random = para
        
    def step(self, actions):
        # actions clip
        soft_bound = [-0.5, 1.5]
        out_of_limits = -(actions - soft_bound[0]).clip(max=0.)
        out_of_limits += (actions - soft_bound[1]).clip(min=0.)
        scale_action = -0.1
        reward_action = scale_action * torch.sum(out_of_limits, dim=1).clip(max=1.).to(self.device)
        self.actions = torch.clip(actions, 0., 1.).to(self.device)

        # update actions & states
        b, p = self.states[:, -2] * self.B, self.states[:, -1]
        inv_c = self.cost_function(self.actions)
        b -= inv_c
        b = torch.clip(b, 0., self.B).to(self.device)
        mask = (b > 0).float().unsqueeze(-1)
        self.act = self.actions * mask
        inv_c = self.cost_function(self.act)
        next_state, reward_original = self.transition(self.act)
        self.extras['reward_original'] = reward_original
        self.extras['inv_cost'] = inv_c
        self.episode_length_buf += 1
        p = self.episode_length_buf / self.max_episode_length
        self.states = torch.cat([next_state / self.N, (b / self.B).unsqueeze(-1), p.unsqueeze(-1)], dim=-1)
        
        # check termination
        self.reset_buf = self.episode_length_buf >= self.max_episode_length
        
        # compute reward
        r_mean = -6584
        r_std  =  7347
        reward = (reward_original - inv_c - r_mean) / r_std
        #if reward > 0: 
        #reward = torch.exp(reward)/10
        #reward = torch.exp((1e5 + reward_original - inv_c) / 5e4)
        self.rew_buf       = reward + reward_action
        self.episode_sums += reward + reward_action
        self.episode_acts += reward_action
        
        # compute resets
        env_ids = self.reset_buf.nonzero(as_tuple=False).flatten()
        self.reset_idx(env_ids)
        
        # compute observations
        return self.get_observations(), self.states, self.rew_buf, self.reset_buf, self.extras

    def reset_idx(self, env_ids):
        """Reset selected robots"""
        if len(env_ids) == 0:
            return
        
        assert len(env_ids) == self.num_envs
        # reset robot states
        self.states[env_ids] = self.init_state
        # reset buffers
        self.episode_length_buf[env_ids] = 0
        self.reset_buf[env_ids] = 1
        # fill extras
        self.extras["episode"] = {}
        self.extras["episode"]['rew_sum'] = torch.mean(self.episode_sums[env_ids]) / (self.max_episode_length * ΔT)
        self.extras["episode"]['rew_act'] = torch.mean(self.episode_acts[env_ids]) / (self.max_episode_length * ΔT)
        self.episode_sums[env_ids] = 0.
        self.episode_acts[env_ids] = 0.
    
    def reset(self):
        """ Reset all robots"""
        self.reset_idx(torch.arange(self.num_envs, device=self.device))
        return {}, {}
    
    def get_observations(self):
        o_mean = torch.tensor([[0.58712867, 0.06804276, 0.00308146, 0.25684301, 0.00261079, 0.08229331, 0.26572794, 0.51      ]], dtype=torch.float32).to(torch.device(self.device))
        o_std  = torch.tensor([[0.41484398, 0.07883003, 0.00389494, 0.292568  , 0.00394907, 0.06906768, 0.33943075, 0.28861739]], dtype=torch.float32).to(torch.device(self.device))
        self.obs_buf = (self.states - o_mean) / o_std
        return self.obs_buf
    
    def get_privileged_observations(self):
        return self.privileged_obs_buf

    def cost_function(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]

        cost_it  = it * u_it * parameter_static['cost_ti']
        cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
        cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
        per_poc  = ((st + et + at + rt) / self.N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
        cost_poc = (st + et + rt + at) * w * per_poc
        return cost_poc + cost_it + cost_v + cost_q

    def transition(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
        ht = st + et + at + it + rt

        st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * self.parameter_random['beta1'] + (et + at * (1 - u_aq)) * self.parameter_random['beta2']) / ht
        st_out_e = st_out * parameter_static['alpha']
        st_out_i = st_out * (1 - parameter_static['alpha'])
        st_out_r = u_sv * parameter_static['v_max'] * st * parameter_static['psr']
        et_out_r = et * self.parameter_random['per']
        et_out_i = et * self.parameter_random['pei']
        et_out_a = et * w * (1 - self.parameter_random['per'] - self.parameter_random['pei'])
        at_out_i = at * self.parameter_random['pei']
        at_out_r = at * self.parameter_random['per']
        it_out_r = it * parameter_static['pir'] * u_it
        it_out_d = it * parameter_static['pid'] * (1 - u_it) + it * u_it * parameter_static['pid_plus']
        rt_out_s = rt * parameter_static['prs']
        
        stn = st - st_out_e - st_out_i - st_out_r + rt_out_s
        etn = et - et_out_r - et_out_i - et_out_a + st_out_e
        atn = at - at_out_r - at_out_i + et_out_a
        itn = it - it_out_r - it_out_d + st_out_i + et_out_i + at_out_i
        dtn = dt + it_out_d
        rtn = rt + et_out_r + at_out_r + it_out_r + st_out_r - rt_out_s

        reward = -2.6 * st_out - 100 * it_out_d

        next_state = torch.stack([stn, etn, atn, itn, dtn, rtn], dim=-1)
        return next_state, reward

# %%
import inspect

class BaseConfig:
    def __init__(self) -> None:
        """ Initializes all member classes recursively. Ignores all namse starting with '__' (buit-in methods)."""
        self.init_member_classes(self)
    
    @staticmethod
    def init_member_classes(obj):
        # iterate over all attributes names
        for key in dir(obj):
            # disregard builtin attributes
            # if key.startswith("__"):
            if key=="__class__":
                continue
            # get the corresponding attribute object
            var =  getattr(obj, key)
            # check if it the attribute is a class
            if inspect.isclass(var):
                # instantate the class
                i_var = var()
                # set the attribute to the instance instead of the type
                setattr(obj, key, i_var)
                # recursively init members of the attribute
                BaseConfig.init_member_classes(i_var)

class LeggedRobotCfgPPO(BaseConfig):
    seed = 1
    runner_class_name = 'OnPolicyRunner'
    class policy:
        init_noise_std = 2
        actor_hidden_dims  = [64, 32, 16] 
        critic_hidden_dims = [64, 32, 16]
        activation = 'elu' # can be elu, relu, selu, crelu, lrelu, tanh, sigmoid
        # only for 'ActorCriticRecurrent':
        # rnn_type = 'lstm'
        # rnn_hidden_size = 512
        # rnn_num_layers = 1
        
    class algorithm:
        # training params
        value_loss_coef = 0.5
        use_clipped_value_loss = True
        clip_param = 0.2
        entropy_coef = 0.01
        num_learning_epochs = 5
        num_mini_batches = 64 # mini batch size = num_envs*nsteps / nminibatches
        learning_rate = 1.e-4
        schedule = 'adaptive' # could be adaptive, fixed
        gamma = 0.99
        lam = 0.95
        desired_kl = 0.01
        max_grad_norm = 1.

    class runner:
        policy_class_name = 'ActorCritic'
        algorithm_class_name = 'PPO'
        num_steps_per_env =  150 # per iteration
        max_iterations    = 100 # number of policy updates

        # logging
        save_interval = 100 # check for potential saves every this many iterations
        experiment_name = 'test'
        run_name = ''
        # load and resume
        resume = True
        load_run = -1 # -1 = last run
        checkpoint = -1 # -1 = last saved model
        resume_path = None # updated from load_run and chkpt
        
def class_to_dict(obj) -> dict:
    if not  hasattr(obj,"__dict__"):
        return obj
    result = {}
    for key in dir(obj):
        if key.startswith("_"):
            continue
        element = []
        val = getattr(obj, key)
        if isinstance(val, list):
            for item in val:
                element.append(class_to_dict(item))
        else:
            element = class_to_dict(val)
        result[key] = element
    return result

# %%
def para_sampling(intvl, num_sample=N_envs):
    parameter_random = {
        key: torch.empty(num_sample).normal_(
        intvl[key][0],
        intvl[key][1]
        ).to(torch.device(device))
        for key, value in Random_mean.items()
    }
    for key, value in Random_mean.items():
        indice = parameter_random[key] < 0
        parameter_random[key][indice] = -parameter_random[key][indice] 
    return parameter_random

def update_space(final_indices, para_buf, space):
    para_est = {}
    for key, tensor_values in para_buf.items():
        selected_values = torch.mean(tensor_values[final_indices[0], final_indices[1]]) 
        para_values = torch.mean(tensor_values[final_indices[0], final_indices[1]], dim=0)
        update_values = space[key][0] + 0.5 * (selected_values - space[key][0])
        space[key] = [update_values , update_values  * 0.1]
        para_est[key] = para_values
    return space, para_est


def cal_err(para_value, env_para):
    gap = []
    for key, value in env_para.items():
        gap_temp = torch.mean(torch.abs(para_value[key] - env_para[key])/(env_para[key]))
        gap.append(gap_temp)
    return sum(gap)/len(gap) # 所有值都在范围内，返回 0
    
def state_estimator(env_sample, action_sim, state_sim, state_prior, space, iter): 
    env_sample.reset()
    env_sample.states = state_prior  
    para_buf, mse_buf, obs_buf, states_buf = {}, {}, {}, {}
    for i in range(iter):
        para = para_sampling(space, test_num)
        env_sample.para_update(para)
        obs_sample, states_sample, _, _, _ = env_sample.step(action_sim.detach())  
        mse = torch.mean((state_sim[:,2:4] - states_sample[:,2:4]) ** 2, dim=1) 
        if i == 0:
            mse_buf = mse.unsqueeze(0)
            obs_buf = obs_sample.unsqueeze(0)
            states_buf = states_sample.unsqueeze(0)
            for key, values in para.items():
                para_buf[key] = para[key].unsqueeze(0)
        else:
            mse_buf = torch.cat((mse_buf, mse.unsqueeze(0)), dim=0)
            obs_buf = torch.cat((obs_buf, obs_sample.unsqueeze(0)),dim=0)
            states_buf = torch.cat((states_buf, states_sample.unsqueeze(0)), dim=0)
            for key, values in para.items():
                para_buf[key] = torch.cat((para_buf[key], para[key].unsqueeze(0)), dim=0)
                
     
    k = int(iter * 0.05)
    _, row_indices = torch.topk(mse_buf, k=k, dim=0, largest=False)
    column_indices = torch.arange(mse_buf.shape[1]).repeat(k, 1)
    top_indices = [row_indices, column_indices]
    obs_est = torch.mean(obs_buf[row_indices,column_indices,:], dim=0)
    state_est = torch.mean(states_buf[row_indices,column_indices,:], dim=0)
    state_est[:,-1] = state_prior[:,-1] + torch.tensor(1/T)
    return obs_est, state_est, top_indices, para_buf

# %%
para_err = 0.5
torch.manual_seed(seed)
para_true = []
para_temp = {
    key: torch.empty(test_num).uniform_(
        value * (1-para_err),
        value * (1+para_err)
    ).to(torch.device(device))
    for key, value in Random_mean.items()
}


para = {}
for t in range(T):
    para = {
        key: (para_temp[key] - para_temp[key] * torch.sin(torch.tensor(t/(3.1415926 * 3))) * 0.25).to(torch.device(device))
        for key, value in Random_mean.items()
        }
    para_true.append(para)

# %%
env = myVecEnv(space, test_num)
env.para_update(para_true[0])
train_cfg = LeggedRobotCfgPPO()
train_cfg_dict = class_to_dict(train_cfg)


env_transfer = myVecEnv(space)
runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_5ind', device=env.device)
runner.load(f'rsl_output_main/model_100.pt')

policy = runner.get_inference_policy(device=env.device)

reward_history = []
act_buf = []
state_his_buf = []
death_buf = []

env_sample = myVecEnv(space, test_num)
state_est = env.states
obs_est = env.get_observations()
for t in range(T-1):
    actions = policy(obs_est.detach())
    obs, states, _, _, infos = env.step(actions.detach())
    reward_history.append((-infos['reward_original'] + infos['inv_cost']).tolist())
    death_buf.append((-infos['reward_original']).tolist())
    act_buf.append(env.act)
    state_his_buf.append(env.states)
    obs_est, state_buf, top_indices, para_buf = state_estimator(env_sample, actions, states, state_est, space, 1024)
    space, para_v = update_space(top_indices, para_buf, space) 
    if t % 10 ==0:
        runner.learn(num_learning_iterations=25, init_at_random_ep_len=False)
        policy = runner.get_inference_policy(device=env.device)
        env_transfer = myVecEnv(space)
        runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_5ind', device=env.device)
        runner.load(f'rsl_5ind/model_{int(t/10)* 25}.pt')
        

    if t < T - 1: env.para_update(para_true[t + 1])
    print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
env.reset()

reward_history = np.array(reward_history)
print(f'score     : {np.sum(reward_history, axis=0)/T       }')
print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
# Out:
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2338852 steps/s (collection: 0.655s, learning 3.548s)
#                Value function loss: 142.5378
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.63
#                        Mean reward: 45.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4641
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.20s
#                         Total time: 4.20s
#                                ETA: 105.1s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2359517 steps/s (collection: 0.656s, learning 3.511s)
#                Value function loss: 144.6782
#                     Surrogate loss: 0.0007
#              Mean action noise std: 4.69
#                        Mean reward: 46.00
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7657
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.17s
#                         Total time: 8.37s
#                                ETA: 100.4s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2433058 steps/s (collection: 0.638s, learning 3.402s)
#                Value function loss: 131.0451
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.76
#                        Mean reward: 45.80
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7668
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.04s
#                         Total time: 12.41s
#                                ETA: 95.1s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2382578 steps/s (collection: 0.644s, learning 3.482s)
#                Value function loss: 131.8155
#                     Surrogate loss: 0.0007
#              Mean action noise std: 4.81
#                        Mean reward: 45.82
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7668
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.13s
#                         Total time: 16.54s
#                                ETA: 90.9s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2386232 steps/s (collection: 0.664s, learning 3.455s)
#                Value function loss: 120.9523
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.87
#                        Mean reward: 45.80
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7668
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.12s
#                         Total time: 20.66s
#                                ETA: 86.8s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2395045 steps/s (collection: 0.645s, learning 3.459s)
#                Value function loss: 121.5071
#                     Surrogate loss: 0.0031
#              Mean action noise std: 4.94
#                        Mean reward: 46.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7649
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.10s
#                         Total time: 24.76s
#                                ETA: 82.5s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2403983 steps/s (collection: 0.638s, learning 3.451s)
#                Value function loss: 114.3146
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.00
#                        Mean reward: 45.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7639
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.09s
#                         Total time: 28.85s
#                                ETA: 78.3s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2399920 steps/s (collection: 0.644s, learning 3.453s)
#                Value function loss: 115.2126
#                     Surrogate loss: 0.0009
#              Mean action noise std: 5.08
#                        Mean reward: 46.04
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7645
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.10s
#                         Total time: 32.95s
#                                ETA: 74.1s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2423538 steps/s (collection: 0.649s, learning 3.407s)
#                Value function loss: 110.0399
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.15
#                        Mean reward: 45.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7633
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.06s
#                         Total time: 37.00s
#                                ETA: 69.9s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2427965 steps/s (collection: 0.638s, learning 3.411s)
#                Value function loss: 110.2140
#                     Surrogate loss: 0.0026
#              Mean action noise std: 5.21
#                        Mean reward: 45.59
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7630
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.05s
#                         Total time: 41.05s
#                                ETA: 65.7s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2416978 steps/s (collection: 0.643s, learning 3.424s)
#                Value function loss: 104.9139
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.28
#                        Mean reward: 45.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7605
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.07s
#                         Total time: 45.12s
#                                ETA: 61.5s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2412314 steps/s (collection: 0.647s, learning 3.428s)
#                Value function loss: 104.5630
#                     Surrogate loss: 0.0011
#              Mean action noise std: 5.35
#                        Mean reward: 45.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7586
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.08s
#                         Total time: 49.19s
#                                ETA: 57.4s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2407554 steps/s (collection: 0.644s, learning 3.439s)
#                Value function loss: 101.6371
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.43
#                        Mean reward: 45.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7586
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.08s
#                         Total time: 53.28s
#                                ETA: 53.3s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2419486 steps/s (collection: 0.637s, learning 3.426s)
#                Value function loss: 102.0143
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.50
#                        Mean reward: 45.26
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7595
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.06s
#                         Total time: 57.34s
#                                ETA: 49.1s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2424536 steps/s (collection: 0.651s, learning 3.404s)
#                Value function loss: 94.8475
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.56
#                        Mean reward: 45.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7599
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.05s
#                         Total time: 61.39s
#                                ETA: 45.0s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2409215 steps/s (collection: 0.642s, learning 3.439s)
#                Value function loss: 111.2999
#                     Surrogate loss: 0.0010
#              Mean action noise std: 5.64
#                        Mean reward: 45.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7597
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.08s
#                         Total time: 65.47s
#                                ETA: 40.9s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2406198 steps/s (collection: 0.643s, learning 3.442s)
#                Value function loss: 107.3011
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.72
#                        Mean reward: 45.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7585
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.09s
#                         Total time: 69.56s
#                                ETA: 36.8s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2401899 steps/s (collection: 0.646s, learning 3.447s)
#                Value function loss: 115.9443
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.80
#                        Mean reward: 45.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7565
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.09s
#                         Total time: 73.65s
#                                ETA: 32.7s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2414733 steps/s (collection: 0.639s, learning 3.432s)
#                Value function loss: 118.1301
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.88
#                        Mean reward: 45.37
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7555
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.07s
#                         Total time: 77.72s
#                                ETA: 28.6s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2396514 steps/s (collection: 0.640s, learning 3.462s)
#                Value function loss: 137.7706
#                     Surrogate loss: 0.0020
#              Mean action noise std: 5.96
#                        Mean reward: 45.76
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7562
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.10s
#                         Total time: 81.82s
#                                ETA: 24.5s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2411336 steps/s (collection: 0.634s, learning 3.443s)
#                Value function loss: 146.2068
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.04
#                        Mean reward: 45.68
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7553
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.08s
#                         Total time: 85.90s
#                                ETA: 20.5s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2391200 steps/s (collection: 0.644s, learning 3.467s)
#                Value function loss: 164.4678
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.11
#                        Mean reward: 45.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7534
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.11s
#                         Total time: 90.01s
#                                ETA: 16.4s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2387455 steps/s (collection: 0.645s, learning 3.472s)
#                Value function loss: 175.4398
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.20
#                        Mean reward: 45.37
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7524
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.12s
#                         Total time: 94.13s
#                                ETA: 12.3s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2273813 steps/s (collection: 0.769s, learning 3.554s)
#                Value function loss: 202.2828
#                     Surrogate loss: 0.0008
#              Mean action noise std: 6.28
#                        Mean reward: 45.45
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7526
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.32s
#                         Total time: 98.45s
#                                ETA: 8.2s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2396785 steps/s (collection: 0.643s, learning 3.459s)
#                Value function loss: 204.6421
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.35
#                        Mean reward: 45.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7535
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.10s
#                         Total time: 102.55s
#                                ETA: 4.1s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 3.0514750366210937
# score.mean: 5.785346303304037
# score.mean: 8.024731651306151
# score.mean: 10.39461119333903
# score.mean: 12.079788745880128
# score.mean: 14.300420529623826
# score.mean: 15.619279932459195
# score.mean: 17.634546690086527
# score.mean: 18.794828233579793
# score.mean: 20.920793232599895
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2270716 steps/s (collection: 0.703s, learning 3.626s)
#                Value function loss: 131.6615
#                     Surrogate loss: 0.0003
#              Mean action noise std: 4.70
#                        Mean reward: 45.10
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4494
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.33s
#                         Total time: 4.33s
#                                ETA: 108.2s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2346363 steps/s (collection: 0.678s, learning 3.512s)
#                Value function loss: 139.0234
#                     Surrogate loss: 0.0014
#              Mean action noise std: 4.76
#                        Mean reward: 45.60
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7417
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.19s
#                         Total time: 8.52s
#                                ETA: 102.2s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2341509 steps/s (collection: 0.674s, learning 3.524s)
#                Value function loss: 135.2565
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.82
#                        Mean reward: 45.24
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7439
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.20s
#                         Total time: 12.72s
#                                ETA: 97.5s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2350187 steps/s (collection: 0.657s, learning 3.526s)
#                Value function loss: 157.4935
#                     Surrogate loss: 0.0012
#              Mean action noise std: 4.88
#                        Mean reward: 44.43
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7441
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.18s
#                         Total time: 16.90s
#                                ETA: 92.9s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2376761 steps/s (collection: 0.657s, learning 3.479s)
#                Value function loss: 154.0746
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.94
#                        Mean reward: 45.36
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7454
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.14s
#                         Total time: 21.04s
#                                ETA: 88.4s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2364830 steps/s (collection: 0.677s, learning 3.480s)
#                Value function loss: 182.8988
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.98
#                        Mean reward: 45.32
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7455
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.16s
#                         Total time: 25.19s
#                                ETA: 84.0s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2305108 steps/s (collection: 0.648s, learning 3.616s)
#                Value function loss: 172.0361
#                     Surrogate loss: 0.0010
#              Mean action noise std: 5.04
#                        Mean reward: 45.45
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7474
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.26s
#                         Total time: 29.46s
#                                ETA: 80.0s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2286346 steps/s (collection: 0.657s, learning 3.643s)
#                Value function loss: 210.5425
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.10
#                        Mean reward: 45.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7496
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.30s
#                         Total time: 33.76s
#                                ETA: 76.0s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2301601 steps/s (collection: 0.656s, learning 3.615s)
#                Value function loss: 191.9826
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.18
#                        Mean reward: 45.66
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7529
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.27s
#                         Total time: 38.03s
#                                ETA: 71.8s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2288319 steps/s (collection: 0.657s, learning 3.639s)
#                Value function loss: 234.0033
#                     Surrogate loss: 0.0008
#              Mean action noise std: 5.22
#                        Mean reward: 46.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7550
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.30s
#                         Total time: 42.32s
#                                ETA: 67.7s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2285706 steps/s (collection: 0.648s, learning 3.653s)
#                Value function loss: 204.1142
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.30
#                        Mean reward: 46.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7567
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.30s
#                         Total time: 46.62s
#                                ETA: 63.6s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2287345 steps/s (collection: 0.652s, learning 3.646s)
#                Value function loss: 248.3009
#                     Surrogate loss: 0.0000
#              Mean action noise std: 5.37
#                        Mean reward: 45.83
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7563
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.30s
#                         Total time: 50.92s
#                                ETA: 59.4s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2296215 steps/s (collection: 0.650s, learning 3.631s)
#                Value function loss: 212.2840
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.44
#                        Mean reward: 45.79
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7569
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.28s
#                         Total time: 55.20s
#                                ETA: 55.2s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2322745 steps/s (collection: 0.652s, learning 3.580s)
#                Value function loss: 256.6385
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.52
#                        Mean reward: 45.90
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7594
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.23s
#                         Total time: 59.44s
#                                ETA: 50.9s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2353064 steps/s (collection: 0.653s, learning 3.525s)
#                Value function loss: 217.4121
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.60
#                        Mean reward: 46.18
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7620
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.18s
#                         Total time: 63.61s
#                                ETA: 46.7s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2349850 steps/s (collection: 0.661s, learning 3.522s)
#                Value function loss: 260.6379
#                     Surrogate loss: 0.0013
#              Mean action noise std: 5.67
#                        Mean reward: 46.09
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7617
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.18s
#                         Total time: 67.80s
#                                ETA: 42.4s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2359932 steps/s (collection: 0.651s, learning 3.515s)
#                Value function loss: 218.4733
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.76
#                        Mean reward: 45.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7619
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.17s
#                         Total time: 71.96s
#                                ETA: 38.1s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2363654 steps/s (collection: 0.653s, learning 3.506s)
#                Value function loss: 262.4592
#                     Surrogate loss: 0.0008
#              Mean action noise std: 5.82
#                        Mean reward: 46.21
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7626
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.16s
#                         Total time: 76.12s
#                                ETA: 33.8s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2350217 steps/s (collection: 0.661s, learning 3.522s)
#                Value function loss: 222.0326
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.91
#                        Mean reward: 46.16
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7646
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.18s
#                         Total time: 80.30s
#                                ETA: 29.6s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2351446 steps/s (collection: 0.658s, learning 3.522s)
#                Value function loss: 274.1543
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.99
#                        Mean reward: 46.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7634
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.18s
#                         Total time: 84.49s
#                                ETA: 25.3s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2385847 steps/s (collection: 0.649s, learning 3.471s)
#                Value function loss: 232.5704
#                     Surrogate loss: 0.0007
#              Mean action noise std: 6.08
#                        Mean reward: 46.30
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7629
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.12s
#                         Total time: 88.61s
#                                ETA: 21.1s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2394088 steps/s (collection: 0.656s, learning 3.450s)
#                Value function loss: 287.5589
#                     Surrogate loss: 0.0007
#              Mean action noise std: 6.15
#                        Mean reward: 46.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7608
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.11s
#                         Total time: 92.71s
#                                ETA: 16.9s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2397696 steps/s (collection: 0.646s, learning 3.454s)
#                Value function loss: 241.6160
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.25
#                        Mean reward: 45.67
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7596
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.10s
#                         Total time: 96.81s
#                                ETA: 12.6s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2401037 steps/s (collection: 0.655s, learning 3.439s)
#                Value function loss: 299.6156
#                     Surrogate loss: 0.0007
#              Mean action noise std: 6.33
#                        Mean reward: 45.71
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7602
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.09s
#                         Total time: 100.91s
#                                ETA: 8.4s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2394260 steps/s (collection: 0.658s, learning 3.448s)
#                Value function loss: 248.4595
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.42
#                        Mean reward: 45.33
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7594
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.11s
#                         Total time: 105.01s
#                                ETA: 4.2s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 21.973258914848167
# score.mean: 24.270667370855808
# score.mean: 26.28036880425612
# score.mean: 28.440707339266933
# score.mean: 30.237789791385335
# score.mean: 32.278652462830145
# score.mean: 33.86727990009387
# score.mean: 35.74731815260648
# score.mean: 37.2406348370115
# score.mean: 38.97485904170076
# ################################################################################
#                         Learning iteration 25/50
#
#                        Computation: 2385334 steps/s (collection: 0.684s, learning 3.437s)
#                Value function loss: 249.7292
#                     Surrogate loss: 0.0011
#              Mean action noise std: 6.48
#                        Mean reward: 45.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4603
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.12s
#                         Total time: 4.12s
#                                ETA: 0.0s
#
# ################################################################################
#                         Learning iteration 26/50
#
#                        Computation: 2402377 steps/s (collection: 0.649s, learning 3.443s)
#                Value function loss: 279.9098
#                     Surrogate loss: 0.0008
#              Mean action noise std: 6.56
#                        Mean reward: 46.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7578
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.09s
#                         Total time: 8.21s
#                                ETA: -0.3s
#
# ################################################################################
#                         Learning iteration 27/50
#
#                        Computation: 2398994 steps/s (collection: 0.653s, learning 3.445s)
#                Value function loss: 222.2909
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.65
#                        Mean reward: 45.96
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7588
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.10s
#                         Total time: 12.31s
#                                ETA: -0.9s
#
# ################################################################################
#                         Learning iteration 28/50
#
#                        Computation: 2403372 steps/s (collection: 0.651s, learning 3.439s)
#                Value function loss: 264.9877
#                     Surrogate loss: 0.0014
#              Mean action noise std: 6.72
#                        Mean reward: 45.60
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7596
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.09s
#                         Total time: 16.40s
#                                ETA: -1.7s
#
# ################################################################################
#                         Learning iteration 29/50
#
#                        Computation: 2406267 steps/s (collection: 0.650s, learning 3.435s)
#                Value function loss: 217.6389
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.82
#                        Mean reward: 46.08
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7610
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.09s
#                         Total time: 20.49s
#                                ETA: -2.7s
#
# ################################################################################
#                         Learning iteration 30/50
#
#                        Computation: 2398224 steps/s (collection: 0.654s, learning 3.445s)
#                Value function loss: 268.4100
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.91
#                        Mean reward: 46.23
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7599
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.10s
#                         Total time: 24.59s
#                                ETA: -4.0s
#
# ################################################################################
#                         Learning iteration 31/50
#
#                        Computation: 2403899 steps/s (collection: 0.649s, learning 3.440s)
#                Value function loss: 226.6879
#                     Surrogate loss: 0.0003
#              Mean action noise std: 7.02
#                        Mean reward: 46.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7600
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
# ...
#                        Learning iteration 108/125
#
#                        Computation: 2279341 steps/s (collection: 0.655s, learning 3.658s)
#                Value function loss: 960.1170
#                     Surrogate loss: 0.0003
#              Mean action noise std: 22.02
#                        Mean reward: 44.97
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7427
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.31s
#                         Total time: 38.89s
#                                ETA: -29.6s
#
# ################################################################################
#                        Learning iteration 109/125
#
#                        Computation: 2324223 steps/s (collection: 0.697s, learning 3.533s)
#                Value function loss: 1215.2846
#                     Surrogate loss: 0.0001
#              Mean action noise std: 22.37
#                        Mean reward: 45.58
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7414
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.23s
#                         Total time: 43.12s
#                                ETA: -32.9s
#
# ################################################################################
#                        Learning iteration 110/125
#
#                        Computation: 2327227 steps/s (collection: 0.673s, learning 3.551s)
#                Value function loss: 951.3287
#                     Surrogate loss: 0.0003
#              Mean action noise std: 22.73
#                        Mean reward: 45.31
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7421
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.22s
#                         Total time: 47.34s
#                                ETA: -36.3s
#
# ################################################################################
#                        Learning iteration 111/125
#
#                        Computation: 2321749 steps/s (collection: 0.668s, learning 3.566s)
#                Value function loss: 1233.1321
#                     Surrogate loss: 0.0002
#              Mean action noise std: 23.09
#                        Mean reward: 44.46
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7407
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.23s
#                         Total time: 51.58s
#                                ETA: -39.6s
#
# ################################################################################
#                        Learning iteration 112/125
#
#                        Computation: 2303454 steps/s (collection: 0.677s, learning 3.591s)
#                Value function loss: 930.1169
#                     Surrogate loss: 0.0005
#              Mean action noise std: 23.47
#                        Mean reward: 44.87
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7410
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.27s
#                         Total time: 55.84s
#                                ETA: -43.0s
#
# ################################################################################
#                        Learning iteration 113/125
#
#                        Computation: 2351454 steps/s (collection: 0.667s, learning 3.513s)
#                Value function loss: 1228.9140
#                     Surrogate loss: 0.0002
#              Mean action noise std: 23.85
#                        Mean reward: 44.94
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7433
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.18s
#                         Total time: 60.03s
#                                ETA: -46.3s
#
# ################################################################################
#                        Learning iteration 114/125
#
#                        Computation: 2386181 steps/s (collection: 0.651s, learning 3.468s)
#                Value function loss: 934.8853
#                     Surrogate loss: 0.0002
#              Mean action noise std: 24.23
#                        Mean reward: 45.04
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7455
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.12s
#                         Total time: 64.15s
#                                ETA: -49.6s
#
# ################################################################################
#                        Learning iteration 115/125
#
#                        Computation: 2361866 steps/s (collection: 0.660s, learning 3.502s)
#                Value function loss: 1169.6402
#                     Surrogate loss: 0.0002
#              Mean action noise std: 24.62
#                        Mean reward: 45.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7468
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.16s
#                         Total time: 68.31s
#                                ETA: -53.0s
#
# ################################################################################
#                        Learning iteration 116/125
#
#                        Computation: 2364917 steps/s (collection: 0.657s, learning 3.500s)
#                Value function loss: 887.6660
#                     Surrogate loss: 0.0006
#              Mean action noise std: 25.04
#                        Mean reward: 44.78
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7473
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.16s
#                         Total time: 72.46s
#                                ETA: -56.4s
#
# ################################################################################
#                        Learning iteration 117/125
#
#                        Computation: 2364885 steps/s (collection: 0.665s, learning 3.492s)
#                Value function loss: 1089.0159
#                     Surrogate loss: 0.0002
#              Mean action noise std: 25.45
#                        Mean reward: 45.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7461
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.16s
#                         Total time: 76.62s
#                                ETA: -59.7s
#
# ################################################################################
#                        Learning iteration 118/125
#
#                        Computation: 2345476 steps/s (collection: 0.680s, learning 3.511s)
#                Value function loss: 823.8857
#                     Surrogate loss: 0.0002
#              Mean action noise std: 25.89
#                        Mean reward: 45.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7471
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.19s
#                         Total time: 80.81s
#                                ETA: -63.2s
#
# ################################################################################
#                        Learning iteration 119/125
#
#                        Computation: 2357423 steps/s (collection: 0.669s, learning 3.501s)
#                Value function loss: 968.6274
#                     Surrogate loss: 0.0002
#              Mean action noise std: 26.30
#                        Mean reward: 45.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7463
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.17s
#                         Total time: 84.98s
#                                ETA: -66.6s
#
# ################################################################################
#                        Learning iteration 120/125
#
#                        Computation: 2372986 steps/s (collection: 0.666s, learning 3.476s)
#                Value function loss: 726.3375
#                     Surrogate loss: 0.0003
#              Mean action noise std: 26.74
#                        Mean reward: 45.15
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7430
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.14s
#                         Total time: 89.12s
#                                ETA: -70.0s
#
# ################################################################################
#                        Learning iteration 121/125
#
#                        Computation: 2346839 steps/s (collection: 0.667s, learning 3.522s)
#                Value function loss: 871.2110
#                     Surrogate loss: 0.0002
#              Mean action noise std: 27.16
#                        Mean reward: 45.43
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7402
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.19s
#                         Total time: 93.31s
#                                ETA: -73.4s
#
# ################################################################################
#                        Learning iteration 122/125
#
#                        Computation: 2367821 steps/s (collection: 0.675s, learning 3.477s)
#                Value function loss: 654.5345
#                     Surrogate loss: 0.0005
#              Mean action noise std: 27.60
#                        Mean reward: 44.86
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7406
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.15s
#                         Total time: 97.47s
#                                ETA: -76.9s
#
# ################################################################################
#                        Learning iteration 123/125
#
#                        Computation: 2360784 steps/s (collection: 0.659s, learning 3.505s)
#                Value function loss: 777.0259
#                     Surrogate loss: 0.0001
#              Mean action noise std: 28.04
#                        Mean reward: 45.06
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7425
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.16s
#                         Total time: 101.63s
#                                ETA: -80.3s
#
# ################################################################################
#                        Learning iteration 124/125
#
#                        Computation: 2341675 steps/s (collection: 0.680s, learning 3.518s)
#                Value function loss: 574.7075
#                     Surrogate loss: 0.0003
#              Mean action noise std: 28.49
#                        Mean reward: 44.94
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7437
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.20s
#                         Total time: 105.83s
#                                ETA: -83.8s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 606.1255287222427
# score.mean: 726.2060577968718
# score.mean: 849.1326808634562
# score.mean: 971.0902130409045
# score.mean: 1091.6901410121086
# score.mean: 1215.0549401171963
# score.mean: 1344.9403663526339
# score.mean: 1481.4611375014745
# score.mean: 1622.2642247296137
# score     : [1500.77540369 2212.72870477   98.25403589   65.69959723  114.37833916
#  1840.61969668  375.63702873  162.20011427  161.45195507 1519.51484955
#   364.0341125   471.79810845   61.35247119   94.34805874  113.02106885
#    97.249639   5303.3934065  5027.39818872   63.80680364  542.07313702
#  3128.80241091  339.53368789  139.76267689 5128.93061214  258.24095411
#    87.37135597 5747.37951551   62.37414254   63.01229109  151.69570757
#   325.38617393  567.93866708   61.78435738   68.28069818   66.13461166
#    61.5898387    66.91928556 5659.36337684 3871.15816651 3403.29526259
#  1005.39640001   68.03824275  766.0424547    60.35906192   61.10137176
#    81.52202293  192.88038304 5239.60634948  103.25557104  393.39646326
#  5327.11648484 4169.78545139  340.02302809 1448.62651522 5239.71808023
#    62.14536271 5458.77339628   59.48838448  152.7069945   121.4136939
#  5328.33629004 2488.36408232   63.47968098   71.02103096 2648.9362294
#   160.11970812  601.28917369 2716.79640505  172.14387693 4751.40292206
#   193.09273023   97.50319988 5936.90225984 5233.10555841 5745.36678049
#  6741.70564801   75.25003638   60.39799613  493.10516011   60.90320457
#    61.36386446 5842.31483285 5807.72985891   60.35419747  855.57245638
#    66.670879    282.6588422    63.43530084 3700.6686087    76.98561291
#  5117.08644162 3971.75061669 3542.44541143 3909.68570142   61.43708422
#    62.37655133  106.73656942 5069.37301936   61.98572063   66.48470428]
# score.mean: 1622.2642247296137

# %%
a = np.sum(reward_history, axis=0)/T

# %%
min(a)
# Out:
# 59.48838447704911

# %%
max(a)
# Out:
# 6741.7056480109695

# %%
np.std(a)
# Out:
# 2140.6376201207463

# %%
exp_result = {
    'reward_total': reward_history,
    'reward_peo': death_buf,
    'state': state_his_buf,
    'action': act_buf
}

# %%
# torch.save(exp_result, 'mid_budget_result.pt')
