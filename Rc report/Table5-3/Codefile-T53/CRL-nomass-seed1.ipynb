# %%
from rsl_rl.env import VecEnv
from rsl_rl.runners import OnPolicyRunner
import torch
import numpy as np
torch.set_printoptions(precision=5, linewidth=200, sci_mode=False)

N          = 100020
state_dim  = 8
action_dim = 4
T          = 60
budget     = 3600.
N_envs     = 1024 * 64
ΔT         = 1.0
device     = 'cuda'
usr_std = 0.1
test_num = 100
seed = 0

parameter_static = dict(N          = N,
                        B          = budget,
                        T          = T,
                        alpha      = 0.6,
                        v_max      = 0.2/14,
                        cost_ti    = 0.0977,
                        cost_ta    = 0.02,
                        cost_v     = 0.07,
                        cost_poc_0 = 0.000369,
                        cost_poc_1 = 0.001057,
                        pid        = 1.10/1000,
                        psr        = 0.7,
                        pid_plus   = 0.1221/1000,
                        pir        = 1/8,
                        prs        = 1/7)

Random_mean = {"beta2" : 0.78735,
               "beta1" : 0.15747,
               "pei"   : 0.10714,
               "per"   : 0.04545}

space = {"beta2" : [Random_mean['beta2'],Random_mean['beta2']*usr_std],
         "beta1" : [Random_mean['beta1'], Random_mean['beta1']*usr_std],
         "pei"   : [Random_mean['pei'], Random_mean['pei']*usr_std],
         "per"   : [Random_mean['per'], Random_mean['per']*usr_std]}

Init_state = torch.tensor([[100000 / N, 20 / N, 0, 0, 0, 0, 1, 0]], 
                         dtype=torch.float32).to(torch.device(device))

# %%
class myVecEnv(VecEnv):
    def __init__(self, interval, n_envs = N_envs):
        self.B = parameter_static['B']  # total budget
        self.N = parameter_static['N']
        self.device = device
        self.init_state = Init_state
        self.states = self.init_state.repeat(n_envs, 1)
        self.num_envs = n_envs
        self.num_obs = state_dim
        self.num_privileged_obs = None
        self.num_actions = action_dim
        self.max_episode_length = parameter_static['T']
        
        torch.manual_seed(seed)
        self.parameter_random = {
            key: torch.empty(self.num_envs).normal_(
                interval[key][0],
                interval[key][1]
            ).to(torch.device(device))
            for key, value in Random_mean.items()
        }

        for key, value in Random_mean.items():
            indice = self.parameter_random[key] < 0
            self.parameter_random[key][indice] = -self.parameter_random[key][indice] 

        # optimization flags for pytorch JIT
        torch._C._jit_set_profiling_mode(False)
        torch._C._jit_set_profiling_executor(False)
        
        # allocate buffers
        self.privileged_obs_buf = None
        self.obs_buf = torch.zeros(self.num_envs, self.num_obs, device=self.device, dtype=torch.float)
        self.rew_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.float)
        self.reset_buf = torch.ones(self.num_envs, device=self.device, dtype=torch.long)
        self.episode_length_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.long)
        
        self.actions = torch.zeros(self.num_envs, self.num_actions, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_sums = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_acts = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.extras = {}
    
    def para_update(self, para):
        self.parameter_random = para
        
    def step(self, actions):
        # actions clip
        soft_bound = [-0.5, 1.5]
        out_of_limits = -(actions - soft_bound[0]).clip(max=0.)
        out_of_limits += (actions - soft_bound[1]).clip(min=0.)
        scale_action = -5
        reward_action = scale_action * torch.sum(out_of_limits, dim=1).clip(max=1.).to(self.device)
        self.actions = torch.clip(actions, 0., 1.).to(self.device)

        # update actions & states
        b, p = self.states[:, -2] * self.B, self.states[:, -1]
        inv_c = self.cost_function(self.actions)
        b -= inv_c
        b = torch.clip(b, 0., self.B).to(self.device)
        mask = (b > 0).float().unsqueeze(-1)
        self.act = self.actions * mask
        inv_c = self.cost_function(self.act)
        next_state, reward_original = self.transition(self.act)
        self.extras['reward_original'] = reward_original
        self.extras['inv_cost'] = inv_c
        self.episode_length_buf += 1
        p = self.episode_length_buf / self.max_episode_length
        self.states = torch.cat([next_state / self.N, (b / self.B).unsqueeze(-1), p.unsqueeze(-1)], dim=-1)
        
        # check termination
        self.reset_buf = self.episode_length_buf >= self.max_episode_length
        
        # compute reward
        r_mean = -6584
        r_std  =  7347
        reward = (reward_original - inv_c - r_mean) / r_std
        #if reward > 0: 
        #reward = torch.exp(reward)/10
        #reward = torch.exp((1e5 + reward_original - inv_c) / 5e4)
        self.rew_buf       = reward + reward_action
        self.episode_sums += reward + reward_action
        self.episode_acts += reward_action
        
        # compute resets
        env_ids = self.reset_buf.nonzero(as_tuple=False).flatten()
        self.reset_idx(env_ids)
        
        # compute observations
        return self.get_observations(), self.states, self.rew_buf, self.reset_buf, self.extras

    def reset_idx(self, env_ids):
        """Reset selected robots"""
        if len(env_ids) == 0:
            return
        
        assert len(env_ids) == self.num_envs
        # reset robot states
        self.states[env_ids] = self.init_state
        # reset buffers
        self.episode_length_buf[env_ids] = 0
        self.reset_buf[env_ids] = 1
        # fill extras
        self.extras["episode"] = {}
        self.extras["episode"]['rew_sum'] = torch.mean(self.episode_sums[env_ids]) / (self.max_episode_length * ΔT)
        self.extras["episode"]['rew_act'] = torch.mean(self.episode_acts[env_ids]) / (self.max_episode_length * ΔT)
        self.episode_sums[env_ids] = 0.
        self.episode_acts[env_ids] = 0.
    
    def reset(self):
        """ Reset all robots"""
        self.reset_idx(torch.arange(self.num_envs, device=self.device))
        return {}, {}
    
    def get_observations(self):
        o_mean = torch.tensor([[0.58712867, 0.06804276, 0.00308146, 0.25684301, 0.00261079, 0.08229331, 0.26572794, 0.51      ]], dtype=torch.float32).to(torch.device(self.device))
        o_std  = torch.tensor([[0.41484398, 0.07883003, 0.00389494, 0.292568  , 0.00394907, 0.06906768, 0.33943075, 0.28861739]], dtype=torch.float32).to(torch.device(self.device))
        self.obs_buf = (self.states - o_mean) / o_std
        return self.obs_buf
    
    def get_privileged_observations(self):
        return self.privileged_obs_buf

    def cost_function(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq = action[:, 0], action[:, 1], action[:, 2], action[:, 3]
        w = 0
        cost_it  = it * u_it * parameter_static['cost_ti']
        cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
        cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
        per_poc  = ((st + et + at + rt) / self.N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
        cost_poc = (st + et + rt + at) * w * per_poc
        return cost_poc + cost_it + cost_v + cost_q

    def transition(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq = action[:, 0], action[:, 1], action[:, 2], action[:, 3]
        w = 0
        ht = st + et + at + it + rt

        st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * self.parameter_random['beta1'] + (et + at * (1 - u_aq)) * self.parameter_random['beta2']) / ht
        st_out_e = st_out * parameter_static['alpha']
        st_out_i = st_out * (1 - parameter_static['alpha'])
        st_out_r = u_sv * parameter_static['v_max'] * st * parameter_static['psr']
        et_out_r = et * self.parameter_random['per']
        et_out_i = et * self.parameter_random['pei']
        et_out_a = et * w * (1 - self.parameter_random['per'] - self.parameter_random['pei'])
        at_out_i = at * self.parameter_random['pei']
        at_out_r = at * self.parameter_random['per']
        it_out_r = it * parameter_static['pir'] * u_it
        it_out_d = it * parameter_static['pid'] * (1 - u_it) + it * u_it * parameter_static['pid_plus']
        rt_out_s = rt * parameter_static['prs']
        
        stn = st - st_out_e - st_out_i - st_out_r + rt_out_s
        etn = et - et_out_r - et_out_i - et_out_a + st_out_e
        atn = at - at_out_r - at_out_i + et_out_a
        itn = it - it_out_r - it_out_d + st_out_i + et_out_i + at_out_i
        dtn = dt + it_out_d
        rtn = rt + et_out_r + at_out_r + it_out_r + st_out_r - rt_out_s

        reward = -2.6 * st_out - 100 * it_out_d

        next_state = torch.stack([stn, etn, atn, itn, dtn, rtn], dim=-1)
        return next_state, reward

# %%
import inspect

class BaseConfig:
    def __init__(self) -> None:
        """ Initializes all member classes recursively. Ignores all namse starting with '__' (buit-in methods)."""
        self.init_member_classes(self)
    
    @staticmethod
    def init_member_classes(obj):
        # iterate over all attributes names
        for key in dir(obj):
            # disregard builtin attributes
            # if key.startswith("__"):
            if key=="__class__":
                continue
            # get the corresponding attribute object
            var =  getattr(obj, key)
            # check if it the attribute is a class
            if inspect.isclass(var):
                # instantate the class
                i_var = var()
                # set the attribute to the instance instead of the type
                setattr(obj, key, i_var)
                # recursively init members of the attribute
                BaseConfig.init_member_classes(i_var)

class LeggedRobotCfgPPO(BaseConfig):
    seed = 1
    runner_class_name = 'OnPolicyRunner'
    class policy:
        init_noise_std = 1
        actor_hidden_dims  = [64, 32, 16] 
        critic_hidden_dims = [64, 32, 16]
        activation = 'elu' # can be elu, relu, selu, crelu, lrelu, tanh, sigmoid
        # only for 'ActorCriticRecurrent':
        # rnn_type = 'lstm'
        # rnn_hidden_size = 512
        # rnn_num_layers = 1
        
    class algorithm:
        # training params
        value_loss_coef = 0.5
        use_clipped_value_loss = True
        clip_param = 0.2
        entropy_coef = 0.01
        num_learning_epochs = 5
        num_mini_batches = 64 # mini batch size = num_envs*nsteps / nminibatches
        learning_rate = 1.e-4
        schedule = 'adaptive' # could be adaptive, fixed
        gamma = 0.99
        lam = 0.95
        desired_kl = 0.01
        max_grad_norm = 1.

    class runner:
        policy_class_name = 'ActorCritic'
        algorithm_class_name = 'PPO'
        num_steps_per_env =  150 # per iteration
        max_iterations    = 100 # number of policy updates

        # logging
        save_interval = 100 # check for potential saves every this many iterations
        experiment_name = 'test'
        run_name = ''
        # load and resume
        resume = True
        load_run = -1 # -1 = last run
        checkpoint = -1 # -1 = last saved model
        resume_path = None # updated from load_run and chkpt
        
def class_to_dict(obj) -> dict:
    if not  hasattr(obj,"__dict__"):
        return obj
    result = {}
    for key in dir(obj):
        if key.startswith("_"):
            continue
        element = []
        val = getattr(obj, key)
        if isinstance(val, list):
            for item in val:
                element.append(class_to_dict(item))
        else:
            element = class_to_dict(val)
        result[key] = element
    return result

# %%
def para_sampling(intvl, num_sample=N_envs):
    parameter_random = {
        key: torch.empty(num_sample).normal_(
        intvl[key][0],
        intvl[key][1]
        ).to(torch.device(device))
        for key, value in Random_mean.items()
    }
    for key, value in Random_mean.items():
        indice = parameter_random[key] < 0
        parameter_random[key][indice] = -parameter_random[key][indice] 
    return parameter_random

def update_space(final_indices, para_buf, space):
    para_est = {}
    for key, tensor_values in para_buf.items():
        selected_values = torch.mean(tensor_values[final_indices[0], final_indices[1]]) 
        para_values = torch.mean(tensor_values[final_indices[0], final_indices[1]], dim=0)
        update_values = space[key][0] + 0.5 * (selected_values - space[key][0])
        space[key] = [update_values , update_values  * 0.1]
        para_est[key] = para_values
    return space, para_est


def cal_err(para_value, env_para):
    gap = []
    for key, value in env_para.items():
        gap_temp = torch.mean(torch.abs(para_value[key] - env_para[key])/(env_para[key]))
        gap.append(gap_temp)
    return sum(gap)/len(gap) # 所有值都在范围内，返回 0
    
def state_estimator(env_sample, action_sim, state_sim, state_prior, space, iter): 
    env_sample.reset()
    env_sample.states = state_prior  
    para_buf, mse_buf, obs_buf, states_buf = {}, {}, {}, {}
    for i in range(iter):
        para = para_sampling(space, test_num)
        env_sample.para_update(para)
        obs_sample, states_sample, _, _, _ = env_sample.step(action_sim.detach())  
        mse = torch.mean((state_sim[:,2:4] - states_sample[:,2:4]) ** 2, dim=1) 
        if i == 0:
            mse_buf = mse.unsqueeze(0)
            obs_buf = obs_sample.unsqueeze(0)
            states_buf = states_sample.unsqueeze(0)
            for key, values in para.items():
                para_buf[key] = para[key].unsqueeze(0)
        else:
            mse_buf = torch.cat((mse_buf, mse.unsqueeze(0)), dim=0)
            obs_buf = torch.cat((obs_buf, obs_sample.unsqueeze(0)),dim=0)
            states_buf = torch.cat((states_buf, states_sample.unsqueeze(0)), dim=0)
            for key, values in para.items():
                para_buf[key] = torch.cat((para_buf[key], para[key].unsqueeze(0)), dim=0)
                
     
    k = int(iter * 0.05)
    _, row_indices = torch.topk(mse_buf, k=k, dim=0, largest=False)
    column_indices = torch.arange(mse_buf.shape[1]).repeat(k, 1)
    top_indices = [row_indices, column_indices]
    obs_est = torch.mean(obs_buf[row_indices,column_indices,:], dim=0)
    state_est = torch.mean(states_buf[row_indices,column_indices,:], dim=0)
    state_est[:,-1] = state_prior[:,-1] + torch.tensor(1/T)
    return obs_est, state_est, top_indices, para_buf

# %%
para_err = 0.5
torch.manual_seed(seed)
para_true = []
para_temp = {
    key: torch.empty(test_num).uniform_(
        value * (1-para_err),
        value * (1+para_err)
    ).to(torch.device(device))
    for key, value in Random_mean.items()
}


para = {}
for t in range(T):
    para = {
        key: (para_temp[key] + t * 0.5 *  para_temp[key] /T).to(torch.device(device)) if key == 'per' 
        else (para_temp[key] - t * 0.5 *  para_temp[key] /T).to(torch.device(device))
        for key, value in Random_mean.items()
        }
    para_true.append(para)

# %%
env = myVecEnv(space, test_num)
env.para_update(para_true[0])
train_cfg = LeggedRobotCfgPPO()
train_cfg_dict = class_to_dict(train_cfg)


env_transfer = myVecEnv(space)
runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_nomass', device=env.device)
runner.load(f'rsl_low_no_mass/model_100.pt')

policy = runner.get_inference_policy(device=env.device)

reward_history = []
act_buf = []
state_his_buf = []
death_buf = []

env_sample = myVecEnv(space, test_num)
state_est = env.states
obs_est = env.get_observations()
for t in range(T-1):
    actions = policy(obs_est.detach())
    obs, states, _, _, infos = env.step(actions.detach())
    reward_history.append((-infos['reward_original'] + infos['inv_cost']).tolist())
    death_buf.append((-infos['reward_original']).tolist())
    act_buf.append(env.act)
    state_his_buf.append(env.states)
    obs_est, state_buf, top_indices, para_buf = state_estimator(env_sample, actions, states, state_est, space, 1024)
    space, para_v = update_space(top_indices, para_buf, space) 

    runner.learn(num_learning_iterations=25, init_at_random_ep_len=False)
    policy = runner.get_inference_policy(device=env.device)
    env_transfer = myVecEnv(space)
    runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_nomass', device=env.device)
    runner.load(f'rsl_nomass/model_{int(t)* 25}.pt')

    if t < T - 1: env.para_update(para_true[t + 1])
    print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')

reward_history = np.array(reward_history)
print(f'score     : {np.sum(reward_history, axis=0)/T       }')
print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
# Out:
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=4, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2227045 steps/s (collection: 0.717s, learning 3.697s)
#                Value function loss: 99.3605
#                     Surrogate loss: -0.0001
#              Mean action noise std: 0.38
#                        Mean reward: -27.91
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.2862
#               Mean episode rew_act: -0.0206
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.41s
#                         Total time: 4.41s
#                                ETA: 110.4s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2327238 steps/s (collection: 0.723s, learning 3.501s)
#                Value function loss: 91.5452
#                     Surrogate loss: -0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.88
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4715
#               Mean episode rew_act: -0.0340
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.22s
#                         Total time: 8.64s
#                                ETA: 103.7s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2402866 steps/s (collection: 0.663s, learning 3.428s)
#                Value function loss: 89.9908
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.37
#                        Mean reward: -28.09
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4696
#               Mean episode rew_act: -0.0328
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.09s
#                         Total time: 12.73s
#                                ETA: 97.6s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2413212 steps/s (collection: 0.651s, learning 3.423s)
#                Value function loss: 84.8850
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.38
#                        Mean reward: -28.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4691
#               Mean episode rew_act: -0.0323
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.07s
#                         Total time: 16.80s
#                                ETA: 92.4s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2425325 steps/s (collection: 0.666s, learning 3.387s)
#                Value function loss: 86.6275
#                     Surrogate loss: -0.0001
#              Mean action noise std: 0.38
#                        Mean reward: -27.90
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4701
#               Mean episode rew_act: -0.0342
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.05s
#                         Total time: 20.86s
#                                ETA: 87.6s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2391644 steps/s (collection: 0.658s, learning 3.453s)
#                Value function loss: 82.9945
#                     Surrogate loss: -0.0000
#              Mean action noise std: 0.38
#                        Mean reward: -28.05
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4711
#               Mean episode rew_act: -0.0360
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.11s
#                         Total time: 24.97s
#                                ETA: 83.2s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2404098 steps/s (collection: 0.660s, learning 3.430s)
#                Value function loss: 81.1493
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.37
#                        Mean reward: -27.90
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4707
#               Mean episode rew_act: -0.0361
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.09s
#                         Total time: 29.06s
#                                ETA: 78.9s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2402308 steps/s (collection: 0.674s, learning 3.418s)
#                Value function loss: 75.7685
#                     Surrogate loss: -0.0000
#              Mean action noise std: 0.37
#                        Mean reward: -28.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4699
#               Mean episode rew_act: -0.0356
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.09s
#                         Total time: 33.15s
#                                ETA: 74.6s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2434859 steps/s (collection: 0.646s, learning 3.392s)
#                Value function loss: 74.3363
#                     Surrogate loss: -0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.89
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4685
#               Mean episode rew_act: -0.0345
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.04s
#                         Total time: 37.18s
#                                ETA: 70.2s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2424718 steps/s (collection: 0.659s, learning 3.396s)
#                Value function loss: 65.8216
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.94
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4675
#               Mean episode rew_act: -0.0330
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.05s
#                         Total time: 41.24s
#                                ETA: 66.0s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2462022 steps/s (collection: 0.646s, learning 3.347s)
#                Value function loss: 69.2717
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.37
#                        Mean reward: -27.83
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4674
#               Mean episode rew_act: -0.0323
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 3.99s
#                         Total time: 45.23s
#                                ETA: 61.7s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2436951 steps/s (collection: 0.673s, learning 3.361s)
#                Value function loss: 63.2948
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.91
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4676
#               Mean episode rew_act: -0.0326
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.03s
#                         Total time: 49.27s
#                                ETA: 57.5s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2462221 steps/s (collection: 0.648s, learning 3.345s)
#                Value function loss: 68.7852
#                     Surrogate loss: -0.0000
#              Mean action noise std: 0.37
#                        Mean reward: -27.51
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4679
#               Mean episode rew_act: -0.0337
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 3.99s
#                         Total time: 53.26s
#                                ETA: 53.3s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2447559 steps/s (collection: 0.646s, learning 3.370s)
#                Value function loss: 64.3346
#                     Surrogate loss: 0.0012
#              Mean action noise std: 0.37
#                        Mean reward: -28.02
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4681
#               Mean episode rew_act: -0.0343
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.02s
#                         Total time: 57.27s
#                                ETA: 49.1s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2411036 steps/s (collection: 0.665s, learning 3.412s)
#                Value function loss: 67.9897
#                     Surrogate loss: -0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -28.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4684
#               Mean episode rew_act: -0.0350
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.08s
#                         Total time: 61.35s
#                                ETA: 45.0s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2392665 steps/s (collection: 0.660s, learning 3.448s)
#                Value function loss: 61.3903
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.78
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4678
#               Mean episode rew_act: -0.0351
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.11s
#                         Total time: 65.46s
#                                ETA: 40.9s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2390763 steps/s (collection: 0.679s, learning 3.433s)
#                Value function loss: 63.5920
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.37
#                        Mean reward: -27.53
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4671
#               Mean episode rew_act: -0.0347
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.11s
#                         Total time: 69.57s
#                                ETA: 36.8s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2435592 steps/s (collection: 0.652s, learning 3.385s)
#                Value function loss: 57.7267
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.87
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4676
#               Mean episode rew_act: -0.0353
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.04s
#                         Total time: 73.61s
#                                ETA: 32.7s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2411411 steps/s (collection: 0.653s, learning 3.424s)
#                Value function loss: 63.1959
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.37
#                        Mean reward: -27.70
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4681
#               Mean episode rew_act: -0.0357
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.08s
#                         Total time: 77.69s
#                                ETA: 28.6s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2424429 steps/s (collection: 0.654s, learning 3.400s)
#                Value function loss: 55.8968
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.88
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4687
#               Mean episode rew_act: -0.0364
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.05s
#                         Total time: 81.74s
#                                ETA: 24.5s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2425117 steps/s (collection: 0.645s, learning 3.409s)
#                Value function loss: 61.2484
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.88
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4678
#               Mean episode rew_act: -0.0357
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.05s
#                         Total time: 85.79s
#                                ETA: 20.4s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2414376 steps/s (collection: 0.650s, learning 3.421s)
#                Value function loss: 55.9406
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.92
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4675
#               Mean episode rew_act: -0.0353
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.07s
#                         Total time: 89.86s
#                                ETA: 16.3s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2371110 steps/s (collection: 0.663s, learning 3.483s)
#                Value function loss: 61.5228
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.69
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4675
#               Mean episode rew_act: -0.0362
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.15s
#                         Total time: 94.01s
#                                ETA: 12.3s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2432103 steps/s (collection: 0.665s, learning 3.377s)
#                Value function loss: 55.9352
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.62
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4667
#               Mean episode rew_act: -0.0357
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.04s
#                         Total time: 98.05s
#                                ETA: 8.2s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2411111 steps/s (collection: 0.685s, learning 3.392s)
#                Value function loss: 59.7896
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.81
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4666
#               Mean episode rew_act: -0.0353
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.08s
#                         Total time: 102.13s
#                                ETA: 4.1s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=4, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 1.6026003392537436
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2362528 steps/s (collection: 0.716s, learning 3.445s)
#                Value function loss: 97.7772
#                     Surrogate loss: -0.0001
#              Mean action noise std: 0.38
#                        Mean reward: -27.74
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.2843
#               Mean episode rew_act: -0.0207
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.16s
#                         Total time: 4.16s
#                                ETA: 104.0s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2387487 steps/s (collection: 0.679s, learning 3.438s)
#                Value function loss: 89.9388
#                     Surrogate loss: -0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.73
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4687
#               Mean episode rew_act: -0.0344
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.12s
#                         Total time: 8.28s
#                                ETA: 99.3s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2419777 steps/s (collection: 0.674s, learning 3.389s)
#                Value function loss: 89.5235
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.37
#                        Mean reward: -28.00
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4678
#               Mean episode rew_act: -0.0337
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.06s
#                         Total time: 12.34s
#                                ETA: 94.6s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2344850 steps/s (collection: 0.672s, learning 3.520s)
#                Value function loss: 82.2391
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.38
#                        Mean reward: -27.92
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4674
#               Mean episode rew_act: -0.0337
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.19s
#                         Total time: 16.53s
#                                ETA: 90.9s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2369981 steps/s (collection: 0.675s, learning 3.473s)
#                Value function loss: 82.5136
#                     Surrogate loss: -0.0001
#              Mean action noise std: 0.38
#                        Mean reward: -27.74
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4680
#               Mean episode rew_act: -0.0354
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.15s
#                         Total time: 20.68s
#                                ETA: 86.9s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2273523 steps/s (collection: 0.675s, learning 3.649s)
#                Value function loss: 78.2605
#                     Surrogate loss: -0.0000
#              Mean action noise std: 0.38
#                        Mean reward: -27.92
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4686
#               Mean episode rew_act: -0.0365
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.32s
#                         Total time: 25.01s
#                                ETA: 83.4s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2327900 steps/s (collection: 0.675s, learning 3.548s)
#                Value function loss: 78.3641
#                     Surrogate loss: -0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.73
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4683
#               Mean episode rew_act: -0.0365
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.22s
#                         Total time: 29.23s
#                                ETA: 79.3s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2356050 steps/s (collection: 0.663s, learning 3.510s)
#                Value function loss: 70.3288
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.37
#                        Mean reward: -27.84
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4667
#               Mean episode rew_act: -0.0349
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.17s
#                         Total time: 33.40s
#                                ETA: 75.2s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2292458 steps/s (collection: 0.725s, learning 3.563s)
#                Value function loss: 72.1810
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.37
#                        Mean reward: -27.66
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4648
#               Mean episode rew_act: -0.0332
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.29s
#                         Total time: 37.69s
#                                ETA: 71.2s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2310199 steps/s (collection: 0.661s, learning 3.595s)
#                Value function loss: 64.4039
#                     Surrogate loss: 0.0002
#              Mean action noise std: 0.37
#                        Mean reward: -27.67
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4636
#               Mean episode rew_act: -0.0321
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.26s
#                         Total time: 41.94s
#                                ETA: 67.1s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2308700 steps/s (collection: 0.661s, learning 3.597s)
#                Value function loss: 66.9645
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.67
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4640
#               Mean episode rew_act: -0.0322
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.26s
#                         Total time: 46.20s
#                                ETA: 63.0s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2315743 steps/s (collection: 0.662s, learning 3.583s)
#                Value function loss: 58.3129
#                     Surrogate loss: 0.0013
#              Mean action noise std: 0.37
#                        Mean reward: -27.78
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4651
#               Mean episode rew_act: -0.0338
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.25s
#                         Total time: 50.45s
#                                ETA: 58.9s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2373642 steps/s (collection: 0.660s, learning 3.481s)
#                Value function loss: 65.6911
#                     Surrogate loss: -0.0000
#              Mean action noise std: 0.37
#                        Mean reward: -27.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4662
#               Mean episode rew_act: -0.0355
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.14s
#                         Total time: 54.59s
#                                ETA: 54.6s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2388370 steps/s (collection: 0.661s, learning 3.455s)
#                Value function loss: 57.3281
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.38
#                        Mean reward: -27.90
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4665
#               Mean episode rew_act: -0.0356
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.12s
#                         Total time: 58.70s
#                                ETA: 50.3s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2351928 steps/s (collection: 0.654s, learning 3.526s)
#                Value function loss: 63.3264
#                     Surrogate loss: -0.0000
#              Mean action noise std: 0.37
#                        Mean reward: -28.09
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4673
#               Mean episode rew_act: -0.0369
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.18s
#                         Total time: 62.88s
#                                ETA: 46.1s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2375303 steps/s (collection: 0.686s, learning 3.452s)
#                Value function loss: 55.9680
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.81
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4677
#               Mean episode rew_act: -0.0379
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.14s
#                         Total time: 67.02s
#                                ETA: 41.9s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2400501 steps/s (collection: 0.652s, learning 3.443s)
#                Value function loss: 62.7024
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.38
#                        Mean reward: -27.55
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4678
#               Mean episode rew_act: -0.0378
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.10s
#                         Total time: 71.12s
#                                ETA: 37.7s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2369807 steps/s (collection: 0.678s, learning 3.470s)
#                Value function loss: 57.9081
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -27.97
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4685
#               Mean episode rew_act: -0.0380
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.15s
#                         Total time: 75.27s
#                                ETA: 33.5s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2376037 steps/s (collection: 0.670s, learning 3.468s)
#                Value function loss: 63.2658
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.38
#                        Mean reward: -27.64
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4682
#               Mean episode rew_act: -0.0369
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.14s
#                         Total time: 79.40s
#                                ETA: 29.3s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2415920 steps/s (collection: 0.673s, learning 3.396s)
#                Value function loss: 60.8424
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.38
#                        Mean reward: -27.85
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4681
#               Mean episode rew_act: -0.0371
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.07s
#                         Total time: 83.47s
#                                ETA: 25.0s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2399459 steps/s (collection: 0.663s, learning 3.434s)
#                Value function loss: 63.4576
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.37
#                        Mean reward: -28.01
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4686
#               Mean episode rew_act: -0.0381
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.10s
#                         Total time: 87.57s
#                                ETA: 20.8s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2398807 steps/s (collection: 0.661s, learning 3.437s)
#                Value function loss: 62.5235
#                     Surrogate loss: 0.0002
#              Mean action noise std: 0.37
#                        Mean reward: -27.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4682
#               Mean episode rew_act: -0.0372
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.10s
#                         Total time: 91.67s
#                                ETA: 16.7s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2400763 steps/s (collection: 0.649s, learning 3.446s)
#                Value function loss: 64.6439
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.38
#                        Mean reward: -27.74
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4678
#               Mean episode rew_act: -0.0365
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.09s
#                         Total time: 95.76s
#                                ETA: 12.5s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2410984 steps/s (collection: 0.668s, learning 3.409s)
#                Value function loss: 65.3693
#                     Surrogate loss: 0.0002
#              Mean action noise std: 0.38
#                        Mean reward: -27.84
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4689
#               Mean episode rew_act: -0.0374
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.08s
#                         Total time: 99.84s
#                                ETA: 8.3s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2406847 steps/s (collection: 0.670s, learning 3.414s)
#                Value function loss: 66.3304
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.38
#                        Mean reward: -27.97
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4700
#               Mean episode rew_act: -0.0375
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.08s
#                         Total time: 103.92s
#                                ETA: 4.2s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=4, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 3.5834619967142745
# ################################################################################
#                         Learning iteration 25/50
#
#                        Computation: 2386298 steps/s (collection: 0.695s, learning 3.425s)
#                Value function loss: 68.1043
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.38
#                        Mean reward: -27.87
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.2859
#               Mean episode rew_act: -0.0226
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.12s
#                         Total time: 4.12s
#                                ETA: 0.0s
#
# ################################################################################
#                         Learning iteration 26/50
#
#                        Computation: 2421544 steps/s (collection: 0.676s, learning 3.384s)
#                Value function loss: 74.9798
#                     Surrogate loss: 0.0015
#              Mean action noise std: 0.38
#                        Mean reward: -27.98
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4717
#               Mean episode rew_act: -0.0379
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.06s
#                         Total time: 8.18s
#                                ETA: -0.3s
#
# ################################################################################
#                         Learning iteration 27/50
#
#                        Computation: 2430293 steps/s (collection: 0.653s, learning 3.392s)
#                Value function loss: 71.8733
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.38
#                        Mean reward: -28.38
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4727
#               Mean episode rew_act: -0.0389
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.04s
#                         Total time: 12.22s
#                                ETA: -0.9s
#
# ################################################################################
#                         Learning iteration 28/50
#
#                        Computation: 2447070 steps/s (collection: 0.669s, learning 3.349s)
#                Value function loss: 77.4417
#                     Surrogate loss: 0.0002
#              Mean action noise std: 0.39
#                        Mean reward: -28.43
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4743
#               Mean episode rew_act: -0.0400
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.02s
#                         Total time: 16.24s
#                                ETA: -1.7s
#
# ################################################################################
#                         Learning iteration 29/50
#
#                        Computation: 2454697 steps/s (collection: 0.659s, learning 3.345s)
#                Value function loss: 73.7531
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.39
#                        Mean reward: -28.38
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4773
#               Mean episode rew_act: -0.0425
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.00s
#                         Total time: 20.25s
#                                ETA: -2.7s
#
# ################################################################################
#                         Learning iteration 30/50
#
#                        Computation: 2390433 steps/s (collection: 0.651s, learning 3.461s)
#                Value function loss: 79.0540
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.39
#                        Mean reward: -28.46
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4789
#               Mean episode rew_act: -0.0435
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.11s
#                         Total time: 24.36s
#                                ETA: -3.9s
#
# ################################################################################
#                         Learning iteration 31/50
#
#                        Computation: 2426218 steps/s (collection: 0.665s, learning 3.386s)
#                Value function loss: 75.4771
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.39
#                        Mean reward: -28.57
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.4805
#               Mean episode rew_act: -0.0441
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.05s
#                         Total time: 28.41s
#                                ETA: -5.3s
#
# ################################################################################
#                         Learning iteration 32/50
#
#                        Computation: 2383281 steps/s (collection: 0.681s, learning 3.444s)
#                Value function loss: 80.5569
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.39
# ...
#                         Total time: 32.24s
#                                ETA: -31.7s
#
# ################################################################################
#                       Learning iteration 1433/1450
#
#                        Computation: 2471465 steps/s (collection: 0.668s, learning 3.310s)
#                Value function loss: 98.0778
#                     Surrogate loss: 0.0012
#              Mean action noise std: 0.40
#                        Mean reward: -30.32
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5084
#               Mean episode rew_act: -0.0451
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 3.98s
#                         Total time: 36.22s
#                                ETA: -35.6s
#
# ################################################################################
#                       Learning iteration 1434/1450
#
#                        Computation: 2465512 steps/s (collection: 0.649s, learning 3.338s)
#                Value function loss: 109.1103
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.40
#                        Mean reward: -30.53
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5095
#               Mean episode rew_act: -0.0464
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 3.99s
#                         Total time: 40.20s
#                                ETA: -39.5s
#
# ################################################################################
#                       Learning iteration 1435/1450
#
#                        Computation: 2445699 steps/s (collection: 0.668s, learning 3.351s)
#                Value function loss: 98.0328
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.40
#                        Mean reward: -30.38
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5111
#               Mean episode rew_act: -0.0480
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.02s
#                         Total time: 44.22s
#                                ETA: -43.4s
#
# ################################################################################
#                       Learning iteration 1436/1450
#
#                        Computation: 2437470 steps/s (collection: 0.675s, learning 3.358s)
#                Value function loss: 108.9395
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.40
#                        Mean reward: -30.67
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5123
#               Mean episode rew_act: -0.0496
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.03s
#                         Total time: 48.25s
#                                ETA: -47.4s
#
# ################################################################################
#                       Learning iteration 1437/1450
#
#                        Computation: 2442014 steps/s (collection: 0.680s, learning 3.346s)
#                Value function loss: 98.4057
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.40
#                        Mean reward: -30.29
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5144
#               Mean episode rew_act: -0.0522
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.03s
#                         Total time: 52.28s
#                                ETA: -51.3s
#
# ################################################################################
#                       Learning iteration 1438/1450
#
#                        Computation: 2397627 steps/s (collection: 0.669s, learning 3.431s)
#                Value function loss: 109.3309
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.40
#                        Mean reward: -30.95
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5149
#               Mean episode rew_act: -0.0528
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.10s
#                         Total time: 56.38s
#                                ETA: -55.4s
#
# ################################################################################
#                       Learning iteration 1439/1450
#
#                        Computation: 2383230 steps/s (collection: 0.675s, learning 3.450s)
#                Value function loss: 98.4259
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.40
#                        Mean reward: -31.06
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5158
#               Mean episode rew_act: -0.0536
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.12s
#                         Total time: 60.51s
#                                ETA: -59.4s
#
# ################################################################################
#                       Learning iteration 1440/1450
#
#                        Computation: 2434871 steps/s (collection: 0.694s, learning 3.344s)
#                Value function loss: 109.2814
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.40
#                        Mean reward: -30.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5160
#               Mean episode rew_act: -0.0541
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.04s
#                         Total time: 64.54s
#                                ETA: -63.4s
#
# ################################################################################
#                       Learning iteration 1441/1450
#
#                        Computation: 2450015 steps/s (collection: 0.646s, learning 3.366s)
#                Value function loss: 98.2712
#                     Surrogate loss: 0.0016
#              Mean action noise std: 0.40
#                        Mean reward: -30.33
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5158
#               Mean episode rew_act: -0.0537
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.01s
#                         Total time: 68.56s
#                                ETA: -67.3s
#
# ################################################################################
#                       Learning iteration 1442/1450
#
#                        Computation: 2372530 steps/s (collection: 0.683s, learning 3.460s)
#                Value function loss: 109.3037
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.40
#                        Mean reward: -30.63
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5150
#               Mean episode rew_act: -0.0523
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.14s
#                         Total time: 72.70s
#                                ETA: -71.4s
#
# ################################################################################
#                       Learning iteration 1443/1450
#
#                        Computation: 2406448 steps/s (collection: 0.682s, learning 3.403s)
#                Value function loss: 98.2959
#                     Surrogate loss: -0.0000
#              Mean action noise std: 0.40
#                        Mean reward: -30.51
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5154
#               Mean episode rew_act: -0.0520
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.09s
#                         Total time: 76.78s
#                                ETA: -75.4s
#
# ################################################################################
#                       Learning iteration 1444/1450
#
#                        Computation: 2346101 steps/s (collection: 0.685s, learning 3.505s)
#                Value function loss: 109.1286
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.41
#                        Mean reward: -30.63
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5154
#               Mean episode rew_act: -0.0519
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.19s
#                         Total time: 80.97s
#                                ETA: -79.5s
#
# ################################################################################
#                       Learning iteration 1445/1450
#
#                        Computation: 2396451 steps/s (collection: 0.651s, learning 3.451s)
#                Value function loss: 98.4136
#                     Surrogate loss: 0.0000
#              Mean action noise std: 0.41
#                        Mean reward: -30.97
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5164
#               Mean episode rew_act: -0.0520
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.10s
#                         Total time: 85.08s
#                                ETA: -83.5s
#
# ################################################################################
#                       Learning iteration 1446/1450
#
#                        Computation: 2347675 steps/s (collection: 0.684s, learning 3.503s)
#                Value function loss: 108.8847
#                     Surrogate loss: 0.0001
#              Mean action noise std: 0.41
#                        Mean reward: -30.86
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5174
#               Mean episode rew_act: -0.0525
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.19s
#                         Total time: 89.26s
#                                ETA: -87.7s
#
# ################################################################################
#                       Learning iteration 1447/1450
#
#                        Computation: 2418492 steps/s (collection: 0.661s, learning 3.403s)
#                Value function loss: 98.4351
#                     Surrogate loss: 0.0060
#              Mean action noise std: 0.41
#                        Mean reward: -30.77
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5188
#               Mean episode rew_act: -0.0538
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.06s
#                         Total time: 93.33s
#                                ETA: -91.7s
#
# ################################################################################
#                       Learning iteration 1448/1450
#
#                        Computation: 2390364 steps/s (collection: 0.672s, learning 3.440s)
#                Value function loss: 109.2495
#                     Surrogate loss: 0.0004
#              Mean action noise std: 0.41
#                        Mean reward: -30.98
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5208
#               Mean episode rew_act: -0.0532
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.11s
#                         Total time: 97.44s
#                                ETA: -95.7s
#
# ################################################################################
#                       Learning iteration 1449/1450
#
#                        Computation: 2430968 steps/s (collection: 0.661s, learning 3.383s)
#                Value function loss: 98.7922
#                     Surrogate loss: -0.0002
#              Mean action noise std: 0.41
#                        Mean reward: -31.08
#                Mean episode length: 60.00
#               Mean episode rew_sum: -0.5224
#               Mean episode rew_act: -0.0518
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.04s
#                         Total time: 101.48s
#                                ETA: -99.7s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=4, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 6903.742731777192
# score     : [ 8890.40937729 10098.42621791  2728.80126317  2643.76399434
#   5999.91489194  9237.29936333  8232.22380002 10100.48028806
#   7480.61820094  9479.15292727  7159.12975934  7994.73862178
#    164.3929774   4909.35337512  6015.86927795  7728.20941696
#   9931.02680321 10431.78822556   635.7162487   6878.06569532
#   9884.18680127 10484.42528763  7261.92028618 10675.50357869
#   7564.64802081  7716.83622233 10964.27485657   393.1648084
#   2790.44400787  7115.88989321  6643.11125921 10621.55469869
#    772.44654744  2197.74693743  2659.31803703   544.46927274
#   1518.85368131 10959.97916781 10106.43359324 10061.52229652
#   8928.3716231   4355.2070207   9493.59356092   217.91489271
#   1007.00243098  4978.67570445 10294.08566208 10502.3657355
#   5820.95969569  7932.7149526  10235.84505208 10696.06717733
#   9422.38274562  9310.91706861 10677.73553314  2790.4307312
#   9670.21155065   283.52400792  4438.85378456  5347.61183523
#  10008.56789207  9662.64986394  2727.58146083  8321.94205958
#   9954.17261098  7668.72867406  8306.95183016  9432.67797775
#   9862.42753779 10862.72430598  4409.05559972  5978.88330243
#  10008.64439952 10708.30005099 10491.54162013 10787.18310165
#   8272.71680323   528.76238403  9064.2821228    805.18015862
#    176.18471959 10803.93670998 10933.94865036    94.52148959
#   9243.60426178  6027.86758512  7552.28990122  3490.36930542
#   9652.57707011  3571.47483304 10120.66104813 10169.17881571
#  10274.64962858  9808.81958275   485.78504651  2642.2916256
#   9392.88720258  9661.06195361   885.62582041  3442.98342628]
# score.mean: 6903.742731777192

# %%
6903.74273177719 * 0.6
# Out:
# 4142.245639066314
