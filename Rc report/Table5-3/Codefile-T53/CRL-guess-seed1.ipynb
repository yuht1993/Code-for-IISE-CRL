# %%
from rsl_rl.env import VecEnv
from rsl_rl.runners import OnPolicyRunner
import torch
import numpy as np
torch.set_printoptions(precision=5, linewidth=200, sci_mode=False)

N          = 100020
state_dim  = 8
action_dim = 5
T          = 60
budget     = 3600.
N_envs     = 1024 * 64
ΔT         = 1.0
device     = 'cuda'
usr_std = 0.01
test_num = 100
seed = 0

parameter_static = dict(N          = N,
                        B          = budget,
                        T          = T,
                        alpha      = 0.6,
                        v_max      = 0.2/14,
                        cost_ti    = 0.0977,
                        cost_ta    = 0.02,
                        cost_v     = 0.07,
                        cost_poc_0 = 0.000369,
                        cost_poc_1 = 0.001057,
                        pid        = 1.10/1000,
                        psr        = 0.7,
                        pid_plus   = 0.1221/1000,
                        pir        = 1/8,
                        prs        = 1/7)

Random_mean = {"beta2" : 0.78735,
               "beta1" : 0.15747,
               "pei"   : 0.10714,
               "per"   : 0.04545}

space = {"beta2" : [Random_mean['beta2'],Random_mean['beta2']*usr_std],
         "beta1" : [Random_mean['beta1'], Random_mean['beta1']*usr_std],
         "pei"   : [Random_mean['pei'], Random_mean['pei']*usr_std],
         "per"   : [Random_mean['per'], Random_mean['per']*usr_std]}

Init_state = torch.tensor([[100000 / N, 20 / N, 0, 0, 0, 0, 1, 0]], 
                         dtype=torch.float32).to(torch.device(device))

# %%
class myVecEnv(VecEnv):
    def __init__(self, interval, n_envs = N_envs):
        self.B = parameter_static['B']  # total budget
        self.N = parameter_static['N']
        self.device = device
        self.init_state = Init_state
        self.states = self.init_state.repeat(n_envs, 1)
        self.num_envs = n_envs
        self.num_obs = state_dim
        self.num_privileged_obs = None
        self.num_actions = action_dim
        self.max_episode_length = parameter_static['T']
        
        torch.manual_seed(seed)
        self.parameter_random = {
            key: torch.empty(self.num_envs).normal_(
                interval[key][0],
                interval[key][1]
            ).to(torch.device(device))
            for key, value in Random_mean.items()
        }

        for key, value in Random_mean.items():
            indice = self.parameter_random[key] < 0
            self.parameter_random[key][indice] = -self.parameter_random[key][indice] 

        # optimization flags for pytorch JIT
        torch._C._jit_set_profiling_mode(False)
        torch._C._jit_set_profiling_executor(False)
        
        # allocate buffers
        self.privileged_obs_buf = None
        self.obs_buf = torch.zeros(self.num_envs, self.num_obs, device=self.device, dtype=torch.float)
        self.rew_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.float)
        self.reset_buf = torch.ones(self.num_envs, device=self.device, dtype=torch.long)
        self.episode_length_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.long)
        
        self.actions = torch.zeros(self.num_envs, self.num_actions, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_sums = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_acts = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.extras = {}
    
    def para_update(self, para):
        self.parameter_random = para
        
    def step(self, actions):
        # actions clip
        soft_bound = [-0.5, 1.5]
        out_of_limits = -(actions - soft_bound[0]).clip(max=0.)
        out_of_limits += (actions - soft_bound[1]).clip(min=0.)
        scale_action = -0.1
        reward_action = scale_action * torch.sum(out_of_limits, dim=1).clip(max=1.).to(self.device)
        self.actions = torch.clip(actions, 0., 1.).to(self.device)

        # update actions & states
        b, p = self.states[:, -2] * self.B, self.states[:, -1]
        inv_c = self.cost_function(self.actions)
        b -= inv_c
        b = torch.clip(b, 0., self.B).to(self.device)
        mask = (b > 0).float().unsqueeze(-1)
        self.act = self.actions * mask
        inv_c = self.cost_function(self.act)
        next_state, reward_original = self.transition(self.act)
        self.extras['reward_original'] = reward_original
        self.extras['inv_cost'] = inv_c
        self.episode_length_buf += 1
        p = self.episode_length_buf / self.max_episode_length
        self.states = torch.cat([next_state / self.N, (b / self.B).unsqueeze(-1), p.unsqueeze(-1)], dim=-1)
        
        # check termination
        self.reset_buf = self.episode_length_buf >= self.max_episode_length
        
        # compute reward
        r_mean = -6584
        r_std  =  7347
        reward = (reward_original - inv_c - r_mean) / r_std
        #if reward > 0: 
        #reward = torch.exp(reward)/10
        #reward = torch.exp((1e5 + reward_original - inv_c) / 5e4)
        self.rew_buf       = reward + reward_action
        self.episode_sums += reward + reward_action
        self.episode_acts += reward_action
        
        # compute resets
        env_ids = self.reset_buf.nonzero(as_tuple=False).flatten()
        self.reset_idx(env_ids)
        
        # compute observations
        return self.get_observations(), self.states, self.rew_buf, self.reset_buf, self.extras

    def reset_idx(self, env_ids):
        """Reset selected robots"""
        if len(env_ids) == 0:
            return
        
        assert len(env_ids) == self.num_envs
        # reset robot states
        self.states[env_ids] = self.init_state
        # reset buffers
        self.episode_length_buf[env_ids] = 0
        self.reset_buf[env_ids] = 1
        # fill extras
        self.extras["episode"] = {}
        self.extras["episode"]['rew_sum'] = torch.mean(self.episode_sums[env_ids]) / (self.max_episode_length * ΔT)
        self.extras["episode"]['rew_act'] = torch.mean(self.episode_acts[env_ids]) / (self.max_episode_length * ΔT)
        self.episode_sums[env_ids] = 0.
        self.episode_acts[env_ids] = 0.
    
    def reset(self):
        """ Reset all robots"""
        self.reset_idx(torch.arange(self.num_envs, device=self.device))
        return {}, {}
    
    def get_observations(self):
        o_mean = torch.tensor([[0.58712867, 0.06804276, 0.00308146, 0.25684301, 0.00261079, 0.08229331, 0.26572794, 0.51      ]], dtype=torch.float32).to(torch.device(self.device))
        o_std  = torch.tensor([[0.41484398, 0.07883003, 0.00389494, 0.292568  , 0.00394907, 0.06906768, 0.33943075, 0.28861739]], dtype=torch.float32).to(torch.device(self.device))
        self.obs_buf = (self.states - o_mean) / o_std
        return self.obs_buf
    
    def get_privileged_observations(self):
        return self.privileged_obs_buf

    def cost_function(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]

        cost_it  = it * u_it * parameter_static['cost_ti']
        cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
        cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
        per_poc  = ((st + et + at + rt) / self.N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
        cost_poc = (st + et + rt + at) * w * per_poc
        return cost_poc + cost_it + cost_v + cost_q

    def transition(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
        ht = st + et + at + it + rt

        st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * self.parameter_random['beta1'] + (et + at * (1 - u_aq)) * self.parameter_random['beta2']) / ht
        st_out_e = st_out * parameter_static['alpha']
        st_out_i = st_out * (1 - parameter_static['alpha'])
        st_out_r = u_sv * parameter_static['v_max'] * st * parameter_static['psr']
        et_out_r = et * self.parameter_random['per']
        et_out_i = et * self.parameter_random['pei']
        et_out_a = et * w * (1 - self.parameter_random['per'] - self.parameter_random['pei'])
        at_out_i = at * self.parameter_random['pei']
        at_out_r = at * self.parameter_random['per']
        it_out_r = it * parameter_static['pir'] * u_it
        it_out_d = it * parameter_static['pid'] * (1 - u_it) + it * u_it * parameter_static['pid_plus']
        rt_out_s = rt * parameter_static['prs']
        
        stn = st - st_out_e - st_out_i - st_out_r + rt_out_s
        etn = et - et_out_r - et_out_i - et_out_a + st_out_e
        atn = at - at_out_r - at_out_i + et_out_a
        itn = it - it_out_r - it_out_d + st_out_i + et_out_i + at_out_i
        dtn = dt + it_out_d
        rtn = rt + et_out_r + at_out_r + it_out_r + st_out_r - rt_out_s

        reward = -2.6 * st_out - 100 * it_out_d

        next_state = torch.stack([stn, etn, atn, itn, dtn, rtn], dim=-1)
        return next_state, reward

# %%
import inspect

class BaseConfig:
    def __init__(self) -> None:
        """ Initializes all member classes recursively. Ignores all namse starting with '__' (buit-in methods)."""
        self.init_member_classes(self)
    
    @staticmethod
    def init_member_classes(obj):
        # iterate over all attributes names
        for key in dir(obj):
            # disregard builtin attributes
            # if key.startswith("__"):
            if key=="__class__":
                continue
            # get the corresponding attribute object
            var =  getattr(obj, key)
            # check if it the attribute is a class
            if inspect.isclass(var):
                # instantate the class
                i_var = var()
                # set the attribute to the instance instead of the type
                setattr(obj, key, i_var)
                # recursively init members of the attribute
                BaseConfig.init_member_classes(i_var)

class LeggedRobotCfgPPO(BaseConfig):
    seed = 1
    runner_class_name = 'OnPolicyRunner'
    class policy:
        init_noise_std = 2
        actor_hidden_dims  = [64, 32, 16] 
        critic_hidden_dims = [64, 32, 16]
        activation = 'elu' # can be elu, relu, selu, crelu, lrelu, tanh, sigmoid
        # only for 'ActorCriticRecurrent':
        # rnn_type = 'lstm'
        # rnn_hidden_size = 512
        # rnn_num_layers = 1
        
    class algorithm:
        # training params
        value_loss_coef = 0.5
        use_clipped_value_loss = True
        clip_param = 0.2
        entropy_coef = 0.01
        num_learning_epochs = 5
        num_mini_batches = 64 # mini batch size = num_envs*nsteps / nminibatches
        learning_rate = 1.e-4
        schedule = 'adaptive' # could be adaptive, fixed
        gamma = 0.99
        lam = 0.95
        desired_kl = 0.01
        max_grad_norm = 1.

    class runner:
        policy_class_name = 'ActorCritic'
        algorithm_class_name = 'PPO'
        num_steps_per_env =  150 # per iteration
        max_iterations    = 100 # number of policy updates

        # logging
        save_interval = 100 # check for potential saves every this many iterations
        experiment_name = 'test'
        run_name = ''
        # load and resume
        resume = True
        load_run = -1 # -1 = last run
        checkpoint = -1 # -1 = last saved model
        resume_path = None # updated from load_run and chkpt
        
def class_to_dict(obj) -> dict:
    if not  hasattr(obj,"__dict__"):
        return obj
    result = {}
    for key in dir(obj):
        if key.startswith("_"):
            continue
        element = []
        val = getattr(obj, key)
        if isinstance(val, list):
            for item in val:
                element.append(class_to_dict(item))
        else:
            element = class_to_dict(val)
        result[key] = element
    return result

# %%
def para_sampling(intvl, num_sample=N_envs):
    parameter_random = {
        key: torch.empty(num_sample).normal_(
        intvl[key][0],
        intvl[key][1]
        ).to(torch.device(device))
        for key, value in Random_mean.items()
    }
    for key, value in Random_mean.items():
        indice = parameter_random[key] < 0
        parameter_random[key][indice] = -parameter_random[key][indice] 
    return parameter_random

def update_space(final_indices, para_buf, space):
    para_est = {}
    for key, tensor_values in para_buf.items():
        selected_values = torch.mean(tensor_values[final_indices[0], final_indices[1]]) 
        para_values = torch.mean(tensor_values[final_indices[0], final_indices[1]], dim=0)
        update_values = space[key][0] + 0.5 * (selected_values - space[key][0])

        para_est[key] = para_values
    return space, para_est


def cal_err(para_value, env_para):
    gap = []
    for key, value in env_para.items():
        gap_temp = torch.mean(torch.abs(para_value[key] - env_para[key])/(env_para[key]))
        gap.append(gap_temp)
    return sum(gap)/len(gap) # 所有值都在范围内，返回 0
    
def state_estimator(env_sample, action_sim, state_sim, state_prior, space, iter): 
    env_sample.reset()
    env_sample.states = state_prior  
    para_buf, mse_buf, obs_buf, states_buf = {}, {}, {}, {}
    for i in range(iter):
        para = para_sampling(space, test_num)
        env_sample.para_update(para)
        obs_sample, states_sample, _, _, _ = env_sample.step(action_sim.detach())  
        mse = torch.mean((state_sim[:,2:4] - states_sample[:,2:4]) ** 2, dim=1) 
        if i == 0:
            mse_buf = mse.unsqueeze(0)
            obs_buf = obs_sample.unsqueeze(0)
            states_buf = states_sample.unsqueeze(0)
            for key, values in para.items():
                para_buf[key] = para[key].unsqueeze(0)
        else:
            mse_buf = torch.cat((mse_buf, mse.unsqueeze(0)), dim=0)
            obs_buf = torch.cat((obs_buf, obs_sample.unsqueeze(0)),dim=0)
            states_buf = torch.cat((states_buf, states_sample.unsqueeze(0)), dim=0)
            for key, values in para.items():
                para_buf[key] = torch.cat((para_buf[key], para[key].unsqueeze(0)), dim=0)
                
     
    k = int(iter * 0.05)
    _, row_indices = torch.topk(mse_buf, k=k, dim=0, largest=False)
    column_indices = torch.arange(mse_buf.shape[1]).repeat(k, 1)
    top_indices = [row_indices, column_indices]
    obs_est = torch.mean(obs_buf[row_indices,column_indices,:], dim=0)
    state_est = torch.mean(states_buf[row_indices,column_indices,:], dim=0)
    state_est[:,-1] = state_prior[:,-1] + torch.tensor(1/T)
    return obs_est, state_est, top_indices, para_buf

# %%
para_err = 0.5
torch.manual_seed(seed)
para_true = []
para_temp = {
    key: torch.empty(test_num).uniform_(
        value * (1-para_err),
        value * (1+para_err)
    ).to(torch.device(device))
    for key, value in Random_mean.items()
}


para = {}
for t in range(T):
    para = {
        key: (para_temp[key] - para_temp[key] * torch.sin(torch.tensor(t/(3.1415926 * 3))) * 0.25).to(torch.device(device))
        for key, value in Random_mean.items()
        }
    para_true.append(para)

# %%
env = myVecEnv(space, test_num)
env.para_update(para_true[0])
train_cfg = LeggedRobotCfgPPO()
train_cfg_dict = class_to_dict(train_cfg)


env_transfer = myVecEnv(space)
runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_test', device=env.device)
runner.load(f'rsl_output_main/model_100.pt')

policy = runner.get_inference_policy(device=env.device)

reward_history = []
act_buf = []
state_his_buf = []
death_buf = []

env_sample = myVecEnv(space, test_num)
state_est = env.states
obs_est = env.get_observations()
for t in range(T-1):
    actions = policy(obs_est.detach())
    obs, states, _, _, infos = env.step(actions.detach())
    reward_history.append((-infos['reward_original'] + infos['inv_cost']).tolist())
    death_buf.append((-infos['reward_original']).tolist())
    act_buf.append(env.act)
    state_his_buf.append(env.states)
    obs_est, state_buf, top_indices, para_buf = state_estimator(env_sample, actions, states, state_est, space, 1024)
    # space, para_v = update_space(top_indices, para_buf, space) 

    runner.learn(num_learning_iterations=25, init_at_random_ep_len=False)
    policy = runner.get_inference_policy(device=env.device)
    env_transfer = myVecEnv(space)
    runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_test', device=env.device)
    runner.load(f'rsl_test/model_{int(t)* 25}.pt')
        

    if t < T - 1: env.para_update(para_true[t + 1])
    print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
env.reset()

reward_history = np.array(reward_history)
print(f'score     : {np.sum(reward_history, axis=0)/T       }')
print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
# Out:
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2306951 steps/s (collection: 0.670s, learning 3.591s)
#                Value function loss: 142.5378
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.63
#                        Mean reward: 45.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4641
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.26s
#                         Total time: 4.26s
#                                ETA: 106.5s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2400013 steps/s (collection: 0.646s, learning 3.450s)
#                Value function loss: 144.6782
#                     Surrogate loss: 0.0007
#              Mean action noise std: 4.69
#                        Mean reward: 46.00
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7657
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.10s
#                         Total time: 8.36s
#                                ETA: 100.3s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2363463 steps/s (collection: 0.672s, learning 3.487s)
#                Value function loss: 131.0451
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.76
#                        Mean reward: 45.80
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7668
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.16s
#                         Total time: 12.52s
#                                ETA: 96.0s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2418374 steps/s (collection: 0.649s, learning 3.416s)
#                Value function loss: 131.8155
#                     Surrogate loss: 0.0007
#              Mean action noise std: 4.81
#                        Mean reward: 45.82
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7668
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.06s
#                         Total time: 16.58s
#                                ETA: 91.2s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2439634 steps/s (collection: 0.634s, learning 3.396s)
#                Value function loss: 120.9523
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.87
#                        Mean reward: 45.80
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7668
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.03s
#                         Total time: 20.61s
#                                ETA: 86.6s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2436562 steps/s (collection: 0.639s, learning 3.396s)
#                Value function loss: 121.5071
#                     Surrogate loss: 0.0031
#              Mean action noise std: 4.94
#                        Mean reward: 46.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7649
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.03s
#                         Total time: 24.65s
#                                ETA: 82.2s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2434441 steps/s (collection: 0.640s, learning 3.398s)
#                Value function loss: 114.3146
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.00
#                        Mean reward: 45.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7639
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.04s
#                         Total time: 28.68s
#                                ETA: 77.9s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2422793 steps/s (collection: 0.635s, learning 3.423s)
#                Value function loss: 115.2126
#                     Surrogate loss: 0.0009
#              Mean action noise std: 5.08
#                        Mean reward: 46.04
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7645
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.06s
#                         Total time: 32.74s
#                                ETA: 73.7s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2435416 steps/s (collection: 0.640s, learning 3.397s)
#                Value function loss: 110.0399
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.15
#                        Mean reward: 45.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7633
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.04s
#                         Total time: 36.78s
#                                ETA: 69.5s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2430771 steps/s (collection: 0.636s, learning 3.408s)
#                Value function loss: 110.2140
#                     Surrogate loss: 0.0026
#              Mean action noise std: 5.21
#                        Mean reward: 45.59
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7630
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.04s
#                         Total time: 40.82s
#                                ETA: 65.3s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2386256 steps/s (collection: 0.647s, learning 3.473s)
#                Value function loss: 104.9139
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.28
#                        Mean reward: 45.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7605
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.12s
#                         Total time: 44.94s
#                                ETA: 61.3s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2367106 steps/s (collection: 0.654s, learning 3.499s)
#                Value function loss: 104.5630
#                     Surrogate loss: 0.0011
#              Mean action noise std: 5.35
#                        Mean reward: 45.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7586
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.15s
#                         Total time: 49.09s
#                                ETA: 57.3s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2381948 steps/s (collection: 0.654s, learning 3.473s)
#                Value function loss: 101.6371
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.43
#                        Mean reward: 45.93
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7586
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.13s
#                         Total time: 53.22s
#                                ETA: 53.2s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2382911 steps/s (collection: 0.656s, learning 3.469s)
#                Value function loss: 102.0143
#                     Surrogate loss: 0.0001
#              Mean action noise std: 5.50
#                        Mean reward: 45.26
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7595
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.13s
#                         Total time: 57.35s
#                                ETA: 49.2s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2385410 steps/s (collection: 0.640s, learning 3.481s)
#                Value function loss: 94.8475
#                     Surrogate loss: -0.0001
#              Mean action noise std: 5.56
#                        Mean reward: 45.41
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7599
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.12s
#                         Total time: 61.47s
#                                ETA: 45.1s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2400726 steps/s (collection: 0.658s, learning 3.437s)
#                Value function loss: 111.2999
#                     Surrogate loss: 0.0010
#              Mean action noise std: 5.64
#                        Mean reward: 45.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7597
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.09s
#                         Total time: 65.56s
#                                ETA: 41.0s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2277853 steps/s (collection: 0.633s, learning 3.683s)
#                Value function loss: 107.3011
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.72
#                        Mean reward: 45.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7585
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.32s
#                         Total time: 69.88s
#                                ETA: 37.0s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2160339 steps/s (collection: 0.725s, learning 3.825s)
#                Value function loss: 115.9443
#                     Surrogate loss: 0.0006
#              Mean action noise std: 5.80
#                        Mean reward: 45.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7565
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.55s
#                         Total time: 74.43s
#                                ETA: 33.1s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2249967 steps/s (collection: 0.750s, learning 3.619s)
#                Value function loss: 118.1301
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.88
#                        Mean reward: 45.37
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7555
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.37s
#                         Total time: 78.80s
#                                ETA: 29.0s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2351033 steps/s (collection: 0.650s, learning 3.531s)
#                Value function loss: 137.7706
#                     Surrogate loss: 0.0020
#              Mean action noise std: 5.96
#                        Mean reward: 45.76
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7562
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.18s
#                         Total time: 82.98s
#                                ETA: 24.9s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2369923 steps/s (collection: 0.670s, learning 3.478s)
#                Value function loss: 146.2068
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.04
#                        Mean reward: 45.68
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7553
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.15s
#                         Total time: 87.13s
#                                ETA: 20.7s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2297328 steps/s (collection: 0.663s, learning 3.616s)
#                Value function loss: 164.4678
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.11
#                        Mean reward: 45.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7534
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.28s
#                         Total time: 91.41s
#                                ETA: 16.6s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2377573 steps/s (collection: 0.640s, learning 3.495s)
#                Value function loss: 175.4398
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.20
#                        Mean reward: 45.37
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7524
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.13s
#                         Total time: 95.54s
#                                ETA: 12.5s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2354697 steps/s (collection: 0.660s, learning 3.514s)
#                Value function loss: 202.2828
#                     Surrogate loss: 0.0008
#              Mean action noise std: 6.28
#                        Mean reward: 45.45
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7526
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.17s
#                         Total time: 99.72s
#                                ETA: 8.3s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2369624 steps/s (collection: 0.661s, learning 3.487s)
#                Value function loss: 204.6421
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.35
#                        Mean reward: 45.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7535
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.15s
#                         Total time: 103.86s
#                                ETA: 4.2s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 3.0514750366210937
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2375052 steps/s (collection: 0.700s, learning 3.439s)
#                Value function loss: 135.3860
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.69
#                        Mean reward: 45.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4647
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.14s
#                         Total time: 4.14s
#                                ETA: 103.5s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2418886 steps/s (collection: 0.645s, learning 3.419s)
#                Value function loss: 137.9040
#                     Surrogate loss: 0.0013
#              Mean action noise std: 4.75
#                        Mean reward: 45.97
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7668
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.06s
#                         Total time: 8.20s
#                                ETA: 98.4s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2412162 steps/s (collection: 0.655s, learning 3.420s)
#                Value function loss: 126.9650
#                     Surrogate loss: 0.0005
#              Mean action noise std: 4.82
#                        Mean reward: 45.77
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7676
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.08s
#                         Total time: 12.28s
#                                ETA: 94.1s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2430910 steps/s (collection: 0.641s, learning 3.403s)
#                Value function loss: 131.9949
#                     Surrogate loss: 0.0007
#              Mean action noise std: 4.88
#                        Mean reward: 45.76
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7670
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.04s
#                         Total time: 16.32s
#                                ETA: 89.8s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2415777 steps/s (collection: 0.647s, learning 3.422s)
#                Value function loss: 123.9039
#                     Surrogate loss: 0.0002
#              Mean action noise std: 4.95
#                        Mean reward: 46.15
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7669
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.07s
#                         Total time: 20.39s
#                                ETA: 85.6s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2389100 steps/s (collection: 0.672s, learning 3.443s)
#                Value function loss: 125.7011
#                     Surrogate loss: 0.0005
#              Mean action noise std: 5.03
#                        Mean reward: 46.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7661
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.11s
#                         Total time: 24.51s
#                                ETA: 81.7s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2329318 steps/s (collection: 0.630s, learning 3.590s)
#                Value function loss: 116.8382
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.10
#                        Mean reward: 45.74
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7658
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.22s
#                         Total time: 28.73s
#                                ETA: 78.0s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2327394 steps/s (collection: 0.644s, learning 3.580s)
#                Value function loss: 117.2138
#                     Surrogate loss: 0.0013
#              Mean action noise std: 5.17
#                        Mean reward: 45.98
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7652
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 78643200
#                     Iteration time: 4.22s
#                         Total time: 32.95s
#                                ETA: 74.1s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2330133 steps/s (collection: 0.636s, learning 3.583s)
#                Value function loss: 111.3942
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.24
#                        Mean reward: 45.67
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7639
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.22s
#                         Total time: 37.17s
#                                ETA: 70.2s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2329168 steps/s (collection: 0.645s, learning 3.576s)
#                Value function loss: 112.6685
#                     Surrogate loss: 0.0025
#              Mean action noise std: 5.29
#                        Mean reward: 45.95
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7641
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.22s
#                         Total time: 41.39s
#                                ETA: 66.2s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2324682 steps/s (collection: 0.642s, learning 3.587s)
#                Value function loss: 107.7571
#                     Surrogate loss: 0.0005
#              Mean action noise std: 5.36
#                        Mean reward: 45.68
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7636
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.23s
#                         Total time: 45.62s
#                                ETA: 62.2s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2324251 steps/s (collection: 0.637s, learning 3.593s)
#                Value function loss: 108.1558
#                     Surrogate loss: 0.0004
#              Mean action noise std: 5.43
#                        Mean reward: 45.76
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7619
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.23s
#                         Total time: 49.85s
#                                ETA: 58.2s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2333064 steps/s (collection: 0.637s, learning 3.577s)
#                Value function loss: 104.4051
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.50
#                        Mean reward: 45.81
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7598
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.21s
#                         Total time: 54.06s
#                                ETA: 54.1s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2282110 steps/s (collection: 0.653s, learning 3.655s)
#                Value function loss: 104.4591
#                     Surrogate loss: 0.0021
#              Mean action noise std: 5.58
#                        Mean reward: 45.55
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7598
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.31s
#                         Total time: 58.37s
#                                ETA: 50.0s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2393316 steps/s (collection: 0.639s, learning 3.469s)
#                Value function loss: 101.2231
#                     Surrogate loss: 0.0003
#              Mean action noise std: 5.66
#                        Mean reward: 45.47
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7598
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.11s
#                         Total time: 62.48s
#                                ETA: 45.8s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2384174 steps/s (collection: 0.651s, learning 3.472s)
#                Value function loss: 100.4154
#                     Surrogate loss: 0.0009
#              Mean action noise std: 5.74
#                        Mean reward: 45.42
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7593
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.12s
#                         Total time: 66.60s
#                                ETA: 41.6s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2350113 steps/s (collection: 0.661s, learning 3.522s)
#                Value function loss: 98.0407
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.82
#                        Mean reward: 44.91
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7573
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.18s
#                         Total time: 70.78s
#                                ETA: 37.5s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2383538 steps/s (collection: 0.646s, learning 3.478s)
#                Value function loss: 96.8685
#                     Surrogate loss: 0.0007
#              Mean action noise std: 5.90
#                        Mean reward: 44.79
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7559
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.12s
#                         Total time: 74.91s
#                                ETA: 33.3s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2385155 steps/s (collection: 0.639s, learning 3.482s)
#                Value function loss: 94.2241
#                     Surrogate loss: 0.0002
#              Mean action noise std: 5.98
#                        Mean reward: 45.23
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7539
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.12s
#                         Total time: 79.03s
#                                ETA: 29.1s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2378873 steps/s (collection: 0.655s, learning 3.478s)
#                Value function loss: 95.5160
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.05
#                        Mean reward: 45.50
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7531
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.13s
#                         Total time: 83.16s
#                                ETA: 24.9s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2396584 steps/s (collection: 0.662s, learning 3.440s)
#                Value function loss: 94.0861
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.12
#                        Mean reward: 45.50
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7512
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.10s
#                         Total time: 87.26s
#                                ETA: 20.8s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2425200 steps/s (collection: 0.651s, learning 3.402s)
#                Value function loss: 103.0963
#                     Surrogate loss: 0.0006
#              Mean action noise std: 6.18
#                        Mean reward: 45.32
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7502
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.05s
#                         Total time: 91.32s
#                                ETA: 16.6s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2418117 steps/s (collection: 0.642s, learning 3.423s)
#                Value function loss: 105.1442
#                     Surrogate loss: 0.0010
#              Mean action noise std: 6.27
#                        Mean reward: 45.76
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7542
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.07s
#                         Total time: 95.38s
#                                ETA: 12.4s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2424720 steps/s (collection: 0.647s, learning 3.407s)
#                Value function loss: 109.2508
#                     Surrogate loss: 0.0001
#              Mean action noise std: 6.35
#                        Mean reward: 45.52
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7560
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 4.05s
#                         Total time: 99.44s
#                                ETA: 8.3s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2300531 steps/s (collection: 0.666s, learning 3.607s)
#                Value function loss: 110.1235
#                     Surrogate loss: 0.0003
#              Mean action noise std: 6.44
#                        Mean reward: 45.48
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7561
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 4.27s
#                         Total time: 103.71s
#                                ETA: 4.1s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 5.785346303304037
# ################################################################################
#                         Learning iteration 25/50
#
#                        Computation: 2370686 steps/s (collection: 0.715s, learning 3.431s)
#                Value function loss: 113.5468
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.52
#                        Mean reward: 45.34
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4582
#               Mean episode rew_act: -0.0607
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 4.15s
#                         Total time: 4.15s
#                                ETA: 0.0s
#
# ################################################################################
#                         Learning iteration 26/50
#
#                        Computation: 2414550 steps/s (collection: 0.681s, learning 3.390s)
#                Value function loss: 123.6746
#                     Surrogate loss: 0.0005
#              Mean action noise std: 6.60
#                        Mean reward: 45.48
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7549
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 19660800
#                     Iteration time: 4.07s
#                         Total time: 8.22s
#                                ETA: -0.3s
#
# ################################################################################
#                         Learning iteration 27/50
#
#                        Computation: 2447654 steps/s (collection: 0.636s, learning 3.380s)
#                Value function loss: 124.4296
#                     Surrogate loss: 0.0008
#              Mean action noise std: 6.69
#                        Mean reward: 44.61
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7550
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 29491200
#                     Iteration time: 4.02s
#                         Total time: 12.23s
#                                ETA: -0.9s
#
# ################################################################################
#                         Learning iteration 28/50
#
#                        Computation: 2449672 steps/s (collection: 0.638s, learning 3.375s)
#                Value function loss: 136.1665
#                     Surrogate loss: 0.0007
#              Mean action noise std: 6.77
#                        Mean reward: 45.48
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7560
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 39321600
#                     Iteration time: 4.01s
#                         Total time: 16.25s
#                                ETA: -1.7s
#
# ################################################################################
#                         Learning iteration 29/50
#
#                        Computation: 2430864 steps/s (collection: 0.663s, learning 3.381s)
#                Value function loss: 137.4402
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.85
#                        Mean reward: 45.18
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7574
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 49152000
#                     Iteration time: 4.04s
#                         Total time: 20.29s
#                                ETA: -2.7s
#
# ################################################################################
#                         Learning iteration 30/50
#
#                        Computation: 2444832 steps/s (collection: 0.636s, learning 3.385s)
#                Value function loss: 153.8186
#                     Surrogate loss: 0.0002
#              Mean action noise std: 6.94
#                        Mean reward: 45.35
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7569
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 58982400
#                     Iteration time: 4.02s
#                         Total time: 24.31s
#                                ETA: -3.9s
#
# ################################################################################
#                         Learning iteration 31/50
#
#                        Computation: 2448107 steps/s (collection: 0.636s, learning 3.380s)
#                Value function loss: 148.0701
#                     Surrogate loss: 0.0003
#              Mean action noise std: 7.03
#                        Mean reward: 45.53
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7580
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 68812800
#                     Iteration time: 4.02s
#                         Total time: 28.33s
#                                ETA: -5.3s
#
# ################################################################################
#                         Learning iteration 32/50
#
#                        Computation: 2436061 steps/s (collection: 0.640s, learning 3.395s)
#                Value function loss: 165.2604
#                     Surrogate loss: 0.0010
#              Mean action noise std: 7.12
#                        Mean reward: 45.62
# ...
#                    Total timesteps: 78643200
#                     Iteration time: 4.07s
#                         Total time: 32.05s
#                                ETA: -31.5s
#
# ################################################################################
#                       Learning iteration 1433/1450
#
#                        Computation: 2345115 steps/s (collection: 0.643s, learning 3.549s)
#                Value function loss: 232.2529
#                     Surrogate loss: 0.0002
#              Mean action noise std: 2992.96
#                        Mean reward: 47.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7864
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 88473600
#                     Iteration time: 4.19s
#                         Total time: 36.24s
#                                ETA: -35.6s
#
# ################################################################################
#                       Learning iteration 1434/1450
#
#                        Computation: 2348340 steps/s (collection: 0.637s, learning 3.549s)
#                Value function loss: 268.5548
#                     Surrogate loss: 0.0002
#              Mean action noise std: 2995.70
#                        Mean reward: 47.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7864
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 4.19s
#                         Total time: 40.43s
#                                ETA: -39.7s
#
# ################################################################################
#                       Learning iteration 1435/1450
#
#                        Computation: 2346867 steps/s (collection: 0.645s, learning 3.544s)
#                Value function loss: 237.3571
#                     Surrogate loss: 0.0001
#              Mean action noise std: 2998.64
#                        Mean reward: 47.15
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7862
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 108134400
#                     Iteration time: 4.19s
#                         Total time: 44.62s
#                                ETA: -43.8s
#
# ################################################################################
#                       Learning iteration 1436/1450
#
#                        Computation: 2331415 steps/s (collection: 0.661s, learning 3.556s)
#                Value function loss: 274.5431
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3001.39
#                        Mean reward: 47.18
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7861
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 117964800
#                     Iteration time: 4.22s
#                         Total time: 48.83s
#                                ETA: -48.0s
#
# ################################################################################
#                       Learning iteration 1437/1450
#
#                        Computation: 2353576 steps/s (collection: 0.633s, learning 3.543s)
#                Value function loss: 241.0012
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3004.27
#                        Mean reward: 47.13
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7860
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 127795200
#                     Iteration time: 4.18s
#                         Total time: 53.01s
#                                ETA: -52.1s
#
# ################################################################################
#                       Learning iteration 1438/1450
#
#                        Computation: 2349931 steps/s (collection: 0.653s, learning 3.530s)
#                Value function loss: 281.6109
#                     Surrogate loss: -0.0000
#              Mean action noise std: 3007.15
#                        Mean reward: 47.11
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7858
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 137625600
#                     Iteration time: 4.18s
#                         Total time: 57.19s
#                                ETA: -56.2s
#
# ################################################################################
#                       Learning iteration 1439/1450
#
#                        Computation: 2353226 steps/s (collection: 0.646s, learning 3.532s)
#                Value function loss: 246.5474
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3010.10
#                        Mean reward: 47.19
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7858
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 147456000
#                     Iteration time: 4.18s
#                         Total time: 61.37s
#                                ETA: -60.3s
#
# ################################################################################
#                       Learning iteration 1440/1450
#
#                        Computation: 2389868 steps/s (collection: 0.649s, learning 3.464s)
#                Value function loss: 286.1656
#                     Surrogate loss: 0.0007
#              Mean action noise std: 3012.88
#                        Mean reward: 47.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7858
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 157286400
#                     Iteration time: 4.11s
#                         Total time: 65.49s
#                                ETA: -64.3s
#
# ################################################################################
#                       Learning iteration 1441/1450
#
#                        Computation: 2432040 steps/s (collection: 0.641s, learning 3.402s)
#                Value function loss: 250.7582
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3015.82
#                        Mean reward: 47.19
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7859
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 167116800
#                     Iteration time: 4.04s
#                         Total time: 69.53s
#                                ETA: -68.3s
#
# ################################################################################
#                       Learning iteration 1442/1450
#
#                        Computation: 2429604 steps/s (collection: 0.637s, learning 3.409s)
#                Value function loss: 294.7094
#                     Surrogate loss: 0.0004
#              Mean action noise std: 3018.58
#                        Mean reward: 47.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7861
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 176947200
#                     Iteration time: 4.05s
#                         Total time: 73.57s
#                                ETA: -72.2s
#
# ################################################################################
#                       Learning iteration 1443/1450
#
#                        Computation: 2429033 steps/s (collection: 0.642s, learning 3.405s)
#                Value function loss: 256.2546
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3021.48
#                        Mean reward: 47.19
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7861
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 186777600
#                     Iteration time: 4.05s
#                         Total time: 77.62s
#                                ETA: -76.2s
#
# ################################################################################
#                       Learning iteration 1444/1450
#
#                        Computation: 2433470 steps/s (collection: 0.640s, learning 3.399s)
#                Value function loss: 301.0140
#                     Surrogate loss: -0.0000
#              Mean action noise std: 3024.30
#                        Mean reward: 47.11
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7860
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 4.04s
#                         Total time: 81.66s
#                                ETA: -80.2s
#
# ################################################################################
#                       Learning iteration 1445/1450
#
#                        Computation: 2417471 steps/s (collection: 0.657s, learning 3.410s)
#                Value function loss: 265.0658
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3027.27
#                        Mean reward: 47.23
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7860
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 206438400
#                     Iteration time: 4.07s
#                         Total time: 85.73s
#                                ETA: -84.2s
#
# ################################################################################
#                       Learning iteration 1446/1450
#
#                        Computation: 2428833 steps/s (collection: 0.642s, learning 3.405s)
#                Value function loss: 315.2523
#                     Surrogate loss: 0.0005
#              Mean action noise std: 3030.06
#                        Mean reward: 47.14
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7861
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 216268800
#                     Iteration time: 4.05s
#                         Total time: 89.77s
#                                ETA: -88.2s
#
# ################################################################################
#                       Learning iteration 1447/1450
#
#                        Computation: 2444500 steps/s (collection: 0.652s, learning 3.369s)
#                Value function loss: 272.4731
#                     Surrogate loss: 0.0000
#              Mean action noise std: 3032.95
#                        Mean reward: 47.16
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7861
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 226099200
#                     Iteration time: 4.02s
#                         Total time: 93.80s
#                                ETA: -92.1s
#
# ################################################################################
#                       Learning iteration 1448/1450
#
#                        Computation: 2483436 steps/s (collection: 0.634s, learning 3.324s)
#                Value function loss: 328.1268
#                     Surrogate loss: -0.0000
#              Mean action noise std: 3035.73
#                        Mean reward: 47.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7863
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 235929600
#                     Iteration time: 3.96s
#                         Total time: 97.75s
#                                ETA: -96.0s
#
# ################################################################################
#                       Learning iteration 1449/1450
#
#                        Computation: 2475044 steps/s (collection: 0.645s, learning 3.327s)
#                Value function loss: 286.8627
#                     Surrogate loss: 0.0001
#              Mean action noise std: 3038.51
#                        Mean reward: 47.24
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7864
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 245760000
#                     Iteration time: 3.97s
#                         Total time: 101.73s
#                                ETA: -99.9s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: 2600.8104184910208
# score     : [2865.97416497 5650.70841672  304.74580374  287.60566969  544.17492251
#  2905.6888263  2009.69998049 5173.8655863  1024.74068164 3170.69775168
#  1313.46729569 3277.35299793   79.45185942 1198.47191432 1320.45345771
#  1220.61408289 5053.03874199 5742.37506502  183.08111289 1769.74697803
#  3951.18283285 5540.8097215   454.8580071  5964.01035593 1247.6749717
#   809.79643479 6070.61140771  110.47774345  260.55268507  937.12458752
#   667.16583966 5911.39520143  119.15430037  284.1033112   480.38697503
#   154.4625125   228.90911296 6023.11688507 4217.30937543 5535.01185049
#  2956.91350531  671.57836273 3965.64664511  105.64220813  116.30226363
#   459.1356619  5773.8198088  4095.0537282   350.44406653 1383.80858395
#  4598.13929261 5663.2031781  5101.16328929 3543.559692   5979.04424404
#   159.37872844 5021.25250923   87.57647423  587.81154334  629.32420679
#  4710.73543782 5171.09785306  128.40521981  660.70687452 5259.90134732
#  1898.97570807 1956.35024559 5230.47424261 4917.74061511 5934.71170535
#  1054.49744568  639.82834876 5560.34477415 5917.18065053 6053.3979601
#  6362.95200528 1129.84987261  120.44460751 3272.7098127   108.98927422
#   109.74821808 6276.84396245 6161.52500689  107.69250836 2769.81275183
#   845.00412336 1607.14978666  263.03173968 3068.27449344  745.65251884
#  4764.90557123 5679.52051936 5452.54111427 3973.14570648  106.94085549
#   216.18136643 1574.15830799 4438.63086743  131.21776262  386.90325338]
# score.mean: 2600.8104184910208

# %%
a = np.sum(reward_history, axis=0)/T

# %%
min(a)
# Out:
# 79.45185941755771

# %%
max(a)
# Out:
# 6362.95200527509

# %%
np.std(a)
# Out:
# 2271.3848127665196

# %%
exp_result = {
    'reward_total': reward_history,
    'reward_peo': death_buf,
    'state': state_his_buf,
    'action': act_buf
}

# %%
torch.save(exp_result, 'mid_budget_result.pt')

# %%
2600.8104184910208 * 0.6
# Out:
# 1560.4862510946125
