# %%
from rsl_rl.env import VecEnv
from rsl_rl.runners import OnPolicyRunner
import torch
import numpy as np
torch.set_printoptions(precision=5, linewidth=200, sci_mode=False)

# %%
loaded_params = torch.load("calibrated_parameters.pt")
T=60
device = 'cuda:0'
para_true = []
for t in range(T):
    # Extract the scalar for day t, and use .view(1) to maintain compatibility 
    # with the vectorized environment (myVecEnv)
    day_params = {
        "beta1": loaded_params["beta1"][t].view(1).to(device),
        "beta2": loaded_params["beta2"][t].view(1).to(device),
        "pei":   loaded_params["pei"][t].view(1).to(device),
        "per":   loaded_params["per"][t].view(1).to(device)
    }
    para_true.append(day_params)

# %%
N          = 100020
state_dim  = 8
action_dim = 5
budget     = 6.
N_envs     = 1024 * 64
ΔT         = 1.0

usr_std = 0.01
test_num = 1
seed = 0

parameter_static = dict(N          = N,
                        B          = budget,
                        T          = T,
                        alpha      = 0.6,
                        v_max      = 0.2/14,
                        cost_ti    = 0.0977,
                        cost_ta    = 0.02,
                        cost_v     = 0.07,
                        cost_poc_0 = 0.000369,
                        cost_poc_1 = 0.001057,
                        pid        = 1.10/1000,
                        psr        = 0.7,
                        pid_plus   = 0.1221/1000,
                        pir        = 1/8,
                        prs        = 1/7)

Random_mean = {"beta2" : para_true[0]['beta2'][0].to(device).item(),
               "beta1" : para_true[0]['beta1'][0].to(device).item(),
               "pei"   : para_true[0]['pei'][0].to(device).item(),
               "per"   : para_true[0]['per'][0].to(device).item()}

space = {"beta2" : [Random_mean['beta2'],Random_mean['beta2']*usr_std],
         "beta1" : [Random_mean['beta1'], Random_mean['beta1']*usr_std],
         "pei"   : [Random_mean['pei'], Random_mean['pei']*usr_std],
         "per"   : [Random_mean['per'], Random_mean['per']*usr_std]}

Init_state = torch.tensor([[100000 / N, 20 / N, 0, 0, 0, 0, 1, 0]], 
                         dtype=torch.float32).to(torch.device(device))

# %%
class myVecEnv(VecEnv):
    def __init__(self, interval, n_envs = N_envs):
        self.B = parameter_static['B']  # total budget
        self.N = parameter_static['N']
        self.device = device
        self.init_state = Init_state
        self.states = self.init_state.repeat(n_envs, 1)
        self.num_envs = n_envs
        self.num_obs = state_dim
        self.num_privileged_obs = None
        self.num_actions = action_dim
        self.max_episode_length = parameter_static['T']
        
        torch.manual_seed(seed)
        self.parameter_random = {
            key: torch.empty(self.num_envs).normal_(
                interval[key][0],
                interval[key][1]
            ).to(torch.device(device))
            for key, value in Random_mean.items()
        }

        for key, value in Random_mean.items():
            indice = self.parameter_random[key] < 0
            self.parameter_random[key][indice] = -self.parameter_random[key][indice] 

        # optimization flags for pytorch JIT
        torch._C._jit_set_profiling_mode(False)
        torch._C._jit_set_profiling_executor(False)
        
        # allocate buffers
        self.privileged_obs_buf = None
        self.obs_buf = torch.zeros(self.num_envs, self.num_obs, device=self.device, dtype=torch.float)
        self.rew_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.float)
        self.reset_buf = torch.ones(self.num_envs, device=self.device, dtype=torch.long)
        self.episode_length_buf = torch.zeros(self.num_envs, device=self.device, dtype=torch.long)
        
        self.actions = torch.zeros(self.num_envs, self.num_actions, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_sums = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.episode_acts = torch.zeros(self.num_envs, dtype=torch.float, device=self.device, requires_grad=False)
        self.extras = {}
    
    def para_update(self, para):
        # Ensure all incoming tensors are moved to the environment's device
        self.parameter_random = {
            k: (v.to(self.device) if isinstance(v, torch.Tensor) else v) 
            for k, v in para.items()
        }
        
    def step(self, actions):
        # actions clip
        soft_bound = [-0.5, 1.5]
        out_of_limits = -(actions - soft_bound[0]).clip(max=0.)
        out_of_limits += (actions - soft_bound[1]).clip(min=0.)
        scale_action = -0.1
        reward_action = scale_action * torch.sum(out_of_limits, dim=1).clip(max=1.).to(self.device)
        self.actions = torch.clip(actions, 0., 1.).to(self.device)

        # update actions & states
        b, p = self.states[:, -2] * self.B, self.states[:, -1]
        inv_c = self.cost_function(self.actions)
        b -= inv_c
        b = torch.clip(b, 0., self.B).to(self.device)
        mask = (b > 0).float().unsqueeze(-1)
        self.act = self.actions * mask
        inv_c = self.cost_function(self.act)
        next_state, reward_original = self.transition(self.act)
        self.extras['reward_original'] = reward_original
        self.extras['inv_cost'] = inv_c
        self.episode_length_buf += 1
        p = self.episode_length_buf / self.max_episode_length
        self.states = torch.cat([next_state / self.N, (b / self.B).unsqueeze(-1), p.unsqueeze(-1)], dim=-1)
        
        # check termination
        self.reset_buf = self.episode_length_buf >= self.max_episode_length
        
        # compute reward
        r_mean = -6584
        r_std  =  7347
        reward = (reward_original - inv_c - r_mean) / r_std
        #if reward > 0: 
        #reward = torch.exp(reward)/10
        #reward = torch.exp((1e5 + reward_original - inv_c) / 5e4)
        self.rew_buf       = reward + reward_action
        self.episode_sums += reward + reward_action
        self.episode_acts += reward_action
        
        # compute resets
        env_ids = self.reset_buf.nonzero(as_tuple=False).flatten()
        self.reset_idx(env_ids)
        
        # compute observations
        return self.get_observations(), self.states, self.rew_buf, self.reset_buf, self.extras

    def reset_idx(self, env_ids):
        """Reset selected robots"""
        if len(env_ids) == 0:
            return
        
        assert len(env_ids) == self.num_envs
        # reset robot states
        self.states[env_ids] = self.init_state
        # reset buffers
        self.episode_length_buf[env_ids] = 0
        self.reset_buf[env_ids] = 1
        # fill extras
        self.extras["episode"] = {}
        self.extras["episode"]['rew_sum'] = torch.mean(self.episode_sums[env_ids]) / (self.max_episode_length * ΔT)
        self.extras["episode"]['rew_act'] = torch.mean(self.episode_acts[env_ids]) / (self.max_episode_length * ΔT)
        self.episode_sums[env_ids] = 0.
        self.episode_acts[env_ids] = 0.
    
    def reset(self):
        """ Reset all robots"""
        self.reset_idx(torch.arange(self.num_envs, device=self.device))
        return {}, {}
    
    def get_observations(self):
        o_mean = torch.tensor([[0.58712867, 0.06804276, 0.00308146, 0.25684301, 0.00261079, 0.08229331, 0.26572794, 0.51      ]], dtype=torch.float32).to(torch.device(self.device))
        o_std  = torch.tensor([[0.41484398, 0.07883003, 0.00389494, 0.292568  , 0.00394907, 0.06906768, 0.33943075, 0.28861739]], dtype=torch.float32).to(torch.device(self.device))
        self.obs_buf = (self.states - o_mean) / o_std
        return self.obs_buf
    
    def get_privileged_observations(self):
        return self.privileged_obs_buf

    def cost_function(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]

        cost_it  = it * u_it * parameter_static['cost_ti']
        cost_v   = st * u_sv * parameter_static['cost_v'] * parameter_static['v_max']
        cost_q   = (u_aq * at + u_iq * it) * parameter_static['cost_ta']
        per_poc  = ((st + et + at + rt) / self.N).pow(2) * parameter_static['cost_poc_0'] + parameter_static['cost_poc_1']
        cost_poc = (st + et + rt + at) * w * per_poc
        return cost_poc + cost_it + cost_v + cost_q

    def transition(self, action):
        states = self.states[:,:-2] * self.N
        st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
        u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
        ht = st + et + at + it + rt

        st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * self.parameter_random['beta1'] + (et + at * (1 - u_aq)) * self.parameter_random['beta2']) / ht
        st_out_e = st_out * parameter_static['alpha']
        st_out_i = st_out * (1 - parameter_static['alpha'])
        st_out_r = u_sv * parameter_static['v_max'] * st * parameter_static['psr']
        et_out_r = et * self.parameter_random['per']
        et_out_i = et * self.parameter_random['pei']
        et_out_a = et * w * (1 - self.parameter_random['per'] - self.parameter_random['pei'])
        at_out_i = at * self.parameter_random['pei']
        at_out_r = at * self.parameter_random['per']
        it_out_r = it * parameter_static['pir'] * u_it
        it_out_d = it * parameter_static['pid'] * (1 - u_it) + it * u_it * parameter_static['pid_plus']
        rt_out_s = rt * parameter_static['prs']
        
        stn = st - st_out_e - st_out_i - st_out_r + rt_out_s
        etn = et - et_out_r - et_out_i - et_out_a + st_out_e
        atn = at - at_out_r - at_out_i + et_out_a
        itn = it - it_out_r - it_out_d + st_out_i + et_out_i + at_out_i
        dtn = dt + it_out_d
        rtn = rt + et_out_r + at_out_r + it_out_r + st_out_r - rt_out_s

        reward = -2.6 * st_out - 100 * it_out_d

        next_state = torch.stack([stn, etn, atn, itn, dtn, rtn], dim=-1)
        return next_state, reward

# %%
import inspect

class BaseConfig:
    def __init__(self) -> None:
        """ Initializes all member classes recursively. Ignores all namse starting with '__' (buit-in methods)."""
        self.init_member_classes(self)
    
    @staticmethod
    def init_member_classes(obj):
        # iterate over all attributes names
        for key in dir(obj):
            # disregard builtin attributes
            # if key.startswith("__"):
            if key=="__class__":
                continue
            # get the corresponding attribute object
            var =  getattr(obj, key)
            # check if it the attribute is a class
            if inspect.isclass(var):
                # instantate the class
                i_var = var()
                # set the attribute to the instance instead of the type
                setattr(obj, key, i_var)
                # recursively init members of the attribute
                BaseConfig.init_member_classes(i_var)

class LeggedRobotCfgPPO(BaseConfig):
    seed = 1
    runner_class_name = 'OnPolicyRunner'
    class policy:
        init_noise_std = 2
        actor_hidden_dims  = [64, 32, 16] 
        critic_hidden_dims = [64, 32, 16]
        activation = 'elu' # can be elu, relu, selu, crelu, lrelu, tanh, sigmoid
        # only for 'ActorCriticRecurrent':
        # rnn_type = 'lstm'
        # rnn_hidden_size = 512
        # rnn_num_layers = 1
        
    class algorithm:
        # training params
        value_loss_coef = 0.5
        use_clipped_value_loss = True
        clip_param = 0.2
        entropy_coef = 0.01
        num_learning_epochs = 5
        num_mini_batches = 64 # mini batch size = num_envs*nsteps / nminibatches
        learning_rate = 1.e-3 # 5.e-4
        schedule = 'adaptive' # could be adaptive, fixed
        gamma = 0.99
        lam = 0.95
        desired_kl = 0.01
        max_grad_norm = 1.

    class runner:
        policy_class_name = 'ActorCritic'
        algorithm_class_name = 'PPO'
        num_steps_per_env =  500 # per iteration
        max_iterations    = 1000 # number of policy updates

        # logging
        save_interval = 100 # check for potential saves every this many iterations
        experiment_name = 'test'
        run_name = ''
        # load and resume
        resume = False
        load_run = -1 # -1 = last run
        checkpoint = -1 # -1 = last saved model
        resume_path = None # updated from load_run and chkpt
        
def class_to_dict(obj) -> dict:
    if not  hasattr(obj,"__dict__"):
        return obj
    result = {}
    for key in dir(obj):
        if key.startswith("_"):
            continue
        element = []
        val = getattr(obj, key)
        if isinstance(val, list):
            for item in val:
                element.append(class_to_dict(item))
        else:
            element = class_to_dict(val)
        result[key] = element
    return result

# %%
def para_sampling(intvl, num_sample=N_envs):
    parameter_random = {
        key: torch.empty(num_sample).normal_(
        intvl[key][0],
        intvl[key][1]
        ).to(torch.device(device))
        for key, value in Random_mean.items()
    }
    for key, value in Random_mean.items():
        indice = parameter_random[key] < 0
        parameter_random[key][indice] = -parameter_random[key][indice] 
    return parameter_random

def update_space(final_indices, para_buf, space):
    para_est = {}
    for key, tensor_values in para_buf.items():
        selected_values = torch.mean(tensor_values[final_indices[0], final_indices[1]]) 
        para_values = torch.mean(tensor_values[final_indices[0], final_indices[1]], dim=0)
        update_values = space[key][0] + 0.5 * (selected_values - space[key][0])
        space[key] = [update_values , update_values  * usr_std]
        para_est[key] = para_values
    return space, para_est


def cal_err(para_value, env_para):
    gap = []
    for key, value in env_para.items():
        gap_temp = torch.mean(torch.abs(para_value[key] - env_para[key])/(env_para[key]))
        gap.append(gap_temp)
    return sum(gap)/len(gap) # 所有值都在范围内，返回 0
    
def state_estimator(env_sample, action_sim, state_sim, state_prior, space, iter): 
    env_sample.reset()
    env_sample.states = state_prior  
    para_buf, mse_buf, obs_buf, states_buf = {}, {}, {}, {}
    for i in range(iter):
        para = para_sampling(space, test_num)
        env_sample.para_update(para)
        obs_sample, states_sample, _, _, _ = env_sample.step(action_sim.detach())  
        mse = torch.mean((state_sim[:,2:4] - states_sample[:,2:4]) ** 2, dim=1) 
        if i == 0:
            mse_buf = mse.unsqueeze(0)
            obs_buf = obs_sample.unsqueeze(0)
            states_buf = states_sample.unsqueeze(0)
            for key, values in para.items():
                para_buf[key] = para[key].unsqueeze(0)
        else:
            mse_buf = torch.cat((mse_buf, mse.unsqueeze(0)), dim=0)
            obs_buf = torch.cat((obs_buf, obs_sample.unsqueeze(0)),dim=0)
            states_buf = torch.cat((states_buf, states_sample.unsqueeze(0)), dim=0)
            for key, values in para.items():
                para_buf[key] = torch.cat((para_buf[key], para[key].unsqueeze(0)), dim=0)
                
     
    k = int(iter * 0.05)
    _, row_indices = torch.topk(mse_buf, k=k, dim=0, largest=False)
    column_indices = torch.arange(mse_buf.shape[1]).repeat(k, 1)
    top_indices = [row_indices, column_indices]
    obs_est = torch.mean(obs_buf[row_indices,column_indices,:], dim=0)
    state_est = torch.mean(states_buf[row_indices,column_indices,:], dim=0)
    state_est[:,-1] = state_prior[:,-1] + torch.tensor(1/T)
    return obs_est, state_est, top_indices, para_buf

# %%
torch.manual_seed(seed)
env = myVecEnv(space, test_num)
env.para_update(para_true[0])
train_cfg = LeggedRobotCfgPPO()
train_cfg_dict = class_to_dict(train_cfg)


env_transfer = myVecEnv(space)
runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_test', device=env.device)
runner.load(f'rsl_real/model_110.pt')

policy = runner.get_inference_policy(device=env.device)

reward_history = []
act_buf = []
state_his_buf = []
death_buf = []

space_init = {"beta2" : [Random_mean['beta2'],Random_mean['beta2']*usr_std],
         "beta1" : [Random_mean['beta1'], Random_mean['beta1']*usr_std],
         "pei"   : [Random_mean['pei'], Random_mean['pei']*usr_std],
         "per"   : [Random_mean['per'], Random_mean['per']*usr_std]}

env_sample = myVecEnv(space, test_num)
state_est = env.states
obs_est = env.get_observations()
for t in range(T-1):
    actions = policy(obs_est.detach())
    actions = actions.to(device)
    obs, states, _, _, infos = env.step(actions.detach())
    reward_history.append((-infos['reward_original'] + infos['inv_cost']).tolist())
    death_buf.append((-infos['reward_original']).tolist())
    act_buf.append(env.act)
    state_his_buf.append(env.states)
    obs_est, state_buf, top_indices, para_buf = state_estimator(env_sample, actions, states, state_est, space, 1024)
    space, para_v = update_space(top_indices, para_buf, space) 

    runner.learn(num_learning_iterations=25, init_at_random_ep_len=False)
    policy = runner.get_inference_policy(device=env.device)
    env_transfer = myVecEnv(space)
    runner = OnPolicyRunner(env_transfer, train_cfg_dict, f'rsl_test', device=env.device)
    runner.load(f'rsl_test/model_{int(t)* 25}.pt')
        

    if t < T - 1: env.para_update(para_true[t + 1])
    print(f'score.mean: {t, np.sum(reward_history, axis=0).mean()/T}')
env.reset()

reward_history = np.array(reward_history)
print(f'score     : {np.sum(reward_history, axis=0)/T       }')
print(f'score.mean: {np.sum(reward_history, axis=0).mean()/T}')
# Out:
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2716005 steps/s (collection: 2.242s, learning 9.823s)
#                Value function loss: 47.0234
#                     Surrogate loss: -0.0000
#              Mean action noise std: 12.44
#                        Mean reward: 32.61
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4749
#               Mean episode rew_act: -0.0882
# --------------------------------------------------------------------------------
#                    Total timesteps: 32768000
#                     Iteration time: 12.06s
#                         Total time: 12.06s
#                                ETA: 301.6s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2726605 steps/s (collection: 2.318s, learning 9.700s)
#                Value function loss: 52.0002
#                     Surrogate loss: 0.0001
#              Mean action noise std: 12.65
#                        Mean reward: 32.79
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5408
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 65536000
#                     Iteration time: 12.02s
#                         Total time: 24.08s
#                                ETA: 289.0s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2754724 steps/s (collection: 2.249s, learning 9.646s)
#                Value function loss: 48.7940
#                     Surrogate loss: 0.0001
#              Mean action noise std: 12.86
#                        Mean reward: 32.84
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5414
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 11.90s
#                         Total time: 35.98s
#                                ETA: 275.8s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2761894 steps/s (collection: 2.234s, learning 9.630s)
#                Value function loss: 54.7081
#                     Surrogate loss: 0.0001
#              Mean action noise std: 13.06
#                        Mean reward: 32.59
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5423
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 131072000
#                     Iteration time: 11.86s
#                         Total time: 47.84s
#                                ETA: 263.1s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2764690 steps/s (collection: 2.211s, learning 9.641s)
#                Value function loss: 54.6351
#                     Surrogate loss: 0.0001
#              Mean action noise std: 13.28
#                        Mean reward: 32.67
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5432
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 163840000
#                     Iteration time: 11.85s
#                         Total time: 59.69s
#                                ETA: 250.7s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2760045 steps/s (collection: 2.225s, learning 9.647s)
#                Value function loss: 58.4113
#                     Surrogate loss: 0.0002
#              Mean action noise std: 13.51
#                        Mean reward: 32.32
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5438
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 11.87s
#                         Total time: 71.57s
#                                ETA: 238.6s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2766553 steps/s (collection: 2.213s, learning 9.631s)
#                Value function loss: 61.7350
#                     Surrogate loss: 0.0002
#              Mean action noise std: 13.74
#                        Mean reward: 32.82
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5439
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 229376000
#                     Iteration time: 11.84s
#                         Total time: 83.41s
#                                ETA: 226.4s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2760511 steps/s (collection: 2.238s, learning 9.632s)
#                Value function loss: 63.1511
#                     Surrogate loss: 0.0002
#              Mean action noise std: 13.97
#                        Mean reward: 32.70
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5431
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 262144000
#                     Iteration time: 11.87s
#                         Total time: 95.28s
#                                ETA: 214.4s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2762128 steps/s (collection: 2.230s, learning 9.633s)
#                Value function loss: 52.4520
#                     Surrogate loss: 0.0001
#              Mean action noise std: 14.20
#                        Mean reward: 32.75
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5423
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 294912000
#                     Iteration time: 11.86s
#                         Total time: 107.14s
#                                ETA: 202.4s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2755185 steps/s (collection: 2.260s, learning 9.633s)
#                Value function loss: 57.9990
#                     Surrogate loss: 0.0001
#              Mean action noise std: 14.43
#                        Mean reward: 32.53
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5426
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 327680000
#                     Iteration time: 11.89s
#                         Total time: 119.04s
#                                ETA: 190.5s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2766786 steps/s (collection: 2.217s, learning 9.626s)
#                Value function loss: 55.7961
#                     Surrogate loss: 0.0001
#              Mean action noise std: 14.68
#                        Mean reward: 33.03
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5427
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 360448000
#                     Iteration time: 11.84s
#                         Total time: 130.88s
#                                ETA: 178.5s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2760517 steps/s (collection: 2.248s, learning 9.622s)
#                Value function loss: 49.3877
#                     Surrogate loss: 0.0001
#              Mean action noise std: 14.92
#                        Mean reward: 32.75
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5428
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 393216000
#                     Iteration time: 11.87s
#                         Total time: 142.75s
#                                ETA: 166.5s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2770052 steps/s (collection: 2.220s, learning 9.609s)
#                Value function loss: 46.5599
#                     Surrogate loss: 0.0002
#              Mean action noise std: 15.15
#                        Mean reward: 32.68
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5443
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 425984000
#                     Iteration time: 11.83s
#                         Total time: 154.58s
#                                ETA: 154.6s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2761438 steps/s (collection: 2.228s, learning 9.638s)
#                Value function loss: 71.0953
#                     Surrogate loss: 0.0001
#              Mean action noise std: 15.40
#                        Mean reward: 32.52
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5467
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 458752000
#                     Iteration time: 11.87s
#                         Total time: 166.45s
#                                ETA: 142.7s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2765623 steps/s (collection: 2.217s, learning 9.631s)
#                Value function loss: 58.4870
#                     Surrogate loss: 0.0001
#              Mean action noise std: 15.65
#                        Mean reward: 33.11
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5480
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 491520000
#                     Iteration time: 11.85s
#                         Total time: 178.30s
#                                ETA: 130.7s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2745058 steps/s (collection: 2.213s, learning 9.724s)
#                Value function loss: 54.0796
#                     Surrogate loss: -0.0000
#              Mean action noise std: 15.91
#                        Mean reward: 32.74
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5499
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 524288000
#                     Iteration time: 11.94s
#                         Total time: 190.23s
#                                ETA: 118.9s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2740020 steps/s (collection: 2.210s, learning 9.749s)
#                Value function loss: 52.4132
#                     Surrogate loss: 0.0001
#              Mean action noise std: 16.17
#                        Mean reward: 32.78
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5526
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 557056000
#                     Iteration time: 11.96s
#                         Total time: 202.19s
#                                ETA: 107.0s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2738423 steps/s (collection: 2.234s, learning 9.732s)
#                Value function loss: 48.7374
#                     Surrogate loss: 0.0001
#              Mean action noise std: 16.43
#                        Mean reward: 33.47
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5540
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 589824000
#                     Iteration time: 11.97s
#                         Total time: 214.16s
#                                ETA: 95.2s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2745746 steps/s (collection: 2.203s, learning 9.731s)
#                Value function loss: 52.2292
#                     Surrogate loss: 0.0001
#              Mean action noise std: 16.70
#                        Mean reward: 33.24
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5542
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 622592000
#                     Iteration time: 11.93s
#                         Total time: 226.09s
#                                ETA: 83.3s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2741164 steps/s (collection: 2.221s, learning 9.733s)
#                Value function loss: 58.7664
#                     Surrogate loss: 0.0001
#              Mean action noise std: 16.97
#                        Mean reward: 33.17
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5544
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 655360000
#                     Iteration time: 11.95s
#                         Total time: 238.05s
#                                ETA: 71.4s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2738650 steps/s (collection: 2.224s, learning 9.741s)
#                Value function loss: 59.6634
#                     Surrogate loss: 0.0001
#              Mean action noise std: 17.26
#                        Mean reward: 33.37
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5548
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 688128000
#                     Iteration time: 11.97s
#                         Total time: 250.01s
#                                ETA: 59.5s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2743682 steps/s (collection: 2.211s, learning 9.732s)
#                Value function loss: 56.8112
#                     Surrogate loss: 0.0001
#              Mean action noise std: 17.55
#                        Mean reward: 33.29
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5558
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 720896000
#                     Iteration time: 11.94s
#                         Total time: 261.95s
#                                ETA: 47.6s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2748731 steps/s (collection: 2.211s, learning 9.710s)
#                Value function loss: 59.2984
#                     Surrogate loss: 0.0001
#              Mean action noise std: 17.84
#                        Mean reward: 33.71
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5565
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 753664000
#                     Iteration time: 11.92s
#                         Total time: 273.87s
#                                ETA: 35.7s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2746438 steps/s (collection: 2.267s, learning 9.664s)
#                Value function loss: 56.5314
#                     Surrogate loss: 0.0001
#              Mean action noise std: 18.13
#                        Mean reward: 33.20
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5571
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 786432000
#                     Iteration time: 11.93s
#                         Total time: 285.81s
#                                ETA: 23.8s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2759119 steps/s (collection: 2.226s, learning 9.650s)
#                Value function loss: 56.9771
#                     Surrogate loss: 0.0001
#              Mean action noise std: 18.43
#                        Mean reward: 33.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5570
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 819200000
#                     Iteration time: 11.88s
#                         Total time: 297.68s
#                                ETA: 11.9s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: (0, 0.23397852579752604)
# ################################################################################
#                         Learning iteration 0/25
#
#                        Computation: 2728189 steps/s (collection: 2.356s, learning 9.655s)
#                Value function loss: 52.1230
#                     Surrogate loss: 0.0001
#              Mean action noise std: 12.65
#                        Mean reward: 32.71
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4777
#               Mean episode rew_act: -0.0882
# --------------------------------------------------------------------------------
#                    Total timesteps: 32768000
#                     Iteration time: 12.01s
#                         Total time: 12.01s
#                                ETA: 300.3s
#
# ################################################################################
#                         Learning iteration 1/25
#
#                        Computation: 2761206 steps/s (collection: 2.207s, learning 9.660s)
#                Value function loss: 50.2784
#                     Surrogate loss: 0.0001
#              Mean action noise std: 12.86
#                        Mean reward: 32.83
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5419
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 65536000
#                     Iteration time: 11.87s
#                         Total time: 23.88s
#                                ETA: 286.5s
#
# ################################################################################
#                         Learning iteration 2/25
#
#                        Computation: 2758663 steps/s (collection: 2.219s, learning 9.659s)
#                Value function loss: 47.9195
#                     Surrogate loss: 0.0001
#              Mean action noise std: 13.07
#                        Mean reward: 32.90
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5425
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 11.88s
#                         Total time: 35.76s
#                                ETA: 274.1s
#
# ################################################################################
#                         Learning iteration 3/25
#
#                        Computation: 2759351 steps/s (collection: 2.215s, learning 9.660s)
#                Value function loss: 50.7324
#                     Surrogate loss: 0.0001
#              Mean action noise std: 13.27
#                        Mean reward: 32.72
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5438
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 131072000
#                     Iteration time: 11.88s
#                         Total time: 47.63s
#                                ETA: 262.0s
#
# ################################################################################
#                         Learning iteration 4/25
#
#                        Computation: 2765855 steps/s (collection: 2.208s, learning 9.639s)
#                Value function loss: 50.3160
#                     Surrogate loss: 0.0001
#              Mean action noise std: 13.49
#                        Mean reward: 32.79
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5451
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 163840000
#                     Iteration time: 11.85s
#                         Total time: 59.48s
#                                ETA: 249.8s
#
# ################################################################################
#                         Learning iteration 5/25
#
#                        Computation: 2777541 steps/s (collection: 2.195s, learning 9.602s)
#                Value function loss: 48.5800
#                     Surrogate loss: 0.0001
#              Mean action noise std: 13.70
#                        Mean reward: 32.39
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5460
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 11.80s
#                         Total time: 71.28s
#                                ETA: 237.6s
#
# ################################################################################
#                         Learning iteration 6/25
#
#                        Computation: 2772634 steps/s (collection: 2.218s, learning 9.600s)
#                Value function loss: 45.9209
#                     Surrogate loss: 0.0001
#              Mean action noise std: 13.92
#                        Mean reward: 33.00
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5471
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 229376000
#                     Iteration time: 11.82s
#                         Total time: 83.09s
#                                ETA: 225.5s
#
# ################################################################################
#                         Learning iteration 7/25
#
#                        Computation: 2768186 steps/s (collection: 2.243s, learning 9.594s)
#                Value function loss: 48.9948
#                     Surrogate loss: 0.0001
#              Mean action noise std: 14.14
#                        Mean reward: 33.13
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5481
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 262144000
#                     Iteration time: 11.84s
#                         Total time: 94.93s
#                                ETA: 213.6s
#
# ################################################################################
#                         Learning iteration 8/25
#
#                        Computation: 2768652 steps/s (collection: 2.223s, learning 9.612s)
#                Value function loss: 48.8531
#                     Surrogate loss: 0.0001
#              Mean action noise std: 14.37
#                        Mean reward: 33.12
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5491
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 294912000
#                     Iteration time: 11.84s
#                         Total time: 106.77s
#                                ETA: 201.7s
#
# ################################################################################
#                         Learning iteration 9/25
#
#                        Computation: 2772857 steps/s (collection: 2.216s, learning 9.601s)
#                Value function loss: 49.8016
#                     Surrogate loss: 0.0001
#              Mean action noise std: 14.60
#                        Mean reward: 33.15
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5501
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 327680000
#                     Iteration time: 11.82s
#                         Total time: 118.58s
#                                ETA: 189.7s
#
# ################################################################################
#                         Learning iteration 10/25
#
#                        Computation: 2772150 steps/s (collection: 2.227s, learning 9.593s)
#                Value function loss: 50.1799
#                     Surrogate loss: 0.0001
#              Mean action noise std: 14.84
#                        Mean reward: 33.46
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5504
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 360448000
#                     Iteration time: 11.82s
#                         Total time: 130.41s
#                                ETA: 177.8s
#
# ################################################################################
#                         Learning iteration 11/25
#
#                        Computation: 2777781 steps/s (collection: 2.192s, learning 9.604s)
#                Value function loss: 51.9444
#                     Surrogate loss: 0.0001
#              Mean action noise std: 15.09
#                        Mean reward: 33.05
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5506
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 393216000
#                     Iteration time: 11.80s
#                         Total time: 142.20s
#                                ETA: 165.9s
#
# ################################################################################
#                         Learning iteration 12/25
#
#                        Computation: 2757961 steps/s (collection: 2.231s, learning 9.650s)
#                Value function loss: 49.3398
#                     Surrogate loss: 0.0001
#              Mean action noise std: 15.33
#                        Mean reward: 33.05
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5511
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 425984000
#                     Iteration time: 11.88s
#                         Total time: 154.08s
#                                ETA: 154.1s
#
# ################################################################################
#                         Learning iteration 13/25
#
#                        Computation: 2773092 steps/s (collection: 2.215s, learning 9.601s)
#                Value function loss: 48.7289
#                     Surrogate loss: 0.0001
#              Mean action noise std: 15.58
#                        Mean reward: 32.88
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5517
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 458752000
#                     Iteration time: 11.82s
#                         Total time: 165.90s
#                                ETA: 142.2s
#
# ################################################################################
#                         Learning iteration 14/25
#
#                        Computation: 2762129 steps/s (collection: 2.263s, learning 9.600s)
#                Value function loss: 49.6045
#                     Surrogate loss: 0.0001
#              Mean action noise std: 15.82
#                        Mean reward: 33.37
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5530
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 491520000
#                     Iteration time: 11.86s
#                         Total time: 177.76s
#                                ETA: 130.4s
#
# ################################################################################
#                         Learning iteration 15/25
#
#                        Computation: 2759124 steps/s (collection: 2.258s, learning 9.618s)
#                Value function loss: 50.5659
#                     Surrogate loss: 0.0001
#              Mean action noise std: 16.08
#                        Mean reward: 33.24
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5540
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 524288000
#                     Iteration time: 11.88s
#                         Total time: 189.64s
#                                ETA: 118.5s
#
# ################################################################################
#                         Learning iteration 16/25
#
#                        Computation: 2772151 steps/s (collection: 2.203s, learning 9.617s)
#                Value function loss: 51.2466
#                     Surrogate loss: 0.0001
#              Mean action noise std: 16.34
#                        Mean reward: 32.89
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5552
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 557056000
#                     Iteration time: 11.82s
#                         Total time: 201.46s
#                                ETA: 106.7s
#
# ################################################################################
#                         Learning iteration 17/25
#
#                        Computation: 2769127 steps/s (collection: 2.230s, learning 9.603s)
#                Value function loss: 50.4079
#                     Surrogate loss: 0.0001
#              Mean action noise std: 16.60
#                        Mean reward: 33.62
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5562
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 589824000
#                     Iteration time: 11.83s
#                         Total time: 213.29s
#                                ETA: 94.8s
#
# ################################################################################
#                         Learning iteration 18/25
#
#                        Computation: 2770975 steps/s (collection: 2.214s, learning 9.611s)
#                Value function loss: 51.2718
#                     Surrogate loss: 0.0001
#              Mean action noise std: 16.87
#                        Mean reward: 33.40
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5568
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 622592000
#                     Iteration time: 11.83s
#                         Total time: 225.12s
#                                ETA: 82.9s
#
# ################################################################################
#                         Learning iteration 19/25
#
#                        Computation: 2762824 steps/s (collection: 2.249s, learning 9.611s)
#                Value function loss: 51.4831
#                     Surrogate loss: 0.0001
#              Mean action noise std: 17.14
#                        Mean reward: 33.38
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5573
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 655360000
#                     Iteration time: 11.86s
#                         Total time: 236.98s
#                                ETA: 71.1s
#
# ################################################################################
#                         Learning iteration 20/25
#
#                        Computation: 2774021 steps/s (collection: 2.213s, learning 9.599s)
#                Value function loss: 50.1776
#                     Surrogate loss: 0.0001
#              Mean action noise std: 17.41
#                        Mean reward: 33.47
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5577
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 688128000
#                     Iteration time: 11.81s
#                         Total time: 248.79s
#                                ETA: 59.2s
#
# ################################################################################
#                         Learning iteration 21/25
#
#                        Computation: 2773793 steps/s (collection: 2.209s, learning 9.604s)
#                Value function loss: 50.0703
#                     Surrogate loss: 0.0004
#              Mean action noise std: 17.67
#                        Mean reward: 33.47
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5587
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 720896000
#                     Iteration time: 11.81s
#                         Total time: 260.60s
#                                ETA: 47.4s
#
# ################################################################################
#                         Learning iteration 22/25
#
#                        Computation: 2764458 steps/s (collection: 2.240s, learning 9.613s)
#                Value function loss: 52.7202
#                     Surrogate loss: 0.0001
#              Mean action noise std: 17.96
#                        Mean reward: 33.87
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5599
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 753664000
#                     Iteration time: 11.85s
#                         Total time: 272.46s
#                                ETA: 35.5s
#
# ################################################################################
#                         Learning iteration 23/25
#
#                        Computation: 2766548 steps/s (collection: 2.223s, learning 9.621s)
#                Value function loss: 51.3757
#                     Surrogate loss: 0.0001
#              Mean action noise std: 18.24
#                        Mean reward: 33.54
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5611
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 786432000
#                     Iteration time: 11.84s
#                         Total time: 284.30s
#                                ETA: 23.7s
#
# ################################################################################
#                         Learning iteration 24/25
#
#                        Computation: 2770752 steps/s (collection: 2.208s, learning 9.618s)
#                Value function loss: 52.5473
#                     Surrogate loss: 0.0000
#              Mean action noise std: 18.52
#                        Mean reward: 33.82
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5620
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 819200000
#                     Iteration time: 11.83s
#                         Total time: 296.13s
#                                ETA: 11.8s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: (1, 0.37027432123819987)
# ################################################################################
#                         Learning iteration 25/50
#
#                        Computation: 2760742 steps/s (collection: 2.258s, learning 9.611s)
#                Value function loss: 54.0404
#                     Surrogate loss: 0.0001
#              Mean action noise std: 18.81
#                        Mean reward: 34.13
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.4972
#               Mean episode rew_act: -0.0882
# --------------------------------------------------------------------------------
#                    Total timesteps: 32768000
#                     Iteration time: 11.87s
#                         Total time: 11.87s
#                                ETA: 0.0s
#
# ################################################################################
#                         Learning iteration 26/50
#
#                        Computation: 2772391 steps/s (collection: 2.220s, learning 9.599s)
#                Value function loss: 55.5403
#                     Surrogate loss: 0.0001
#              Mean action noise std: 19.13
#                        Mean reward: 34.22
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5641
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 65536000
#                     Iteration time: 11.82s
#                         Total time: 23.69s
#                                ETA: -0.9s
#
# ################################################################################
#                         Learning iteration 27/50
#
#                        Computation: 2768651 steps/s (collection: 2.228s, learning 9.607s)
#                Value function loss: 64.2902
#                     Surrogate loss: 0.0001
#              Mean action noise std: 19.45
#                        Mean reward: 34.39
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5643
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304000
#                     Iteration time: 11.84s
#                         Total time: 35.52s
#                                ETA: -2.5s
#
# ################################################################################
#                         Learning iteration 28/50
#
#                        Computation: 2759578 steps/s (collection: 2.253s, learning 9.621s)
#                Value function loss: 49.0926
#                     Surrogate loss: 0.0000
#              Mean action noise std: 19.73
#                        Mean reward: 34.13
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5639
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 131072000
#                     Iteration time: 11.87s
#                         Total time: 47.40s
#                                ETA: -4.9s
#
# ################################################################################
#                         Learning iteration 29/50
#
#                        Computation: 2772164 steps/s (collection: 2.210s, learning 9.610s)
#                Value function loss: 57.3484
#                     Surrogate loss: 0.0002
#              Mean action noise std: 20.06
#                        Mean reward: 33.94
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5650
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 163840000
#                     Iteration time: 11.82s
#                         Total time: 59.22s
#                                ETA: -7.9s
#
# ################################################################################
#                         Learning iteration 30/50
#
#                        Computation: 2768418 steps/s (collection: 2.229s, learning 9.607s)
#                Value function loss: 53.0706
#                     Surrogate loss: 0.0002
#              Mean action noise std: 20.40
#                        Mean reward: 34.30
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5646
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608000
#                     Iteration time: 11.84s
#                         Total time: 71.06s
#                                ETA: -11.5s
#
# ################################################################################
#                         Learning iteration 31/50
#
#                        Computation: 2770752 steps/s (collection: 2.214s, learning 9.612s)
#                Value function loss: 49.5040
#                     Surrogate loss: 0.0002
#              Mean action noise std: 20.73
#                        Mean reward: 33.59
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.5634
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 229376000
#                     Iteration time: 11.83s
#                         Total time: 82.88s
#                                ETA: -15.5s
#
# ################################################################################
#                         Learning iteration 32/50
#
#                        Computation: 2767719 steps/s (collection: 2.230s, learning 9.609s)
# ...
#                       Learning iteration 1431/1450
#
#                        Computation: 2735458 steps/s (collection: 2.332s, learning 9.647s)
#                Value function loss: 49.9286
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4032.19
#                        Mean reward: 44.51
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7418
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 229376000
#                     Iteration time: 11.98s
#                         Total time: 83.72s
#                                ETA: -82.2s
#
# ################################################################################
#                       Learning iteration 1432/1450
#
#                        Computation: 2740021 steps/s (collection: 2.338s, learning 9.621s)
#                Value function loss: 51.1300
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4035.20
#                        Mean reward: 44.52
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7418
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 262144000
#                     Iteration time: 11.96s
#                         Total time: 95.67s
#                                ETA: -93.9s
#
# ################################################################################
#                       Learning iteration 1433/1450
#
#                        Computation: 2742996 steps/s (collection: 2.329s, learning 9.617s)
#                Value function loss: 51.5112
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4038.27
#                        Mean reward: 44.56
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7419
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 294912000
#                     Iteration time: 11.95s
#                         Total time: 107.62s
#                                ETA: -105.7s
#
# ################################################################################
#                       Learning iteration 1434/1450
#
#                        Computation: 2730910 steps/s (collection: 2.354s, learning 9.645s)
#                Value function loss: 52.2357
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4041.41
#                        Mean reward: 44.53
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7421
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 327680000
#                     Iteration time: 12.00s
#                         Total time: 119.62s
#                                ETA: -117.5s
#
# ################################################################################
#                       Learning iteration 1435/1450
#
#                        Computation: 2741850 steps/s (collection: 2.327s, learning 9.624s)
#                Value function loss: 52.0927
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4044.47
#                        Mean reward: 44.55
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7420
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 360448000
#                     Iteration time: 11.95s
#                         Total time: 131.57s
#                                ETA: -129.2s
#
# ################################################################################
#                       Learning iteration 1436/1450
#
#                        Computation: 2751034 steps/s (collection: 2.296s, learning 9.615s)
#                Value function loss: 52.5631
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4047.60
#                        Mean reward: 44.45
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7420
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 393216000
#                     Iteration time: 11.91s
#                         Total time: 143.48s
#                                ETA: -140.9s
#
# ################################################################################
#                       Learning iteration 1437/1450
#
#                        Computation: 2740480 steps/s (collection: 2.315s, learning 9.642s)
#                Value function loss: 53.5548
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4050.69
#                        Mean reward: 44.54
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7420
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 425984000
#                     Iteration time: 11.96s
#                         Total time: 155.44s
#                                ETA: -152.6s
#
# ################################################################################
#                       Learning iteration 1438/1450
#
#                        Computation: 2745516 steps/s (collection: 2.326s, learning 9.609s)
#                Value function loss: 53.5072
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4053.80
#                        Mean reward: 44.65
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7418
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 458752000
#                     Iteration time: 11.94s
#                         Total time: 167.37s
#                                ETA: -164.3s
#
# ################################################################################
#                       Learning iteration 1439/1450
#
#                        Computation: 2721636 steps/s (collection: 2.363s, learning 9.677s)
#                Value function loss: 53.6300
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4056.80
#                        Mean reward: 44.39
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7419
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 491520000
#                     Iteration time: 12.04s
#                         Total time: 179.41s
#                                ETA: -176.2s
#
# ################################################################################
#                       Learning iteration 1440/1450
#
#                        Computation: 2718709 steps/s (collection: 2.388s, learning 9.665s)
#                Value function loss: 54.3594
#                     Surrogate loss: -0.0000
#              Mean action noise std: 4059.97
#                        Mean reward: 44.45
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7418
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 524288000
#                     Iteration time: 12.05s
#                         Total time: 191.47s
#                                ETA: -188.0s
#
# ################################################################################
#                       Learning iteration 1441/1450
#
#                        Computation: 2745517 steps/s (collection: 2.313s, learning 9.622s)
#                Value function loss: 53.9425
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4063.04
#                        Mean reward: 44.31
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7417
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 557056000
#                     Iteration time: 11.94s
#                         Total time: 203.40s
#                                ETA: -199.7s
#
# ################################################################################
#                       Learning iteration 1442/1450
#
#                        Computation: 2754261 steps/s (collection: 2.293s, learning 9.604s)
#                Value function loss: 53.8233
#                     Surrogate loss: 0.0001
#              Mean action noise std: 4066.16
#                        Mean reward: 44.58
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7418
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 589824000
#                     Iteration time: 11.90s
#                         Total time: 215.30s
#                                ETA: -211.4s
#
# ################################################################################
#                       Learning iteration 1443/1450
#
#                        Computation: 2746429 steps/s (collection: 2.298s, learning 9.633s)
#                Value function loss: 48.7433
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4069.17
#                        Mean reward: 44.63
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7419
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 622592000
#                     Iteration time: 11.93s
#                         Total time: 227.23s
#                                ETA: -223.1s
#
# ################################################################################
#                       Learning iteration 1444/1450
#
#                        Computation: 2746893 steps/s (collection: 2.313s, learning 9.616s)
#                Value function loss: 48.4222
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4072.24
#                        Mean reward: 44.49
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7419
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 655360000
#                     Iteration time: 11.93s
#                         Total time: 239.16s
#                                ETA: -234.9s
#
# ################################################################################
#                       Learning iteration 1445/1450
#
#                        Computation: 2742537 steps/s (collection: 2.333s, learning 9.615s)
#                Value function loss: 47.5651
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4075.41
#                        Mean reward: 44.42
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7418
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 688128000
#                     Iteration time: 11.95s
#                         Total time: 251.11s
#                                ETA: -246.6s
#
# ################################################################################
#                       Learning iteration 1446/1450
#
#                        Computation: 2728189 steps/s (collection: 2.382s, learning 9.629s)
#                Value function loss: 46.9202
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4078.54
#                        Mean reward: 44.60
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7419
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 720896000
#                     Iteration time: 12.01s
#                         Total time: 263.12s
#                                ETA: -258.4s
#
# ################################################################################
#                       Learning iteration 1447/1450
#
#                        Computation: 2728408 steps/s (collection: 2.386s, learning 9.624s)
#                Value function loss: 46.9592
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4081.65
#                        Mean reward: 44.45
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7416
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 753664000
#                     Iteration time: 12.01s
#                         Total time: 275.13s
#                                ETA: -270.2s
#
# ################################################################################
#                       Learning iteration 1448/1450
#
#                        Computation: 2741163 steps/s (collection: 2.282s, learning 9.672s)
#                Value function loss: 46.7230
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4084.74
#                        Mean reward: 44.60
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7415
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 786432000
#                     Iteration time: 11.95s
#                         Total time: 287.08s
#                                ETA: -281.9s
#
# ################################################################################
#                       Learning iteration 1449/1450
#
#                        Computation: 2748732 steps/s (collection: 2.286s, learning 9.635s)
#                Value function loss: 47.0380
#                     Surrogate loss: 0.0000
#              Mean action noise std: 4087.78
#                        Mean reward: 44.53
#                Mean episode length: 60.00
#               Mean episode rew_sum: 0.7415
#               Mean episode rew_act: -0.1000
# --------------------------------------------------------------------------------
#                    Total timesteps: 819200000
#                     Iteration time: 11.92s
#                         Total time: 299.00s
#                                ETA: -293.6s
#
# Actor MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=5, bias=True)
# )
# Critic MLP: Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=32, out_features=16, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=16, out_features=1, bias=True)
# )
# score.mean: (58, 471.94071923891704)
# score     : [471.94071924]
# score.mean: 471.94071923891704

# %%
a = np.sum(reward_history, axis=0)/T

# %%
min(a)
# Out:
# 471.94071923891704

# %%
max(a)
# Out:
# 471.94071923891704

# %%
np.std(a)
# Out:
# 0.0

# %%
exp_result = {
    'reward_total': reward_history,
    'reward_peo': death_buf,
    'state': state_his_buf,
    'action': act_buf
}

# %%
torch.save(exp_result, 'mid_budget_result.pt')

# %%
run_result = torch.load('mid_budget_result.pt', weights_only=False)
death_mean = torch.mean(run_result['state'][-2][:,4]) * N
print(death_mean)
# Out:
# tensor(41.64480, device='cuda:0')

# %%
def infections(states, action, para, i):
    st, et, at, it, dt, rt = states[:, 0], states[:, 1], states[:, 2], states[:, 3], states[:, 4], states[:, 5]
    u_sv, u_it, u_aq, u_iq, w = action[:, 0], action[:, 1], action[:, 2], action[:, 3], action[:, 4]
    ht = st + et + at + it + rt

    st_out   = (1 - u_sv * parameter_static['v_max']) * st * (it * (1 - u_iq) * para['beta1'][i] + (et + at * (1 - u_aq)) * para['beta2'][i]) / ht
    st_out_e = st_out * parameter_static['alpha']
    st_out_i = st_out * (1 - parameter_static['alpha'])
    et_out_a = et * w * (1 - para['per'] - para['pei'])
    return et_out_a, st_out_e, st_out_i


init_state = torch.tensor([[100000, 20, 0, 0, 0, 0]], dtype=torch.float32).to(torch.device(device))
s_i = torch.zeros(test_num).to(device)
s_a = torch.zeros(test_num).to(device)
s_t = torch.zeros(test_num).to(device)
for i in range(test_num):
    for t in range(T):
        if t == 0:
            sa_temp, se_temp, si_temp = infections(init_state, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        if t > 0 and t < T-1:
            sa_temp, se_temp, si_temp = infections(run_result['state'][t-1][i][:6].unsqueeze(0)*N, run_result['action'][t][i].unsqueeze(0), para_true[t], i)
        s_i[i] += si_temp[0]
        s_a[i] += sa_temp[0]
        s_t[i] += se_temp[0] + si_temp[0]
print([torch.mean(s_i), torch.mean(s_a), torch.mean(s_t)])
# Out:
# [tensor(4091.57788, device='cuda:0'), tensor(0., device='cuda:0'), tensor(10228.94531, device='cuda:0')]

# %%
471.94071923891704 * 0.6 / 6.8343
# Out:
# 41.43283606855862
